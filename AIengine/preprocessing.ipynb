# %%
import pandas as pd
import json
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from collections import Counter
import string
import re

# Ensure required NLTK resources are downloaded
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('punkt_tab')

# Custom stopwords specific to cricket commentary
custom_stopwords = {
    'runs', 'run', 'bowler', 'batsman', 'batting', 'bowling',
    'wicket', 'innings', 'match', 'player', 'team', 'score',
    'field', 'fielder', 'boundary',
    'comes', 'goes', 'gets', 'got', 'taking', 'taken', 'makes', 'made',
    'going', 'comes', 'well', 'right', 'left',
    'great', 'nice', 'now', 'just', 'one', 'two', 'three',
    'four', 'six', 'single', 'double'
}

# Load JSON file
file_path = "commentarydata.json"  # Replace with your actual file path
with open(file_path, 'r') as file:
    data = json.load(file)

# Normalize both innings
inning1 = pd.json_normalize(data, record_path=['commentary_innings1'])
inning2 = pd.json_normalize(data, record_path=['commentary_innings2'])

# Add a column to distinguish between innings
inning1['inning'] = 1
inning2['inning'] = 2

# Combine both innings into a single DataFrame
commentary = pd.concat([inning1, inning2], ignore_index=True)

# Combine NLTK stopwords with custom stopwords (excluding 'off')
stop_words = set(stopwords.words('english')) | custom_stopwords - {'off'}

def remove_first_phrase(text):
    """Remove the first phrase up to the first comma"""
    parts = text.split(',', 1)
    if len(parts) > 1:
        return parts[1].strip()
    return text

# Function to preprocess and tokenize commText
def preprocess_and_tokenize(text, n=1):
    # Remove the first phrase (bowler to batsman)
    text = remove_first_phrase(text)
    
    # Convert to lowercase
    text = text.lower()
    
    # Remove punctuation
    text = text.translate(str.maketrans('', '', string.punctuation))
    
    # Remove numeric numbers (both standalone and within words)
    text = re.sub(r'\b\d+\b|\d+', '', text)
    
    # Remove extra whitespace
    text = ' '.join(text.split())
    
    # Tokenize the text
    tokens = word_tokenize(text)
    
    # Remove stopwords and empty strings
    tokens = [word for word in tokens if word not in stop_words and word.strip()]
    
    # Generate n-grams
    if n > 1:
        ngrams = nltk.ngrams(tokens, n)
        return list(ngrams)
    return tokens

# Count word or n-gram frequency
def count_word_frequency(df, n=1):
    all_tokens = []
    
    for text in df['commText']:
        tokens = preprocess_and_tokenize(text, n)
        all_tokens.extend(tokens)
    
    return Counter(all_tokens)

# Count frequencies for unigrams and bigrams
unigram_frequency = count_word_frequency(commentary, n=1)
bigram_frequency = count_word_frequency(commentary, n=2)

# Convert Counter to DataFrame for better readability
unigram_df = pd.DataFrame(unigram_frequency.items(), columns=['Word', 'Count']).sort_values(by='Count', ascending=False)
bigram_df = pd.DataFrame([(' '.join(gram), count) for gram, count in bigram_frequency.items()], 
                         columns=['Bigram', 'Count']).sort_values(by='Count', ascending=False)

# Output results
print("Top 10 Unigrams:")
print(unigram_df.head(10))
print("\nTop 10 Bigrams:")
print(bigram_df.head(20))

# Print a few example processed comments to verify the first phrase removal
# print("\nExample processed comments:")
# for text in commentary['commText'][:3]:
#     print("Original:", text)
#     print("Processed:", remove_first_phrase(text))
#     print()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# Top 10 Unigrams:
#          Word  Count
# 41     length  14010
# 66       ball  12304
# 16    outside  11927
# 65      short  10805
# 40       back   9920
# 5         leg   9573
# 215      wide   7728
# 55       full   7371
# 42   delivery   6782
# 30       deep   6655
#
# Top 10 Bigrams:
#                 Bigram  Count
# 42         back length   3031
# 4           square leg   2806
# 43     length delivery   2765
# 364       short length   2559
# 520        good length   2462
# 481        length ball   2453
# 183     deep midwicket   2387
# 663     backward point   2358
# 706     length outside   2206
# 1153         third man   1579
# 1573   backward square   1366
# 62           full toss   1341
# 82          middle leg   1325
# 1592       slower ball   1259
# 868        extra cover   1225
# 1145  delivery outside   1175
# 72          short ball   1158
# 1572     deep backward   1072
# 146           fine leg   1068
# 49         deep square   1068

# %%
import pandas as pd
import json
from pymongo import MongoClient

# MongoDB Atlas connection
client = MongoClient("mongodb+srv://harsh8423:8423047004@cluster0.1xbklyu.mongodb.net/cricket")
db = client["cricket"]

# Collections
matches_collection = db["matches"]
players_collection = db["players"]

# Load JSON file
file_path = "commentarydata.json"  # Replace with your actual file path
with open(file_path, 'r') as file:
    data = json.load(file)

# Fetch all players and matches data once
players_data = list(players_collection.find({}, {'_id': 1, 'bowling_type': 1, 'batting_style': 1, 'bowling_style': 1}))
matches_data = list(matches_collection.find({}, {'_id': 1, 'venue.name': 1}))

# Convert players data to dictionaries for faster lookup
players_dict = {str(player['_id']): player for player in players_data}
matches_dict = {str(match['_id']): match for match in matches_data}

# Since data is a list, we'll process each match in the list
all_commentary = []

for match in data:
    # For innings 1
    if 'commentary_innings1' in match:
        for ball in match['commentary_innings1']:
            ball_data = {
                '_id': match['_id'],
                'commText': ball.get('commText', ''),
                'overNumber': ball.get('overNumber', None),
                'batTeamName': ball.get('batTeamName', ''),
                'inningruns': ball.get('inningruns', None),
                'batsman_name': ball.get('batsman', {}).get('batName', ''),
                'bowler_name': ball.get('bowler', {}).get('bowlName', ''),
                'batsman_id': int(ball.get('batsman', {}).get('batId')) if ball.get('batsman', {}).get('batId') is not None else None,
                'bowler_id': int(ball.get('bowler', {}).get('bowlId')) if ball.get('bowler', {}).get('bowlId') is not None else None,
                'event': ball.get('event', ''),
                'is_wicket': ball.get('isWicket', False),
                'wicket_type': ball.get('wicketType', ''),
                'shot_played': ball.get('shotPlayed', ''),
                'ball_length': ball.get('ballLength', ''),
                'ball_line': ball.get('ballLine', ''),
                'batting_control': ball.get('battingControl', ''),
                'bowling_variation': ball.get('bowlingVariation', ''),
                'shot_direction': ball.get('shotDirection', ''),
                'inning': 1
            }
            all_commentary.append(ball_data)

    # For innings 2
    if 'commentary_innings2' in match:
        for ball in match['commentary_innings2']:
            ball_data = {
                '_id': match['_id'],
                'commText': ball.get('commText', ''),
                'overNumber': ball.get('overNumber', None),
                'batTeamName': ball.get('batTeamName', ''),
                'inningruns': ball.get('inningruns', None),
                'batsman_name': ball.get('batsman', {}).get('batName', ''),
                'bowler_name': ball.get('bowler', {}).get('bowlName', ''),
                'batsman_id': int(ball.get('batsman', {}).get('batId')) if ball.get('batsman', {}).get('batId') is not None else None,
                'bowler_id': int(ball.get('bowler', {}).get('bowlId')) if ball.get('bowler', {}).get('bowlId') is not None else None,
                'event': ball.get('event', ''),
                'is_wicket': ball.get('isWicket', False),
                'wicket_type': ball.get('wicketType', ''),
                'shot_played': ball.get('shotPlayed', ''),
                'ball_length': ball.get('ballLength', ''),
                'ball_line': ball.get('ballLine', ''),
                'batting_control': ball.get('battingControl', ''),
                'bowling_variation': ball.get('bowlingVariation', ''),
                'shot_direction': ball.get('shotDirection', ''),
                'inning': 2
            }
            all_commentary.append(ball_data)

# Convert to DataFrame
commentary = pd.DataFrame(all_commentary)

def process_commentary(commentary):
    
    # Convert IDs to strings for consistent comparison
    commentary['batsman_id'] = commentary['batsman_id'].astype(str)
    commentary['bowler_id'] = commentary['bowler_id'].astype(str)
    commentary['_id'] = commentary['_id'].astype(str)

        # Function to extract runs scored
    def extract_runs(comm_text):
        if "SIX" in comm_text or "six" in comm_text:
            return 6
        elif "FOUR" in comm_text or "four" in comm_text:
            return 4
        elif "1 run" in comm_text:
            return 1
        elif "2 runs" in comm_text:
            return 2
        elif "3 runs" in comm_text:
            return 3
        elif "no run" in comm_text:
            return 0
        else:
            return 0
        return None

    def wicket_type(comm_text):
        # Array of wicket type keywords for easy future additions
        wicket_keywords = ['runout', 'stumped', 'lbw', 'hit wicket']
        
        # Check for special combinations first
        text_lower = comm_text.lower()
        if 'caught' in text_lower and 'edge' in text_lower:
            return 'edge&caught'
        elif 'played on' in text_lower and 'bowled' in text_lower:
            return 'played_on'
        
        # Check for individual keywords
        if 'caught' in text_lower:
            return 'caught'
        if 'bowled' in text_lower:
            return 'bowled'
        
        # Check other wicket types
        for wicket in wicket_keywords:
            if wicket in text_lower:
                return wicket
        
        return 'wicket'

    def extract_shot(comm_text):
        shot_keywords = ['pull', 'cut', 'drive', 'sweep', 'flick', 'hook', 'loft','slog', 'punch','down the ground','across the line','scoop']
        if 'goes down' in comm_text.lower() or 'whip' in comm_text.lower():
            return 'loft'
        if 'nudge' in comm_text.lower() or 'tap' in comm_text.lower() or 'darted' in comm_text.lower() or 'paddle' in comm_text.lower() or 'tuck' in comm_text.lower() or 'pushed' in comm_text.lower() or 'knock' in comm_text.lower() or 'clipped' in comm_text.lower() or 'steer' in comm_text.lower() or 'dab' in comm_text.lower():
            return 'pushed slightly'
        if 'defend' in comm_text.lower() or 'defence' in comm_text.lower() or 'blocked' in comm_text.lower():
            return 'defend'
        for shot in shot_keywords:
            if shot in comm_text.lower():
                return shot
        return None

    def extract_direction(comm_text):
        direction_keywords = ['cover', 'square', 'point']
        
        for direction in direction_keywords:
            if direction in comm_text.lower():
                return direction
        if 'fine leg' in comm_text.lower() or 'fine-leg' in comm_text.lower() or 'fine' in comm_text.lower():
            return 'fine-leg'
        if 'third-man' in comm_text.lower() or 'third man' in comm_text.lower():
            return 'third-man'
        if 'mid-wicket' in comm_text.lower() or 'midwicket' in comm_text.lower() or 'mid wicket' in comm_text.lower():
            return 'mid-wicket'
        if 'mid-on' in comm_text.lower() or 'mid on' in comm_text.lower():
            return 'mid-wicket'
        if 'mid-off' in comm_text.lower() or 'mid off' in comm_text.lower():
            return 'long-off'
        if 'long-on' in comm_text.lower() or 'long on' in comm_text.lower():
            return 'long-on'
        if 'long-off' in comm_text.lower() or 'long off' in comm_text.lower():
            return 'long-off'
        if 'defend' in comm_text.lower() or 'defence' in comm_text.lower() or 'blocked' in comm_text.lower() or 'wide' in comm_text.lower():
            return 'blocked'
        if  'keeper' in comm_text.lower():
            return 'keeper'
        return None

    def extract_length(comm_text):
        length_keywords = ['short', 'full', 'yorker', 'bouncer','half-volley','good length','tossed up']
        
        if 'full toss' in comm_text.lower() or 'full-toss' in comm_text.lower():
            return 'full-toss'
        for length in length_keywords:
            if length in comm_text.lower():
                return length
        if 'back of a length' in comm_text.lower() or 'short of a length' in comm_text.lower():
            return 'back of a length'
        elif 'length delivery' in comm_text.lower() or 'length ball' in comm_text.lower():
            return 'length ball'
        
        return None

    def extract_ball_line(comm_text):
        text_lower = comm_text.lower()
        line_keywords = {
            'outside-off': ['outside off', 'outside-off'],
            'off-stump': ['off stump line', 'off-stump', 'off stump', 'around off','middle and off'],
            'middle-stump': ['middle stump', 'middle-stump','on middle', 'on stump', 'around middle','middle and leg', 'body'],
            'leg-stump': ['leg stump', 'leg-stump', 'outside leg','on leg','leg bye', 'around leg','down leg', 'down-leg'],
            'wide': ['wide']
        }
        variations = ['seam', 'swing', 'seam-away', 'seam-in', 'seam-up',]
        for line, variations in line_keywords.items():
            for variation in variations:
                if variation in text_lower:
                    return line
            if ('swing' not in text_lower or 'seam' not in text_lower) and 'pads' in text_lower:
                return 'leg-stump'
        return None

    def extract_batting_control(row):
        text_lower = row['commText'].lower()
        control_keywords = {
            'no-control': ['missed', 'misses', 'edge', 'edges'],
            'beaten': ['beaten', 'beats']
        }

        if row['event'] == 'WICKET':
            return 'no-control'
        
        for control, keywords in control_keywords.items():
            for keyword in keywords:
                if keyword in text_lower:
                    return control
        return 'in-control'



    def extract_bowling_variation(comm_text):
        text_lower = comm_text.lower()
        
        # Check for combined variations first
        if 'seam' in text_lower and 'away' in text_lower:
            return 'seam-away'
        if 'seaming' in text_lower and 'in' in text_lower:
            return 'seam-in'
        
        variation_keywords = {
            'seam-up': ['seam up', 'seam-up'],
            'out-swing': ['swinging away','outswinger'],
            'in-swing': ['swinging in','inswinger'],
            'swing': ['swinging'],
            'googly': ['googly'],
            'slower': ['slower', 'lack of pace'],
            'cutter': ['cutter'],
            'yorker': ['yorker'],
            'bouncer': ['bouncer'],
            'off-break': ['off-break'],
            'carrom ball': ['carrom'],
            'flipper': ['flipper'],
            'leg-break': ['leg-break'],
            'off-spin': ['off-spin'],
            'leg-spin': ['leg spin'],
            'knuckle ball': ['knuckle ball'],
            'quick': ['quick'],
            'arm ball': ['arm ball'],
            'slider':['slider'],
            'skidding':['skidding', 'skidded']

        }
        
        for variation, keywords in variation_keywords.items():
            for keyword in keywords:
                if keyword in text_lower:
                    return variation
        return 'normal'
    
    # Add new fields from MongoDB data
    def get_bowler_type(bowler_id):
        player = players_dict.get(str(bowler_id))
        return player.get('bowling_type') if player else None

    def get_batting_hand(batsman_id):
        player = players_dict.get(str(batsman_id))
        if player and player.get('batting_style'):
            return 'right' if player['batting_style'].startswith('Right') else 'left'
        return None

    def get_bowling_hand(bowler_id):
        player = players_dict.get(str(bowler_id))
        if player and player.get('bowling_style'):
            if player['bowling_style'].startswith('Right'):
                return 'right'
            elif player['bowling_style'].startswith('Left'):
                return 'left'
        return None

    def get_venue(match_id):
        match = matches_dict.get(str(match_id))
        return match.get('venue', {}).get('name') if match else None

    # Extract runs and apply transformations
    commentary['runs'] = commentary['commText'].apply(extract_runs)
    
    # Apply the new transformations
    commentary['bowler_type'] = commentary['bowler_id'].apply(get_bowler_type)
    commentary['batter_hand'] = commentary['batsman_id'].apply(get_batting_hand)
    commentary['bowler_hand'] = commentary['bowler_id'].apply(get_bowling_hand)
    commentary['venue'] = commentary['_id'].apply(get_venue)

    # Identify if it's a wicket ball
    commentary['is_wicket'] = commentary['event'] == 'WICKET'
    
    # Apply wicket type only if it's a wicket ball
    commentary['wicket_type'] = commentary.apply(
        lambda row: wicket_type(row['commText']) if row['event'] == 'WICKET' else 'N/A',
        axis=1
    )
    
    # Apply existing transformations
    commentary['shot_played'] = commentary['commText'].apply(extract_shot)
    commentary['ball_length'] = commentary['commText'].apply(extract_length)
    commentary['ball_line'] = commentary['commText'].apply(extract_ball_line)
    commentary['batting_control'] = commentary.apply(extract_batting_control, axis=1)
    commentary['bowling_variation'] = commentary['commText'].apply(extract_bowling_variation)
    commentary['shot_direction'] = commentary['commText'].apply(extract_direction)
    
    return commentary

# Process the commentary DataFrame
commentary = process_commentary(commentary)

# Update column order to include new fields
column_order = [
    '_id', 'commText', 'overNumber', 'batTeamName',
    'batsman_name', 'bowler_name', 'batsman_id', 'bowler_id',
    'batter_hand', 'bowler_hand', 'bowler_type', 'venue',
    'is_wicket', 'wicket_type', 'shot_played', 'ball_length',
    'ball_line', 'batting_control', 'bowling_variation', 'shot_direction',
    'inning','runs'
]
commentary = commentary[column_order]
# # Remove unwanted columns
# columns_to_remove = [
#         'event','inningruns','batsman_name', 'bowler_name', 'batsman_id', 'bowler_id',
#     ]
# commentary.drop(columns=columns_to_remove, inplace=True)

# %%
def refine_commentary_fields(commentary):
    """
    Refine values in the filtered commentary based on specific cricket-related conditions
    """
    # Create a copy to avoid modifying the original DataFrame
    refined_df = commentary.copy()
    
    # Apply condition 1: Update shot_direction based on batting control and wicket type
    mask_control = (refined_df['batting_control'] != 'in-control') & (refined_df['shot_direction'].isnull())
    mask_stumped = refined_df['wicket_type'] == 'stumped'
    refined_df.loc[mask_control | mask_stumped, 'shot_direction'] = 'keeper'
    
    # Apply condition 2: Update shot_played based on direction and runs
    mask_shot_null = refined_df['shot_played'].isnull() & refined_df['shot_direction'].notnull()
    mask_low_runs = refined_df['runs'].isin([0, 1, 2])
    refined_df.loc[mask_shot_null & mask_low_runs, 'shot_played'] = 'pushed slightly'
    
    # Apply condition 3: Update ball_line based on shot direction and bowling variation
    mask_offside_direction = refined_df['shot_direction'].isin(['cover', 'point', 'third-man'])
    mask_not_away = ~refined_df['bowling_variation'].isin(['seam-away', 'out-swing'])
    mask_valid_line = refined_df['ball_line'].isnull()
    refined_df.loc[mask_valid_line & mask_offside_direction & mask_not_away, 'ball_line'] = 'outside-off'
    
    # Apply condition 4: Update ball_length based on multiple conditions
    # Condition 4.1: outside-off drive
    mask_outside_off_drive = (refined_df['ball_line'] == 'outside-off') & (refined_df['shot_played'] == 'drive')
    
    # Condition 4.2: specific shots
    mask_specific_shots = refined_df['shot_played'].isin(['slog', 'scoop', 'sweep'])
    
    # Condition 4.3: swing variations
    mask_swing = refined_df['bowling_variation'].isin(['in-swing', 'out-swing'])
    
    # Condition 4.4: point/third-man cut
    mask_cut_direction = refined_df['shot_direction'].isin(['point', 'third-man'])
    mask_cut_shot = refined_df['shot_played'] == 'cut'
    
    # Apply length updates
    mask_valid_length = refined_df['ball_length'].isnull()
    refined_df.loc[mask_valid_length & (mask_outside_off_drive | mask_specific_shots | mask_swing), 'ball_length'] = 'full'
    refined_df.loc[mask_valid_length & mask_cut_direction & mask_cut_shot, 'ball_length'] = 'back of a length'
    
    # Apply condition 5: Update ball_line based on additional conditions
    # Condition 5.1: off-stump line
    mask_off_direction = refined_df['shot_direction'].isin(['mid-off', 'long-off'])
    mask_pushed = refined_df['shot_played'] == 'pushed slightly'
    mask_not_short = refined_df['ball_length'] != 'short'
    mask_valid_line = refined_df['ball_line'].isnull()
    refined_df.loc[mask_valid_line & mask_off_direction & mask_pushed & mask_not_short, 'ball_line'] = 'off-stump'
    
    # Condition 5.2: leg-stump line for fine-leg direction
    mask_fine_leg = refined_df['shot_direction'] == 'fine-leg'
    mask_leg_shots = refined_df['shot_played'].isin(['pull', 'flick', 'sweep'])
    refined_df.loc[mask_valid_line & mask_fine_leg & mask_leg_shots, 'ball_line'] = 'leg-stump'
    
    # Condition 5.3: leg-stump line for square direction
    mask_square = refined_df['shot_direction'] == 'square'
    mask_not_short_back = ~refined_df['ball_length'].isin(['short', 'back of a length'])
    refined_df.loc[mask_valid_line & mask_square & mask_not_short_back, 'ball_line'] = 'leg-stump'
    
    return refined_df

# Apply the refinements to the filtered commentary
refined_commentary = refine_commentary_fields(commentary)


# Filter rows where specific columns are not None
commentary_before = commentary[
    # (commentary['bowler_id']==265)
    # (commentary['batsman_id']==1413)
    (commentary['shot_played'].notnull())&
    (commentary['ball_length'].notnull())&
    (commentary['ball_line'].notnull())&
    # (commentary['batting_control'] != 'in-control')&
    # (commentary['bowling_variation'] !='normal')
    (commentary['shot_direction'].notnull())
    # ((commentary['runs']==0) | (commentary['runs']==1) | (commentary['runs']==2)) & 
    # (commentary['is_wicket']!=True)
]


# Filter rows where specific columns are not None
commentary_after = refined_commentary[
    # (refined_commentary['bowler_id']==265)
    # (refined_commentary['batsman_id']==1413)
    (refined_commentary['shot_played'].notnull())&
    (refined_commentary['ball_length'].notnull())&
    (refined_commentary['ball_line'].notnull())&
    # (refined_commentary['batting_control'].notnull)
#     (refined_commentary['bowling_variation'] !='normal')
    (refined_commentary['shot_direction'].notnull())
#     ((refined_commentary['runs']==0) | (refined_commentary['runs']==1) | (refined_commentary['runs']==2)) & 
#     (refined_commentary['is_wicket']!=True)
]

# Print the filtered rows
row_count = len(commentary_before)
print(f"Number of rows in commentary_before: {row_count}")

# Print the filtered rows
row_count = len(commentary_after)
print(f"Number of rows in refined_commentary: {row_count}")
commentary_after.tail(25)

# Get first 20 rows and save to CSV
refined_commentary.head(20).to_csv('commentary_20_rows.csv', index=False)
# Out:
# Number of rows in commentary_before: 9083
# Number of rows in refined_commentary: 19434

# %%
from pymongo import MongoClient
import pandas as pd

# MongoDB Atlas connection
client = MongoClient("mongodb+srv://harsh8423:8423047004@cluster0.1xbklyu.mongodb.net/cricket")
db = client["cricket"]  # Replace with your database name

# Collections
matches_collection = db["matches"]
teams_collection = db["teams"]
players_collection = db["players"]
scorecards_collection = db["scorecards"]
commentaries_collection = db["commentaries"]

def analyze_venue_matches(venue_name, commentary_df):
    # Filter commentary data for the specific venue
    venue_data = commentary_df[commentary_df['venue'] == venue_name].copy()

    # print(venue_data)
    
    # Helper function to calculate metrics for a group of data
    def calculate_metrics(data):
        total_runs = data['runs'].sum()
        total_balls = len(data)
        total_wickets = data['is_wicket'].sum()
        economy_rate = (total_runs * 6) / total_balls if total_balls > 0 else 0
        strike_rate = (total_runs * 100) / total_balls if total_balls > 0 else 0
        balls_per_wicket=total_balls/total_wickets if total_balls > 0 else 0
        runs_per_wicket=total_runs/total_wickets if total_balls > 0 else 0
        
        return {
            'total_runs': total_runs,
            'total_balls': total_balls,
            'total_wickets': total_wickets,
            'runs_per_wicket': round(runs_per_wicket,2),
            'balls_per_wicket':round(balls_per_wicket,2),
            'economy_rate': round(economy_rate, 2),
            'strike_rate': round(strike_rate, 2)
        }
    
    # 1. Overall analysis by bowler_type
    overall_stats = []
    for bowler_type in ['pace', 'spin']:
        type_data = venue_data[venue_data['bowler_type'] == bowler_type]
        metrics = calculate_metrics(type_data)
        metrics['bowler_type'] = bowler_type
        metrics['innings'] = 'Overall'
        overall_stats.append(metrics)
    
    # 2. Analysis by innings and bowler_type
    innings_stats = []
    for inning in [1, 2]:
        inning_data = venue_data[venue_data['inning'] == inning]
        for bowler_type in ['pace', 'spin']:
            type_data = inning_data[inning_data['bowler_type'] == bowler_type]
            metrics = calculate_metrics(type_data)
            metrics['bowler_type'] = bowler_type
            metrics['innings'] = f'Inning {inning}'
            innings_stats.append(metrics)
    
    # Combine all stats
    all_stats = overall_stats + innings_stats
    
    # Convert to DataFrame and normalize
    stats_df = pd.DataFrame(all_stats)
    
    # Add venue information
    stats_df['venue'] = venue_name
    
    # Reorder columns for better readability
    column_order = [
        'venue', 'innings', 'bowler_type', 'total_runs', 'total_balls',
        'total_wickets', 'runs_per_wicket', 'balls_per_wicket', 'economy_rate', 'strike_rate'
    ]
    stats_df = stats_df[column_order]
    
    # Fetch the last 10 matches at this venue from MongoDB
    matches = list(
        matches_collection.find(
            {"venue.name": venue_name},
            {"matchStartTimestamp": 1, "tossResults": 1, "result": 1}
        ).sort("matchStartTimestamp", -1).limit(10)
    )
    
    # Create matches DataFrame
    matches_df = pd.json_normalize(matches)
    
    return matches_df,stats_df

# 2. Fetch the last 10 matches between both teams
def analyze_team_head_to_head(team1, team2):
    # Query the last 10 matches between two teams
    matches = list(
        matches_collection.find(
            {
                "$or": [
                    {"team1.name": team1, "team2.name": team2},
                    {"team1.name": team2, "team2.name": team1}
                ]
            },
            {"matchStartTimestamp": 1, "result": 1}
        ).sort("matchStartTimestamp", -1).limit(10)
    )
    
    # Normalize the data
    df = pd.json_normalize(matches)
    return df


def analyze_players(team1, team2, venue_name):
    # Get player IDs from both teams
    team1_data = teams_collection.find_one({"team_name": team1}, {"players": 1})
    team2_data = teams_collection.find_one({"team_name": team2}, {"players": 1})
    
    # Combine player IDs
    player_ids = team1_data["players"] + team2_data["players"]

    # Dictionary to store venue matches for each player
    venue_matches_by_player = {}
    
    # First, get all venue matches for each player
    for player_id in player_ids:
        player_data = players_collection.find_one({"_id": player_id}, {"matches": 1})
        if player_data and "matches" in player_data:
            # Find matches at the specified venue
            venue_matches = list(matches_collection.find({
                "_id": {"$in": player_data["matches"]},
                "venue.name": venue_name
            }))
            venue_matches_by_player[player_id] = [match["_id"] for match in venue_matches][:5]
    
    # Get recent matches for each player
    player_recent_matches = {}
    for player_id in player_ids:
        player_data = players_collection.find_one({"_id": player_id}, {"matches": 1})
        if player_data and "matches" in player_data:
            match_ids = sorted(player_data["matches"], reverse=True)[:10]
            player_recent_matches[player_id] = match_ids

    batting_rows = []
    bowling_rows = []

    # Process recent matches
    for player_id, match_ids in player_recent_matches.items():
        for match_id in match_ids:
            scorecard = scorecards_collection.find_one(
                {"_id": match_id},
                {"firstInnings": 1, "secondInnings": 1}
            )
            if scorecard:
                for innings_key in ["firstInnings", "secondInnings"]:
                    innings = scorecard.get(innings_key, [])
                    for index, row in enumerate(innings):
                        if row.get("playerId") == str(player_id):
                            row_copy = row.copy()
                            row_copy['stats_type'] = 'recent'
                            row_copy['match_id'] = match_id
                            if row.get("type") == "Batting" and row.get('balls', 0) > 0:
                                row_copy["batting_position"] = index + 1
                                batting_rows.append(row_copy)
                            elif row.get("type") == "Bowling":
                                bowling_rows.append(row_copy)

    # Process venue matches
    for player_id, venue_match_ids in venue_matches_by_player.items():
        for match_id in venue_match_ids:
            scorecard = scorecards_collection.find_one(
                {"_id": match_id},
                {"firstInnings": 1, "secondInnings": 1}
            )
            if scorecard:
                for innings_key in ["firstInnings", "secondInnings"]:
                    innings = scorecard.get(innings_key, [])
                    for index, row in enumerate(innings):
                        if row.get("playerId") == str(player_id):
                            row_copy = row.copy()
                            row_copy['stats_type'] = 'venue'
                            row_copy['match_id'] = match_id
                            if row.get("type") == "Batting" and row.get('balls', 0) > 0:
                                row_copy["batting_position"] = index + 1
                                batting_rows.append(row_copy)
                            elif row.get("type") == "Bowling":
                                bowling_rows.append(row_copy)

    # Normalize the batting and bowling data
    batting_df = pd.DataFrame(batting_rows)
    bowling_df = pd.DataFrame(bowling_rows)

    # Calculate fantasy points for batting
    def calculate_batting_points(row):
        points = row['runs']  # +1 per run
        points += row['fours']  # +1 per four
        points += row['sixes'] * 2  # +2 per six
        
        if row['runs'] >= 100:
            points += 16  # Century bonus
        elif row['runs'] >= 50:
            points += 8  # Half-century bonus
        elif row['runs'] >= 30:
            points += 4  # 30-run bonus

        if row['dismissal'] == 'Duck' and row['balls'] > 0:
            points -= 2  # Duck penalty
        
        # Strike rate points
        if row['balls'] >= 10:
            strike_rate = (row['runs'] / row['balls']) * 100
            if strike_rate > 170:
                points += 6
            elif 150.01 <= strike_rate <= 170:
                points += 4
            elif 130 <= strike_rate <= 150:
                points += 2
            elif 60 <= strike_rate < 70:
                points -= 2
            elif 50 <= strike_rate < 60:
                points -= 4
            elif strike_rate < 50:
                points -= 6
        
        return points

    if not batting_df.empty:
        batting_df['fantasy_points'] = batting_df.apply(calculate_batting_points, axis=1)

    # Calculate fantasy points for bowling
    def calculate_bowling_points(row):
        points = row['wickets'] * 25  # +25 per wicket

        if row['wickets'] >= 5:
            points += 16  # 5-wicket haul bonus
        elif row['wickets'] == 4:
            points += 8  # 4-wicket haul bonus
        elif row['wickets'] == 3:
            points += 4  # 3-wicket haul bonus

        points += row['maidens'] * 12  # +12 per maiden over

        # Economy rate points
        if row['overs'] >= 2:
            economy_rate = row['runs'] / row['overs']
            if economy_rate < 5:
                points += 6
            elif 5 <= economy_rate < 6:
                points += 4
            elif 6 <= economy_rate <= 7:
                points += 2
            elif 10 <= economy_rate < 11:
                points -= 2
            elif 11 <= economy_rate < 12:
                points -= 4
            elif economy_rate >= 12:
                points -= 6
        
        return points

    if not bowling_df.empty:
        bowling_df['fantasy_points'] = bowling_df.apply(calculate_bowling_points, axis=1)

    return batting_df, bowling_df




def analyze_commentary(team1, team2, refined_commentary):
    
    # Get player IDs for both teams
    team1_data = teams_collection.find_one({"team_name": team1}, {"players": 1})
    team2_data = teams_collection.find_one({"team_name": team2}, {"players": 1})
    
    # Assume `players` is a list of integers representing player IDs
    player_ids = team1_data["players"] + team2_data["players"]
    player_ids_str = [str(player_id) for player_id in player_ids]
    print(type(player_ids_str[0]))

    # Filter commentary rows where batsman_id or bowler_id matches player IDs
    batting_commentary = refined_commentary[refined_commentary["batsman_id"].isin(player_ids_str)]
    bowling_commentary = refined_commentary[(refined_commentary["bowler_id"].isin(player_ids_str))]
    
    
    return batting_commentary, bowling_commentary



# Main Function
if __name__ == "__main__":
    # Example inputs
    venue_name = "Narendra Modi Stadium"
    team1 = "Gujarat Titans"
    team2 = "Chennai Super Kings"
    
    # 1. Venue Analysis
    venue_df, venue_stats_df = analyze_venue_matches(venue_name, refined_commentary)
    venue_df['toss_decision'] = venue_df['tossResults.decision']
    venue_df['winByRuns'] = venue_df['result.winByRuns']
    columns_to_remove_venue = ['matchStartTimestamp','result.resultType','result.winningTeam','result.winningteamId','result.winningMargin','result.winByRuns','result.winByInnings','tossResults.tossWinnerId','tossResults.tossWinnerName','tossResults.decision']
    venue_df.drop(columns=columns_to_remove_venue, inplace=True)
    
    # 2. Head-to-Head Analysis
    h2h_df = analyze_team_head_to_head(team1, team2)
    h2h_df['winningTeam'] = h2h_df['result.winningTeam']
    h2h_df['winningMargin'] = h2h_df['result.winningMargin']
    h2h_df['winByRuns'] = h2h_df['result.winByRuns']
    columns_to_remove_h2h = ['matchStartTimestamp','result.resultType','result.winningTeam','result.winningteamId','result.winningMargin','result.winByRuns','result.winByInnings']
    h2h_df.drop(columns=columns_to_remove_h2h, inplace=True)
    
    # # 3. Player Analysis
    batting_df, bowling_df = analyze_players(team1, team2, venue_name)
    
    # 4. Commentary Analysis
    batting_commentary, bowling_commentary = analyze_commentary(team1, team2, refined_commentary)
# Out:
# <class 'str'>

# %%
batting_commentary.tail(5)
# Out:
#          _id                                           commText  overNumber  \
# 46623  47605   Boult to Shubman Gill, no run, 134kph, anothe...         2.2
# 46624  47605   Boult to Shubman Gill, no run, cuts back in o...         2.1
# 46631  47605   Boult to Shubman Gill, FOUR, strays onto the ...         0.6
# 46632  47605   Boult to Shubman Gill, no run, length, on the...         0.5
# 46633  47605   Boult to Shubman Gill, no run, dropped. Now, ...         0.4
#
#       batTeamName  batsman_name  bowler_name batsman_id bowler_id batter_hand  \
# 46623          GT  Shubman Gill  Trent Boult      11808      8117       right
# 46624          GT  Shubman Gill  Trent Boult      11808      8117       right
# 46631          GT  Shubman Gill  Trent Boult      11808      8117       right
# 46632          GT  Shubman Gill  Trent Boult      11808      8117       right
# 46633          GT  Shubman Gill  Trent Boult      11808      8117       right
#
#       bowler_hand  ... is_wicket wicket_type      shot_played ball_length  \
# 46623        left  ...     False         N/A            punch        None
# 46624        left  ...     False         N/A           defend        None
# 46631        left  ...     False         N/A            flick        None
# 46632        left  ...     False         N/A             None        None
# 46633        left  ...     False         N/A  pushed slightly        None
#
#          ball_line batting_control bowling_variation shot_direction inning  \
# 46623  outside-off      in-control            normal          point      2
# 46624  outside-off      in-control            normal          cover      2
# 46631    leg-stump      in-control            normal       fine-leg      2
# 46632         None      in-control            normal           None      2
# 46633    leg-stump      in-control            normal         square      2
#
#       runs
# 46623    0
# 46624    0
# 46631    4
# 46632    0
# 46633    0
#
# [5 rows x 22 columns]

# %%
import pandas as pd

def process_match_summary(venue_df, h2h_df):
    """Process basic match information from venue and head-to-head dataframes"""

    match_analysis_report = {}

    # 1. Venue Analysis
    venue_analysis = []
    for _, row in venue_df.iterrows():
        toss_decision = row["toss_decision"]
        win_by_runs = row["winByRuns"]
        winner = "Batting Team" if win_by_runs else "Bowling Team"
        
        venue_analysis.append({
            "toss_decision": toss_decision,
            "winner": winner
        })
    match_analysis_report["venue_analysis"] = venue_analysis

    venue_stats=[]
    for _, row in venue_stats_df.iterrows():
        innings=row['innings']
        bowler_type=row['bowler_type']
        total_runs=row['total_runs']	
        total_balls	=row['total_balls']
        total_wickets=row['total_wickets']	
        runs_per_wicket	=row['runs_per_wicket']
        balls_per_wicket=row['balls_per_wicket']	
        economy_rate=row['economy_rate']	
        strike_rate=row['strike_rate']

        venue_stats.append({
            'innings':innings,
            'bowler_type':bowler_type,
            'total_runs':total_runs,
            'total_balls':total_balls,
            'total_wickets':total_wickets,
            'runs_per_wicket':runs_per_wicket,
            'balls_per_wicket':balls_per_wicket,	
            'economy_rate':economy_rate,
            'strike_rate':strike_rate
        })

        match_analysis_report["venue_stats"] = venue_stats
    # 2. Head-to-Head Analysis
    h2h_analysis = []
    for _, row in h2h_df.iterrows():
        winning_team = row["winningTeam"]
        winning_margin = row["winningMargin"]
        win_by_runs = row["winByRuns"]
        result = f"{winning_team} won by {winning_margin} runs" if win_by_runs else f"{winning_team} won by {winning_margin} wickets"
        h2h_analysis.append(result)
    match_analysis_report["head_to_head_analysis"] = h2h_analysis
        
    return match_analysis_report


def generate_bowler_analysis(bowling_df, commentary_df, team1_ids, team2_ids):
    """
    Generate a comprehensive analysis of bowling statistics for each player by combining
    bowling performance from `bowling_df` and detailed analysis from `commentary_df`.
    
    Args:
    - bowling_df (pd.DataFrame): Dataframe with player bowling performance.
    - commentary_df (pd.DataFrame): Dataframe with commentary analysis.

    Returns:
    - dict: Comprehensive analysis for each bowler.
    """
    bowler_analysis = {}

    # Process Bowling Stats from `bowling_df`
    for _, player in bowling_df.groupby('playerId'):
        player_id = int(player['playerId'].iloc[0])
        player_name = player['name'].iloc[0]

        # Fetch player details from players_collection
        player_details = players_collection.find_one({"_id": player_id})
        
        # Fetch team details from teams_collection
        team_info = teams_collection.find_one({"players": player_id})
        
        # Extract required fields from player_details
        role = player_details.get('role', '')
        batting_style = player_details.get('batting_style', '')
        bowling_style = player_details.get('bowling_style', '')
        team_name = team_info.get('team_name', '') if team_info else ''

        matches = []
        total_runs = 0
        total_wickets = 0
        total_balls = 0
        total_fantasy_points=0

        for _, innings in player.iterrows():
            # Convert overs to balls (e.g., 4.3 overs = 4*6 + 3 = 27 balls)
            overs_whole = int(innings['overs'])
            overs_decimal = round((innings['overs'] - overs_whole) * 10)  # Get decimal part
            balls = (overs_whole * 6) + overs_decimal

            match_stats = {
                'runs': innings['runs'],
                'overs': innings['overs'],
                'wickets': innings['wickets'],
                'economy': innings['economy'],
                'fantasy_points': innings['fantasy_points'],
                'match_id': innings['match_id'],
                'stats_type': innings['stats_type']
            }
            matches.append(match_stats)

            total_runs += innings['runs']
            total_wickets += innings['wickets']
            total_balls += balls
            total_fantasy_points +=innings['fantasy_points']

        # Initialize bowler's data
        bowler_analysis[player_id] = {
            'name': player_name,
            'role': role,
            'batting_style': batting_style,
            'bowling_style': bowling_style,
            'team_name': team_name,
            'matches': matches,
            'total_runs': total_runs,
            'total_wickets': total_wickets,
            'total_balls': total_balls,
            'runs_per_wicket': total_runs / total_wickets if total_wickets > 0 else float('inf'),
            'balls_per_wicket': total_balls / total_wickets if total_wickets > 0 else float('inf'),
            'total_fantasy_points': total_fantasy_points
        }

    # Process Detailed Bowling Analysis from `commentary_df`
    commentary_df['bowler_id'] = commentary_df['bowler_id'].astype(int)

    for bowler_id in commentary_df['bowler_id'].unique():
        bowler_data = commentary_df[commentary_df['bowler_id'] == bowler_id]
        bowler_name = bowler_data['bowler_name'].iloc[0]

        # Determine the opponent team
        if player_id in team1_ids:
            opponent_players = team2_ids
        elif player_id in team2_ids:
            opponent_players = team1_ids
        else:
            continue

        # Phase-wise analysis
        phases = {
            'powerplay': bowler_data[(bowler_data['overNumber'] >= 0) & (bowler_data['overNumber'] <= 6)],
            'middle': bowler_data[(bowler_data['overNumber'] > 6) & (bowler_data['overNumber'] <= 16)],
            'death': bowler_data[(bowler_data['overNumber'] > 16) & (bowler_data['overNumber'] <= 20)]
        }

        phase_stats = {}
        for phase_name, phase_data in phases.items():
            total_runs = phase_data['runs'].sum()
            total_balls = len(phase_data)
            total_wickets = len(phase_data[phase_data['is_wicket'] == True])

            phase_stats[phase_name] = {
                'runs': total_runs,
                'balls': total_balls,
                'wickets': total_wickets,
                'runs_per_wicket': total_runs / total_wickets if total_wickets > 0 else float('inf'),
                'balls_per_wicket': total_balls / total_wickets if total_wickets > 0 else float('inf'),
                'economy': (total_runs * 6) / total_balls if total_balls > 0 else 0
            }

        leftVSright={
            'left_arm': bowler_data[bowler_data['bowler_hand']=='left'],
            'right_arm': bowler_data[bowler_data['bowler_hand']=='right']
        }
        leftVright={}
        for bowl_hand, data in leftVSright.items():
            total_runs = data['runs'].sum()
            total_balls = len(data)
            strike_rate = (total_runs / total_balls * 100) if total_balls > 0 else 0
            wickets = len(data[data['is_wicket'] == True])
            leftVright[bowl_hand] = {
                'runs': total_runs,
                'balls': total_balls,
                'strike_rate': strike_rate,
                'wickets': wickets
            }

        # Wicket analysis
        wicket_data = bowler_data[bowler_data['is_wicket'] == True]
        filtered_wicket_stats = {
            str(tuple(row)): count
            for row, count in wicket_data.groupby(["ball_length", "ball_line", "bowling_variation"]).size().items()
            if count >= 2  # Add only if count >= 2
        }


        # Boundary analysis
        boundaries = bowler_data[bowler_data['runs'].isin([4, 6])]
        boundary_percentage = (len(boundaries) / len(bowler_data)) * 100 if len(bowler_data) > 0 else 0

        # Group boundary details and filter conditions
        boundary_details = boundaries.groupby(["ball_length", "ball_line", "bowling_variation"]).size()
        filtered_boundary_stats = {
            str(tuple(row)): count
            for row, count in boundary_details.items()
            if count >= 3  # Add only if count >= 3
        }

        # If no boundary group satisfies count >= 3, include groups with count >= 2
        if not filtered_boundary_stats:
            filtered_boundary_stats = {
                str(tuple(row)): count
                for row, count in boundary_details.items()
                if count >= 2
            }

        boundary_analysis = {
            "details": filtered_boundary_stats,
            "percentage": boundary_percentage
        }
        # Bowling variation frequency
        variation_frequency = bowler_data['bowling_variation'].value_counts().to_dict()


        # Analysis against opponents
        opponent_analysis = {}
        for opponent_id in opponent_players:
            # Get all interactions between current player and opponent
            interactions = bowler_data[
                (bowler_data['batsman_id'] == opponent_id)
            ]


            if len(interactions) >= 18 or interactions['is_wicket'].any():

                batter_name = interactions['batsman_name'].iloc[0] if not interactions.empty else "Unknown"

                total_balls = len(interactions)
                total_runs = interactions['runs'].sum()
                strike_rate = (total_runs / total_balls * 100) if total_balls > 0 else 0
                wickets = interactions['is_wicket'].sum()

                opponent_stats = {
                    'balls': total_balls,
                    'runs': total_runs,
                    'strike_rate': strike_rate,
                    'wickets': wickets
                }

                # Detailed wicket analysis if multiple wickets
                if wickets > 0:
                    wicket_rows = interactions[interactions['is_wicket'] == True]
                    
                    # Fill null values with 'unknown' before grouping
                    wicket_rows_filled = wicket_rows.fillna({
                        'wicket_type': 'unknown',
                        'shot_played': 'unknown',
                        'ball_line': 'unknown',
                        'ball_length': 'unknown'
                    })
                    
                    wicket_patterns = wicket_rows_filled.groupby(
                        ['wicket_type', 'shot_played', 'ball_line', 'ball_length'],
                        dropna=False  # Include groups with null values
                    ).size().to_dict()
                    
                    opponent_stats['wicket_patterns'] = {
                        str(k): v for k, v in wicket_patterns.items()
                    }

                opponent_analysis[batter_name] = opponent_stats

        # Update or merge detailed analysis into existing entry
        if bowler_id in bowler_analysis:
            bowler_analysis[bowler_id].update({
                'name': bowler_name,
                'phase_stats': phase_stats,
                'left_vs_right': leftVright,
                'wicket_analysis': filtered_wicket_stats,
                'boundary_analysis': boundary_analysis,
                'variation_frequency': variation_frequency,
                'opponent_analysis': opponent_analysis  # New field added
            })
        else:
            bowler_analysis[bowler_id] = {
                'name': bowler_name,
                'phase_stats': phase_stats,
                'left_vs_right': leftVright,
                'wicket_analysis': filtered_wicket_stats,
                'boundary_analysis': boundary_analysis,
                'variation_frequency': variation_frequency,
                'opponent_analysis': opponent_analysis  # New field added
            }

    return bowler_analysis





def generate_batting_analysis(batting_df, commentary_df, team1_ids, team2_ids):
    """
    Generate a comprehensive analysis of batting statistics for each player by combining
    batting performance from `batting_df` and detailed commentary analysis from `commentary_df`.
    Now includes analysis of performance against specific opponents.

    Args:
    - batting_df (pd.DataFrame): Dataframe with player batting performance.
    - commentary_df (pd.DataFrame): Dataframe with commentary analysis.

    Returns:
    - dict: Comprehensive analysis for each batsman.
    """
    player_analysis = {}

    # Process Batting Stats from `batting_df`
    for _, player in batting_df.groupby('playerId'):
        player_id = int(player['playerId'].iloc[0])
        player_name = player['name'].iloc[0]

        # Fetch player details from players_collection
        player_details = players_collection.find_one({"_id": player_id})
        
        # Fetch team details from teams_collection
        team_info = teams_collection.find_one({"players": player_id})
        
        # Extract required fields from player_details
        role = player_details.get('role', '')
        batting_style = player_details.get('batting_style', '')
        bowling_style = player_details.get('bowling_style', '')
        team_name = team_info.get('team_name', '') if team_info else ''

        matches = []
        total_runs = 0
        total_balls = 0
        total_fantasy_points=0

        for _, innings in player.iterrows():
            match_stats = {
                'runs': innings['runs'],
                'balls': innings['balls'],
                'strike_rate': innings['strikeRate'],
                'fantasy_points': innings['fantasy_points'],
                'match_id': innings['match_id'],
                'stats_type': innings['stats_type'],
                'batting_position': innings['batting_position']
            }
            matches.append(match_stats)
            total_runs += innings['runs']
            total_balls += innings['balls']
            total_fantasy_points +=innings['fantasy_points']

        # Initialize player's data
        player_analysis[player_id] = {
            'name': player_name,
            'role': role,
            'batting_style': batting_style,
            'bowling_style': bowling_style,
            'team_name': team_name,
            'matches': matches,
            'total_runs': total_runs,
            'total_balls': total_balls,
            'average_runs': total_runs / len(matches) if matches else 0,
            'overall_strike_rate': (total_runs / total_balls * 100) if total_balls > 0 else 0,
            'total_fantasy_points': total_fantasy_points,

        }

    commentary_df['batsman_id'] = commentary_df['batsman_id'].astype(int)
    # Process Detailed Commentary Analysis from `commentary_df`
    for player_id in commentary_df['batsman_id'].unique():
        player_data = commentary_df[commentary_df['batsman_id'] == (player_id)]

        player_name = player_data['batsman_name'].iloc[0]


        # Determine the opponent team
        if player_id in team1_ids:
            opponent_players = team2_ids
        elif player_id in team2_ids:
            opponent_players = team1_ids
        else:
            continue

        # Phase-wise analysis
        phases = {
            'powerplay': player_data[(player_data['overNumber'] >= 0) & (player_data['overNumber'] <= 6)],
            'middle': player_data[(player_data['overNumber'] > 6) & (player_data['overNumber'] <= 16)],
            'death': player_data[(player_data['overNumber'] > 16) & (player_data['overNumber'] <= 20)]
        }
        phase_stats = {}
        for phase_name, phase_data in phases.items():
            total_runs = phase_data['runs'].sum()
            total_balls = len(phase_data)
            strike_rate = (total_runs / total_balls * 100) if total_balls > 0 else 0
            phase_stats[phase_name] = {
                'runs': total_runs,
                'balls': total_balls,
                'strike_rate': strike_rate
            }
            

        spinVSpace={
            'spin': player_data[player_data['bowler_type']=='spin'],
            'pace': player_data[player_data['bowler_type']=='pace']
        }
        spinVpace={}
        for bowl_type, data in spinVSpace.items():
            total_runs = data['runs'].sum()
            total_balls = len(data)
            strike_rate = (total_runs / total_balls * 100) if total_balls > 0 else 0
            wickets = len(data[data['is_wicket'] == True])
            spinVpace[bowl_type] = {
                'runs': total_runs,
                'balls': total_balls,
                'strike_rate': strike_rate,
                'wickets': wickets
            }

        leftVSright={
            'left_arm': player_data[player_data['bowler_hand']=='left'],
            'right_arm': player_data[player_data['bowler_hand']=='right']
        }
        leftVright={}
        for bowl_hand, data in leftVSright.items():
            total_runs = data['runs'].sum()
            total_balls = len(data)
            strike_rate = (total_runs / total_balls * 100) if total_balls > 0 else 0
            wickets = len(data[data['is_wicket'] == True])
            leftVright[bowl_hand] = {
                'runs': total_runs,
                'balls': total_balls,
                'strike_rate': strike_rate,
                'wickets': wickets
            }


        # Analysis against opponents
        opponent_analysis = {}
        for opponent_id in opponent_players:
            # Get all interactions between current player and opponent
            interactions = player_data[
                (player_data['bowler_id'] == str(opponent_id))
            ]
            
            if len(interactions) >= 18 or interactions['is_wicket'].any():

                bowler_name = interactions['bowler_name'].iloc[0] if not interactions.empty else "Unknown"

                total_balls = len(interactions)
                total_runs = interactions['runs'].sum()
                strike_rate = (total_runs / total_balls * 100) if total_balls > 0 else 0
                wickets = interactions['is_wicket'].sum()

                opponent_stats = {
                    'balls': total_balls,
                    'runs': total_runs,
                    'strike_rate': strike_rate,
                    'wickets': wickets
                }

                if wickets > 0:
                    wicket_rows = interactions[interactions['is_wicket'] == True]
                    
                    # Fill null values with 'unknown' before grouping
                    wicket_rows_filled = wicket_rows.fillna({
                        'wicket_type': 'unknown',
                        'shot_played': 'unknown',
                        'ball_line': 'unknown',
                        'ball_length': 'unknown'
                    })
                    
                    wicket_patterns = wicket_rows_filled.groupby(
                        ['wicket_type', 'shot_played', 'ball_line', 'ball_length'],
                        dropna=False  # Include groups with null values
                    ).size().to_dict()
                    
                    opponent_stats['wicket_patterns'] = {
                        str(k): v for k, v in wicket_patterns.items()
                    }


                opponent_analysis[bowler_name] = opponent_stats

        control_stats = player_data['batting_control'].value_counts().to_dict()
        scoring_zone = player_data['shot_direction'].value_counts().to_dict()

        # Wicket analysis
        wicket_data = player_data[player_data['is_wicket'] == True]
        wicket_stats = {
            str(tuple(row)): count
            for row, count in wicket_data.groupby(["shot_played", "ball_length", "ball_line", "shot_direction"]).size().items()
            if count >= 2
        }

        # Boundary analysis
        boundaries = player_data[player_data['runs'].isin([4, 6])]
        boundary_percentage = (len(boundaries) / len(player_data)) * 100 if len(player_data) > 0 else 0

        boundary_details = boundaries.groupby(["shot_played", "ball_length", "ball_line"]).size()
        boundary_stats = {
            str(tuple(row)): count
            for row, count in boundary_details.items()
            if count >= 3
        }

        if not boundary_stats:
            boundary_stats = {
                str(tuple(row)): count
                for row, count in boundary_details.items()
                if count >= 2
            }

        # Update or merge detailed analysis into existing entry
        if player_id in player_analysis:
            player_analysis[player_id].update({
                'name': player_name,
                'phase_stats': phase_stats,
                'spin_vs_pace': spinVpace,
                'left_vs_right': leftVright,
                'wicket_analysis': wicket_stats,
                'batting_control': control_stats,
                'scoring_zone': scoring_zone,
                'boundary_analysis': {
                    "details": boundary_stats,
                    "percentage": boundary_percentage
                },
                'opponent_analysis': opponent_analysis  # New field added
            })
        else:
            player_analysis[player_id] = {
                'name': player_name,
                'phase_stats': phase_stats,
                'wicket_analysis': wicket_stats,
                'spin_vs_pace': spinVpace,
                'left_vs_right': leftVright,
                'batting_control': control_stats,
                'scoring_zone': scoring_zone,
                'boundary_analysis': {
                    "details": boundary_stats,
                    "percentage": boundary_percentage
                },
                'opponent_analysis': opponent_analysis  # New field added
            }

    return player_analysis



# Usage example:
def analyze_match(venue_df, h2h_df, batting_df,bowling_df, batting_commentary, bowling_commentary):
    """Analyze complete match data and return results dictionary"""
    team1 = "Gujarat Titans"
    team2 = "Chennai Super Kings"
    team1_ids = teams_collection.find_one({"team_name": team1}, {"players": 1})
    team2_ids = teams_collection.find_one({"team_name": team2}, {"players": 1})
    results = {
        'match_summary': process_match_summary(venue_df, h2h_df),
        'bowler_analysis': generate_bowler_analysis(bowling_df, bowling_commentary,team1_ids['players'],team2_ids['players']),
        'batting_analysis': generate_batting_analysis(batting_df, batting_commentary,team1_ids['players'],team2_ids['players']),
    }
    return results

result= analyze_match(venue_df, h2h_df, batting_df,bowling_df, batting_commentary, bowling_commentary)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_20880\1696384459.py:135: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   commentary_df['bowler_id'] = commentary_df['bowler_id'].astype(int)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_20880\1696384459.py:369: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   commentary_df['batsman_id'] = commentary_df['batsman_id'].astype(int)

# %%
import json
import numpy as np 

def preprocess_for_json(obj):
    """
    Recursively convert non-serializable types in a dictionary or list to standard Python types.
    """
    if isinstance(obj, dict):
        new_dict = {}
        for key, value in obj.items():
            # Ensure all keys are strings
            if not isinstance(key, (str, int, float, bool, type(None))):
                key = str(key)
            new_dict[key] = preprocess_for_json(value)
        return new_dict
    elif isinstance(obj, list):
        return [preprocess_for_json(item) for item in obj]
    elif isinstance(obj, (np.int64, np.int32)):
        return int(obj)
    elif isinstance(obj, (np.float64, np.float32)):
        return float(obj)
    else:
        return obj


# Preprocess the report
preprocessed_result = preprocess_for_json(result)
# Specify the file path
output_file = "match_analysis_claude.json"

# Save the report as a JSON file
with open(output_file, "w") as json_file:
    json.dump(preprocessed_result, json_file, indent=4)

print(f"Match analysis report saved to {output_file}")
# Out:
# Match analysis report saved to match_analysis_claude.json

# %%
import json
from groq import Groq
import os
from dotenv import load_dotenv

# Load environment variables
load_dotenv()

class CricketAnalysisBot:
    def __init__(self, api_key):
        """Initialize the bot with Groq API key"""
        self.client = Groq(api_key=api_key)
        self.summary_file = "player_summaries.json"
        
    def create_player_prompt(self, player_id, batting_data, bowling_data):
        """
        Create a detailed prompt for AI to summarize player statistics.
        
        Args:
        - player_id (int): Player ID
        - batting_data (dict): Batting statistics
        - bowling_data (dict): Bowling statistics
        
        Returns:
        - str: AI prompt
        """
        def convert_to_serializable(data):
            """Recursively convert numpy types in dictionaries to Python native types."""
            if isinstance(data, dict):
                return {key: convert_to_serializable(value) for key, value in data.items()}
            elif isinstance(data, list):
                return [convert_to_serializable(value) for value in data]
            elif isinstance(data, (np.integer, np.int64)):
                return int(data)
            elif isinstance(data, (np.floating, np.float64)):
                return float(data)
            else:
                return data

        prompt = f"Analyze the following cricket statistics for {batting_data.get('name', '') or bowling_data.get('name', '')}:\n\n"

        # Add batting data if available
        if batting_data:
            prompt += "BATTING STATISTICS:\n"
            prompt += f"- Matches:\n{json.dumps(convert_to_serializable(batting_data.get('matches', [])), indent=2)}\n"
            prompt += f"- Total Runs: {batting_data.get('total_runs', 0)}\n"
            prompt += f"- Total Balls: {batting_data.get('total_balls', 0)}\n"
            prompt += f"- Average Runs: {batting_data.get('average_runs', 0)}\n"
            prompt += f"- Overall Strike Rate: {batting_data.get('overall_strike_rate', 0)}\n"
            prompt += f"- Phase Stats:\n{json.dumps(convert_to_serializable(batting_data.get('phase_stats', {})), indent=2)}\n"
            prompt += f"- Wicket Analysis ('shot_played', 'ball_length', 'ball_line','shot_direction'):\n{json.dumps(convert_to_serializable(batting_data.get('wicket_analysis', {})), indent=2)}\n"
            prompt += f"- Batting Control:\n{json.dumps(convert_to_serializable(batting_data.get('batting_control', {})), indent=2)}\n"
            prompt += f"- Scoring Zones:\n{json.dumps(convert_to_serializable(batting_data.get('scoring_zone', {})), indent=2)}\n"
            prompt += f"- Boundary Analysis ('shot_played', 'ball_length', 'ball_line'):\n{json.dumps(convert_to_serializable(batting_data.get('boundary_analysis', {})), indent=2)}\n"
            prompt += f"- Opponent team bolwers head to head Analysis:\n{json.dumps(convert_to_serializable(batting_data.get('opponent_analysis', {})), indent=2)}\n"

        # Add bowling data if available
        if bowling_data:
            prompt += "\nBOWLING STATISTICS:\n"
            prompt += f"- Matches:\n{json.dumps(convert_to_serializable(bowling_data.get('matches', [])), indent=2)}\n"
            prompt += f"- Total Runs Conceded: {bowling_data.get('total_runs', 0)}\n"
            prompt += f"- Total Wickets: {bowling_data.get('total_wickets', 0)}\n"
            prompt += f"- Total Balls Bowled: {bowling_data.get('total_balls', 0)}\n"
            prompt += f"- Runs per Wicket: {bowling_data.get('runs_per_wicket', 0)}\n"
            prompt += f"- Balls per Wicket: {bowling_data.get('balls_per_wicket', 0)}\n"
            prompt += f"- Phase Stats:\n{json.dumps(convert_to_serializable(bowling_data.get('phase_stats', {})), indent=2)}\n"
            prompt += f"- Wicket Analysis ('ball_length', 'ball_line','bowling_variation'):\n{json.dumps(convert_to_serializable(bowling_data.get('wicket_analysis', {})), indent=2)}\n"
            prompt += f"- Boundary Analysis ('ball_length', 'ball_line','bowling_variation'):\n{json.dumps(convert_to_serializable(bowling_data.get('boundary_analysis', {})), indent=2)}\n"
            prompt += f"- Variation Frequency:\n{json.dumps(convert_to_serializable(bowling_data.get('variation_frequency', {})), indent=2)}\n"
            prompt += f"- Opponent team players head to head Analysis:\n{json.dumps(convert_to_serializable(bowling_data.get('opponent_analysis', {})), indent=2)}\n"

        prompt += "\nProvide a detailed, human-readable breakdown of the player's performance based on the following statistics. For each field, convert the data into an easy-to-analyze format. The output should emphasize clarity and readability, making it easy to quickly interpret the player's performance at a glance. Avoid summarizing the data; present the statistics as described in their respective formats."

        
        return prompt



    def get_ai_summary(self, prompt):
        """Get AI-generated summary using Groq"""
        try:
            messages = [
                {
                    "role": "system",
                    "content": '''
                        Provide a detailed, human-readable breakdown of the player's performance based on the following statistics. For each field, convert the data into an easy-to-analyze format as described below:

                        1. Matches: Summarize each match's performance in the format "Runs(Balls) SR: StrikeRate" (e.g., 23(10) SR: 230, 40(20) SR: 200).
                        2. batting Phase Stats: Summarize runs, balls, and strike rates for each phase in the format "Runs(Balls) SR: StrikeRate" for Powerplay, Middle Overs, and Death Overs.
                        3. Total Batting Statistics: Provide the player's total runs, balls faced, average runs, and overall strike rate in clear terms.
                        4. batsman's Wicket Analysis: Summarize dismissal patterns in the proper statistical format .
                        5. batsman's Boundary Analysis: List boundary details in the proper statistical format and include the boundary percentage that batsman scores.
                        8. Shot selection: Summarize the frequency of shot_played in the format "shot pyed by batsmen: Count" (e.g., drive: 12, cut: 8).
                        6. Bowling Matches: Summarize each match's bowling performance in the format "Runs(Overs) Econ: EconomyRate Wkts: Wickets" (e.g., 24(4) Econ: 6.0 Wkts: 2).
                        7. Bowling Phase Stats: Summarize runs, balls, economy, and wickets for each phase (Powerplay, Middle Overs, Death Overs) in a human-readable format.
                        4. bowler's Analysis: Summarize dismissal patterns in the proper statistical format .
                        5. bowler's Boundary Analysis: List boundary details in the proper statistical format and include the boundary percentage that bowler conceed.
                        8. Bowling Variations: Summarize the frequency of bowling variations in the format "Variation: Count" (e.g., Yorker: 12, Slower: 8).
                        9. Overall Bowling Statistics: Provide total runs conceded, total balls bowled, total wickets, runs per wicket, and balls per wicket in a concise format.

                        The output should emphasize clarity and readability, making it easy to quickly interpret the player's performance at a glance. Avoid summarizing the data; present the statistics as described in their respective formats.
                        generate in large and detailed manner.
                    '''
                },
                {
                    "role": "user",
                    "content": f"Context: {prompt}"
                }
            ]
            
            response = self.client.chat.completions.create(
                model='llama-3.1-8b-instant',
                messages=messages,
                temperature=0.2,
                max_tokens=1500
            )
            
            return response.choices[0].message.content
            
        except Exception as e:
            return f"Error generating summary: {str(e)}"
    
    def save_summary(self, player_id, player_name, summary):
        """Save or update player summary in JSON file"""
        try:
            # Load existing summaries
            if os.path.exists(self.summary_file):
                with open(self.summary_file, 'r') as f:
                    summaries = json.load(f)
            else:
                summaries = {}
            
            # Update or add new summary
            summaries[player_id] = {
                "name": player_name,
                "summary": summary
            }
            
            # Save updated summaries
            with open(self.summary_file, 'w') as f:
                json.dump(summaries, f, indent=4)
                
        except Exception as e:
            print(f"Error saving summary: {str(e)}")

    def analyze_players(self, batting_analysis, bowling_analysis):
        """Analyze all players in the provided data"""
        # Get all unique player IDs
        player_ids = set(list(batting_analysis.keys()) + list(bowling_analysis.keys()))
        
        for player_id in player_ids:
            batting_data = batting_analysis.get(player_id, {})
            bowling_data = bowling_analysis.get(player_id, {})
            
            # Skip if no data available
            if not batting_data and not bowling_data:
                continue
            
            # Get player name from e  ither batting or bowling data
            player_name = batting_data.get('name') or bowling_data.get('name')
            
            # Create prompt and get AI summary
            prompt = self.create_player_prompt(player_id, batting_data, bowling_data)
            summary = self.get_ai_summary(prompt)
            
            # Save the summary
            self.save_summary(player_id, player_name, summary)
            print(f"Processed analysis for {player_name}")
        


def main():
    
    # Initialize and run the bot
    bot = CricketAnalysisBot(api_key=os.getenv("GROQ_API_KEY"))
    bot.analyze_players(result['batting_analysis'], result['bowler_analysis'])

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 178
#     175     bot.analyze_players(result['batting_analysis'], result['bowler_analysis'])
#     177 if __name__ == "__main__":
# --> 178     main()
#
# Cell In[7], line 175, in main()
#     171 def main():
#     172
#     173     # Initialize and run the bot
#     174     bot = CricketAnalysisBot(api_key=os.getenv("GROQ_API_KEY"))
# --> 175     bot.analyze_players(result['batting_analysis'], result['bowler_analysis'])
#
# Cell In[7], line 163, in CricketAnalysisBot.analyze_players(self, batting_analysis, bowling_analysis)
#     160 player_name = batting_data.get('name') or bowling_data.get('name')
#     162 # Create prompt and get AI summary
# --> 163 prompt = self.create_player_prompt(player_id, batting_data, bowling_data)
#     164 summary = self.get_ai_summary(prompt)
#     166 # Save the summary
#
# Cell In[7], line 45, in CricketAnalysisBot.create_player_prompt(self, player_id, batting_data, bowling_data)
#      43 if batting_data:
#      44     prompt += "BATTING STATISTICS:\n"
# ---> 45     prompt += f"- Matches:\n{json.dumps(convert_to_serializable(batting_data.get('matches', [])), indent=2)}\n"
#      46     prompt += f"- Total Runs: {batting_data.get('total_runs', 0)}\n"
#      47     prompt += f"- Total Balls: {batting_data.get('total_balls', 0)}\n"
#
# Cell In[7], line 32, in CricketAnalysisBot.create_player_prompt.<locals>.convert_to_serializable(data)
#      30     return {key: convert_to_serializable(value) for key, value in data.items()}
#      31 elif isinstance(data, list):
# ---> 32     return [convert_to_serializable(value) for value in data]
#      33 elif isinstance(data, (np.integer, np.int64)):
#      34     return int(data)
#
# Cell In[7], line 30, in CricketAnalysisBot.create_player_prompt.<locals>.convert_to_serializable(data)
#      28 """Recursively convert numpy types in dictionaries to Python native types."""
#      29 if isinstance(data, dict):
# ---> 30     return {key: convert_to_serializable(value) for key, value in data.items()}
#      31 elif isinstance(data, list):
#      32     return [convert_to_serializable(value) for value in data]
#
# Cell In[7], line 33, in CricketAnalysisBot.create_player_prompt.<locals>.convert_to_serializable(data)
#      31 elif isinstance(data, list):
#      32     return [convert_to_serializable(value) for value in data]
# ---> 33 elif isinstance(data, (np.integer, np.int64)):
#      34     return int(data)
#      35 elif isinstance(data, (np.floating, np.float64)):
#
# NameError: name 'np' is not defined

# %%
import json

# Specify the file name where summaries are stored
summary_file = "player_summaries.json"

def load_summaries(summary_file):
    """Load player summaries from the JSON file."""
    if os.path.exists(summary_file):
        with open(summary_file, 'r') as f:
            summaries = json.load(f)
            return summaries
    else:
        print(f"Summary file '{summary_file}' not found.")
        return {}

# Load the summaries
summaries = load_summaries(summary_file)

# Example: Display the summaries
for player_id, player_summary in summaries.items():
    print(f"Player ID: {player_id}")
    print(f"Name: {player_summary['name']}")
    print(f"Summary: {player_summary['summary']}")
    print("-" * 50)
# Out:
# Player ID: 13184
# Name: Mukesh Choudhary
# Summary: **Mukesh Choudhary's Performance Breakdown**
#
# **Batting Statistics**
#
# ### Matches
#
# * Match 1: 6(9) SR: 66.67
# * Match 2: 3(5) SR: 60.0
# * Match 3: 4(4) SR: 100.0
#
# ### Total Batting Statistics
#
# * Total Runs: 13
# * Total Balls: 18
# * Average Runs: 4.33
# * Overall Strike Rate: 72.22
#
# ### Batting Phase Stats
#
# * **Powerplay**: 0(0) SR: 0
# * **Middle**: 4(4) SR: 100.0
# * **Death**: 2(2) SR: 100.0
#
# ### Wicket Analysis
#
# * No wickets taken, no data available
#
# ### Batting Control
#
# * In-control: 4
# * No-control: 2
#
# ### Scoring Zones
#
# * Mid-wicket: 1
# * Keeper: 1
# * Blocked: 1
# * Point: 1
# * Long-on: 1
#
# ### Boundary Analysis
#
# * Boundary percentage: 16.67%
#
# ### Shot Selection
#
# * No shot selection data available
#
# **Bowling Statistics**
#
# ### Matches
#
# * Match 1: 48(4.0) Econ: 12.0 Wkts: 2
# * Match 2: 33(4.0) Econ: 8.2 Wkts: 3
# * Match 3: 21(4.0) Econ: 5.2 Wkts: 3
# * Match 4: 33(4.0) Econ: 8.2 Wkts: 4
# * Match 5: 39(3.0) Econ: 13.0 Wkts: 1
# * Match 6: 20(3.0) Econ: 6.7 Wkts: 2
# * Match 7: 41(4.0) Econ: 10.2 Wkts: 0
# * Match 8: 28(3.0) Econ: 9.3 Wkts: 0
# * Match 9: 23(4.0) Econ: 5.8 Wkts: 3
# * Match 10: 22(3.0) Econ: 7.3 Wkts: 2
#
# ### Total Bowling Statistics
#
# * Total Runs Conceded: 308
# * Total Wickets: 20
# * Total Balls Bowled: 216
# * Runs per Wicket: 15.4
# * Balls per Wicket: 10.8
#
# ### Bowling Phase Stats
#
# * **Powerplay**: 291(208) Econ: 8.39 Wkts: 7
# 	+ Runs per Wicket: 41.57
# 	+ Balls per Wicket: 29.71
# * **Middle**: 58(46) Econ: 7.57 Wkts: 3
# 	+ Runs per Wicket: 19.33
# 	+ Balls per Wicket: 15.33
# * **Death**: 90(44) Econ: 12.27 Wkts: 0
# 	+ Runs per Wicket: Infinity
# 	+ Balls per Wicket: Infinity
#
# ### Wicket Analysis
#
# * No wicket analysis data available
#
# ### Boundary Analysis
#
# * Boundary percentage: 23.49%
#
# ### Bowling Variations
#
# * Normal: 231
# * Slower: 12
# * In-swing: 12
# * Quick: 11
# * Out-swing: 11
# * Yorker: 10
# * Swing: 8
# * Bouncer: 1
# * Seam-in: 1
# * Seam-away: 1
# --------------------------------------------------
# Player ID: 14596
# Name: Manav Suthar
# Summary: **Manav Suthar's Performance Breakdown**
#
# **BATTING STATISTICS**
#
# ### Matches
#
# 1. 11(4) SR: 275.0
# 2. 1(2) SR: 50.0
# 3. 0(1) SR: 0.0
# 4. 0(0) SR: 0.0
# 5. 0(0) SR: 0.0
#
# ### Total Batting Statistics
#
# - Total Runs: 12
# - Total Balls: 7
# - Average Runs: 2.4
# - Overall Strike Rate: 171.42857142857142
#
# ### Batting Phase Stats
#
# No data available for Powerplay, Middle Overs, and Death Overs.
#
# ### Wicket Analysis
#
# No data available for shot_played, ball_length, ball_line, and shot_direction.
#
# ### Boundary Analysis
#
# No data available for shot_played, ball_length, and ball_line.
#
# ### Shot Selection
#
# No data available for shot_played.
#
# ### BOWLING STATISTICS
#
# ### Matches
#
# 1. 20(2) Econ: 10.0 Wkts: 0
# 2. 22(1.4) Econ: 13.2 Wkts: 0
# 3. 17(4) Econ: 4.2 Wkts: 2
# 4. 25(4) Econ: 6.2 Wkts: 0
# 5. 10(2) Econ: 5.0 Wkts: 2
# 6. 18(2) Econ: 9.0 Wkts: 0
# 7. 12(4) Econ: 3.0 Wkts: 2
#
# ### Total Bowling Statistics
#
# - Total Runs Conceded: 124
# - Total Wickets: 6
# - Total Balls Bowled: 118
# - Runs per Wicket: 20.666666666666668
# - Balls per Wicket: 19.666666666666668
#
# ### Bowling Phase Stats
#
# No data available for Powerplay, Middle Overs, and Death Overs.
#
# ### Wicket Analysis
#
# No data available for ball_length, ball_line, and bowling_variation.
#
# ### Boundary Analysis
#
# No data available for ball_length, ball_line, and bowling_variation.
#
# ### Bowling Variations
#
# No data available for bowling_variation.
#
# ### Variation Frequency
#
# No data available for bowling_variation.
# --------------------------------------------------
# Player ID: 14598
# Name: Anshul Kamboj
# Summary: **Anshul Kamboj's Performance Breakdown**
#
# **Batting Performance**
#
# ### Matches
#
# 1. 1(1) SR: 100
# 2. 8(5) SR: 160
# 3. 17(11) SR: 154.55
#
# ### Total Batting Statistics
#
# - Total Runs: 26
# - Total Balls: 17
# - Average Runs: 8.67
# - Overall Strike Rate: 152.94
#
# ### Batting Phase Stats
#
# - Powerplay: No data available
# - Middle Overs: No data available
# - Death Overs: No data available
#
# ### Wicket Analysis
#
# No data available
#
# ### Boundary Analysis
#
# No data available
#
# ### Shot Selection
#
# No data available
#
# ### Bowling Performance
#
# ### Matches
#
# 1. 15(2.3) Econ: 6.0 Wkts: 2
# 2. 26(4.0) Econ: 6.5 Wkts: 3
# 3. 37(4.0) Econ: 9.2 Wkts: 0
# 4. 16(3.0) Econ: 5.3 Wkts: 1
# 5. 30(3.2) Econ: 9.0 Wkts: 1
# 6. 8(2.0) Econ: 4.0 Wkts: 1
# 7. 15(3.0) Econ: 5.0 Wkts: 1
#
# ### Total Bowling Statistics
#
# - Total Runs Conceded: 147
# - Total Wickets: 9
# - Total Balls Bowled: 131
# - Runs per Wicket: 16.33
# - Balls per Wicket: 14.56
#
# ### Bowling Phase Stats
#
# - Powerplay: No data available
# - Middle Overs: No data available
# - Death Overs: No data available
#
# ### Wicket Analysis
#
# No data available
#
# ### Boundary Analysis
#
# No data available
#
# ### Bowling Variations
#
# No data available
#
# ### Variation Frequency
#
# No data available
# --------------------------------------------------
# Player ID: 13320
# Name: Gerald Coetzee
# Summary: **Gerald Coetzee's Performance Breakdown**
#
# **BATTING STATISTICS**
#
# ### Matches
#
# - Match 1: 0(1) SR: 0.0
# - Match 2: 0(0) SR: 0.0
# - Match 3: 4(9) SR: 44.44
# - Match 4: 1(3) SR: 33.33
#
# ### Total Batting Statistics
#
# - Total Runs: 5
# - Total Balls: 13
# - Average Runs: 1.25
# - Overall Strike Rate: 38.46
#
# ### Batting Phase Stats
#
# - **Powerplay**: 0(0) SR: 0
# - **Middle**: 5(6) SR: 83.33
# - **Death**: 1(7) SR: 14.29
#
# ### Batting Control
#
# - No Control: 7
# - In-Control: 6
#
# ### Scoring Zones
#
# - Cover: 3
# - Keeper: 3
# - Square: 3
# - Long-On: 2
# - Point: 1
# - Mid-Wicket: 1
#
# ### Boundary Analysis
#
# - No boundaries scored
# - Boundary Percentage: 0.0%
#
# ### Shot Selection
#
# - Shot Played: Count
#   - Drive: 0
#   - Cut: 0
#   - Pull: 0
#   - Sweep: 0
#   - Flick: 0
#   - Reverse Sweep: 0
#   - Hook: 0
#   - Other: 0
#
# **BOWLING STATISTICS**
#
# ### Matches
#
# - Match 1: 25(2.0) Econ: 12.5 Wkts: 0
# - Match 2: 32(4.0) Econ: 8.0 Wkts: 3
# - Match 3: 35(4.0) Econ: 8.8 Wkts: 1
# - Match 4: 42(4.0) Econ: 10.5 Wkts: 1
# - Match 5: 34(4.0) Econ: 8.5 Wkts: 4
# - Match 6: 36(2.3) Econ: 14.4 Wkts: 0
# - Match 7: 57(4.0) Econ: 14.2 Wkts: 1
# - Match 8: 27(4.0) Econ: 6.8 Wkts: 2
#
# ### Total Bowling Statistics
#
# - Total Runs Conceded: 288
# - Total Wickets: 12
# - Total Balls Bowled: 171
# - Runs per Wicket: 24.0
# - Balls per Wicket: 14.25
#
# ### Bowling Phase Stats
#
# - **Powerplay**: 86(60) Wkts: 3 Runs per Wicket: 28.67 Balls per Wicket: 20.0 Econ: 8.6
# - **Middle**: 145(86) Wkts: 2 Runs per Wicket: 72.5 Balls per Wicket: 43.0 Econ: 10.11
# - **Death**: 49(37) Wkts: 4 Runs per Wicket: 12.25 Balls per Wicket: 9.25 Econ: 7.95
#
# ### Wicket Analysis
#
# - ('short', 'leg-stump', 'normal'): 2
# - ('short', 'outside-off', 'normal'): 2
#
# ### Boundary Analysis
#
# - ('full', 'outside-off', 'normal'): 3
# - ('short', 'leg-stump', 'normal'): 3
# - ('short', 'outside-off', 'normal'): 3
# - Boundary Percentage: 23.50%
#
# ### Bowling Variations
#
# - Normal: 144
# - Yorker: 19
# - Slower: 10
# - Quick: 6
# - Bouncer: 3
# - Seam-Away: 1
# --------------------------------------------------
# Player ID: 265
# Name: MS Dhoni
# Summary: **MS Dhoni's Batting Performance Breakdown**
#
# ### Matches
#
# Here are the details of each match played by MS Dhoni:
#
# 1. 4(1) SR: 400
# 2. 28(9) SR: 311.11
# 3. 20(4) SR: 500
# 4. 1(3) SR: 33.33
# 5. 1(2) SR: 50
# 6. 37(16) SR: 231.25
# 7. 0(0) SR: 0
# 8. 0(1) SR: 0
# 9. 1(2) SR: 50
#
# ### Total Batting Statistics
#
# * Total Runs: 92
# * Total Balls: 38
# * Average Runs: 10.22
# * Overall Strike Rate: 242.11
#
# ### Batting Phase Stats
#
# Here are the details of MS Dhoni's batting performance in different phases:
#
# * **Powerplay**: 6(7) SR: 85.71
# * **Middle Overs**: 78(102) SR: 76.47
# * **Death Overs**: 360(193) SR: 186.53
#
# ### Wicket Analysis
#
# Unfortunately, there is no data available for MS Dhoni's wicket analysis.
#
# ### Batting Control
#
# Here are the details of MS Dhoni's batting control:
#
# * In-control: 244
# * No-control: 53
# * Beaten: 5
#
# ### Scoring Zones
#
# Here are the details of MS Dhoni's scoring zones:
#
# * **Cover**: 46
# * **Blocked**: 38
# * **Mid-wicket**: 35
# * **Square**: 30
# * **Point**: 30
# * **Long-on**: 25
# * **Keeper**: 24
# * **Long-off**: 14
# * **Fine-leg**: 12
# * **Third-man**: 10
#
# ### Boundary Analysis
#
# Here are the details of MS Dhoni's boundary analysis:
#
# * **Boundary Details**: ('pull', 'short', 'leg-stump'): 3
# * **Boundary Percentage**: 20.53%
#
# ### Shot Selection
#
# Unfortunately, there is no data available for MS Dhoni's shot selection.
#
# ### Bowling Statistics
#
# Unfortunately, there is no data available for MS Dhoni's bowling statistics.
#
# ### Overall Bowling Statistics
#
# Unfortunately, there is no data available for MS Dhoni's overall bowling statistics.
#
# ### Bowling Variations
#
# Unfortunately, there is no data available for MS Dhoni's bowling variations.
#
# ### Bowler's Analysis
#
# Unfortunately, there is no data available for MS Dhoni's bowler's analysis.
#
# ### Bowler's Boundary Analysis
#
# Unfortunately, there is no data available for MS Dhoni's bowler's boundary analysis.
# --------------------------------------------------
# Player ID: 8204
# Name: Vijay Shankar
# Summary: **Vijay Shankar's Batting Performance**
#
# ### Matches
#
# 1. 0(2) SR: 0.0
# 2. 3(6) SR: 50.0
# 3. 42(22) SR: 190.91
# 4. 38(17) SR: 223.53
# 5. 16(10) SR: 160.0
# 6. 17(17) SR: 100.0
# 7. 8(10) SR: 80.0
# 8. 14(11) SR: 127.27
# 9. 12(12) SR: 100.0
#
# ### Total Batting Statistics
#
# - Total Runs: 150
# - Total Balls: 107
# - Average Runs: 16.67
# - Overall Strike Rate: 140.19
#
# ### Batting Phase Stats
#
# - **Powerplay**: 80(77) SR: 103.90
# - **Middle**: 209(170) SR: 122.94
# - **Death**: 122(55) SR: 221.82
#
# ### Wicket Analysis
#
# - ('pushed slightly', 'short', 'outside-off', 'point'): 2
#
# ### Batting Control
#
# - In-control: 245
# - No-control: 53
# - Beaten: 4
#
# ### Scoring Zones
#
# - Mid-wicket: 57
# - Cover: 41
# - Point: 30
# - Square: 30
# - Long-on: 27
# - Blocked: 25
# - Keeper: 24
# - Long-off: 21
# - Fine-leg: 13
# - Third-man: 5
#
# ### Boundary Analysis
#
# - ('flick', 'full', 'leg-stump'): 2
# - Boundary Percentage: 17.55%
#
# **Vijay Shankar's Bowling Performance**
#
# ### Matches
#
# 1. 18(1.0) Econ: 18.0 Wkts: 0
# 2. 14(4.0) Econ: 3.5 Wkts: 1
# 3. 19(2.0) Econ: 9.5 Wkts: 2
#
# ### Total Bowling Statistics
#
# - Total Runs Conceded: 51
# - Total Wickets: 3
# - Total Balls Bowled: 42
# - Runs per Wicket: 17.0
# - Balls per Wicket: 14.0
#
# ### Bowling Phase Stats
#
# - **Powerplay**: 0(0) Econ: 0 Wkts: 0
# - **Middle**: 13(7) Econ: 11.14 Wkts: 1
# - **Death**: 1(3) Econ: 2.0 Wkts: 0
#
# ### Wicket Analysis
#
# - No data available
#
# ### Boundary Analysis
#
# - Boundary Percentage: 30.0%
#
# ### Variation Frequency
#
# - Normal: 9
# - Slower: 1
# --------------------------------------------------
# Player ID: 9746
# Name: Shreyas Gopal
# Summary: **Shreyas Gopal's Performance Breakdown**
#
# **BATTING STATISTICS**
#
# ### Matches
#
# 1. 1(2) SR: 50.0
# 2. 18(16) SR: 112.5
# 3. 0(0) SR: 0.0
# 4. 36(22) SR: 163.64
# 5. 0(0) SR: 0.0
# 6. 0(1) SR: 0.0
# 7. 0(0) SR: 0.0
#
# ### Total Batting Statistics
#
# - Total Runs: 55
# - Total Balls: 41
# - Average Runs: 7.86
# - Overall Strike Rate: 134.15
#
# ### Batting Phase Stats
#
# - **Powerplay**: 0(0) SR: 0
# - **Middle**: 0(0) SR: 0
# - **Death**: 10(7) SR: 142.86
#
# ### Wicket Analysis
#
# No wicket analysis data available.
#
# ### Batting Control
#
# - In-Control: 5
# - No-Control: 2
#
# ### Scoring Zones
#
# - Keeper: 2
# - Third-Man: 1
# - Mid-Wicket: 1
# - Cover: 1
# - Long-Off: 1
#
# ### Boundary Analysis
#
# - Percentage: 28.57%
#
# **BOWLING STATISTICS**
#
# ### Matches
#
# 1. 41(3.0) Econ: 13.7 Wkts: 0
# 2. 19(4.0) Econ: 4.8 Wkts: 4
# 3. 14(4.0) Econ: 3.5 Wkts: 1
# 4. 13(4.0) Econ: 3.2 Wkts: 5
# 5. 23(4.0) Econ: 5.8 Wkts: 1
# 6. 26(4.0) Econ: 6.5 Wkts: 1
# 7. 30(4.0) Econ: 7.5 Wkts: 2
# 8. 26(2.0) Econ: 13.0 Wkts: 1
# 9. 9(1.0) Econ: 9.0 Wkts: 1
# 10. 32(4.0) Econ: 8.0 Wkts: 1
#
# ### Total Bowling Statistics
#
# - Total Runs Conceded: 233
# - Total Wickets: 17
# - Total Balls Bowled: 204
# - Runs per Wicket: 13.71
# - Balls per Wicket: 12.0
#
# ### Bowling Phase Stats
#
# - **Powerplay**: 0(0) Econ: 0 Wkts: 0
# - **Middle**: 101(60) Econ: 10.1 Wkts: 2
# - **Death**: 0(0) Econ: 0 Wkts: 0
#
# ### Wicket Analysis
#
# No wicket analysis data available.
#
# ### Boundary Analysis
#
# - Percentage: 18.33%
#
# ### Variation Frequency
#
# - Normal: 52
# - Slower: 3
# - Googly: 3
# - Quick: 2
# --------------------------------------------------
# Player ID: 11808
# Name: Shubman Gill
# Summary: **Shubman Gill's Batting Performance**
#
# ### Matches
#
# Here's a breakdown of each match's performance:
#
# 1. 16(19) SR: 84.21
# 2. 6(5) SR: 120.0
# 3. 35(29) SR: 120.69
# 4. 8(6) SR: 133.33
# 5. 72(44) SR: 163.64
# 6. 19(21) SR: 90.48
# 7. 89(48) SR: 185.42
# 8. 36(28) SR: 128.57
# 9. 8(5) SR: 160.0
# 10. 31(22) SR: 140.91
#
# ### Total Batting Statistics
#
# - **Total Runs:** 320
# - **Total Balls:** 227
# - **Average Runs:** 32.0
# - **Overall Strike Rate:** 140.97
#
# ### Batting Phase Stats
#
# Here's a breakdown of Shubman Gill's performance in different phases:
#
# - **Powerplay:**
#   - **Runs:** 749
#   - **Balls:** 556
#   - **Strike Rate:** 134.71
# - **Middle:**
#   - **Runs:** 848
#   - **Balls:** 545
#   - **Strike Rate:** 155.60
# - **Death:**
#   - **Runs:** 144
#   - **Balls:** 83
#   - **Strike Rate:** 173.49
#
# ### Wicket Analysis
#
# Here's a breakdown of the shots played by Shubman Gill that resulted in wickets:
#
# - **('drive', 'full', 'outside-off', 'cover')**: 2
#
# ### Batting Control
#
# Here's a breakdown of Shubman Gill's batting control:
#
# - **In-Control:** 1054
# - **No-Control:** 114
# - **Beaten:** 16
#
# ### Scoring Zones
#
# Here's a breakdown of the zones where Shubman Gill scored runs:
#
# - **Mid-wicket:** 255
# - **Cover:** 210
# - **Square:** 148
# - **Long-off:** 100
# - **Point:** 99
# - **Long-on:** 80
# - **Blocked:** 68
# - **Keeper:** 48
# - **Fine-leg:** 39
# - **Third-man:** 12
#
# ### Boundary Analysis
#
# Here's a breakdown of the shots played by Shubman Gill that resulted in boundaries:
#
# - **('cut', 'back of a length', 'outside-off')**: 4
# - **('cut', 'full', 'outside-off')**: 3
# - **('cut', 'short', 'outside-off')**: 13
# - **('cut', 'short', 'wide')**: 4
# - **('drive', 'full', 'outside-off')**: 6
# - **('flick', 'full', 'leg-stump')**: 7
# - **('pull', 'short', 'leg-stump')**: 7
# - **('pull', 'short', 'wide')**: 3
# - **('sweep', 'full', 'leg-stump')**: 5
# - **Boundary Percentage:** 19.17%
# --------------------------------------------------
# Player ID: 15779
# Name: Kumar Kushagra
# Summary: **Kumar Kushagra's Batting Performance**
#
# **Match-by-Match Breakdown**
#
# 1. **Match 1:** 9(12) SR: 75.0
# 2. **Match 2:** 55(30) SR: 183.33
# 3. **Match 3:** 5(6) SR: 83.33
# 4. **Match 4:** 2(2) SR: 100.0
# 5. **Match 5:** 37(21) SR: 176.19
# 6. **Match 6:** 3(4) SR: 75.0
# 7. **Match 7:** 0(0) SR: 0.0
#
# **Total Batting Statistics**
#
# * **Total Runs:** 111
# * **Total Balls:** 75
# * **Average Runs:** 15.857142857142858
# * **Overall Strike Rate:** 148.0
#
# **Batting Phase Stats**
#
# * **Powerplay:** 0(0) SR: 0
# * **Middle:** 0(0) SR: 0
# * **Death:** 0(1) SR: 0.0
#
# **Wicket Analysis**
#
# * No wickets taken or dismissed
#
# **Batting Control**
#
# * **No-Control:** 1
#
# **Scoring Zones**
#
# * **Point:** 1
#
# **Boundary Analysis**
#
# * **Boundary Percentage:** 0.0%
# * No boundaries scored
#
# **Shot Selection**
#
# * No shot selection data available
#
# **Batting Summary**
#
# Kumar Kushagra has played 7 matches, scoring a total of 111 runs at an average of 15.857142857142858 and an overall strike rate of 148.0. He has not taken any wickets or been dismissed in the matches played. His batting control has been inconsistent, with 1 instance of no-control. He has scored 1 point in the scoring zones.
# --------------------------------------------------
# Player ID: 11813
# Name: Ruturaj Gaikwad
# Summary: **Ruturaj Gaikwad's Performance Breakdown**
#
# **Matches:**
#
# 1. 97(48) SR: 202.08
# 2. 2(1) SR: 200.0
# 3. 4(6) SR: 66.67
# 4. 19(10) SR: 190.0
# 5. 1(3) SR: 33.33
# 6. 108(60) SR: 180.0
# 7. 17(13) SR: 130.77
# 8. 69(40) SR: 172.5
# 9. 67(58) SR: 115.52
# 10. 26(21) SR: 123.81
#
# **Total Batting Statistics:**
#
# - Total Runs: 410
# - Total Balls: 260
# - Average Runs: 41.0
# - Overall Strike Rate: 157.69
#
# **Batting Phase Stats:**
#
# - **Powerplay:** 726(538) SR: 134.94
# - **Middle Overs:** 564(391) SR: 144.25
# - **Death Overs:** 48(31) SR: 154.84
#
# **Wicket Analysis:**
#
# - ('pushed slightly', 'short', 'outside-off', 'point'): 2
#
# **Boundary Analysis:**
#
# - ('cut', 'short', 'outside-off'): 4
# - ('drive', 'full', 'outside-off'): 12
# - ('drive', 'full', 'wide'): 3
# - ('pull', 'short', 'leg-stump'): 5
# - ('pull', 'short', 'outside-off'): 4
# - Boundary Percentage: 18.44%
#
# **Shot Selection:**
#
# - drive: 12
# - cut: 4
# - pull: 9
# - other shots: 375
#
# **Scoring Zones:**
#
# - mid-wicket: 130
# - cover: 123
# - square: 121
# - point: 120
# - long-off: 79
# - blocked: 78
# - keeper: 67
# - long-on: 57
# - third-man: 31
# - fine-leg: 29
#
# **Batting Control:**
#
# - in-control: 828
# - no-control: 121
# - beaten: 11
# --------------------------------------------------
# Player ID: 11177
# Name: Rachin Ravindra
# Summary: **Rachin Ravindra's Performance Breakdown**
#
# **BATTING STATISTICS**
#
# ### Matches
#
# 1. 0(1) SR: 0.0
# 2. 21(16) SR: 131.25
# 3. 15(8) SR: 187.5
# 4. 12(9) SR: 133.33
# 5. 2(12) SR: 16.67
# 6. 46(20) SR: 230.0
# 7. 37(15) SR: 246.67
#
# ### Total Batting Statistics
#
# - Total Runs: 133
# - Total Balls: 81
# - Average Runs: 19.0
# - Overall Strike Rate: 164.20
#
# ### Batting Phase Stats
#
# - **Powerplay**: 126(81) SR: 155.56
# - **Middle**: 15(7) SR: 214.29
# - **Death**: 0(0) SR: 0
#
# ### Wicket Analysis
#
# No wicket analysis data available.
#
# ### Batting Control
#
# - In-Control: 69
# - No-Control: 18
# - Beaten: 1
#
# ### Scoring Zones
#
# - Mid-Wicket: 12
# - Long-Off: 11
# - Cover: 10
# - Blocked: 10
# - Keeper: 9
# - Square: 8
# - Long-On: 7
# - Point: 5
# - Fine-Leg: 4
#
# ### Boundary Analysis
#
# - Percentage: 28.41%
#
# ### Shot Selection
#
# No shot selection data available.
#
# ### Boundary Analysis Details
#
# No boundary analysis details available.
#
# **BOWLING STATISTICS**
#
# ### Matches
#
# 1. 4(1.0) Econ: 4.0 Wkts: 0
# 2. 3(1.0) Econ: 3.0 Wkts: 0
#
# ### Total Bowling Statistics
#
# - Total Runs Conceded: 7
# - Total Wickets: 0
# - Total Balls Bowled: 12
# - Runs per Wicket: Infinity
# - Balls per Wicket: Infinity
#
# ### Bowling Phase Stats
#
# - **Powerplay**: 0(0) Econ: 0 Wkts: 0
# - **Middle**: 7(12) Econ: 3.5 Wkts: 0
# - **Death**: 0(0) Econ: 0 Wkts: 0
#
# ### Wicket Analysis
#
# No wicket analysis data available.
#
# ### Boundary Analysis
#
# - Percentage: 0.0%
#
# ### Variation Frequency
#
# - Normal: 11
# - Slower: 1
#
# ### Bowler's Analysis
#
# No bowler's analysis data available.
# --------------------------------------------------
# Player ID: 13866
# Name: Sai Sudharsan
# Summary: **Sai Sudharsan's Batting Performance**
#
# **Match-by-Match Breakdown**
#
# 1. 9(9) SR: 100
# 2. 84(49) SR: 171.43
# 3. 12(9) SR: 133.33
# 4. 35(29) SR: 120.69
# 5. 31(23) SR: 134.78
# 6. 33(19) SR: 173.68
# 7. 45(39) SR: 115.38
# 8. 96(47) SR: 204.26
# 9. 43(31) SR: 138.71
# 10. 47(36) SR: 130.56
#
# **Total Batting Statistics**
#
# - Total Runs: 435
# - Total Balls: 291
# - Average Runs: 43.5
# - Overall Strike Rate: 149.48
#
# **Batting Phase Stats**
#
# - **Powerplay**: 241(212) SR: 113.68
# - **Middle Overs**: 581(439) SR: 132.35
# - **Death Overs**: 117(53) SR: 220.75
#
# **Wicket Analysis**
#
# No data available.
#
# **Batting Control**
#
# - In-Control: 603
# - No-Control: 88
# - Beaten: 13
#
# **Scoring Zones**
#
# - Mid-wicket: 141
# - Square: 108
# - Cover: 108
# - Point: 56
# - Blocked: 45
# - Long-on: 43
# - Keeper: 43
# - Long-off: 40
# - Fine-leg: 26
# - Third-man: 23
#
# **Boundary Analysis**
#
# - **Boundary Details**
#   - Drive (full, outside-off): 3
#   - Pull (short, outside-off): 4
#   - Pushed slightly (short, outside-off): 3
#   - Sweep (full, leg-stump): 3
# - **Boundary Percentage**: 16.33%
#
# **Shot Selection**
#
# No data available.
#
# ---
#
# **BOWLING STATISTICS**
#
# **Bowling Matches**
#
# No data available.
#
# **Bowling Phase Stats**
#
# No data available.
#
# **Bowling Variations**
#
# No data available.
#
# **Overall Bowling Statistics**
#
# No data available.
#
# ---
#
# **Note:** Since the provided data does not include bowling statistics, the bowling section of the report is empty.
# --------------------------------------------------
# Player ID: 22571
# Name: Shaik Rasheed
# Summary: **Shaik Rasheed's Performance Breakdown**
#
# **Matches Performance**
#
# 1. 18(14) SR: 128.57
# 2. 0(0) SR: 0.0
# 3. 5(13) SR: 38.46
# 4. 21(19) SR: 110.53
# 5. 0(2) SR: 0.0
# 6. 8(8) SR: 100.0
# 7. 4(6) SR: 66.67
#
# **Total Batting Statistics**
#
# - **Total Runs:** 56
# - **Total Balls:** 62
# - **Average Runs:** 8.0
# - **Overall Strike Rate:** 90.32
#
# **Batting Phase Stats**
#
# - **Powerplay:** No data available
# - **Middle Overs:** No data available
# - **Death Overs:** No data available
#
# **Wicket Analysis**
#
# - No data available
#
# **Boundary Analysis**
#
# - No data available
#
# **Shot Selection**
#
# - No data available
#
# **Bowling Statistics**
#
# Unfortunately, the provided data does not contain any bowling statistics for Shaik Rasheed. However, I can provide a general format for how the bowling statistics could be presented if the data were available.
#
# **Bowling Matches Performance**
#
# 1. Runs(Overs) Econ: EconomyRate Wkts: Wickets
# 2. Runs(Overs) Econ: EconomyRate Wkts: Wickets
# 3. Runs(Overs) Econ: EconomyRate Wkts: Wickets
# 4. Runs(Overs) Econ: EconomyRate Wkts: Wickets
# 5. Runs(Overs) Econ: EconomyRate Wkts: Wickets
# 6. Runs(Overs) Econ: EconomyRate Wkts: Wickets
# 7. Runs(Overs) Econ: EconomyRate Wkts: Wickets
#
# **Bowling Phase Stats**
#
# - **Powerplay:** No data available
# - **Middle Overs:** No data available
# - **Death Overs:** No data available
#
# **Bowler's Analysis**
#
# - No data available
#
# **Bowler's Boundary Analysis**
#
# - No data available
#
# **Bowling Variations**
#
# - No data available
#
# **Overall Bowling Statistics**
#
# - **Total Runs Conceded:** No data available
# - **Total Balls Bowled:** No data available
# - **Total Wickets:** No data available
# - **Runs per Wicket:** No data available
# - **Balls per Wicket:** No data available
# --------------------------------------------------
# Player ID: 22576
# Name: Nishant Sindhu
# Summary: **Nishant Sindhu's Performance Breakdown**
#
# **BATTING STATISTICS**
#
# ### Matches
#
# 1. 7(11) SR: 63.64
# 2. 27(28) SR: 96.43
# 3. 57(36) SR: 158.33
# 4. 7(6) SR: 116.67
# 5. 2(8) SR: 25.0
# 6. 100(48) SR: 208.33
# 7. 0(0) SR: 0.0
#
# ### Total Batting Statistics
#
# - **Total Runs:** 200
# - **Total Balls:** 137
# - **Average Runs:** 28.571428571428573
# - **Overall Strike Rate:** 145.98540145985402
#
# ### Batting Phase Stats
#
# No data available for Powerplay, Middle Overs, and Death Overs.
#
# ### Wicket Analysis
#
# No data available for dismissal patterns.
#
# ### Boundary Analysis
#
# No data available for boundary details.
#
# ### Shot Selection
#
# No data available for the frequency of shot played.
#
# ### Scoring Zones
#
# No data available for scoring zones.
#
# ### Batting Control
#
# No data available for batting control.
#
# ### Bowling Statistics
#
# **Matches**
#
# 1. 29(4.0) Econ: 7.2 Wkts: 0
# 2. 20(3.0) Econ: 6.7 Wkts: 0
# 3. 30(4.0) Econ: 7.5 Wkts: 2
# 4. 8(1.0) Econ: 8.0 Wkts: 0
# 5. 10(2.0) Econ: 5.0 Wkts: 0
# 6. 21(4.0) Econ: 5.2 Wkts: 1
#
# ### Total Bowling Statistics
#
# - **Total Runs Conceded:** 118
# - **Total Wickets:** 3
# - **Total Balls Bowled:** 108
# - **Runs per Wicket:** 39.333333333333336
# - **Balls per Wicket:** 36.0
#
# ### Bowling Phase Stats
#
# No data available for Powerplay, Middle Overs, and Death Overs.
#
# ### Wicket Analysis
#
# No data available for dismissal patterns.
#
# ### Boundary Analysis
#
# No data available for boundary details.
#
# ### Variation Frequency
#
# No data available for the frequency of bowling variations.
#
# **Overall Performance**
#
# Nishant Sindhu has shown impressive batting skills, with a high overall strike rate of 145.98540145985402 and an average of 28.571428571428573 runs per match. However, his bowling performance has been inconsistent, with a total of 118 runs conceded and 3 wickets taken in 6 matches.
# --------------------------------------------------
# Player ID: 10420
# Name: Sam Curran
# Summary: **Sam Curran's Performance Breakdown**
#
# **Batting Statistics**
#
# ### Matches
#
# 1. 20(19) SR: 105.26
# 2. 6(7) SR: 85.71
# 3. 6(10) SR: 60.0
# 4. 29(22) SR: 131.82
# 5. 5(8) SR: 62.5
# 6. 0(1) SR: 0.0
# 7. 23(17) SR: 135.29
# 8. 63(47) SR: 134.04
# 9. 21(11) SR: 190.91
#
# ### Total Batting Statistics
#
# - **Total Runs:** 173
# - **Total Balls:** 142
# - **Average Runs:** 17.3
# - **Overall Strike Rate:** 121.83
#
# ### Batting Phase Stats
#
# - **Powerplay:** 54(51) SR: 105.88
# - **Middle:** 244(221) SR: 110.41
# - **Death:** 135(77) SR: 175.32
#
# ### Batting Control
#
# - **In-Control:** 299
# - **No-Control:** 47
# - **Beaten:** 3
#
# ### Scoring Zones
#
# - **Mid-wicket:** 60
# - **Cover:** 54
# - **Long-on:** 41
# - **Long-off:** 32
# - **Keeper:** 29
# - **Point:** 26
# - **Blocked:** 25
# - **Square:** 25
# - **Fine-leg:** 10
# - **Third-man:** 4
#
# ### Boundary Analysis
#
# - **Details:**
#   - ('cut', 'short', 'outside-off'): 4
#   - ('pull', 'short', 'leg-stump'): 3
# - **Percentage:** 14.33%
#
# **Bowling Statistics**
#
# ### Matches
#
# 1. 60(4) Econ: 15.0 Wkts: 1
# 2. 18(2) Econ: 9.0 Wkts: 1
# 3. 41(4) Econ: 10.2 Wkts: 2
# 4. 25(4) Econ: 6.2 Wkts: 2
# 5. 41(4) Econ: 10.2 Wkts: 2
# 6. 18(2) Econ: 9.0 Wkts: 0
# 7. 28(4) Econ: 7.0 Wkts: 3
# 8. 30(3) Econ: 10.0 Wkts: 1
# 9. 10(1) Econ: 10.0 Wkts: 0
# 10. 38(3) Econ: 12.7 Wkts: 1
#
# ### Total Bowling Statistics
#
# - **Total Runs Conceded:** 309
# - **Total Wickets:** 13
# - **Total Balls Bowled:** 186
# - **Runs per Wicket:** 23.77
# - **Balls per Wicket:** 14.31
#
# ### Bowling Phase Stats
#
# - **Powerplay:** 273(197) Econ: 8.31 Wkts: 1
# - **Middle:** 237(139) Econ: 10.23 Wkts: 5
# - **Death:** 243(136) Econ: 10.72 Wkts: 12
#
# ### Wicket Analysis
#
# - **Details:**
#   - ('full', 'outside-off', 'normal'): 2
#
# ### Boundary Analysis
#
# - **Details:**
#   - ('full', 'outside-off', 'normal'): 10
#   - ('full', 'wide', 'normal'): 3
#   - ('short', 'leg-stump', 'normal'): 8
#   - ('short', 'outside-off', 'normal'): 10
# - **Percentage:** 23.73%
#
# ### Variation Frequency
#
# - **Normal:** 329
# - **Slower:** 91
# - **Yorker:** 23
# - **Cutter:** 10
# - **Quick:** 9
# - **Seam-away:** 3
# - **Bouncer:** 2
# - **Out-swing:** 2
# - **Swing:** 2
# - **In-swing:** 1
# --------------------------------------------------
# Player ID: 13748
# Name: Sherfane Rutherford
# Summary: **Sherfane Rutherford's Batting Performance**
#
# ### Matches
#
# - **Match 1:** 5(10) SR: 50
# - **Match 2:** 28(40) SR: 70
# - **Match 3:** 0(0) SR: 0
#
# ### Total Batting Statistics
#
# - **Total Runs:** 33
# - **Total Balls:** 50
# - **Average Runs:** 11.0
# - **Overall Strike Rate:** 66.0
#
# ### Batting Phase Stats
#
# - **Powerplay:** 8(12) SR: 66.67
# - **Middle Overs:** 32(40) SR: 80
# - **Death Overs:** 2(4) SR: 50
#
# ### Wicket Analysis
#
# - No wicket data available
#
# ### Batting Control
#
# - **In-Control:** 44
# - **No-Control:** 11
# - **Beaten:** 1
#
# ### Scoring Zones
#
# - **Blocked:** 11
# - **Mid-wicket:** 11
# - **Keeper:** 10
# - **Long-on:** 3
# - **Point:** 3
# - **Square:** 2
# - **Cover:** 2
#
# ### Boundary Analysis
#
# - **Boundary Percentage:** 7.14%
# - **Boundary Details:** No data available
#
# ### Shot Selection
#
# - **Drive:** 0
# - **Cut:** 0
# - **Pull:** 0
# - **Flick:** 0
# - **Sweep:** 0
# - **Other:** 0
#
# ### Bowling Statistics (Not Available for Sherfane Rutherford)
#
# Since the provided data does not include bowling statistics for Sherfane Rutherford, the following sections will be empty.
#
# ### Bowling Matches
#
# No data available
#
# ### Bowling Phase Stats
#
# No data available
#
# ### Bowler's Analysis
#
# No data available
#
# ### Bowler's Boundary Analysis
#
# No data available
#
# ### Bowling Variations
#
# No data available
#
# ### Overall Bowling Statistics
#
# No data available
# --------------------------------------------------
# Player ID: 9012
# Name: Rahul Tripathi
# Summary: **Rahul Tripathi's Batting Performance**
#
# **Match-by-Match Breakdown**
#
# 1. 13(9) SR: 144.44
# 2. 24(16) SR: 150.0
# 3. 21(20) SR: 105.0
# 4. 16(6) SR: 266.67
# 5. 44(28) SR: 157.14
# 6. 5(6) SR: 83.33
# 7. 20(20) SR: 100.0
# 8. 10(6) SR: 166.67
# 9. 15(12) SR: 125.0
# 10. 1(2) SR: 50.0
#
# **Total Batting Statistics**
#
# - Total Runs: 169
# - Total Balls: 125
# - Average Runs: 16.9
# - Overall Strike Rate: 135.20
#
# **Batting Phase Stats**
#
# - **Powerplay**: 242(184) SR: 131.52
# - **Middle Overs**: 443(315) SR: 140.63
# - **Death Overs**: 47(23) SR: 204.35
#
# **Wicket Analysis**
#
# - Sweep (short, leg-stump, fine-leg): 2
#
# **Batting Control**
#
# - In-Control: 442
# - No-Control: 75
# - Beaten: 5
#
# **Scoring Zones**
#
# - Point: 78
# - Cover: 70
# - Square: 61
# - Mid-wicket: 48
# - Fine-leg: 43
# - Blocked: 40
# - Long-on: 36
# - Keeper: 35
# - Third-man: 26
# - Long-off: 25
#
# **Boundary Analysis**
#
# - Details:
#   - Cut (short, outside-off): 4
#   - Flick (full-toss, leg-stump): 3
#   - Loft (full, leg-stump): 3
# - Boundary Percentage: 19.54%
#
# **Shot Selection**
#
# - Drive: 12
# - Cut: 8
# - Flick: 6
# - Sweep: 2
# - Loft: 3
# - Other: 78
#
# **Bowling Statistics (Not Provided)**
#
# However, I can provide a general format for bowling statistics if you provide the necessary data.
#
# **Overall Bowling Statistics (Not Provided)**
#
# However, I can provide a general format for overall bowling statistics if you provide the necessary data.
#
# **Bowling Phase Stats (Not Provided)**
#
# However, I can provide a general format for bowling phase stats if you provide the necessary data.
#
# **Bowling Variations (Not Provided)**
#
# However, I can provide a general format for bowling variations if you provide the necessary data.
#
# **Bowling Wicket Analysis (Not Provided)**
#
# However, I can provide a general format for bowling wicket analysis if you provide the necessary data.
#
# **Bowling Boundary Analysis (Not Provided)**
#
# However, I can provide a general format for bowling boundary analysis if you provide the necessary data.
# --------------------------------------------------
# Player ID: 10551
# Name: Prasidh Krishna
# Summary: **Prasidh Krishna's Performance Breakdown**
#
# **Batting Statistics**
#
# ### Matches
#
# * Match 1: 0(0) SR: 0.0
# * Match 2: 0(0) SR: 0.0
# * Match 3: 0(0) SR: 0.0
# * Match 4: 0(0) SR: 0.0
# * Match 5: 0(0) SR: 0.0
# * Match 6: 2(5) SR: 40.0
#
# ### Total Batting Statistics
#
# * Total Runs: 2
# * Total Balls: 5
# * Average Runs: 0.33
# * Overall Strike Rate: 40.0
#
# ### Batting Phase Stats
#
# * Powerplay: 0(0) SR: 0
# * Middle: 0(0) SR: 0
# * Death: 6(12) SR: 50.0
#
# ### Wicket Analysis
#
# * No wickets taken
#
# ### Batting Control
#
# * No-control: 5
# * In-control: 5
# * Beaten: 2
#
# ### Scoring Zones
#
# * Keeper: 4
# * Blocked: 2
# * Mid-wicket: 1
# * Point: 1
# * Square: 1
#
# ### Boundary Analysis
#
# * No boundaries scored
#
# **Bowling Statistics**
#
# ### Matches
#
# * Match 1: 40(4.0) Econ: 10.0 Wkts: 1
# * Match 2: 22(4.0) Econ: 5.5 Wkts: 3
# * Match 3: 40(3.3) Econ: 11.4 Wkts: 0
# * Match 4: 32(4.0) Econ: 8.0 Wkts: 0
# * Match 5: 32(4.0) Econ: 8.0 Wkts: 2
# * Match 6: 20(3.0) Econ: 6.7 Wkts: 0
# * Match 7: 48(4.0) Econ: 12.0 Wkts: 1
# * Match 8: 37(4.0) Econ: 9.2 Wkts: 1
# * Match 9: 29(4.0) Econ: 7.2 Wkts: 1
# * Match 10: 23(4.0) Econ: 5.8 Wkts: 2
#
# ### Total Bowling Statistics
#
# * Total Runs Conceded: 323
# * Total Wickets: 11
# * Total Balls Bowled: 231
# * Runs per Wicket: 29.36
# * Balls per Wicket: 21.0
#
# ### Bowling Phase Stats
#
# * Powerplay: 242(224) Econ: 6.48 Wkts: 11
# * Middle: 92(72) Econ: 7.67 Wkts: 2
# * Death: 206(136) Econ: 9.09 Wkts: 7
#
# ### Wicket Analysis
#
# * Back of a length, off-stump, normal: 2
# * Short, outside-off, normal: 2
#
# ### Boundary Analysis
#
# * Back of a length, outside-off, normal: 4
# * Full, outside-off, normal: 7
# * Short, leg-stump, normal: 3
# * Short, outside-off, normal: 6
# * Short, wide, normal: 3
#
# ### Variation Frequency
#
# * Normal: 345
# * Yorker: 30
# * Slower: 22
# * Quick: 13
# * Cutter: 7
# * Bouncer: 5
# * Seam-away: 4
# * Seam-up: 2
# * Seam-in: 2
# * In-swing: 1
# * Swing: 1
# --------------------------------------------------
# Player ID: 10808
# Name: Mohammed Siraj
# Summary: **Mohammed Siraj's Performance Breakdown**
#
# **Batting Performance**
#
# ### Matches
#
# | Match | Runs (Balls) | Strike Rate |
# | --- | --- | --- |
# | 1 | 0 (0) SR: 0.0 |  |
# | 2 | 12 (8) SR: 150.0 |  |
#
# ### Total Batting Statistics
#
# * Total Runs: 12
# * Total Balls Faced: 8
# * Average Runs: 6.0
# * Overall Strike Rate: 150.0
#
# ### Batting Phase Stats
#
# | Phase | Runs (Balls) | Strike Rate |
# | --- | --- | --- |
# | Powerplay | 0 (0) SR: 0.0 |  |
# | Middle Overs | 2 (5) SR: 40.0 |  |
# | Death Overs | 41 (39) SR: 105.12820512820514 |  |
#
# ### Wicket Analysis
#
# | Shot Played | Ball Length | Ball Line | Shot Direction |
# | --- | --- | --- | --- |
# |  |  |  |  |
#
# **Note:** No wicket analysis data available.
#
# ### Batting Control
#
# | Control | Count |
# | --- | --- |
# | In-Control | 27 |
# | No-Control | 14 |
# | Beaten | 3 |
#
# ### Scoring Zones
#
# | Zone | Count |
# | --- | --- |
# | Keeper | 14 |
# | Cover | 6 |
# | Point | 5 |
# | Long-Off | 4 |
# | Third-Man | 4 |
# | Long-On | 2 |
# | Blocked | 2 |
# | Fine-Leg | 1 |
#
# ### Boundary Analysis
#
# * Boundary Percentage: 15.909090909090908
# * Boundary Details:
# 	+  |  |  |
# 	+  |  |  |
#
# **Note:** No boundary analysis data available.
#
# **Bowling Performance**
#
# ### Matches
#
# | Match | Runs (Overs) | Economy | Wickets |
# | --- | --- | --- | --- |
# | 1 | 34 (4.0) Econ: 8.5 Wkts: 1 |  |
# | 2 | 20 (4.0) Econ: 5.0 Wkts: 0 |  |
# | 3 | 40 (4.0) Econ: 10.0 Wkts: 1 |  |
# | 4 | 37 (3.0) Econ: 12.3 Wkts: 0 |  |
# | 5 | 35 (4.0) Econ: 8.8 Wkts: 1 |  |
# | 6 | 47 (4.0) Econ: 11.8 Wkts: 1 |  |
# | 7 | 46 (3.0) Econ: 15.3 Wkts: 0 |  |
# | 8 | 26 (4.0) Econ: 6.5 Wkts: 2 |  |
# | 9 | 38 (4.0) Econ: 9.5 Wkts: 0 |  |
# | 10 | 32 (4.0) Econ: 8.0 Wkts: 2 |  |
#
# ### Total Bowling Statistics
#
# * Total Runs Conceded: 355
# * Total Wickets: 8
# * Total Balls Bowled: 228
# * Runs per Wicket: 44.375
# * Balls per Wicket: 28.5
#
# ### Bowling Phase Stats
#
# | Phase | Runs | Balls | Wickets | Runs per Wicket | Balls per Wicket | Economy |
# | --- | --- | --- | --- | --- | --- | --- |
# | Powerplay | 660 | 493 | 10 | 66.0 | 49.3 | 8.032454361054766 |
# | Middle Overs | 226 | 182 | 7 | 32.285714285714285 | 26.0 | 7.450549450549451 |
# | Death Overs | 320 | 198 | 6 | 53.333333333333336 | 33.0 | 9.696969696969697 |
#
# ### Wicket Analysis
#
# | Ball Length | Ball Line | Bowling Variation |
# | --- | --- | --- |
# | ('full', 'leg-stump', 'normal') | 3 |
# | ('short', 'outside-off', 'normal') | 5 |
#
# ### Boundary Analysis
#
# * Boundary Percentage: 21.420389461626574
# * Boundary Details:
# 	+ ('back of a length', 'outside-off', 'normal') | 4
# 	+ ('full', 'leg-stump', 'normal') | 8
# 	+ ('full', 'outside-off', 'normal') | 14
# 	+ ('full-toss', 'leg-stump', 'normal') | 3
# 	+ ('full-toss', 'outside-off', 'normal') | 3
# 	+ ('good length', 'wide', 'normal') | 4
# 	+ ('length ball', 'leg-stump', 'normal') | 4
# 	+ ('short', 'leg-stump', 'normal') | 5
# 	+ ('short', 'outside-off', 'normal') | 14
# 	+ ('short', 'wide', 'normal') | 3
#
# ### Variation Frequency
#
# | Variation | Count |
# | --- | --- |
# | Normal | 713 |
# | Slower | 49 |
# | Quick | 41 |
# | Yorker | 33 |
# | Seam-Away | 11 |
# | Bouncer | 10 |
# | Out-Swing | 5 |
# | Swing | 4 |
# | In
# --------------------------------------------------
# Player ID: 1593
# Name: Ravichandran Ashwin
# Summary: **Ravichandran Ashwin's Performance Breakdown**
#
# **Batting Performance**
#
# ### Matches
#
# 1. 8(11) SR: 72.73
# 2. 0(0) SR: 0.0
# 3. 16(16) SR: 100.0
# 4. 29(19) SR: 152.63
# 5. 0(0) SR: 0.0
# 6. 1(1) SR: 100.0
# 7. 0(0) SR: 0.0
#
# ### Total Batting Statistics
#
# - Total Runs: 54
# - Total Balls: 47
# - Average Runs: 7.71
# - Overall Strike Rate: 114.89
#
# ### Batting Phase Stats
#
# - **Powerplay**: 49(34) SR: 144.12
# - **Middle**: 160(144) SR: 111.11
# - **Death**: 113(64) SR: 176.56
#
# ### Wicket Analysis
#
# No wicket analysis data available.
#
# ### Batting Control
#
# - In-control: 189
# - No-control: 45
# - Beaten: 8
#
# ### Scoring Zones
#
# - Mid-wicket: 41
# - Cover: 31
# - Square: 31
# - Keeper: 23
# - Long-on: 22
# - Point: 21
# - Blocked: 18
# - Long-off: 13
# - Fine-leg: 11
# - Third-man: 9
#
# ### Boundary Analysis
#
# - Percentage: 15.29%
#
# ### Shot Selection
#
# No shot selection data available.
#
# **Bowling Performance**
#
# ### Matches
#
# 1. 39(4.0) Econ: 9.8 Wkts: 1
# 2. 31(4.0) Econ: 7.8 Wkts: 0
# 3. 49(4.0) Econ: 12.2 Wkts: 0
# 4. 40(4.0) Econ: 10.0 Wkts: 0
# 5. 28(4.0) Econ: 7.0 Wkts: 0
# 6. 27(4.0) Econ: 6.8 Wkts: 0
# 7. 30(3.0) Econ: 10.0 Wkts: 0
# 8. 35(4.0) Econ: 8.8 Wkts: 1
# 9. 35(4.0) Econ: 8.8 Wkts: 2
# 10. 33(4.0) Econ: 8.2 Wkts: 0
#
# ### Total Bowling Statistics
#
# - Total Runs Conceded: 347
# - Total Wickets: 4
# - Total Balls Bowled: 234
# - Runs per Wicket: 86.75
# - Balls per Wicket: 58.5
#
# ### Bowling Phase Stats
#
# - **Powerplay**: 230(186) Econ: 7.42 Wkts: 4 Runs per Wicket: 57.5 Balls per Wicket: 46.5
# - **Middle**: 806(682) Econ: 7.09 Wkts: 19 Runs per Wicket: 42.42 Balls per Wicket: 35.89
# - **Death**: 81(57) Econ: 8.53 Wkts: 2 Runs per Wicket: 40.5 Balls per Wicket: 28.5
#
# ### Wicket Analysis
#
# - ('full', 'leg-stump', 'carrom ball'): 2
# - ('full', 'leg-stump', 'normal'): 3
#
# ### Boundary Analysis
#
# - Percentage: 11.68%
#
# ### Bowling Variations
#
# - Normal: 669
# - Carrom ball: 111
# - Quick: 92
# - Slower: 25
# - Slider: 9
# - Off-break: 7
# - Yorker: 5
# - Skidding: 3
# - Off-spin: 2
# - Swing: 2
# --------------------------------------------------
# Player ID: 11195
# Name: Shivam Dube
# Summary: **Shivam Dube's Performance Breakdown**
#
# **BATTING STATISTICS**
#
# ### Matches
#
# 1. 9(6) SR: 150
# 2. 0(1) SR: 0
# 3. 37(22) SR: 168.18
# 4. 34(18) SR: 188.89
# 5. 71(36) SR: 197.22
# 6. 66(27) SR: 244.44
# 7. 3(8) SR: 37.5
# 8. 66(38) SR: 173.68
# 9. 45(24) SR: 187.5
# 10. 51(23) SR: 221.74
#
# ### Total Batting Statistics
#
# - Total Runs: 382
# - Total Balls: 203
# - Average Runs: 38.2
# - Overall Strike Rate: 188.18
#
# ### Batting Phase Stats
#
# - **Powerplay**: 8(8) SR: 100
# - **Middle**: 802(522) SR: 153.64
# - **Death**: 265(136) SR: 194.85
#
# ### Wicket Analysis
#
# No data available
#
# ### Batting Control
#
# - In-control: 563
# - No-control: 93
# - Beaten: 10
#
# ### Scoring Zones
#
# - Cover: 84
# - Square: 82
# - Mid-wicket: 76
# - Long-on: 76
# - Long-off: 66
# - Blocked: 59
# - Keeper: 50
# - Point: 48
# - Fine-leg: 29
# - Third-man: 12
#
# ### Boundary Analysis
#
# - Details:
#   - ('cut', 'short', 'outside-off'): 3
#   - ('pull', 'short', 'leg-stump'): 5
#   - ('pull', 'short', 'middle-stump'): 4
# - Percentage: 20.87%
#
# ### Shot Selection
#
# No data available
#
# **BOWLING STATISTICS**
#
# ### Matches
#
# 1. 27(4) Econ: 6.8 Wkts: 1
# 2. 34(4) Econ: 8.5 Wkts: 1
# 3. 33(4) Econ: 8.2 Wkts: 0
# 4. 62(4) Econ: 15.5 Wkts: 0
# 5. 21(3) Econ: 7.0 Wkts: 1
#
# ### Total Bowling Statistics
#
# - Total Runs Conceded: 177
# - Total Wickets: 3
# - Total Balls Bowled: 114
# - Runs per Wicket: 59.0
# - Balls per Wicket: 38.0
#
# ### Bowling Phase Stats
#
# - **Powerplay**: 0(0) Econ: 0 Wkts: 0
# - **Middle**: 15(6) Econ: 15.0 Wkts: 0
# - **Death**: 27(8) Econ: 20.25 Wkts: 0
#
# ### Wicket Analysis
#
# No data available
#
# ### Boundary Analysis
#
# - Details:
#   - ('full', 'outside-off', 'normal'): 2
# - Percentage: 57.14%
#
# ### Bowling Variations
#
# - Normal: 11
# - Slower: 2
# - Quick: 1
# --------------------------------------------------
# Player ID: 12092
# Name: K Nagarkoti
# Summary: **K Nagarkoti's Performance Breakdown**
#
# **BATTING PERFORMANCE**
#
# ### Matches
#
# 1. 0(1) SR: 0.0
# 2. 13(8) SR: 162.5
# 3. 0(1) SR: 0.0
# 4. 2(1) SR: 200.0
#
# ### Total Batting Statistics
#
# - Total Runs: 15
# - Total Balls: 11
# - Average Runs: 3.75
# - Overall Strike Rate: 136.36
#
# ### Batting Phase Stats
#
# No data available for Powerplay, Middle Overs, and Death Overs.
#
# ### Wicket Analysis
#
# No data available.
#
# ### Boundary Analysis
#
# No data available.
#
# ### Shot Selection
#
# No data available.
#
# **BOWLING PERFORMANCE**
#
# ### Matches
#
# 1. 27(4) Econ: 6.8 Wkts: 1
# 2. 26(4) Econ: 6.5 Wkts: 1
# 3. 24(4) Econ: 6.0 Wkts: 1
# 4. 14(3) Econ: 4.7 Wkts: 3
# 5. 45(4) Econ: 11.2 Wkts: 1
# 6. 23(4) Econ: 5.8 Wkts: 2
# 7. 22(4) Econ: 5.5 Wkts: 1
# 8. 29(2) Econ: 14.5 Wkts: 0
#
# ### Total Bowling Statistics
#
# - Total Runs Conceded: 210
# - Total Wickets: 10
# - Total Balls Bowled: 174
# - Runs per Wicket: 21.0
# - Balls per Wicket: 17.4
#
# ### Bowling Phase Stats
#
# 1. **Powerplay**
#    - Runs: 20
#    - Balls: 7
#    - Wickets: 0
#    - Runs per Wicket: Infinity
#    - Balls per Wicket: Infinity
#    - Economy: 17.14
# 2. **Middle**
#    - Runs: 13
#    - Balls: 6
#    - Wickets: 0
#    - Runs per Wicket: Infinity
#    - Balls per Wicket: Infinity
#    - Economy: 13.0
# 3. **Death**
#    - Runs: 0
#    - Balls: 0
#    - Wickets: 0
#    - Runs per Wicket: Infinity
#    - Balls per Wicket: Infinity
#    - Economy: 0
#
# ### Wicket Analysis
#
# No data available.
#
# ### Boundary Analysis
#
# - Details:
#   - ('short', 'wide', 'normal'): 2
# - Percentage: 53.85%
#
# ### Bowling Variations
#
# - Normal: 12
# - Yorker: 1
# --------------------------------------------------
# Player ID: 702
# Name: Ishant Sharma
# Summary: **Ishant Sharma's Performance Breakdown**
#
# **BATTING STATISTICS**
#
# ### Matches
#
# | Match | Runs (Balls) | Strike Rate |
# | --- | --- | --- |
# | 1 | 0(0) SR: 0.0 |  |
# | 2 | 0(0) SR: 0.0 |  |
# | 3 | 2(4) SR: 50.0 |  |
#
# ### Total Batting Statistics
#
# * Total Runs: 0
# * Total Balls: 0
# * Average Runs: 0.0
# * Overall Strike Rate: 0
#
# ### Batting Phase Stats
#
# | Phase | Runs (Balls) | Strike Rate |
# | --- | --- | --- |
# | Powerplay | 0(0) SR: 0.0 |  |
# | Middle Overs | 0(0) SR: 0.0 |  |
# | Death Overs | 2(4) SR: 50.0 |  |
#
# ### Wicket Analysis
#
# | Shot Played | Ball Length | Ball Line | Shot Direction |
# | --- | --- | --- | --- |
# |  |  |  |  |
#
# ### Batting Control
#
# * In-Control: 3
# * No-Control: 1
#
# ### Scoring Zones
#
# * Long-On: 2
# * Cover: 1
#
# ### Boundary Analysis
#
# | Shot Played | Ball Length | Ball Line | Boundary Percentage |
# | --- | --- | --- | --- |
# |  |  |  | 0.0% |
#
# **BOWLING STATISTICS**
#
# ### Matches
#
# | Match | Runs (Overs) | Economy | Wickets |
# | --- | --- | --- | --- |
# | 1 | 12(3.0) Econ: 4.0 Wkts: 2 |  |
# | 2 | 11(3.0) Econ: 3.7 Wkts: 1 |  |
# | 3 | 38(4.0) Econ: 9.5 Wkts: 2 |  |
# | 4 | 25(2.4) Econ: 9.4 Wkts: 1 |  |
# | 5 | 23(1.5) Econ: 12.5 Wkts: 0 |  |
# | 6 | 22(3.0) Econ: 7.3 Wkts: 2 |  |
# | 7 | 23(4.0) Econ: 5.8 Wkts: 2 |  |
# | 8 | 8(2.0) Econ: 4.0 Wkts: 2 |  |
# | 9 | 36(4.0) Econ: 9.0 Wkts: 1 |  |
# | 10 | 40(3.0) Econ: 13.3 Wkts: 0 |  |
#
# ### Total Bowling Statistics
#
# * Total Runs Conceded: 238
# * Total Wickets: 13
# * Total Balls Bowled: 183
# * Runs per Wicket: 18.307692307692307
# * Balls per Wicket: 14.076923076923077
#
# ### Bowling Phase Stats
#
# | Phase | Runs | Balls | Wickets | Runs per Wicket | Balls per Wicket | Economy |
# | --- | --- | --- | --- | --- | --- | --- |
# | Powerplay | 232 | 179 | 9 | 25.77777777777778 | 19.88888888888889 | 7.776536312849162 |
# | Middle Overs | 53 | 52 | 3 | 17.666666666666668 | 17.333333333333332 | 6.115384615384615 |
# | Death Overs | 83 | 42 | 3 | 27.666666666666668 | 14.0 | 11.857142857142858 |
#
# ### Wicket Analysis
#
# | Ball Length | Ball Line | Bowling Variation | Wickets |
# | --- | --- | --- | --- |
# | ('full', 'outside-off', 'normal') |  |  | 2 |
#
# ### Boundary Analysis
#
# | Ball Length | Ball Line | Bowling Variation | Boundary Percentage |
# | --- | --- | --- | --- |
# | ('back of a length', 'outside-off', 'normal') |  |  |  |
# | ('full', 'outside-off', 'normal') |  |  |  |
# | ('short', 'outside-off', 'normal') |  |  |  |
# | ('short', 'wide', 'normal') |  |  |  |
#
# ### Variation Frequency
#
# | Variation | Count |
# | --- | --- |
# | normal | 225 |
# | slower | 24 |
# | yorker | 12 |
# | quick | 5 |
# | knuckle ball | 2 |
# | skidding | 1 |
# | cutter | 1 |
# | seam-away | 1 |
# | in-swing | 1 |
# | seam-in | 1 |
# --------------------------------------------------
# Player ID: 10945
# Name: Washington Sundar
# Summary: **Washington Sundar's Performance Breakdown**
#
# **Batting Statistics**
#
# ### Matches
#
# 1. 24(15) SR: 160
# 2. 9(6) SR: 150
# 3. 10(6) SR: 166.67
# 4. 16(28) SR: 57.14
# 5. 1(5) SR: 20
# 6. 25(19) SR: 131.58
# 7. 9(7) SR: 128.57
# 8. 4(9) SR: 44.44
# 9. 2(2) SR: 100
#
# ### Total Batting Statistics
#
# - **Total Runs:** 100
# - **Total Balls:** 97
# - **Average Runs:** 11.11
# - **Overall Strike Rate:** 103.09
#
# ### Batting Phase Stats
#
# - **Powerplay:** 0(0) SR: 0
# - **Middle:** 42(57) SR: 73.68
# - **Death:** 127(82) SR: 154.88
#
# ### Wicket Analysis
#
# No data available.
#
# ### Batting Control
#
# - **In-Control:** 110
# - **No-Control:** 25
# - **Beaten:** 4
#
# ### Scoring Zones
#
# - **Cover:** 19
# - **Mid-Wicket:** 18
# - **Long-Off:** 16
# - **Point:** 15
# - **Keeper:** 13
# - **Long-On:** 12
# - **Blocked:** 10
# - **Square:** 9
# - **Fine-Leg:** 7
# - **Third-Man:** 4
#
# ### Boundary Analysis
#
# - **Details:** ('loft', 'full-toss', 'outside-off'): 2
# - **Percentage:** 14.39%
#
# **Bowling Statistics**
#
# ### Matches
#
# 1. 28(4) Econ: 7.0 Wkts: 3
# 2. 16(2.4) Econ: 6.0 Wkts: 0
# 3. 33(4) Econ: 8.2 Wkts: 0
# 4. 6(1) Econ: 6.0 Wkts: 0
# 5. 11(1) Econ: 11.0 Wkts: 0
# 6. 32(3) Econ: 10.7 Wkts: 0
# 7. 19(2) Econ: 9.5 Wkts: 1
# 8. 36(4) Econ: 9.0 Wkts: 1
# 9. 40(4) Econ: 10.0 Wkts: 0
#
# ### Total Bowling Statistics
#
# - **Total Runs Conceded:** 221
# - **Total Wickets:** 5
# - **Total Balls Bowled:** 154
# - **Runs per Wicket:** 44.2
# - **Balls per Wicket:** 30.8
#
# ### Bowling Phase Stats
#
# - **Powerplay:** 170(85) Econ: 12.0 Wkts: 4
# - **Middle:** 252(205) Econ: 7.38 Wkts: 5
# - **Death:** 43(16) Econ: 16.13 Wkts: 0
#
# ### Wicket Analysis
#
# No data available.
#
# ### Boundary Analysis
#
# - **Details:** ('full', 'leg-stump', 'normal'): 3, ('full', 'outside-off', 'normal'): 4, ('short', 'leg-stump', 'normal'): 3, ('short', 'outside-off', 'normal'): 6
# - **Percentage:** 18.95%
#
# ### Variation Frequency
#
# - **Normal:** 258
# - **Quick:** 29
# - **Slower:** 8
# - **Slider:** 4
# - **Skidding:** 2
# - **Off-Break:** 2
# - **Yorker:** 2
# - **Off-Spin:** 1
# --------------------------------------------------
# Player ID: 32835
# Name: Ramakrishna Ghosh
# Summary: **Ramakrishna Ghosh's Performance Breakdown**
#
# **Batting Performance**
#
# ### Matches
#
# 1. 1(2) SR: 50
# 2. 11(9) SR: 122.22
# 3. 13(5) SR: 260
# 4. 0(1) SR: 0
#
# ### Total Batting Statistics
#
# - Total Runs: 25
# - Total Balls: 17
# - Average Runs: 6.25
# - Overall Strike Rate: 147.05882352941177
#
# ### Batting Phase Stats
#
# No data available for Powerplay, Middle Overs, and Death Overs.
#
# ### Wicket Analysis
#
# No data available for shot_played, ball_length, ball_line, and shot_direction.
#
# ### Boundary Analysis
#
# No data available for shot_played, ball_length, and ball_line.
#
# ### Shot Selection
#
# No data available.
#
# ### Bowling Performance
#
# ### Matches
#
# 1. 23(2) Econ: 11.5 Wkts: 0
# 2. 29(2) Econ: 14.5 Wkts: 0
# 3. 20(2) Econ: 10.0 Wkts: 0
# 4. 18(3) Econ: 6.0 Wkts: 0
#
# ### Total Bowling Statistics
#
# - Total Runs Conceded: 90
# - Total Wickets: 0
# - Total Balls Bowled: 54
# - Runs per Wicket: inf
# - Balls per Wicket: inf
#
# ### Bowling Phase Stats
#
# No data available for Powerplay, Middle Overs, and Death Overs.
#
# ### Wicket Analysis
#
# No data available for ball_length, ball_line, and bowling_variation.
#
# ### Boundary Analysis
#
# No data available for ball_length, ball_line, and bowling_variation.
#
# ### Bowling Variations
#
# No data available.
#
# **Key Takeaways:**
#
# * Ramakrishna Ghosh's batting performance is limited to four matches, with a total of 25 runs at an average of 6.25 and a strike rate of 147.06.
# * His bowling performance is also limited to four matches, with a total of 90 runs conceded at an economy rate of 6.67 and no wickets taken.
# * There is no data available for batting phase stats, wicket analysis, boundary analysis, shot selection, and bowling variations.
# --------------------------------------------------
# Player ID: 10693
# Name: Glenn Phillips
# Summary: **Glenn Phillips' Performance Breakdown**
#
# **BATTING PERFORMANCE**
#
# ### Matches
#
# 1. 1(4) SR: 25.0
# 2. 5(4) SR: 125.0
# 3. 0(1) SR: 0.0
# 4. 25(7) SR: 357.14
# 5. 8(6) SR: 133.33
#
# ### Total Batting Statistics
#
# - **Total Runs:** 39
# - **Total Balls:** 22
# - **Average Runs:** 7.8
# - **Overall Strike Rate:** 177.27
#
# ### Batting Phase Stats
#
# - **Powerplay:** 0(0) SR: 0
# - **Middle:** 8(7) SR: 114.29
# - **Death:** 33(15) SR: 220.00
#
# ### Wicket Analysis
#
# | Shot Played | Ball Length | Ball Line | Shot Direction |
# | --- | --- | --- | --- |
# |  |  |  |  |
#
# **Note:** There is no data available for Wicket Analysis.
#
# ### Batting Control
#
# - **In-Control:** 16
# - **No-Control:** 6
#
# ### Scoring Zones
#
# - **Square:** 4
# - **Cover:** 4
# - **Mid-Wicket:** 2
# - **Keeper:** 1
# - **Fine-Leg:** 1
# - **Point:** 1
# - **Long-Off:** 1
#
# ### Boundary Analysis
#
# - **Details:**
# | Shot Played | Ball Length | Ball Line |
# | --- | --- | --- |
# |  |  |  |
# - **Percentage:** 27.27
#
# **BOWLING PERFORMANCE**
#
# ### Matches
#
# 1. 10(1.0) Econ: 10.0 Wkts: 0
# 2. 10(2.0) Econ: 5.0 Wkts: 1
#
# ### Total Bowling Statistics
#
# - **Total Runs Conceded:** 20
# - **Total Wickets:** 1
# - **Total Balls Bowled:** 18
# - **Runs per Wicket:** 20.0
# - **Balls per Wicket:** 18.0
#
# ### Bowling Phase Stats
#
# - **Powerplay:** 4(6) Econ: 4.0 Wkts: 1
# - **Middle:** 16(12) Econ: 8.0 Wkts: 0
# - **Death:** 0(0) Econ: 0 Wkts: 0
#
# ### Wicket Analysis
#
# | Ball Length | Ball Line | Bowling Variation |
# | --- | --- | --- |
# |  |  |  |
#
# **Note:** There is no data available for Wicket Analysis.
#
# ### Boundary Analysis
#
# - **Details:**
# | Ball Length | Ball Line | Bowling Variation |
# | --- | --- | --- |
# |  |  |  |
# - **Percentage:** 11.11
#
# ### Variation Frequency
#
# - **Normal:** 18
# --------------------------------------------------
# Player ID: 10952
# Name: Khaleel Ahmed
# Summary: **Khaleel Ahmed's Performance Breakdown**
#
# **Batting Statistics**
#
# **Matches:**
#
# 1. 0(0) SR: 0.0
# 2. 0(0) SR: 0.0
# 3. 0(0) SR: 0.0
#
# **Total Batting Statistics:**
#
# - Total Runs: 0
# - Total Balls: 0
# - Average Runs: 0.0
# - Overall Strike Rate: 0
#
# **Batting Phase Stats:**
#
# - **Powerplay:** 0(0) SR: 0
# - **Middle:** 0(0) SR: 0
# - **Death:** 0(2) SR: 0.0
#
# **Batting Control:**
#
# - No Control: 2
#
# **Scoring Zones:**
#
# ...
#
# **BOWLING PERFORMANCE**
#
# ### Matches
#
# 1. 8(1.0) Econ: 8.0 Wkts: 0
# 2. 14(2.0) Econ: 7.0 Wkts: 1
# 3. 4(1.0) Econ: 4.0 Wkts: 0
# 4. 25(3.0) Econ: 8.3 Wkts: 1
# 5. 24(3.0) Econ: 8.0 Wkts: 1
#
# ### Total Bowling Statistics
#
# - **Total Runs Conceded:** 75
# - **Total Wickets:** 3
# - **Total Balls Bowled:** 60
# - **Runs per Wicket:** 25.0
# - **Balls per Wicket:** 20.0
#
# ### Bowling Phase Stats
#
# - **Powerplay:** 0(0) Econ: 0.0 Wkts: 0
# - **Middle Overs:** 51(30) Econ: 10.2 Wkts: 1
# - **Death Overs:** 0(0) Econ: 0.0 Wkts: 0
#
# ### Bowling Variation Frequency
#
# - **Normal:** 22
# - **Quick:** 4
# - **Off-break:** 2
# - **Skidding:** 1
# - **Arm Ball:** 1
#
# ### Boundary Analysis
#
# - **Boundary Details:**
#   - No boundaries conceded
# - **Boundary Percentage:** 23.33%
# --------------------------------------------------
# Player ID: 15452
# Name: Noor Ahmad
# Summary: **Noor Ahmad's Performance Breakdown**
#
# **Batting Performance**
#
# ### Matches
#
# * Match 1: 0(0) SR: 0.0
# * Match 2: 0(0) SR: 0.0
# * Match 3: 1(7) SR: 14.29
# * Match 4: 0(0) SR: 0.0
# * Match 5: 4(2) SR: 200.0
#
# ### Total Batting Statistics
#
# * Total Runs: 5
# * Total Balls: 9
# * Average Runs: 1.0
# * Overall Strike Rate: 55.55555555555556
#
# ### Batting Phase Stats
#
# * **Powerplay**: 0(0) SR: 0
# * **Middle**: 2(7) SR: 28.57142857142857
# * **Death**: 14(11) SR: 127.27272727272727
#
# ### Wicket Analysis
#
# No data available
#
# ### Batting Control
#
# * In-control: 11
# * No-control: 7
#
# ### Scoring Zones
#
# * Keeper: 5
# * Mid-wicket: 4
# * Long-on: 3
# * Blocked: 2
# * Point: 1
# * Cover: 1
# * Square: 1
#
# ### Boundary Analysis
#
# * Percentage: 11.11111111111111
#
# ### Shot Selection
#
# No data available
#
# **Bowling Performance**
#
# ### Matches
#
# * Match 1: 43(4.0) Econ: 10.8 Wkts: 0
# * Match 2: 36(3.0) Econ: 12.0 Wkts: 1
# * Match 3: 20(4.0) Econ: 5.0 Wkts: 2
# * Match 4: 14(1.5) Econ: 7.6 Wkts: 0
# * Match 5: 43(4.0) Econ: 10.8 Wkts: 0
# * Match 6: 22(4.0) Econ: 5.5 Wkts: 0
# * Match 7: 32(4.0) Econ: 8.0 Wkts: 2
# * Match 8: 32(4.0) Econ: 8.0 Wkts: 1
# * Match 9: 17(3.0) Econ: 5.7 Wkts: 2
# * Match 10: 35(4.0) Econ: 8.8 Wkts: 0
#
# ### Total Bowling Statistics
#
# * Total Runs Conceded: 294
# * Total Wickets: 8
# * Total Balls Bowled: 215
# * Runs per Wicket: 36.75
# * Balls per Wicket: 26.875
#
# ### Bowling Phase Stats
#
# * **Powerplay**: 47(37) Econ: 7.621621621621622 Wkts: 1
# * **Middle**: 524(407) Econ: 7.724815724815725 Wkts: 12
# * **Death**: 41(33) Econ: 7.454545454545454 Wkts: 3
#
# ### Wicket Analysis
#
# * ('full', 'leg-stump', 'normal'): 2
#
# ### Boundary Analysis
#
# * Percentage: 15.513626834381553
#
# ### Variation Frequency
#
# * Normal: 358
# * Googly: 67
# * Quick: 44
# * Slower: 5
# * Leg-break: 2
# * Yorker: 1
# --------------------------------------------------
# Player ID: 9693
# Name: Rahul Tewatia
# Summary: **Rahul Tewatia's Performance Breakdown**
#
# **BATTING STATISTICS**
#
# ### Matches
#
# 1. 14(16) SR: 87.5
# 2. 10(7) SR: 142.86
# 3. 8(4) SR: 200.0
# 4. 19(19) SR: 100.0
# 5. 0(1) SR: 0.0
# 6. 0(0) SR: 0.0
# 7. 43(16) SR: 268.75
# 8. 4(5) SR: 80.0
# 9. 36(18) SR: 200.0
#
# ### Total Batting Statistics
#
# - Total Runs: 134
# - Total Balls: 86
# - Average Runs: 14.88888888888889
# - Overall Strike Rate: 155.8139534883721
#
# ### Batting Phase Stats
#
# - **Powerplay**: 0(0) SR: 0
# - **Middle**: 118(126) SR: 93.65
# - **Death**: 359(209) SR: 171.77
#
# ### Wicket Analysis
#
# No data available
#
# ### Batting Control
#
# - In-Control: 269
# - No-Control: 62
# - Beaten: 4
#
# ### Scoring Zones
#
# - Square: 48
# - Mid-wicket: 43
# - Cover: 42
# - Point: 36
# - Blocked: 34
# - Keeper: 27
# - Long-off: 24
# - Fine-leg: 22
# - Long-on: 18
# - Third-man: 10
#
# ### Boundary Analysis
#
# - Details:
#   - ('drive', 'full', 'outside-off'): 3
# - Percentage: 20.298507462686565
#
# **BOWLING STATISTICS**
#
# ### Matches
#
# No data available
#
# ### Total Bowling Statistics
#
# - Total Runs Conceded: 0
# - Total Wickets: 0
# - Total Balls Bowled: 0
# - Runs per Wicket: 0
# - Balls per Wicket: 0
#
# ### Bowling Phase Stats
#
# - **Powerplay**: 0(0) Econ: 0 Wkts: 0
# - **Middle**: 74(38) Econ: 11.68 Wkts: 0
# - **Death**: 16(12) Econ: 8.0 Wkts: 0
#
# ### Wicket Analysis
#
# No data available
#
# ### Boundary Analysis
#
# - Details: {}
# - Percentage: 24.0
#
# ### Variation Frequency
#
# - Normal: 44
# - Quick: 3
# - Googly: 3
# --------------------------------------------------
# Player ID: 19807
# Name: Gurjapneet Singh
# Summary: **Gurjapneet Singh's Performance Breakdown**
#
# **BATTING PERFORMANCE**
#
# ### Matches
#
# 1. 7(4) SR: 175.0
# 2. 2(5) SR: 40.0
# 3. 0(1) SR: 0.0
#
# ### Total Batting Statistics
#
# - **Total Runs:** 9
# - **Total Balls:** 10
# - **Average Runs:** 3.0
# - **Overall Strike Rate:** 90.0
#
# ### Batting Phase Stats
#
# No data available for Powerplay, Middle Overs, and Death Overs.
#
# ### Wicket Analysis
#
# No data available for shot_played, ball_length, ball_line, and shot_direction.
#
# ### Batting Control
#
# No data available.
#
# ### Scoring Zones
#
# No data available.
#
# ### Boundary Analysis
#
# No data available for shot_played, ball_length, and ball_line.
#
# ### Shot Selection
#
# No data available.
#
# **BOWLING PERFORMANCE**
#
# ### Matches
#
# 1. 41(4.0) Econ: 10.2 Wkts: 3
# 2. 15(2.0) Econ: 7.5 Wkts: 2
# 3. 27(4.0) Econ: 6.8 Wkts: 2
# 4. 44(3.0) Econ: 14.7 Wkts: 0
# 5. 28(4.0) Econ: 7.0 Wkts: 2
#
# ### Total Bowling Statistics
#
# - **Total Runs Conceded:** 155
# - **Total Wickets:** 9
# - **Total Balls Bowled:** 102
# - **Runs per Wicket:** 17.22222222222222
# - **Balls per Wicket:** 11.333333333333334
#
# ### Bowling Phase Stats
#
# No data available for Powerplay, Middle Overs, and Death Overs.
#
# ### Wicket Analysis
#
# No data available for ball_length, ball_line, and bowling_variation.
#
# ### Boundary Analysis
#
# No data available for ball_length, ball_line, and bowling_variation.
#
# ### Bowling Variations
#
# No data available.
#
# Note: The provided data is incomplete, and some sections are empty. The output reflects this limitation.
# --------------------------------------------------
# Player ID: 12643
# Name: Kulwant Khejroliya
# Summary: **Kulwant Khejroliya's Performance Breakdown**
#
# **BATTING STATISTICS**
#
# ### Matches
#
# * Match 1: 0(0) SR: 0.0
# * Match 2: 0(0) SR: 0.0
# * Match 3: 0(0) SR: 0.0
# * Match 4: 0(0) SR: 0.0
#
# ### Total Batting Statistics
#
# * Total Runs: 0
# * Total Balls: 0
# * Average Runs: 0.0
# * Overall Strike Rate: 0
#
# ### Batting Phase Stats
#
# * No data available for Powerplay, Middle Overs, and Death Overs.
#
# ### Wicket Analysis
#
# * No data available for shot played, ball length, ball line, and shot direction.
#
# ### Batting Control
#
# * No data available.
#
# ### Scoring Zones
#
# * No data available.
#
# ### Boundary Analysis
#
# * No data available for shot played, ball length, and ball line.
#
# **BOWLING STATISTICS**
#
# ### Matches
#
# * Match 1: 30(2.0) Econ: 15.0 Wkts: 0
# * Match 2: 26(3.0) Econ: 8.7 Wkts: 2
# * Match 3: 44(3.0) Econ: 14.7 Wkts: 2
# * Match 4: 20(1.2) Econ: 15.0 Wkts: 0
#
# ### Total Bowling Statistics
#
# * Total Runs Conceded: 120
# * Total Wickets: 4
# * Total Balls Bowled: 56
# * Runs per Wicket: 30.0
# * Balls per Wicket: 14.0
#
# ### Bowling Phase Stats
#
# * Powerplay: 27(12) Econ: 13.5 Wkts: 0
# * Middle: 0(0) Econ: 0 Wkts: 0
# * Death: 39(16) Econ: 14.625 Wkts: 2
#
# ### Wicket Analysis
#
# * No data available for ball length, ball line, and bowling variation.
#
# ### Boundary Analysis
#
# * Details:
#  + (full-toss, wide, normal): 2
#  + (short, outside-off, normal): 2
# * Percentage: 35.714285714285715
#
# ### Bowling Variations
#
# * Normal: 23
# * Yorker: 4
# * Slower: 1
# --------------------------------------------------
# Player ID: 9838
# Name: Devon Conway
# Summary: **Devon Conway's Batting Performance**
#
# ### Matches
#
# Here's a breakdown of Devon Conway's performance in each match:
#
# 1. 47(25) SR: 188.0
# 2. 40(34) SR: 117.65
# 3. 8(16) SR: 50.0
# 4. 87(52) SR: 167.31
# 5. 30(28) SR: 107.14
# 6. 56(40) SR: 140.0
# 7. 10(13) SR: 76.92
# 8. 44(42) SR: 104.76
# 9. 77(57) SR: 135.09
# 10. 92(52) SR: 176.92
#
# ### Total Batting Statistics
#
# Here are Devon Conway's total batting statistics:
#
# - **Total Runs:** 491
# - **Total Balls:** 359
# - **Average Runs:** 49.1
# - **Overall Strike Rate:** 136.77
#
# ### Batting Phase Stats
#
# Here's a breakdown of Devon Conway's batting performance in different phases:
#
# - **Powerplay:**
#   - **Runs:** 418
#   - **Balls:** 310
#   - **Strike Rate:** 134.84
# - **Middle Overs:**
#   - **Runs:** 471
#   - **Balls:** 315
#   - **Strike Rate:** 149.52
# - **Death Overs:**
#   - **Runs:** 64
#   - **Balls:** 42
#   - **Strike Rate:** 152.38
#
# ### Wicket Analysis
#
# Unfortunately, there is no wicket analysis data available for Devon Conway.
#
# ### Batting Control
#
# Here's a breakdown of Devon Conway's batting control:
#
# - **In-Control:** 550
# - **No-Control:** 102
# - **Beaten:** 15
#
# ### Scoring Zones
#
# Here's a breakdown of Devon Conway's scoring zones:
#
# - **Square:** 94
# - **Mid-wicket:** 82
# - **Cover:** 72
# - **Keeper:** 60
# - **Long-on:** 53
# - **Point:** 52
# - **Long-off:** 45
# - **Fine-leg:** 43
# - **Blocked:** 37
# - **Third-man:** 23
#
# ### Boundary Analysis
#
# Here's a breakdown of Devon Conway's boundary analysis:
#
# - **Boundary Details:**
#   - ('drive', 'full', 'outside-off'): 7
#   - ('flick', 'full', 'leg-stump'): 4
#   - ('pull', 'short', 'leg-stump'): 4
#   - ('sweep', 'full', 'leg-stump'): 5
# - **Boundary Percentage:** 19.94%
# --------------------------------------------------
# Player ID: 9585
# Name: Kagiso Rabada
# Summary: **Kagiso Rabada's Performance Breakdown**
#
# **Batting Statistics**
#
# ### Matches
#
# - Match 1: 1(1) SR: 100
# - Match 2: 8(3) SR: 266.67
# - Match 3: 0(1) SR: 0
#
# ### Total Batting Statistics
#
# - Total Runs: 9
# - Total Balls Faced: 5
# - Average Runs: 3.0
# - Overall Strike Rate: 180.0
#
# ### Batting Phase Stats
#
# - **Powerplay**: 0(0) SR: 0
# - **Middle Overs**: 6(17) SR: 35.29
# - **Death Overs**: 52(37) SR: 140.54
#
# ### Batting Control
#
# - In-Control: 35
# - No-Control: 19
#
# ### Scoring Zones
#
# - Blocked: 11
# - Cover: 7
# - Keeper: 7
# - Long-Off: 5
# - Long-On: 4
# - Mid-Wicket: 3
# - Third-Man: 2
# - Point: 2
# - Fine-Leg: 1
# - Square: 1
#
# ### Boundary Analysis
#
# - Boundary Percentage: 14.81%
# - Boundary Details:
#   - ('shot_played', 'ball_length', 'ball_line'): {}
#   - Note: No boundary details available.
#
# **Bowling Statistics**
#
# ### Matches
#
# - Match 1: 52(3.0) Econ: 17.3 Wkts: 0
# - Match 2: 40(4.0) Econ: 10.0 Wkts: 0
# - Match 3: 42(4.0) Econ: 10.5 Wkts: 1
# - Match 4: 18(4.0) Econ: 4.5 Wkts: 2
# - Match 5: 32(4.0) Econ: 8.0 Wkts: 1
# - Match 6: 44(4.0) Econ: 11.0 Wkts: 2
# - Match 7: 38(4.0) Econ: 9.5 Wkts: 1
# - Match 8: 23(4.0) Econ: 5.8 Wkts: 2
# - Match 9: 36(4.0) Econ: 9.0 Wkts: 1
# - Match 10: 52(4.0) Econ: 13.0 Wkts: 2
#
# ### Total Bowling Statistics
#
# - Total Runs Conceded: 377
# - Total Wickets: 12
# - Total Balls Bowled: 234
# - Runs per Wicket: 31.42
# - Balls per Wicket: 19.5
#
# ### Bowling Phase Stats
#
# - **Powerplay**: 510(340) Econ: 9.0 Wkts: 13
# - **Middle Overs**: 265(192) Econ: 8.28 Wkts: 9
# - **Death Overs**: 215(136) Econ: 9.49 Wkts: 11
#
# ### Wicket Analysis
#
# - ('ball_length', 'ball_line','bowling_variation'):
#   - ('full', 'outside-off', 'normal'): 2
#   - ('good length', 'outside-off', 'normal'): 4
#   - ('length ball', 'outside-off', 'normal'): 3
#   - ('short', 'outside-off', 'normal'): 4
#
# ### Boundary Analysis
#
# - Boundary Percentage: 23.05%
# - Boundary Details:
#   - ('ball_length', 'ball_line','bowling_variation'):
#     - ('back of a length', 'outside-off', 'normal'): 3
#     - ('full', 'leg-stump', 'normal'): 6
#     - ('full', 'outside-off', 'normal'): 20
#     - ('full', 'wide', 'normal'): 4
#     - ('full-toss', 'leg-stump', 'normal'): 3
#     - ('good length', 'off-stump', 'normal'): 3
#     - ('good length', 'outside-off', 'normal'): 3
#     - ('length ball', 'outside-off', 'normal'): 5
#     - ('short', 'leg-stump', 'normal'): 8
#     - ('short', 'outside-off', 'normal'): 6
#     - ('short', 'wide', 'normal'): 5
#
# ### Variation Frequency
#
# - Variation: Count
#   - Normal: 550
#   - Slower: 42
#   - Yorker: 27
#   - Quick: 24
#   - Bouncer: 7
#   - Cutter: 5
#   - Seam-Away: 5
#   - Swing: 2
#   - In-Swing: 2
#   - Seam-Up: 2
#   - Out-Swing: 2
# --------------------------------------------------
# Player ID: 10226
# Name: Shahrukh Khan
# Summary: **Shahrukh Khan's Performance Breakdown**
#
# **BATTING STATISTICS**
#
# ### Matches
#
# | Match | Runs (Balls) | Strike Rate |
# | --- | --- | --- |
# | 1 | 15(8) SR: 187.5 |  |
# | 2 | 0(2) SR: 0.0 |  |
# | 3 | 19(17) SR: 111.76 |  |
# | 4 | 33(33) SR: 100.0 |  |
# | 5 | 39(25) SR: 156.0 |  |
# | 6 | 0(0) SR: 0.0 |  |
# | 7 | 31(18) SR: 172.22 |  |
# | 8 | 58(30) SR: 193.33 |  |
# | 9 | 8(5) SR: 160.0 |  |
# | 10 | 8(4) SR: 200.0 |  |
#
# ### Total Batting Statistics
#
# * Total Runs: 211
# * Total Balls: 142
# * Average Runs: 21.1
# * Overall Strike Rate: 148.59
#
# ### Batting Phase Stats
#
# | Phase | Runs (Balls) | Strike Rate |
# | --- | --- | --- |
# | Powerplay | 15(7) SR: 214.29 |  |
# | Middle | 178(148) SR: 120.27 |  |
# | Death | 182(113) SR: 161.06 |  |
#
# ### Wicket Analysis
#
# No data available
#
# ### Batting Control
#
# * In-control: 207
# * No-control: 57
# * Beaten: 4
#
# ### Scoring Zones
#
# | Zone | Runs |
# | --- | --- |
# | Cover | 30 |
# | Long-on | 28 |
# | Blocked | 28 |
# | Mid-wicket | 27 |
# | Long-off | 26 |
# | Keeper | 23 |
# | Square | 21 |
# | Point | 20 |
# | Fine-leg | 17 |
# | Third-man | 8 |
#
# ### Boundary Analysis
#
# * Percentage: 18.28%
# * Details: No data available
#
# **BOWLING STATISTICS**
#
# ### Matches
#
# | Match | Runs (Overs) | Economy | Wickets |
# | --- | --- | --- | --- |
# | 1 | 19(4.0) Econ: 4.8 Wkts: 2 |  |
# | 2 | 16(2.0) Econ: 8.0 Wkts: 1 |  |
# | 3 | 21(1.0) Econ: 21.0 Wkts: 0 |  |
# | 4 | 16(3.0) Econ: 5.3 Wkts: 1 |  |
# | 5 | 18(1.0) Econ: 18.0 Wkts: 0 |  |
# | 6 | 8(1.0) Econ: 8.0 Wkts: 0 |  |
# | 7 | 7(1.0) Econ: 7.0 Wkts: 0 |  |
#
# ### Total Bowling Statistics
#
# * Total Runs Conceded: 105
# * Total Wickets: 4
# * Total Balls Bowled: 78
# * Runs per Wicket: 26.25
# * Balls per Wicket: 19.5
#
# ### Bowling Phase Stats
#
# | Phase | Runs | Balls | Wickets | Runs per Wicket | Balls per Wicket | Economy |
# | --- | --- | --- | --- | --- | --- | --- |
# | Powerplay | 0 | 0 | 0 | Infinity | Infinity | 0 |
# | Middle | 9 | 6 | 0 | Infinity | Infinity | 9.0 |
# | Death | 7 | 6 | 0 | Infinity | Infinity | 7.0 |
#
# ### Wicket Analysis
#
# No data available
#
# ### Boundary Analysis
#
# * Percentage: 8.33%
# * Details: No data available
#
# ### Variation Frequency
#
# * Normal: 10
# * Quick: 2
# --------------------------------------------------
# Player ID: 10738
# Name: Rashid Khan
# Summary: **Rashid Khan's Performance Breakdown**
#
# **Batting Performance**
#
# ### Matches
#
# 1. 21(11) SR: 190.91
# 2. 3(3) SR: 100.0
# 3. 31(24) SR: 129.17
# 4. 24(11) SR: 218.18
# 5. 0(3) SR: 0.0
# 6. 1(2) SR: 50.0
# 7. 4(3) SR: 133.33
#
# ### Total Batting Statistics
#
# - Total Runs: 84
# - Total Balls: 57
# - Average Runs: 12.0
# - Overall Strike Rate: 147.37
#
# ### Batting Phase Stats
#
# - **Powerplay**: 0(0) SR: 0
# - **Middle**: 71(52) SR: 136.54
# - **Death**: 246(119) SR: 206.72
#
# ### Wicket Analysis
#
# No data available.
#
# ### Batting Control
#
# - In-Control: 129
# - No-Control: 40
# - Beaten: 2
#
# ### Scoring Zones
#
# - Mid-Wicket: 27
# - Cover: 21
# - Keeper: 19
# - Blocked: 16
# - Long-Off: 15
# - Long-On: 14
# - Point: 11
# - Square: 11
# - Fine-Leg: 8
# - Third-Man: 4
#
# ### Boundary Analysis
#
# - Details: ('cut', 'short', 'wide'): 2
# - Percentage: 26.90%
#
# **Bowling Performance**
#
# ### Matches
#
# 1. 51(4.0) Econ: 12.8 Wkts: 0
# 2. 35(4.0) Econ: 8.8 Wkts: 0
# 3. 15(4.0) Econ: 3.8 Wkts: 1
# 4. 12(2.0) Econ: 6.0 Wkts: 1
# 5. 18(4.0) Econ: 4.5 Wkts: 1
# 6. 28(4.0) Econ: 7.0 Wkts: 1
# 7. 40(4.0) Econ: 10.0 Wkts: 1
# 8. 33(4.0) Econ: 8.2 Wkts: 1
# 9. 49(4.0) Econ: 12.2 Wkts: 2
# 10. 23(4.0) Econ: 5.8 Wkts: 0
#
# ### Total Bowling Statistics
#
# - Total Runs Conceded: 304
# - Total Wickets: 8
# - Total Balls Bowled: 228
# - Runs per Wicket: 38.0
# - Balls per Wicket: 28.5
#
# ### Bowling Phase Stats
#
# - **Powerplay**: 240(162) Econ: 8.89 Wkts: 5
# - **Middle**: 873(733) Econ: 7.15 Wkts: 24
# - **Death**: 182(126) Econ: 8.67 Wkts: 8
#
# ### Wicket Analysis
#
# - ('full', 'outside-off', 'normal'): 3
# - ('short', 'middle-stump', 'normal'): 2
# - ('short', 'outside-off', 'normal'): 2
#
# ### Boundary Analysis
#
# - Details:
#   - ('full', 'leg-stump', 'normal'): 4
#   - ('full', 'outside-off', 'normal'): 11
#   - ('full', 'wide', 'normal'): 3
#   - ('short', 'leg-stump', 'normal'): 5
#   - ('short', 'outside-off', 'normal'): 4
#   - ('tossed up', 'leg-stump', 'normal'): 3
#   - ('tossed up', 'outside-off', 'normal'): 3
# - Percentage: 13.32%
#
# ### Variation Frequency
#
# - Normal: 692
# - Googly: 198
# - Quick: 83
# - Leg-Break: 28
# - Slower: 12
# - Leg-Spin: 6
# - Slider: 1
# - Yorker: 1
# --------------------------------------------------
