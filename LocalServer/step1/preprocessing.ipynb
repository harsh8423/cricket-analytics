# %%
import pandas as pd
import json
from pymongo import MongoClient

# MongoDB Atlas connection
client = MongoClient("mongodb+srv://harsh8423:8423047004@cluster0.1xbklyu.mongodb.net/cricket")
db = client["cricket"]

# Collections
matches_collection = db["matches"]
players_collection = db["players"]

# Load JSON file
file_path = "cricket.commentaries.json"  # Replace with your actual file path
with open(file_path, 'r') as file:
    data = json.load(file)

# Fetch all players and matches data once
players_data = list(players_collection.find({}, {'_id': 1, 'bowling_type': 1, 'batting_style': 1, 'bowling_style': 1}))
matches_data = list(matches_collection.find({}, {'_id': 1, 'venue.name': 1}))

# Convert players data to dictionaries for faster lookup
players_dict = {str(player['_id']): player for player in players_data}
matches_dict = {str(match['_id']): match for match in matches_data}

# Since data is a list, we'll process each match in the list
all_commentary = []

for match in data:
    # For innings 1
    if 'commentary_innings1' in match:
        for ball in match['commentary_innings1']:
            ball_data = {
                '_id': match['_id'],
                'commText': ball.get('commText', ''),
                'overNumber': ball.get('overNumber', None),
                'batTeamName': ball.get('batTeamName', ''),
                'inningruns': ball.get('inningruns', None),
                'batsman_name': ball.get('batsman', {}).get('batName', ''),
                'bowler_name': ball.get('bowler', {}).get('bowlName', ''),
                'batsman_id': int(ball.get('batsman', {}).get('batId')) if ball.get('batsman', {}).get('batId') is not None else None,
                'bowler_id': int(ball.get('bowler', {}).get('bowlId')) if ball.get('bowler', {}).get('bowlId') is not None else None,
                'event': ball.get('event', ''),
                'is_wicket': ball.get('isWicket', False),
                'wicket_type': ball.get('wicketType', ''),
                'shot_played': ball.get('shotPlayed', ''),
                'ball_length': ball.get('ballLength', ''),
                'ball_line': ball.get('ballLine', ''),
                'batting_control': ball.get('battingControl', ''),
                'bowling_variation': ball.get('bowlingVariation', ''),
                'shot_direction': ball.get('shotDirection', ''),
                'inning': 1
            }
            all_commentary.append(ball_data)

    # For innings 2
    if 'commentary_innings2' in match:
        for ball in match['commentary_innings2']:
            ball_data = {
                '_id': match['_id'],
                'commText': ball.get('commText', ''),
                'overNumber': ball.get('overNumber', None),
                'batTeamName': ball.get('batTeamName', ''),
                'inningruns': ball.get('inningruns', None),
                'batsman_name': ball.get('batsman', {}).get('batName', ''),
                'bowler_name': ball.get('bowler', {}).get('bowlName', ''),
                'batsman_id': int(ball.get('batsman', {}).get('batId')) if ball.get('batsman', {}).get('batId') is not None else None,
                'bowler_id': int(ball.get('bowler', {}).get('bowlId')) if ball.get('bowler', {}).get('bowlId') is not None else None,
                'event': ball.get('event', ''),
                'is_wicket': ball.get('isWicket', False),
                'wicket_type': ball.get('wicketType', ''),
                'shot_played': ball.get('shotPlayed', ''),
                'ball_length': ball.get('ballLength', ''),
                'ball_line': ball.get('ballLine', ''),
                'batting_control': ball.get('battingControl', ''),
                'bowling_variation': ball.get('bowlingVariation', ''),
                'shot_direction': ball.get('shotDirection', ''),
                'inning': 2
            }
            all_commentary.append(ball_data)

# Convert to DataFrame
commentary = pd.DataFrame(all_commentary)

def process_commentary(commentary):
    
    # Convert IDs to strings for consistent comparison
    commentary['batsman_id'] = commentary['batsman_id'].astype(str)
    commentary['bowler_id'] = commentary['bowler_id'].astype(str)
    commentary['_id'] = commentary['_id'].astype(str)

        # Function to extract runs scored
    def extract_runs(comm_text):
        if "SIX" in comm_text or "six" in comm_text:
            return 6
        elif "FOUR" in comm_text or "four" in comm_text:
            return 4
        elif "1 run" in comm_text:
            return 1
        elif "2 runs" in comm_text:
            return 2
        elif "3 runs" in comm_text:
            return 3
        elif "no run" in comm_text:
            return 0
        else:
            return 0
        return None

    def wicket_type(comm_text):
        # Array of wicket type keywords for easy future additions
        wicket_keywords = ['runout', 'stumped', 'lbw', 'hit wicket']
        
        # Check for special combinations first
        text_lower = comm_text.lower()
        if 'caught' in text_lower and 'edge' in text_lower:
            return 'edge&caught'
        elif 'played on' in text_lower and 'bowled' in text_lower:
            return 'played_on'
        
        # Check for individual keywords
        if 'caught' in text_lower:
            return 'caught'
        if 'bowled' in text_lower:
            return 'bowled'
        
        # Check other wicket types
        for wicket in wicket_keywords:
            if wicket in text_lower:
                return wicket
        
        return 'wicket'

    def extract_shot(comm_text):
        shot_keywords = ['pull', 'cut', 'drive', 'sweep', 'flick', 'hook', 'loft','slog', 'punch','down the ground','across the line','scoop']
        if 'goes down' in comm_text.lower() or 'whip' in comm_text.lower():
            return 'loft'
        if 'nudge' in comm_text.lower() or 'tap' in comm_text.lower() or 'darted' in comm_text.lower() or 'paddle' in comm_text.lower() or 'tuck' in comm_text.lower() or 'pushed' in comm_text.lower() or 'knock' in comm_text.lower() or 'clipped' in comm_text.lower() or 'steer' in comm_text.lower() or 'dab' in comm_text.lower():
            return 'pushed slightly'
        if 'defend' in comm_text.lower() or 'defence' in comm_text.lower() or 'blocked' in comm_text.lower():
            return 'defend'
        for shot in shot_keywords:
            if shot in comm_text.lower():
                return shot
        return None

    def extract_direction(comm_text):
        direction_keywords = ['cover', 'square', 'point']
        
        for direction in direction_keywords:
            if direction in comm_text.lower():
                return direction
        if 'fine leg' in comm_text.lower() or 'fine-leg' in comm_text.lower() or 'fine' in comm_text.lower():
            return 'fine-leg'
        if 'third-man' in comm_text.lower() or 'third man' in comm_text.lower():
            return 'third-man'
        if 'mid-wicket' in comm_text.lower() or 'midwicket' in comm_text.lower() or 'mid wicket' in comm_text.lower():
            return 'mid-wicket'
        if 'mid-on' in comm_text.lower() or 'mid on' in comm_text.lower():
            return 'mid-wicket'
        if 'mid-off' in comm_text.lower() or 'mid off' in comm_text.lower():
            return 'long-off'
        if 'long-on' in comm_text.lower() or 'long on' in comm_text.lower():
            return 'long-on'
        if 'long-off' in comm_text.lower() or 'long off' in comm_text.lower():
            return 'long-off'
        if 'defend' in comm_text.lower() or 'defence' in comm_text.lower() or 'blocked' in comm_text.lower() or 'wide' in comm_text.lower():
            return 'blocked'
        if  'keeper' in comm_text.lower():
            return 'keeper'
        return None

    def extract_length(comm_text):
        length_keywords = ['short', 'full', 'yorker', 'bouncer','half-volley','good length','tossed up']
        
        if 'full toss' in comm_text.lower() or 'full-toss' in comm_text.lower():
            return 'full-toss'
        for length in length_keywords:
            if length in comm_text.lower():
                return length
        if 'back of a length' in comm_text.lower() or 'short of a length' in comm_text.lower():
            return 'back of a length'
        elif 'length delivery' in comm_text.lower() or 'length ball' in comm_text.lower():
            return 'length ball'
        
        return None

    def extract_ball_line(comm_text):
        text_lower = comm_text.lower()
        line_keywords = {
            'outside-off': ['outside off', 'outside-off'],
            'off-stump': ['off stump line', 'off-stump', 'off stump', 'around off','middle and off'],
            'middle-stump': ['middle stump', 'middle-stump','on middle', 'on stump', 'around middle','middle and leg', 'body'],
            'leg-stump': ['leg stump', 'leg-stump', 'outside leg','on leg','leg bye', 'around leg','down leg', 'down-leg'],
            'wide': ['wide']
        }
        variations = ['seam', 'swing', 'seam-away', 'seam-in', 'seam-up',]
        for line, variations in line_keywords.items():
            for variation in variations:
                if variation in text_lower:
                    return line
            if ('swing' not in text_lower or 'seam' not in text_lower) and 'pads' in text_lower:
                return 'leg-stump'
        return None

    def extract_batting_control(row):
        text_lower = row['commText'].lower()
        control_keywords = {
            'no-control': ['missed', 'misses', 'edge', 'edges'],
            'beaten': ['beaten', 'beats']
        }

        if row['event'] == 'WICKET':
            return 'no-control'
        
        for control, keywords in control_keywords.items():
            for keyword in keywords:
                if keyword in text_lower:
                    return control
        return 'in-control'



    def extract_bowling_variation(comm_text):
        text_lower = comm_text.lower()
        
        # Check for combined variations first
        if 'seam' in text_lower and 'away' in text_lower:
            return 'seam-away'
        if 'seaming' in text_lower and 'in' in text_lower:
            return 'seam-in'
        
        variation_keywords = {
            'seam-up': ['seam up', 'seam-up'],
            'out-swing': ['swinging away','outswinger'],
            'in-swing': ['swinging in','inswinger'],
            'swing': ['swinging'],
            'googly': ['googly'],
            'slower': ['slower', 'lack of pace'],
            'cutter': ['cutter'],
            'yorker': ['yorker'],
            'bouncer': ['bouncer'],
            'off-break': ['off-break'],
            'carrom ball': ['carrom'],
            'flipper': ['flipper'],
            'leg-break': ['leg-break'],
            'off-spin': ['off-spin'],
            'leg-spin': ['leg spin'],
            'knuckle ball': ['knuckle ball'],
            'quick': ['quick'],
            'arm ball': ['arm ball'],
            'slider':['slider'],
            'skidding':['skidding', 'skidded']

        }
        
        for variation, keywords in variation_keywords.items():
            for keyword in keywords:
                if keyword in text_lower:
                    return variation
        return 'normal'
    
    # Add new fields from MongoDB data
    def get_bowler_type(bowler_id):
        player = players_dict.get(str(bowler_id))
        return player.get('bowling_type') if player else None

    def get_batting_hand(batsman_id):
        player = players_dict.get(str(batsman_id))
        if player and player.get('batting_style'):
            return 'right' if player['batting_style'].startswith('Right') else 'left'
        return None

    def get_bowling_hand(bowler_id):
        player = players_dict.get(str(bowler_id))
        if player and player.get('bowling_style'):
            if player['bowling_style'].startswith('Right'):
                return 'right'
            elif player['bowling_style'].startswith('Left'):
                return 'left'
        return None

    def get_venue(match_id):
        match = matches_dict.get(str(match_id))
        return match.get('venue', {}).get('name') if match else None

    # Extract runs and apply transformations
    commentary['runs'] = commentary['commText'].apply(extract_runs)
    
    # Apply the new transformations
    commentary['bowler_type'] = commentary['bowler_id'].apply(get_bowler_type)
    commentary['batter_hand'] = commentary['batsman_id'].apply(get_batting_hand)
    commentary['bowler_hand'] = commentary['bowler_id'].apply(get_bowling_hand)
    commentary['venue'] = commentary['_id'].apply(get_venue)

    # Identify if it's a wicket ball
    commentary['is_wicket'] = commentary['event'] == 'WICKET'
    
    # Apply wicket type only if it's a wicket ball
    commentary['wicket_type'] = commentary.apply(
        lambda row: wicket_type(row['commText']) if row['event'] == 'WICKET' else 'N/A',
        axis=1
    )
    
    # Apply existing transformations
    commentary['shot_played'] = commentary['commText'].apply(extract_shot)
    commentary['ball_length'] = commentary['commText'].apply(extract_length)
    commentary['ball_line'] = commentary['commText'].apply(extract_ball_line)
    commentary['batting_control'] = commentary.apply(extract_batting_control, axis=1)
    commentary['bowling_variation'] = commentary['commText'].apply(extract_bowling_variation)
    commentary['shot_direction'] = commentary['commText'].apply(extract_direction)
    
    return commentary

# Process the commentary DataFrame
commentary = process_commentary(commentary)

# Update column order to include new fields
column_order = [
    '_id', 'commText', 'overNumber', 'batTeamName',
    'batsman_name', 'bowler_name', 'batsman_id', 'bowler_id',
    'batter_hand', 'bowler_hand', 'bowler_type', 'venue',
    'is_wicket', 'wicket_type', 'shot_played', 'ball_length',
    'ball_line', 'batting_control', 'bowling_variation', 'shot_direction',
    'inning','runs'
]
commentary = commentary[column_order]
# # Remove unwanted columns
# columns_to_remove = [
#         'event','inningruns','batsman_name', 'bowler_name', 'batsman_id', 'bowler_id',
#     ]
# commentary.drop(columns=columns_to_remove, inplace=True)

# %%
def refine_commentary_fields(commentary):
    """
    Refine values in the filtered commentary based on specific cricket-related conditions
    """
    # Create a copy to avoid modifying the original DataFrame
    refined_df = commentary.copy()
    
    # Apply condition 1: Update shot_direction based on batting control and wicket type
    mask_control = (refined_df['batting_control'] != 'in-control') & (refined_df['shot_direction'].isnull())
    mask_stumped = refined_df['wicket_type'] == 'stumped'
    refined_df.loc[mask_control | mask_stumped, 'shot_direction'] = 'keeper'
    
    # Apply condition 2: Update shot_played based on direction and runs
    mask_shot_null = refined_df['shot_played'].isnull() & refined_df['shot_direction'].notnull()
    mask_low_runs = refined_df['runs'].isin([0, 1, 2])
    refined_df.loc[mask_shot_null & mask_low_runs, 'shot_played'] = 'pushed slightly'
    
    # Apply condition 3: Update ball_line based on shot direction and bowling variation
    mask_offside_direction = refined_df['shot_direction'].isin(['cover', 'point', 'third-man'])
    mask_not_away = ~refined_df['bowling_variation'].isin(['seam-away', 'out-swing'])
    mask_valid_line = refined_df['ball_line'].isnull()
    refined_df.loc[mask_valid_line & mask_offside_direction & mask_not_away, 'ball_line'] = 'outside-off'
    
    # Apply condition 4: Update ball_length based on multiple conditions
    # Condition 4.1: outside-off drive
    mask_outside_off_drive = (refined_df['ball_line'] == 'outside-off') & (refined_df['shot_played'] == 'drive')
    
    # Condition 4.2: specific shots
    mask_specific_shots = refined_df['shot_played'].isin(['slog', 'scoop', 'sweep'])
    
    # Condition 4.3: swing variations
    mask_swing = refined_df['bowling_variation'].isin(['in-swing', 'out-swing'])
    
    # Condition 4.4: point/third-man cut
    mask_cut_direction = refined_df['shot_direction'].isin(['point', 'third-man'])
    mask_cut_shot = refined_df['shot_played'] == 'cut'
    
    # Apply length updates
    mask_valid_length = refined_df['ball_length'].isnull()
    refined_df.loc[mask_valid_length & (mask_outside_off_drive | mask_specific_shots | mask_swing), 'ball_length'] = 'full'
    refined_df.loc[mask_valid_length & mask_cut_direction & mask_cut_shot, 'ball_length'] = 'back of a length'
    
    # Apply condition 5: Update ball_line based on additional conditions
    # Condition 5.1: off-stump line
    mask_off_direction = refined_df['shot_direction'].isin(['mid-off', 'long-off'])
    mask_pushed = refined_df['shot_played'] == 'pushed slightly'
    mask_not_short = refined_df['ball_length'] != 'short'
    mask_valid_line = refined_df['ball_line'].isnull()
    refined_df.loc[mask_valid_line & mask_off_direction & mask_pushed & mask_not_short, 'ball_line'] = 'off-stump'
    
    # Condition 5.2: leg-stump line for fine-leg direction
    mask_fine_leg = refined_df['shot_direction'] == 'fine-leg'
    mask_leg_shots = refined_df['shot_played'].isin(['pull', 'flick', 'sweep'])
    refined_df.loc[mask_valid_line & mask_fine_leg & mask_leg_shots, 'ball_line'] = 'leg-stump'
    
    # Condition 5.3: leg-stump line for square direction
    mask_square = refined_df['shot_direction'] == 'square'
    mask_not_short_back = ~refined_df['ball_length'].isin(['short', 'back of a length'])
    refined_df.loc[mask_valid_line & mask_square & mask_not_short_back, 'ball_line'] = 'leg-stump'
    
    return refined_df

# Apply the refinements to the filtered commentary
refined_commentary = refine_commentary_fields(commentary)


# Filter rows where specific columns are not None
commentary_before = commentary[
    # (commentary['bowler_id']==265)
    # (commentary['batsman_id']==1413)
    (commentary['shot_played'].notnull())&
    (commentary['ball_length'].notnull())&
    (commentary['ball_line'].notnull())&
    # (commentary['batting_control'] != 'in-control')&
    # (commentary['bowling_variation'] !='normal')
    (commentary['shot_direction'].notnull())
    # ((commentary['runs']==0) | (commentary['runs']==1) | (commentary['runs']==2)) & 
    # (commentary['is_wicket']!=True)
]


# Filter rows where specific columns are not None
commentary_after = refined_commentary[
    # (refined_commentary['bowler_id']==265)
    # (refined_commentary['batsman_id']==1413)
    (refined_commentary['shot_played'].notnull())&
    (refined_commentary['ball_length'].notnull())&
    (refined_commentary['ball_line'].notnull())&
    # (refined_commentary['batting_control'].notnull)
#     (refined_commentary['bowling_variation'] !='normal')
    (refined_commentary['shot_direction'].notnull())
#     ((refined_commentary['runs']==0) | (refined_commentary['runs']==1) | (refined_commentary['runs']==2)) & 
#     (refined_commentary['is_wicket']!=True)
]

# Print the filtered rows
row_count = len(commentary_before)
print(f"Number of rows in commentary_before: {row_count}")

# Print the filtered rows
row_count = len(commentary_after)
print(f"Number of rows in refined_commentary: {row_count}")
commentary_after.tail(25)

# Get first 20 rows and save to CSV
# refined_commentary.head(20).to_csv('commentary_20_rows.csv', index=False)
refined_commentary.head(20)
# Out:
# Number of rows in commentary_before: 9083
# Number of rows in refined_commentary: 19434
#       _id                                           commText  overNumber  \
# 0   66169   Joshua Little to Dhoni, 1 run, CSK finish wit...        19.6
# 1   66169   Joshua Little to Dhoni, no run, slower one ou...        19.5
# 2   66169   Joshua Little to Dhoni, FOUR, and now Hardik ...        19.4
# 3   66169   Joshua Little to Dhoni, SIX, and MSD makes su...        19.3
# 4   66169   Joshua Little to Santner, leg byes, 1 run, fi...        19.2
# 5   66169   Joshua Little to Dhoni, 1 run, width on offer...        19.1
# 6   66169   Shami to Dhoni, 1 run, short ball by Shami to...        18.6
# 7   66169   Shami to Santner, 1 run, short and quick on m...        18.5
# 8   66169   Shami to Santner, no run, pats this back to t...        18.4
# 9   66169   Shami to Shivam Dube, out Caught by Rashid Kh...        18.3
# 10  66169   Shami to Shivam Dube, SIX, that is what was m...        18.2
# 11  66169   Shami to Shivam Dube, 2 runs, in the air, but...        18.1
# 12  66169   Alzarri Joseph to Shivam Dube, 1 run, that's ...        17.6
# 13  66169   Alzarri Joseph to Dhoni, 1 run, hooked throug...        17.5
# 14  66169  Alzarri Joseph to Jadeja, out Caught by Shanka...        17.4
# 15  66169   Alzarri Joseph to Shivam Dube, 1 run, Alzarri...        17.3
# 16  66169   Alzarri Joseph to Jadeja, 1 run, swiped throu...        17.2
# 17  66169   Alzarri Joseph to Gaikwad, out Caught by Shub...        17.1
# 18  66169   Rashid Khan to Gaikwad, 1 run, end of a prett...        16.6
# 19  66169   Rashid Khan to Gaikwad, no run, fraction shor...        16.5
#
#    batTeamName      batsman_name     bowler_name batsman_id bowler_id  \
# 0          CSK          MS Dhoni   Joshua Little        265     11128
# 1          CSK          MS Dhoni   Joshua Little        265     11128
# 2          CSK          MS Dhoni   Joshua Little        265     11128
# 3          CSK          MS Dhoni   Joshua Little        265     11128
# 4          CSK  Mitchell Santner   Joshua Little      10100     11128
# 5          CSK          MS Dhoni   Joshua Little        265     11128
# 6          CSK          MS Dhoni  Mohammed Shami        265      7909
# 7          CSK  Mitchell Santner  Mohammed Shami      10100      7909
# 8          CSK  Mitchell Santner  Mohammed Shami      10100      7909
# 9          CSK       Shivam Dube  Mohammed Shami      11195      7909
# 10         CSK       Shivam Dube  Mohammed Shami      11195      7909
# 11         CSK       Shivam Dube  Mohammed Shami      11195      7909
# 12         CSK       Shivam Dube  Alzarri Joseph      11195     11220
# 13         CSK          MS Dhoni  Alzarri Joseph        265     11220
# 14         CSK   Ravindra Jadeja  Alzarri Joseph        587     11220
# 15         CSK       Shivam Dube  Alzarri Joseph      11195     11220
# 16         CSK   Ravindra Jadeja  Alzarri Joseph        587     11220
# 17         CSK   Ruturaj Gaikwad  Alzarri Joseph      11813     11220
# 18         CSK   Ruturaj Gaikwad     Rashid Khan      11813     10738
# 19         CSK   Ruturaj Gaikwad     Rashid Khan      11813     10738
#
#    batter_hand bowler_hand  ... is_wicket  wicket_type      shot_played  \
# 0        right        left  ...     False          N/A             pull
# 1        right        left  ...     False          N/A  pushed slightly
# 2        right        left  ...     False          N/A            flick
# 3        right        left  ...     False          N/A             pull
# 4         left        left  ...     False          N/A  pushed slightly
# 5        right        left  ...     False          N/A  pushed slightly
# 6        right       right  ...     False          N/A             pull
# 7         left       right  ...     False          N/A  pushed slightly
# 8         left       right  ...     False          N/A             None
# 9         left       right  ...      True  edge&caught             pull
# 10        left       right  ...     False          N/A             pull
# 11        left       right  ...     False          N/A             pull
# 12        left       right  ...     False          N/A             None
# 13       right       right  ...     False          N/A             hook
# 14        left       right  ...      True       caught            flick
# 15        left       right  ...     False          N/A             pull
# 16        left       right  ...     False          N/A             None
# 17       right       right  ...      True       caught  pushed slightly
# 18       right       right  ...     False          N/A            punch
# 19       right       right  ...     False          N/A            punch
#
#          ball_length     ball_line batting_control bowling_variation  \
# 0               None     leg-stump      in-control            slower
# 1               None   outside-off      no-control            slower
# 2               None     leg-stump      in-control            normal
# 3   back of a length          None      in-control            normal
# 4          full-toss     leg-stump      in-control             quick
# 5               None   outside-off      in-control            normal
# 6              short          None      in-control            normal
# 7              short  middle-stump      in-control             quick
# 8               None          None      in-control            normal
# 9              short          None      no-control            normal
# 10             short          None      in-control            normal
# 11             short     leg-stump      no-control            normal
# 12              full          None      in-control             quick
# 13             short          None      in-control            normal
# 14              full  middle-stump      no-control            normal
# 15             short          None      in-control            normal
# 16              None          None      in-control            normal
# 17         full-toss          None      no-control             quick
# 18              None   outside-off      in-control            normal
# 19             short   outside-off      in-control            normal
#
#    shot_direction inning runs
# 0          square      1    1
# 1          keeper      1    0
# 2          square      1    4
# 3          square      1    6
# 4          square      1    1
# 5           cover      1    1
# 6            None      1    1
# 7         long-on      1    1
# 8            None      1    0
# 9          square      1    6
# 10           None      1    6
# 11       fine-leg      1    2
# 12           None      1    1
# 13         square      1    1
# 14     mid-wicket      1    0
# 15     mid-wicket      1    1
# 16           None      1    1
# 17        long-on      1    0
# 18          cover      1    1
# 19          cover      1    0
#
# [20 rows x 22 columns]

# %%
from pymongo import MongoClient
import pandas as pd

# MongoDB Atlas connection
client = MongoClient("mongodb+srv://harsh8423:8423047004@cluster0.1xbklyu.mongodb.net/cricket")
db = client["cricket"]  # Replace with your database name

# Collections
matches_collection = db["matches"]
teams_collection = db["teams"]
players_collection = db["players"]
scorecards_collection = db["scorecards"]
commentaries_collection = db["commentaries"]

def analyze_venue_matches(venue_name, commentary_df):
    # Filter commentary data for the specific venue
    venue_data = commentary_df[commentary_df['venue'] == venue_name].copy()

    # print(venue_data)
    
    # Helper function to calculate metrics for a group of data
    def calculate_metrics(data):
        total_runs = data['runs'].sum()
        total_balls = len(data)
        total_wickets = data['is_wicket'].sum()
        economy_rate = (total_runs * 6) / total_balls if total_balls > 0 else 0
        strike_rate = (total_runs * 100) / total_balls if total_balls > 0 else 0
        balls_per_wicket=total_balls/total_wickets if total_balls > 0 else 0
        runs_per_wicket=total_runs/total_wickets if total_balls > 0 else 0
        
        return {
            'total_runs': total_runs,
            'total_balls': total_balls,
            'total_wickets': total_wickets,
            'runs_per_wicket': round(runs_per_wicket,2),
            'balls_per_wicket':round(balls_per_wicket,2),
            'economy_rate': round(economy_rate, 2),
            'strike_rate': round(strike_rate, 2)
        }
    
    # 1. Overall analysis by bowler_type
    overall_stats = []
    for bowler_type in ['pace', 'spin']:
        type_data = venue_data[venue_data['bowler_type'] == bowler_type]
        metrics = calculate_metrics(type_data)
        metrics['bowler_type'] = bowler_type
        metrics['innings'] = 'Overall'
        overall_stats.append(metrics)
    
    # 2. Analysis by innings and bowler_type
    innings_stats = []
    for inning in [1, 2]:
        inning_data = venue_data[venue_data['inning'] == inning]
        for bowler_type in ['pace', 'spin']:
            type_data = inning_data[inning_data['bowler_type'] == bowler_type]
            metrics = calculate_metrics(type_data)
            metrics['bowler_type'] = bowler_type
            metrics['innings'] = f'Inning {inning}'
            innings_stats.append(metrics)
    
    # Combine all stats
    all_stats = overall_stats + innings_stats
    
    # Convert to DataFrame and normalize
    stats_df = pd.DataFrame(all_stats)
    
    # Add venue information
    stats_df['venue'] = venue_name
    
    # Reorder columns for better readability
    column_order = [
        'venue', 'innings', 'bowler_type', 'total_runs', 'total_balls',
        'total_wickets', 'runs_per_wicket', 'balls_per_wicket', 'economy_rate', 'strike_rate'
    ]
    stats_df = stats_df[column_order]
    
    # Fetch the last 10 matches at this venue from MongoDB
    matches = list(
        matches_collection.find(
            {"venue.name": venue_name},
            {"matchStartTimestamp": 1, "tossResults": 1, "result": 1}
        ).sort("matchStartTimestamp", -1).limit(10)
    )
    
    # Create matches DataFrame
    matches_df = pd.json_normalize(matches)
    
    return matches_df,stats_df

# 2. Fetch the last 10 matches between both teams
def analyze_team_head_to_head(team1, team2):
    # Query the last 10 matches between two teams
    matches = list(
        matches_collection.find(
            {
                "$or": [
                    {"team1.name": team1, "team2.name": team2},
                    {"team1.name": team2, "team2.name": team1}
                ]
            },
            {"matchStartTimestamp": 1, "result": 1}
        ).sort("matchStartTimestamp", -1).limit(10)
    )
    
    # Normalize the data
    df = pd.json_normalize(matches)
    return df


def analyze_players(team1, team2, venue_name):
    # Get player IDs from both teams
    team1_data = teams_collection.find_one({"team_name": team1}, {"players": 1})
    team2_data = teams_collection.find_one({"team_name": team2}, {"players": 1})
    
    # Combine player IDs
    player_ids = team1_data["players"] + team2_data["players"]

    # Dictionary to store venue matches for each player
    venue_matches_by_player = {}
    
    # First, get all venue matches for each player
    for player_id in player_ids:
        player_data = players_collection.find_one({"_id": player_id}, {"matches": 1})
        if player_data and "matches" in player_data:
            # Find matches at the specified venue
            venue_matches = list(matches_collection.find({
                "_id": {"$in": player_data["matches"]},
                "venue.name": venue_name
            }))
            venue_matches_by_player[player_id] = [match["_id"] for match in venue_matches][:5]
    
    # Get recent matches for each player
    player_recent_matches = {}
    for player_id in player_ids:
        player_data = players_collection.find_one({"_id": player_id}, {"matches": 1})
        if player_data and "matches" in player_data:
            match_ids = sorted(player_data["matches"], reverse=True)[:10]
            player_recent_matches[player_id] = match_ids

    batting_rows = []
    bowling_rows = []

    # Process recent matches
    for player_id, match_ids in player_recent_matches.items():
        for match_id in match_ids:
            scorecard = scorecards_collection.find_one(
                {"_id": match_id},
                {"firstInnings": 1, "secondInnings": 1}
            )
            if scorecard:
                for innings_key in ["firstInnings", "secondInnings"]:
                    innings = scorecard.get(innings_key, [])
                    for index, row in enumerate(innings):
                        if row.get("playerId") == str(player_id):
                            row_copy = row.copy()
                            row_copy['stats_type'] = 'recent'
                            row_copy['match_id'] = match_id
                            if row.get("type") == "Batting" and row.get('balls', 0) > 0:
                                row_copy["batting_position"] = index + 1
                                batting_rows.append(row_copy)
                            elif row.get("type") == "Bowling":
                                bowling_rows.append(row_copy)

    # Process venue matches
    for player_id, venue_match_ids in venue_matches_by_player.items():
        for match_id in venue_match_ids:
            scorecard = scorecards_collection.find_one(
                {"_id": match_id},
                {"firstInnings": 1, "secondInnings": 1}
            )
            if scorecard:
                for innings_key in ["firstInnings", "secondInnings"]:
                    innings = scorecard.get(innings_key, [])
                    for index, row in enumerate(innings):
                        if row.get("playerId") == str(player_id):
                            row_copy = row.copy()
                            row_copy['stats_type'] = 'venue'
                            row_copy['match_id'] = match_id
                            if row.get("type") == "Batting" and row.get('balls', 0) > 0:
                                row_copy["batting_position"] = index + 1
                                batting_rows.append(row_copy)
                            elif row.get("type") == "Bowling":
                                bowling_rows.append(row_copy)

    # Normalize the batting and bowling data
    batting_df = pd.DataFrame(batting_rows)
    bowling_df = pd.DataFrame(bowling_rows)

    # Calculate fantasy points for batting
    def calculate_batting_points(row):
        points = row['runs']  # +1 per run
        points += row['fours']  # +1 per four
        points += row['sixes'] * 2  # +2 per six
        
        if row['runs'] >= 100:
            points += 16  # Century bonus
        elif row['runs'] >= 50:
            points += 8  # Half-century bonus
        elif row['runs'] >= 30:
            points += 4  # 30-run bonus

        if row['dismissal'] == 'Duck' and row['balls'] > 0:
            points -= 2  # Duck penalty
        
        # Strike rate points
        if row['balls'] >= 10:
            strike_rate = (row['runs'] / row['balls']) * 100
            if strike_rate > 170:
                points += 6
            elif 150.01 <= strike_rate <= 170:
                points += 4
            elif 130 <= strike_rate <= 150:
                points += 2
            elif 60 <= strike_rate < 70:
                points -= 2
            elif 50 <= strike_rate < 60:
                points -= 4
            elif strike_rate < 50:
                points -= 6
        
        return points

    if not batting_df.empty:
        batting_df['fantasy_points'] = batting_df.apply(calculate_batting_points, axis=1)

    # Calculate fantasy points for bowling
    def calculate_bowling_points(row):
        points = row['wickets'] * 25  # +25 per wicket

        if row['wickets'] >= 5:
            points += 16  # 5-wicket haul bonus
        elif row['wickets'] == 4:
            points += 8  # 4-wicket haul bonus
        elif row['wickets'] == 3:
            points += 4  # 3-wicket haul bonus

        points += row['maidens'] * 12  # +12 per maiden over

        # Economy rate points
        if row['overs'] >= 2:
            economy_rate = row['runs'] / row['overs']
            if economy_rate < 5:
                points += 6
            elif 5 <= economy_rate < 6:
                points += 4
            elif 6 <= economy_rate <= 7:
                points += 2
            elif 10 <= economy_rate < 11:
                points -= 2
            elif 11 <= economy_rate < 12:
                points -= 4
            elif economy_rate >= 12:
                points -= 6
        
        return points

    if not bowling_df.empty:
        bowling_df['fantasy_points'] = bowling_df.apply(calculate_bowling_points, axis=1)

    return batting_df, bowling_df




def analyze_commentary(team1, team2, refined_commentary):
    
    # Get player IDs for both teams
    team1_data = teams_collection.find_one({"team_name": team1}, {"players": 1})
    team2_data = teams_collection.find_one({"team_name": team2}, {"players": 1})
    
    # Assume `players` is a list of integers representing player IDs
    player_ids = team1_data["players"] + team2_data["players"]
    player_ids_str = [str(player_id) for player_id in player_ids]

    # Filter commentary rows where batsman_id or bowler_id matches player IDs
    batting_commentary = refined_commentary[refined_commentary["batsman_id"].isin(player_ids_str)]
    bowling_commentary = refined_commentary[(refined_commentary["bowler_id"].isin(player_ids_str))]
    
    
    return batting_commentary, bowling_commentary



# Main Function
if __name__ == "__main__":
    # Example inputs
    venue_name = "Rajiv Gandhi International Stadium"
    team1 = "Sunrisers Hyderabad"
    team2 = "Rajasthan Royals" #team-name
    
    # 1. Venue Analysis
    venue_df, venue_stats_df = analyze_venue_matches(venue_name, refined_commentary)
    venue_df['toss_decision'] = venue_df['tossResults.decision']
    venue_df['winByRuns'] = venue_df['result.winByRuns']
    columns_to_remove_venue = ['matchStartTimestamp','result.resultType','result.winningTeam','result.winningteamId','result.winningMargin','result.winByRuns','result.winByInnings','tossResults.tossWinnerId','tossResults.tossWinnerName','tossResults.decision']
    venue_df.drop(columns=columns_to_remove_venue, inplace=True)
    
    # 2. Head-to-Head Analysis
    h2h_df = analyze_team_head_to_head(team1, team2)
    h2h_df['winningTeam'] = h2h_df['result.winningTeam']
    h2h_df['winningMargin'] = h2h_df['result.winningMargin']
    h2h_df['winByRuns'] = h2h_df['result.winByRuns']
    columns_to_remove_h2h = ['matchStartTimestamp','result.resultType','result.winningTeam','result.winningteamId','result.winningMargin','result.winByRuns','result.winByInnings']
    h2h_df.drop(columns=columns_to_remove_h2h, inplace=True)
    
    # # 3. Player Analysis
    batting_df, bowling_df = analyze_players(team1, team2, venue_name)
    
    # 4. Commentary Analysis
    batting_commentary, bowling_commentary = analyze_commentary(team1, team2, refined_commentary)

# %%
batting_commentary.tail(5)
# Out:
#          _id                                           commText  overNumber  \
# 46518  47605   Shami to Jaiswal, no run, that's a cracking d...         0.6
# 46519  47605   Shami to Jaiswal, no run, on a good length an...         0.5
# 46520  47605   Shami to Jaiswal, no run, short of a good len...         0.4
# 46522  47605   Shami to Jaiswal, leg byes, 1 run, a big shou...         0.2
# 46523  47605   Shami to Jaiswal, no run, short of a good len...         0.1
#
#       batTeamName      batsman_name     bowler_name batsman_id bowler_id  \
# 46518          RR  Yashasvi Jaiswal  Mohammed Shami      13940      7909
# 46519          RR  Yashasvi Jaiswal  Mohammed Shami      13940      7909
# 46520          RR  Yashasvi Jaiswal  Mohammed Shami      13940      7909
# 46522          RR  Yashasvi Jaiswal  Mohammed Shami      13940      7909
# 46523          RR  Yashasvi Jaiswal  Mohammed Shami      13940      7909
#
#       batter_hand bowler_hand  ... is_wicket wicket_type      shot_played  \
# 46518        left       right  ...     False         N/A              cut
# 46519        left       right  ...     False         N/A  pushed slightly
# 46520        left       right  ...     False         N/A  pushed slightly
# 46522        left       right  ...     False         N/A            flick
# 46523        left       right  ...     False         N/A            punch
#
#        ball_length    ball_line batting_control bowling_variation  \
# 46518        short    leg-stump      no-control            normal
# 46519  good length         None      in-control             swing
# 46520        short  outside-off      in-control            normal
# 46522         full    leg-stump      no-control          in-swing
# 46523        short  outside-off      in-control            normal
#
#       shot_direction inning runs
# 46518         keeper      1    0
# 46519     mid-wicket      1    0
# 46520          cover      1    0
# 46522         square      1    1
# 46523          cover      1    0
#
# [5 rows x 22 columns]

# %%
import pandas as pd

def process_match_summary(venue_df, h2h_df):
    """Process basic match information from venue and head-to-head dataframes"""

    match_analysis_report = {}

    # 1. Venue Analysis
    venue_analysis = []
    for _, row in venue_df.iterrows():
        toss_decision = row["toss_decision"]
        win_by_runs = row["winByRuns"]
        winner = "Batting Team" if win_by_runs else "Bowling Team"
        
        venue_analysis.append({
            "toss_decision": toss_decision,
            "winner": winner
        })
    match_analysis_report["venue_analysis"] = venue_analysis

    venue_stats=[]
    for _, row in venue_stats_df.iterrows():
        innings=row['innings']
        bowler_type=row['bowler_type']
        total_runs=row['total_runs']	
        total_balls	=row['total_balls']
        total_wickets=row['total_wickets']	
        runs_per_wicket	=row['runs_per_wicket']
        balls_per_wicket=row['balls_per_wicket']	
        economy_rate=row['economy_rate']	
        strike_rate=row['strike_rate']

        venue_stats.append({
            'innings':innings,
            'bowler_type':bowler_type,
            'total_runs':total_runs,
            'total_balls':total_balls,
            'total_wickets':total_wickets,
            'runs_per_wicket':runs_per_wicket,
            'balls_per_wicket':balls_per_wicket,	
            'economy_rate':economy_rate,
            'strike_rate':strike_rate
        })

        match_analysis_report["venue_stats"] = venue_stats
    # 2. Head-to-Head Analysis
    h2h_analysis = []
    for _, row in h2h_df.iterrows():
        winning_team = row["winningTeam"]
        winning_margin = row["winningMargin"]
        win_by_runs = row["winByRuns"]
        result = f"{winning_team} won by {winning_margin} runs" if win_by_runs else f"{winning_team} won by {winning_margin} wickets"
        h2h_analysis.append(result)
    match_analysis_report["head_to_head_analysis"] = h2h_analysis
        
    return match_analysis_report


def generate_bowler_analysis(bowling_df, commentary_df, team1_ids, team2_ids):
    """
    Generate a comprehensive analysis of bowling statistics for each player by combining
    bowling performance from `bowling_df` and detailed analysis from `commentary_df`.
    
    Args:
    - bowling_df (pd.DataFrame): Dataframe with player bowling performance.
    - commentary_df (pd.DataFrame): Dataframe with commentary analysis.

    Returns:
    - dict: Comprehensive analysis for each bowler.
    """
    bowler_analysis = {}

    # Process Bowling Stats from `bowling_df`
    for _, player in bowling_df.groupby('playerId'):
        player_id = int(player['playerId'].iloc[0])
        player_name = player['name'].iloc[0]

        # Fetch player details from players_collection
        player_details = players_collection.find_one({"_id": player_id})
        
        # Fetch team details from teams_collection
        team_info = teams_collection.find_one({"players": player_id})
        
        # Extract required fields from player_details
        role = player_details.get('role', '')
        batting_style = player_details.get('batting_style', '')
        bowling_style = player_details.get('bowling_style', '')
        team_name = team_info.get('team_name', '') if team_info else ''

        matches = []
        total_runs = 0
        total_wickets = 0
        total_balls = 0
        total_fantasy_points=0

        for _, innings in player.iterrows():
            # Convert overs to balls (e.g., 4.3 overs = 4*6 + 3 = 27 balls)
            overs_whole = int(innings['overs'])
            overs_decimal = round((innings['overs'] - overs_whole) * 10)  # Get decimal part
            balls = (overs_whole * 6) + overs_decimal

            match_stats = {
                'runs': innings['runs'],
                'overs': innings['overs'],
                'wickets': innings['wickets'],
                'economy': innings['economy'],
                'fantasy_points': innings['fantasy_points'],
                'match_id': innings['match_id'],
                'stats_type': innings['stats_type']
            }
            matches.append(match_stats)

            total_runs += innings['runs']
            total_wickets += innings['wickets']
            total_balls += balls
            total_fantasy_points +=innings['fantasy_points']

        # Initialize bowler's data
        bowler_analysis[player_id] = {
            'name': player_name,
            'role': role,
            'batting_style': batting_style,
            'bowling_style': bowling_style,
            'team_name': team_name,
            'matches': matches,
            'total_runs': total_runs,
            'total_wickets': total_wickets,
            'total_balls': total_balls,
            'runs_per_wicket': total_runs / total_wickets if total_wickets > 0 else float('inf'),
            'balls_per_wicket': total_balls / total_wickets if total_wickets > 0 else float('inf'),
            'total_fantasy_points': total_fantasy_points
        }

    # Process Detailed Bowling Analysis from `commentary_df`
    commentary_df['bowler_id'] = commentary_df['bowler_id'].astype(int)

    for bowler_id in commentary_df['bowler_id'].unique():
        bowler_data = commentary_df[commentary_df['bowler_id'] == bowler_id]
        bowler_name = bowler_data['bowler_name'].iloc[0]

        # Determine the opponent team
        if player_id in team1_ids:
            opponent_players = team2_ids
        elif player_id in team2_ids:
            opponent_players = team1_ids
        else:
            continue

        # Phase-wise analysis
        phases = {
            'powerplay': bowler_data[(bowler_data['overNumber'] >= 0) & (bowler_data['overNumber'] <= 6)],
            'middle': bowler_data[(bowler_data['overNumber'] > 6) & (bowler_data['overNumber'] <= 16)],
            'death': bowler_data[(bowler_data['overNumber'] > 16) & (bowler_data['overNumber'] <= 20)]
        }

        phase_stats = {}
        for phase_name, phase_data in phases.items():
            total_runs = phase_data['runs'].sum()
            total_balls = len(phase_data)
            total_wickets = len(phase_data[phase_data['is_wicket'] == True])

            phase_stats[phase_name] = {
                'runs': total_runs,
                'balls': total_balls,
                'wickets': total_wickets,
                'runs_per_wicket': total_runs / total_wickets if total_wickets > 0 else float('inf'),
                'balls_per_wicket': total_balls / total_wickets if total_wickets > 0 else float('inf'),
                'economy': (total_runs * 6) / total_balls if total_balls > 0 else 0
            }

        leftVSright={
            'left_arm': bowler_data[bowler_data['bowler_hand']=='left'],
            'right_arm': bowler_data[bowler_data['bowler_hand']=='right']
        }
        leftVright={}
        for bowl_hand, data in leftVSright.items():
            total_runs = data['runs'].sum()
            total_balls = len(data)
            strike_rate = (total_runs / total_balls * 100) if total_balls > 0 else 0
            wickets = len(data[data['is_wicket'] == True])
            leftVright[bowl_hand] = {
                'runs': total_runs,
                'balls': total_balls,
                'strike_rate': strike_rate,
                'wickets': wickets
            }

        # Wicket analysis
        wicket_data = bowler_data[bowler_data['is_wicket'] == True]
        filtered_wicket_stats = {
            str(tuple(row)): count
            for row, count in wicket_data.groupby(["ball_length", "ball_line", "bowling_variation"]).size().items()
            if count >= 2  # Add only if count >= 2
        }


        # Boundary analysis
        boundaries = bowler_data[bowler_data['runs'].isin([4, 6])]
        boundary_percentage = (len(boundaries) / len(bowler_data)) * 100 if len(bowler_data) > 0 else 0

        # Group boundary details and filter conditions
        boundary_details = boundaries.groupby(["ball_length", "ball_line", "bowling_variation"]).size()
        filtered_boundary_stats = {
            str(tuple(row)): count
            for row, count in boundary_details.items()
            if count >= 3  # Add only if count >= 3
        }

        # If no boundary group satisfies count >= 3, include groups with count >= 2
        if not filtered_boundary_stats:
            filtered_boundary_stats = {
                str(tuple(row)): count
                for row, count in boundary_details.items()
                if count >= 2
            }

        boundary_analysis = {
            "details": filtered_boundary_stats,
            "percentage": boundary_percentage
        }
        # Bowling variation frequency
        variation_frequency = bowler_data['bowling_variation'].value_counts().to_dict()


        # Analysis against opponents
        opponent_analysis = {}
        for opponent_id in opponent_players:
            # Get all interactions between current player and opponent
            interactions = bowler_data[
                (bowler_data['batsman_id'] == opponent_id)
            ]


            if len(interactions) >= 18 or interactions['is_wicket'].any():

                batter_name = interactions['batsman_name'].iloc[0] if not interactions.empty else "Unknown"

                total_balls = len(interactions)
                total_runs = interactions['runs'].sum()
                strike_rate = (total_runs / total_balls * 100) if total_balls > 0 else 0
                wickets = interactions['is_wicket'].sum()

                opponent_stats = {
                    'balls': total_balls,
                    'runs': total_runs,
                    'strike_rate': strike_rate,
                    'wickets': wickets
                }

                # Detailed wicket analysis if multiple wickets
                if wickets > 0:
                    wicket_rows = interactions[interactions['is_wicket'] == True]
                    
                    # Fill null values with 'unknown' before grouping
                    wicket_rows_filled = wicket_rows.fillna({
                        'wicket_type': 'unknown',
                        'shot_played': 'unknown',
                        'ball_line': 'unknown',
                        'ball_length': 'unknown'
                    })
                    
                    wicket_patterns = wicket_rows_filled.groupby(
                        ['wicket_type', 'shot_played', 'ball_line', 'ball_length'],
                        dropna=False  # Include groups with null values
                    ).size().to_dict()
                    
                    opponent_stats['wicket_patterns'] = {
                        str(k): v for k, v in wicket_patterns.items()
                    }

                opponent_analysis[batter_name] = opponent_stats

        # Update or merge detailed analysis into existing entry
        if bowler_id in bowler_analysis:
            bowler_analysis[bowler_id].update({
                'name': bowler_name,
                'phase_stats': phase_stats,
                'left_vs_right': leftVright,
                'wicket_analysis': filtered_wicket_stats,
                'boundary_analysis': boundary_analysis,
                'variation_frequency': variation_frequency,
                'opponent_analysis': opponent_analysis  # New field added
            })
        else:
            bowler_analysis[bowler_id] = {
                'name': bowler_name,
                'phase_stats': phase_stats,
                'left_vs_right': leftVright,
                'wicket_analysis': filtered_wicket_stats,
                'boundary_analysis': boundary_analysis,
                'variation_frequency': variation_frequency,
                'opponent_analysis': opponent_analysis  # New field added
            }

    return bowler_analysis





def generate_batting_analysis(batting_df, commentary_df, team1_ids, team2_ids):
    """
    Generate a comprehensive analysis of batting statistics for each player by combining
    batting performance from `batting_df` and detailed commentary analysis from `commentary_df`.
    Now includes analysis of performance against specific opponents.

    Args:
    - batting_df (pd.DataFrame): Dataframe with player batting performance.
    - commentary_df (pd.DataFrame): Dataframe with commentary analysis.

    Returns:
    - dict: Comprehensive analysis for each batsman.
    """
    player_analysis = {}

    # Process Batting Stats from `batting_df`
    for _, player in batting_df.groupby('playerId'):
        player_id = int(player['playerId'].iloc[0])
        player_name = player['name'].iloc[0]

        # Fetch player details from players_collection
        player_details = players_collection.find_one({"_id": player_id})
        
        # Fetch team details from teams_collection
        team_info = teams_collection.find_one({"players": player_id})
        
        # Extract required fields from player_details
        role = player_details.get('role', '')
        batting_style = player_details.get('batting_style', '')
        bowling_style = player_details.get('bowling_style', '')
        team_name = team_info.get('team_name', '') if team_info else ''

        matches = []
        total_runs = 0
        total_balls = 0
        total_fantasy_points=0

        for _, innings in player.iterrows():
            match_stats = {
                'runs': innings['runs'],
                'balls': innings['balls'],
                'strike_rate': innings['strikeRate'],
                'fantasy_points': innings['fantasy_points'],
                'match_id': innings['match_id'],
                'stats_type': innings['stats_type'],
                'batting_position': innings['batting_position']
            }
            matches.append(match_stats)
            total_runs += innings['runs']
            total_balls += innings['balls']
            total_fantasy_points +=innings['fantasy_points']

        # Initialize player's data
        player_analysis[player_id] = {
            'name': player_name,
            'role': role,
            'batting_style': batting_style,
            'bowling_style': bowling_style,
            'team_name': team_name,
            'matches': matches,
            'total_runs': total_runs,
            'total_balls': total_balls,
            'average_runs': total_runs / len(matches) if matches else 0,
            'overall_strike_rate': (total_runs / total_balls * 100) if total_balls > 0 else 0,
            'total_fantasy_points': total_fantasy_points,

        }

    commentary_df['batsman_id'] = commentary_df['batsman_id'].astype(int)
    # Process Detailed Commentary Analysis from `commentary_df`
    for player_id in commentary_df['batsman_id'].unique():
        player_data = commentary_df[commentary_df['batsman_id'] == (player_id)]

        player_name = player_data['batsman_name'].iloc[0]


        # Determine the opponent team
        if player_id in team1_ids:
            opponent_players = team2_ids
        elif player_id in team2_ids:
            opponent_players = team1_ids
        else:
            continue

        # Phase-wise analysis
        phases = {
            'powerplay': player_data[(player_data['overNumber'] >= 0) & (player_data['overNumber'] <= 6)],
            'middle': player_data[(player_data['overNumber'] > 6) & (player_data['overNumber'] <= 16)],
            'death': player_data[(player_data['overNumber'] > 16) & (player_data['overNumber'] <= 20)]
        }
        phase_stats = {}
        for phase_name, phase_data in phases.items():
            total_runs = phase_data['runs'].sum()
            total_balls = len(phase_data)
            strike_rate = (total_runs / total_balls * 100) if total_balls > 0 else 0
            phase_stats[phase_name] = {
                'runs': total_runs,
                'balls': total_balls,
                'strike_rate': strike_rate
            }
            

        spinVSpace={
            'spin': player_data[player_data['bowler_type']=='spin'],
            'pace': player_data[player_data['bowler_type']=='pace']
        }
        spinVpace={}
        for bowl_type, data in spinVSpace.items():
            total_runs = data['runs'].sum()
            total_balls = len(data)
            strike_rate = (total_runs / total_balls * 100) if total_balls > 0 else 0
            wickets = len(data[data['is_wicket'] == True])
            spinVpace[bowl_type] = {
                'runs': total_runs,
                'balls': total_balls,
                'strike_rate': strike_rate,
                'wickets': wickets
            }

        leftVSright={
            'left_arm': player_data[player_data['bowler_hand']=='left'],
            'right_arm': player_data[player_data['bowler_hand']=='right']
        }
        leftVright={}
        for bowl_hand, data in leftVSright.items():
            total_runs = data['runs'].sum()
            total_balls = len(data)
            strike_rate = (total_runs / total_balls * 100) if total_balls > 0 else 0
            wickets = len(data[data['is_wicket'] == True])
            leftVright[bowl_hand] = {
                'runs': total_runs,
                'balls': total_balls,
                'strike_rate': strike_rate,
                'wickets': wickets
            }


        # Analysis against opponents
        opponent_analysis = {}
        for opponent_id in opponent_players:
            # Get all interactions between current player and opponent
            interactions = player_data[
                (player_data['bowler_id'] == str(opponent_id))
            ]
            
            if len(interactions) >= 18 or interactions['is_wicket'].any():

                bowler_name = interactions['bowler_name'].iloc[0] if not interactions.empty else "Unknown"

                total_balls = len(interactions)
                total_runs = interactions['runs'].sum()
                strike_rate = (total_runs / total_balls * 100) if total_balls > 0 else 0
                wickets = interactions['is_wicket'].sum()

                opponent_stats = {
                    'balls': total_balls,
                    'runs': total_runs,
                    'strike_rate': strike_rate,
                    'wickets': wickets
                }

                if wickets > 0:
                    wicket_rows = interactions[interactions['is_wicket'] == True]
                    
                    # Fill null values with 'unknown' before grouping
                    wicket_rows_filled = wicket_rows.fillna({
                        'wicket_type': 'unknown',
                        'shot_played': 'unknown',
                        'ball_line': 'unknown',
                        'ball_length': 'unknown'
                    })
                    
                    wicket_patterns = wicket_rows_filled.groupby(
                        ['wicket_type', 'shot_played', 'ball_line', 'ball_length'],
                        dropna=False  # Include groups with null values
                    ).size().to_dict()
                    
                    opponent_stats['wicket_patterns'] = {
                        str(k): v for k, v in wicket_patterns.items()
                    }


                opponent_analysis[bowler_name] = opponent_stats

        control_stats = player_data['batting_control'].value_counts().to_dict()
        scoring_zone = player_data['shot_direction'].value_counts().to_dict()

        # Wicket analysis
        wicket_data = player_data[player_data['is_wicket'] == True]
        wicket_stats = {
            str(tuple(row)): count
            for row, count in wicket_data.groupby(["shot_played", "ball_length", "ball_line", "shot_direction"]).size().items()
            if count >= 2
        }

        # Boundary analysis
        boundaries = player_data[player_data['runs'].isin([4, 6])]
        boundary_percentage = (len(boundaries) / len(player_data)) * 100 if len(player_data) > 0 else 0

        boundary_details = boundaries.groupby(["shot_played", "ball_length", "ball_line"]).size()
        boundary_stats = {
            str(tuple(row)): count
            for row, count in boundary_details.items()
            if count >= 3
        }

        if not boundary_stats:
            boundary_stats = {
                str(tuple(row)): count
                for row, count in boundary_details.items()
                if count >= 2
            }

        # Update or merge detailed analysis into existing entry
        if player_id in player_analysis:
            player_analysis[player_id].update({
                'name': player_name,
                'phase_stats': phase_stats,
                'spin_vs_pace': spinVpace,
                'left_vs_right': leftVright,
                'wicket_analysis': wicket_stats,
                'batting_control': control_stats,
                'scoring_zone': scoring_zone,
                'boundary_analysis': {
                    "details": boundary_stats,
                    "percentage": boundary_percentage
                },
                'opponent_analysis': opponent_analysis  # New field added
            })
        else:
            player_analysis[player_id] = {
                'name': player_name,
                'phase_stats': phase_stats,
                'wicket_analysis': wicket_stats,
                'spin_vs_pace': spinVpace,
                'left_vs_right': leftVright,
                'batting_control': control_stats,
                'scoring_zone': scoring_zone,
                'boundary_analysis': {
                    "details": boundary_stats,
                    "percentage": boundary_percentage
                },
                'opponent_analysis': opponent_analysis  # New field added
            }

    return player_analysis



# Usage example:
def analyze_match(venue_df, h2h_df, batting_df,bowling_df, batting_commentary, bowling_commentary):
    """Analyze complete match data and return results dictionary"""
    team1 = "Sunrisers Hyderabad"
    team2 = "Rajasthan Royals" #team-name
    team1_ids = teams_collection.find_one({"team_name": team1}, {"players": 1})
    team2_ids = teams_collection.find_one({"team_name": team2}, {"players": 1})
    results = {
        'match_summary': process_match_summary(venue_df, h2h_df),
        'bowler_analysis': generate_bowler_analysis(bowling_df, bowling_commentary,team1_ids['players'],team2_ids['players']),
        'batting_analysis': generate_batting_analysis(batting_df, batting_commentary,team1_ids['players'],team2_ids['players']),
    }
    return results

result= analyze_match(venue_df, h2h_df, batting_df,bowling_df, batting_commentary, bowling_commentary)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_11972\3120968772.py:135: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   commentary_df['bowler_id'] = commentary_df['bowler_id'].astype(int)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_11972\3120968772.py:369: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   commentary_df['batsman_id'] = commentary_df['batsman_id'].astype(int)

# %%
import json
import numpy as np 

def preprocess_for_json(obj):
    """
    Recursively convert non-serializable types in a dictionary or list to standard Python types.
    """
    if isinstance(obj, dict):
        new_dict = {}
        for key, value in obj.items():
            # Ensure all keys are strings
            if not isinstance(key, (str, int, float, bool, type(None))):
                key = str(key)
            new_dict[key] = preprocess_for_json(value)
        return new_dict
    elif isinstance(obj, list):
        return [preprocess_for_json(item) for item in obj]
    elif isinstance(obj, (np.int64, np.int32)):
        return int(obj)
    elif isinstance(obj, (np.float64, np.float32)):
        return float(obj)
    else:
        return obj


# Preprocess the report
preprocessed_result = preprocess_for_json(result)
# Specify the file path
match_id= json.load(open('../match_id.json'))['match_id']
output_file = f"{match_id}_match_analysis.json"

# Save the report as a JSON file
with open(output_file, "w") as json_file:
    json.dump(preprocessed_result, json_file, indent=4)

print(f"Match analysis report saved to {output_file}")
# Out:
# Match analysis report saved to 114967_match_analysis.json

# %%
import json
from groq import Groq
import os
from dotenv import load_dotenv

# Load environment variables
load_dotenv()

class CricketAnalysisBot:
    def __init__(self, api_key):
        """Initialize the bot with Groq API key"""
        self.client = Groq(api_key=api_key)
        self.summary_file = "player_summaries.json"
        
    def create_player_prompt(self, player_id, batting_data, bowling_data):
        """
        Create a detailed prompt for AI to summarize player statistics.
        
        Args:
        - player_id (int): Player ID
        - batting_data (dict): Batting statistics
        - bowling_data (dict): Bowling statistics
        
        Returns:
        - str: AI prompt
        """
        def convert_to_serializable(data):
            """Recursively convert numpy types in dictionaries to Python native types."""
            if isinstance(data, dict):
                return {key: convert_to_serializable(value) for key, value in data.items()}
            elif isinstance(data, list):
                return [convert_to_serializable(value) for value in data]
            elif isinstance(data, (np.integer, np.int64)):
                return int(data)
            elif isinstance(data, (np.floating, np.float64)):
                return float(data)
            else:
                return data

        prompt = f"Analyze the following cricket statistics for {batting_data.get('name', '') or bowling_data.get('name', '')}:\n\n"

        # Add batting data if available
        if batting_data:
            prompt += "BATTING STATISTICS:\n"
            prompt += f"- Matches:\n{json.dumps(convert_to_serializable(batting_data.get('matches', [])), indent=2)}\n"
            prompt += f"- Total Runs: {batting_data.get('total_runs', 0)}\n"
            prompt += f"- Total Balls: {batting_data.get('total_balls', 0)}\n"
            prompt += f"- Average Runs: {batting_data.get('average_runs', 0)}\n"
            prompt += f"- Overall Strike Rate: {batting_data.get('overall_strike_rate', 0)}\n"
            prompt += f"- Phase Stats:\n{json.dumps(convert_to_serializable(batting_data.get('phase_stats', {})), indent=2)}\n"
            prompt += f"- Wicket Analysis ('shot_played', 'ball_length', 'ball_line','shot_direction'):\n{json.dumps(convert_to_serializable(batting_data.get('wicket_analysis', {})), indent=2)}\n"
            prompt += f"- Batting Control:\n{json.dumps(convert_to_serializable(batting_data.get('batting_control', {})), indent=2)}\n"
            prompt += f"- Scoring Zones:\n{json.dumps(convert_to_serializable(batting_data.get('scoring_zone', {})), indent=2)}\n"
            prompt += f"- Boundary Analysis ('shot_played', 'ball_length', 'ball_line'):\n{json.dumps(convert_to_serializable(batting_data.get('boundary_analysis', {})), indent=2)}\n"
            prompt += f"- Opponent team bolwers head to head Analysis:\n{json.dumps(convert_to_serializable(batting_data.get('opponent_analysis', {})), indent=2)}\n"

        # Add bowling data if available
        if bowling_data:
            prompt += "\nBOWLING STATISTICS:\n"
            prompt += f"- Matches:\n{json.dumps(convert_to_serializable(bowling_data.get('matches', [])), indent=2)}\n"
            prompt += f"- Total Runs Conceded: {bowling_data.get('total_runs', 0)}\n"
            prompt += f"- Total Wickets: {bowling_data.get('total_wickets', 0)}\n"
            prompt += f"- Total Balls Bowled: {bowling_data.get('total_balls', 0)}\n"
            prompt += f"- Runs per Wicket: {bowling_data.get('runs_per_wicket', 0)}\n"
            prompt += f"- Balls per Wicket: {bowling_data.get('balls_per_wicket', 0)}\n"
            prompt += f"- Phase Stats:\n{json.dumps(convert_to_serializable(bowling_data.get('phase_stats', {})), indent=2)}\n"
            prompt += f"- Wicket Analysis ('ball_length', 'ball_line','bowling_variation'):\n{json.dumps(convert_to_serializable(bowling_data.get('wicket_analysis', {})), indent=2)}\n"
            prompt += f"- Boundary Analysis ('ball_length', 'ball_line','bowling_variation'):\n{json.dumps(convert_to_serializable(bowling_data.get('boundary_analysis', {})), indent=2)}\n"
            prompt += f"- Variation Frequency:\n{json.dumps(convert_to_serializable(bowling_data.get('variation_frequency', {})), indent=2)}\n"
            prompt += f"- Opponent team players head to head Analysis:\n{json.dumps(convert_to_serializable(bowling_data.get('opponent_analysis', {})), indent=2)}\n"

        prompt += "\nProvide a detailed, human-readable breakdown of the player's performance based on the following statistics. For each field, convert the data into an easy-to-analyze format. The output should emphasize clarity and readability, making it easy to quickly interpret the player's performance at a glance. Avoid summarizing the data; present the statistics as described in their respective formats."

        
        return prompt



    def get_ai_summary(self, prompt):
        """Get AI-generated summary using Groq"""
        try:
            messages = [
                {
                    "role": "system",
                    "content": '''
                        Provide a detailed, human-readable breakdown of the player's performance based on the following statistics. For each field, convert the data into an easy-to-analyze format as described below:

                        1. Matches: Summarize each match's performance in the format "Runs(Balls) SR: StrikeRate" (e.g., 23(10) SR: 230, 40(20) SR: 200).
                        2. batting Phase Stats: Summarize runs, balls, and strike rates for each phase in the format "Runs(Balls) SR: StrikeRate" for Powerplay, Middle Overs, and Death Overs.
                        3. Total Batting Statistics: Provide the player's total runs, balls faced, average runs, and overall strike rate in clear terms.
                        4. batsman's Wicket Analysis: Summarize dismissal patterns in the proper statistical format .
                        5. batsman's Boundary Analysis: List boundary details in the proper statistical format and include the boundary percentage that batsman scores.
                        8. Shot selection: Summarize the frequency of shot_played in the format "shot pyed by batsmen: Count" (e.g., drive: 12, cut: 8).
                        6. Bowling Matches: Summarize each match's bowling performance in the format "Runs(Overs) Econ: EconomyRate Wkts: Wickets" (e.g., 24(4) Econ: 6.0 Wkts: 2).
                        7. Bowling Phase Stats: Summarize runs, balls, economy, and wickets for each phase (Powerplay, Middle Overs, Death Overs) in a human-readable format.
                        4. bowler's Analysis: Summarize dismissal patterns in the proper statistical format .
                        5. bowler's Boundary Analysis: List boundary details in the proper statistical format and include the boundary percentage that bowler conceed.
                        8. Bowling Variations: Summarize the frequency of bowling variations in the format "Variation: Count" (e.g., Yorker: 12, Slower: 8).
                        9. Overall Bowling Statistics: Provide total runs conceded, total balls bowled, total wickets, runs per wicket, and balls per wicket in a concise format.

                        The output should emphasize clarity and readability, making it easy to quickly interpret the player's performance at a glance. Avoid summarizing the data; present the statistics as described in their respective formats.
                        generate in large and detailed manner.
                    '''
                },
                {
                    "role": "user",
                    "content": f"Context: {prompt}"
                }
            ]
            
            response = self.client.chat.completions.create(
                model='llama-3.1-8b-instant',
                messages=messages,
                temperature=0.2,
                max_tokens=1500
            )
            
            return response.choices[0].message.content
            
        except Exception as e:
            return f"Error generating summary: {str(e)}"
    
    def save_summary(self, player_id, player_name, summary):
        """Save or update player summary in JSON file"""
        try:
            # Convert player_id to regular integer if it's numpy.int64
            player_id = int(player_id) if hasattr(player_id, 'item') else player_id
            
            # Load existing summaries
            if os.path.exists(self.summary_file):
                try:
                    with open(self.summary_file, 'r', encoding='utf-8') as f:
                        summaries = json.load(f)
                except json.JSONDecodeError:
                    print(f"Error reading existing file, creating new summaries")
                    summaries = {}
            else:
                summaries = {}
            
            # Clean the summary text if it contains any problematic characters
            if isinstance(summary, str):
                # Remove any invalid JSON characters
                summary = summary.replace('\n', ' ').replace('\r', '')
            
            # Update or add new summary
            summaries[str(player_id)] = {
                "name": str(player_name),
                "summary": summary
            }
            
            # Save updated summaries with proper encoding
            with open(self.summary_file, 'w', encoding='utf-8') as f:
                json.dump(summaries, f, indent=4, ensure_ascii=False)
                
        except Exception as e:
            print(f"Error saving summary for {player_name} (ID: {player_id}): {str(e)}")

    def analyze_players(self, batting_analysis, bowling_analysis):
        """Analyze all players in the provided data"""
        # Get all unique player IDs
        player_ids = set(list(batting_analysis.keys()) + list(bowling_analysis.keys()))
        
        for player_id in player_ids:
            batting_data = batting_analysis.get(player_id, {})
            bowling_data = bowling_analysis.get(player_id, {})
            
            # Skip if no data available
            if not batting_data and not bowling_data:
                continue
            
            # Get player name from e  ither batting or bowling data
            player_name = batting_data.get('name') or bowling_data.get('name')
            
            # Create prompt and get AI summary
            prompt = self.create_player_prompt(player_id, batting_data, bowling_data)
            summary = self.get_ai_summary(prompt)
            
            # Save the summary
            self.save_summary(player_id, player_name, summary)
            print(f"Processed analysis for {player_name}")
        


def main():
    
    # Initialize and run the bot
    bot = CricketAnalysisBot(api_key=os.getenv("GROQ_API_KEY"))
    bot.analyze_players(result['batting_analysis'], result['bowler_analysis'])

if __name__ == "__main__":
    main()
# Out:
# Processed analysis for Shubham Dubey
# Processed analysis for Abhinav Manohar
# Processed analysis for Yudhvir Singh Charak
# Processed analysis for Sachin Baby
# Processed analysis for Riyan Parag
# Processed analysis for Jofra Archer
# Processed analysis for Aniket Verma
# Processed analysis for Pat Cummins
# Processed analysis for Ishan Kishan
# Processed analysis for Sandeep Sharma
# Processed analysis for Tushar Deshpande
# Processed analysis for Wanindu Hasaranga
# Processed analysis for Travis Head
# Processed analysis for Kwena Maphaka
# Processed analysis for Abhishek Sharma
# Processed analysis for Rahul Chahar
# Processed analysis for Jaydev Unadkat
# Processed analysis for Shimron Hetmyer
# Processed analysis for Adam Zampa
# Processed analysis for Maheesh Theekshana
# Processed analysis for Fazalhaq Farooqi
# Processed analysis for Vaibhav Suryavanshi
# Processed analysis for Sanju Samson
# Processed analysis for Simarjeet Singh
# Processed analysis for Atharva Taide
# Processed analysis for Heinrich Klaasen
# Processed analysis for Dhruv Jurel
# Processed analysis for Mohammed Shami
# Processed analysis for Nitish Reddy
# Processed analysis for Kumar Kartikeya
# Processed analysis for Akash Madhwal
# Processed analysis for Harshal Patel
# Processed analysis for Yashasvi Jaiswal
# Processed analysis for Nitish Rana

# %%
import json

# Specify the file name where summaries are stored
summary_file = "player_summaries.json"

def load_summaries(summary_file):
    """Load player summaries from the JSON file."""
    if os.path.exists(summary_file):
        with open(summary_file, 'r') as f:
            summaries = json.load(f)
            return summaries
    else:
        print(f"Summary file '{summary_file}' not found.")
        return {}

# Load the summaries
summaries = load_summaries(summary_file)

# Example: Display the summaries
for player_id, player_summary in summaries.items():
    print(f"Player ID: {player_id}")
    print(f"Name: {player_summary['name']}")
    print(f"Summary: {player_summary['summary']}")
    print("-" * 50)
# Out:
# Player ID: 19328
# Name: Shubham Dubey
# Summary: **Shubham Dubey's Performance Breakdown**  **Matches Performance**  1. **Match 1**: 43(19) SR: 226.32 2. **Match 2**: 52(31) SR: 167.74 3. **Match 3**: 9(10) SR: 90.0 4. **Match 4**: 30(14) SR: 214.29  **Total Batting Statistics**  * **Total Runs**: 134 * **Total Balls**: 74 * **Average Runs**: 33.5 * **Overall Strike Rate**: 181.08  **Batting Phase Stats**  * **Powerplay**: 0(0) SR: 0 * **Middle**: 8(6) SR: 133.33 * **Death**: 0(0) SR: 0  **Wicket Analysis**  * No wickets taken or dismissed  **Batting Control**  * **In-Control**: 5 * **No-Control**: 1  **Scoring Zones**  * **Square**: 2 * **Keeper**: 1 * **Long-Off**: 1 * **Cover**: 1 * **Mid-Wicket**: 1  **Boundary Analysis**  * **Boundary Percentage**: 16.67% * **Boundary Details**: (No data available)  **Bowling Statistics**  Unfortunately, there is no bowling data available for Shubham Dubey in the provided statistics.
# --------------------------------------------------
# Player ID: 10499
# Name: Abhinav Manohar
# Summary: **Abhinav Manohar's Batting Performance**  ### Matches  1. 56(34) SR: 164.71 2. 2(5) SR: 40.0 3. 14(14) SR: 100.0 4. 34(16) SR: 212.5 5. 0(3) SR: 0.0 6. 8(14) SR: 57.14 7. 1(2) SR: 50.0 8. 42(21) SR: 200.0  ### Total Batting Statistics  - **Total Runs:** 157 - **Total Balls:** 109 - **Average Runs:** 19.625 - **Overall Strike Rate:** 144.04  ### Batting Phase Stats  - **Powerplay:** 12(18) SR: 66.67 - **Middle Overs:** 134(116) SR: 115.52 - **Death Overs:** 85(47) SR: 180.85  ### Wicket Analysis  No wicket analysis data available.  ### Batting Control  - **In-Control:** 147 - **No-Control:** 30 - **Beaten:** 4  ### Scoring Zones  - **Cover:** 33 - **Point:** 24 - **Long-On:** 17 - **Long-Off:** 16 - **Keeper:** 15 - **Mid-Wicket:** 14 - **Blocked:** 13 - **Square:** 12 - **Third-Man:** 5 - **Fine-Leg:** 4  ### Boundary Analysis  - **Boundary Percentage:** 17.13% - **Boundary Details:** No data available.  ### Opponent Team Bowlers Head-to-Head Analysis  - **Kumar Kartikeya:**   - **Balls:** 3   - **Runs:** 1   - **Strike Rate:** 33.33   - **Wickets:** 1   - **Wicket Patterns:** ('bowled', 'pull', 'unknown', 'short') - **Maheesh Theekshana:**   - **Balls:** 6   - **Runs:** 3   - **Strike Rate:** 50.0   - **Wickets:** 1   - **Wicket Patterns:** ('caught', 'pushed slightly', 'outside-off', 'short')  ### Shot Selection  No shot selection data available.  ### Bowling Performance  No bowling performance data available.  ### Bowling Phase Stats  No bowling phase stats data available.  ### Bowler's Analysis  No bowler's analysis data available.  ### Bowler's Boundary Analysis  No bowler's boundary analysis data available.  ### Bowling Variations  No bowling variations data available.  ### Overall Bowling Statistics  No overall bowling statistics data available.
# --------------------------------------------------
# Player ID: 15749
# Name: Yudhvir Singh Charak
# Summary: **Yudhvir Singh Charak's Performance Breakdown**  **Batting Performance**  ### Matches  1. 9(5) SR: 180 2. 29(13) SR: 223.08 3. 21(11) SR: 190.91 4. 14(5) SR: 280 5. 1(1) SR: 100 6. 0(1) SR: 0  ### Total Batting Statistics  - Total Runs: 74 - Total Balls: 36 - Average Runs: 12.333333333333334 - Overall Strike Rate: 205.55555555555554  ### Batting Phase Stats  - Powerplay: 0(0) SR: 0 - Middle: 0(0) SR: 0 - Death: 1(2) SR: 50  ### Wicket Analysis  No wicket analysis data available.  ### Batting Control  - No-control: 2  ### Scoring Zones  - Long-on: 1 - Square: 1  ### Boundary Analysis  - Percentage: 0.0 - Details: No boundary data available.  ### Opponent Team Bowlers Head-to-Head Analysis  No data available.  **Bowling Performance**  ### Matches  1. 21(4.0) Econ: 5.2 Wkts: 1 2. 30(4.0) Econ: 7.5 Wkts: 0 3. 20(4.0) Econ: 5.0 Wkts: 1 4. 34(3.3) Econ: 9.7 Wkts: 1 5. 14(3.0) Econ: 4.7 Wkts: 2 6. 23(3.0) Econ: 7.7 Wkts: 1 7. 35(3.0) Econ: 11.7 Wkts: 1 8. 24(3.0) Econ: 8.0 Wkts: 1 9. 27(2.0) Econ: 13.5 Wkts: 0 10. 19(3.0) Econ: 6.3 Wkts: 2 11. 24(3.0) Econ: 8.0 Wkts: 1  ### Total Bowling Statistics  - Total Runs Conceded: 271 - Total Wickets: 11 - Total Balls Bowled: 213 - Runs per Wicket: 24.636363636363637 - Balls per Wicket: 19.363636363636363  ### Bowling Phase Stats  - Powerplay: 59(44) Econ: 8.045454545454545 Wkts: 2 - Middle: 11(6) Econ: 11.0 Wkts: 0 - Death: 0(0) Econ: 0 Wkts: 0  ### Wicket Analysis  No wicket analysis data available.  ### Boundary Analysis  - Percentage: 24.0 - Details: ('full', 'outside-off', 'normal'): 2  ### Variation Frequency  - Normal: 44 - Quick: 4 - Seam-away: 1 - Bouncer: 1  ### Opponent Team Players Head-to-Head Analysis  No data available.
# --------------------------------------------------
# Player ID: 8709
# Name: Sachin Baby
# Summary: **Sachin Baby's Performance Breakdown**  **Matches:**  1. 7(4) SR: 175 2. 48(31) SR: 154.84 3. 40(25) SR: 160 4. 6(4) SR: 150 5. 6(4) SR: 150 6. 40(25) SR: 160 7. 7(4) SR: 175  **Total Batting Statistics:**  - **Total Runs:** 154 - **Total Balls:** 97 - **Average Runs:** 22.0 - **Overall Strike Rate:** 158.76  **Batting Phase Stats:**  Unfortunately, the provided data does not contain any batting phase stats. This section will be left blank.  **Batting Control:**  Unfortunately, the provided data does not contain any batting control stats. This section will be left blank.  **Scoring Zones:**  Unfortunately, the provided data does not contain any scoring zone stats. This section will be left blank.  **Boundary Analysis:**  Unfortunately, the provided data does not contain any boundary analysis stats. This section will be left blank.  **Wicket Analysis:**  Unfortunately, the provided data does not contain any wicket analysis stats. This section will be left blank.  **Opponent Team Bowlers Head-to-Head Analysis:**  Unfortunately, the provided data does not contain any opponent team bowlers head-to-head analysis stats. This section will be left blank.  **Batting Phase Statistics:**  Unfortunately, the provided data does not contain any batting phase statistics. This section will be left blank.  However, we can provide a summary of the batting performance in different phases:  - **Powerplay:** Unfortunately, the provided data does not contain any powerplay stats. This section will be left blank. - **Middle Overs:** Unfortunately, the provided data does not contain any middle overs stats. This section will be left blank. - **Death Overs:** Unfortunately, the provided data does not contain any death overs stats. This section will be left blank.  However, we can provide a summary of the batting performance in different phases:  - **Powerplay:** Unfortunately, the provided data does not contain any powerplay stats. This section will be left blank. - **Middle Overs:** Unfortunately, the provided data does not contain any middle overs stats. This section will be left blank. - **Death Overs:** Unfortunately, the provided data does not contain any death overs stats. This section will be left blank.  However, we can provide a summary of the batting performance in different phases:  - **Powerplay:** Unfortunately, the provided data does not contain any powerplay stats. This section will be left blank. - **Middle Overs:** Unfortunately, the provided data does not contain any middle overs stats. This section will be left blank. - **Death Overs:** Unfortunately, the provided data does not contain any death overs stats. This section will be left blank.  However, we can provide a summary of the batting performance in different phases:  - **Powerplay:** Unfortunately, the provided data does not contain any powerplay stats. This section will be left blank. - **Middle Overs:** Unfortunately, the provided data does not contain any middle overs stats. This section will be left blank. - **Death Overs:** Unfortunately, the provided data does not contain any death overs stats. This section will be left blank.  However, we can provide a summary of the batting performance in different phases:  - **Powerplay:** Unfortunately, the provided data does not contain any powerplay stats. This section will be left blank. - **Middle Overs:** Unfortunately, the provided data does not contain any middle overs stats. This section will be left blank. - **Death Overs:** Unfortunately, the provided data does not contain any death overs stats. This section will be left blank.  However, we can provide a summary of the batting performance in different phases:  - **Powerplay:** Unfortunately, the provided data does not contain any powerplay stats. This section will be left blank. - **Middle Overs:** Unfortunately, the provided data does not contain any middle overs stats. This section will be left blank. - **Death Overs:** Unfortunately, the provided data does not co ...
# --------------------------------------------------
# Player ID: 12305
# Name: Riyan Parag
# Summary: **Riyan Parag's Performance Breakdown**  **Batting Performance**  **Matches:**  1. 34(14) SR: 242.86 2. 23(18) SR: 127.78 3. 76(48) SR: 158.33 4. 4(4) SR: 100.0 5. 54(39) SR: 138.46 6. 84(45) SR: 186.67 7. 43(29) SR: 148.28 8. 20(12) SR: 166.67 9. 15(12) SR: 125.0 10. 7(6) SR: 116.67  **Total Batting Statistics:**  - Total Runs: 360 - Total Balls: 227 - Average Runs: 36.0 - Overall Strike Rate: 158.59  **Batting Phase Stats:**  - **Powerplay:** 25(25) SR: 100.0 - **Middle Overs:** 375(269) SR: 139.41 - **Death Overs:** 217(127) SR: 170.87  **Wicket Analysis:**  No data available  **Batting Control:**  - In-control: 334 - No-control: 82 - Beaten: 5  **Scoring Zones:**  - Mid-wicket: 74 - Square: 44 - Cover: 44 - Long-on: 40 - Blocked: 39 - Long-off: 35 - Point: 32 - Keeper: 32 - Fine-leg: 14 - Third-man: 7  **Boundary Analysis:**  - Details: ('pull', 'short', 'leg-stump'): 3 - Percentage: 18.29%  **Opponent Team Bowlers Head-to-Head Analysis:**  - Mohammed Shami:   - Balls: 10   - Runs: 12   - Strike Rate: 120.0   - Wickets: 1   - Wicket Patterns: ('wicket', 'pushed slightly', 'off-stump', 'unknown'): 1  **Bowling Performance**  **Matches:**  1. 10(1.0) Econ: 10.0 Wkts: 0  **Total Bowling Statistics:**  - Total Runs Conceded: 10 - Total Wickets: 0 - Total Balls Bowled: 6 - Runs per Wicket: inf - Balls per Wicket: inf  **Bowling Phase Stats:**  - **Powerplay:** 0(0) Econ: 0 Wkts: 0 - **Middle Overs:** 53(26) Econ: 12.23 Wkts: 1 - **Death Overs:** 14(6) Econ: 14.0 Wkts: 0  **Wicket Analysis:**  No data available  **Boundary Analysis:**  - Details: {} - Percentage: 28.13%  **Variation Frequency:**  - Normal: 30 - Googly: 1 - Slower: 1  **Opponent Team Players Head-to-Head Analysis:**  No data available
# --------------------------------------------------
# Player ID: 11540
# Name: Jofra Archer
# Summary: **Jofra Archer's Performance Breakdown**  **BATTING STATISTICS**  ### Matches  * Match 1: 1(2) SR: 50 * Match 2: 3(2) SR: 150  ### Total Batting Statistics  * Total Runs: 4 * Total Balls: 4 * Average Runs: 2.0 * Overall Strike Rate: 100.0  ### Batting Phase Stats  * Powerplay: 0(0) SR: 0 * Middle: 0(0) SR: 0 * Death: 4(4) SR: 100.0  ### Wicket Analysis  No wicket analysis data available.  ### Batting Control  * In-control: 2 * Beaten: 1 * No-control: 1  ### Scoring Zones  * Long-off: 1 * Keeper: 1 * Square: 1  ### Boundary Analysis  * No boundary analysis data available.  ### Opponent Team Bowlers Head-to-Head Analysis  No data available.  **BOWLING STATISTICS**  ### Matches  * Match 1: 42(4) Econ: 10.5 Wkts: 1 * Match 2: 24(4) Econ: 6.0 Wkts: 0 * Match 3: 56(4) Econ: 14.0 Wkts: 0 * Match 4: 35(4) Econ: 8.8 Wkts: 1 * Match 5: 33(4) Econ: 8.2 Wkts: 0  ### Total Bowling Statistics  * Total Runs Conceded: 190 * Total Wickets: 2 * Total Balls Bowled: 120 * Runs per Wicket: 95.0 * Balls per Wicket: 60.0  ### Bowling Phase Stats  * Powerplay: 77(58) Econ: 7.97 Wkts: 0 * Middle: 54(46) Econ: 7.04 Wkts: 1 * Death: 58(25) Econ: 13.92 Wkts: 0  ### Wicket Analysis  No wicket analysis data available.  ### Boundary Analysis  * Details: ('short', 'outside-off', 'normal'): 3 * Percentage: 20.93%  ### Variation Frequency  * Normal: 92 * Slower: 23 * Quick: 6 * Yorker: 6 * Swing: 1 * Bouncer: 1  ### Opponent Team Players Head-to-Head Analysis  No data available.
# --------------------------------------------------
# Player ID: 1447065
# Name: Aniket Verma
# Summary: **Aniket Verma's Performance Breakdown**  **1. Matches:**  | Match # | Runs (Balls) | Strike Rate | | --- | --- | --- | | 1 | 0(1) SR: 0.0 |  |  **2. Total Batting Statistics:**  * **Total Runs:** 0 * **Total Balls:** 1 * **Average Runs:** 0.0 * **Overall Strike Rate:** 0.0  **3. Batting Phase Stats:**  * **Powerplay:** No data available * **Middle Overs:** No data available * **Death Overs:** No data available  **4. Batting Control:**  No data available  **5. Scoring Zones:**  No data available  **6. Wicket Analysis:**  | Shot Played | Ball Length | Ball Line | Shot Direction | | --- | --- | --- | --- | |  |  |  |  |  **7. Boundary Analysis:**  | Shot Played | Ball Length | Ball Line | | --- | --- | --- | |  |  |  |  **Boundary Percentage:** Not available (no boundaries scored)  **8. Shot Selection:**  No data available  **9. Opponent Team Bowlers Head-to-Head Analysis:**  No data available  **10. Overall Bowling Statistics:**  No bowling statistics available for Aniket Verma.  Note: Since Aniket Verma has not played any matches, most of the statistics are not available. The output is presented in a clear and readable format, with empty sections indicating the lack of data.
# --------------------------------------------------
# Player ID: 8095
# Name: Pat Cummins
# Summary: **Pat Cummins' Performance Breakdown**  **Batting Statistics**  ### Matches  - **Match 1:** 31(15) SR: 206.67 - **Match 2:** 1(1) SR: 100.0 - **Match 3:** 3(4) SR: 75.0 - **Match 4:** 2(2) SR: 100.0 - **Match 5:** 0(1) SR: 0.0 - **Match 6:** 0(2) SR: 0.0 - **Match 7:** 0(1) SR: 0.0 - **Match 8:** 31(15) SR: 206.67  ### Total Batting Statistics  - **Total Runs:** 68 - **Total Balls:** 41 - **Average Runs:** 8.5 - **Overall Strike Rate:** 165.85  ### Batting Phase Stats  - **Powerplay:** 0(0) SR: 0 - **Middle Overs:** 93(34) SR: 273.53 - **Death Overs:** 9(15) SR: 60.0  ### Wicket Analysis  No data available.  ### Batting Control  - **In-Control:** 37 - **No-Control:** 11 - **Beaten:** 1  ### Scoring Zones  - **Mid-wicket:** 9 - **Square:** 8 - **Keeper:** 6 - **Fine-leg:** 5 - **Long-on:** 4 - **Blocked:** 3 - **Point:** 3 - **Cover:** 2 - **Long-off:** 2 - **Third-man:** 1  ### Boundary Analysis  - **Boundary Percentage:** 30.61% - **Details:** No data available.  ### Shot Selection  No data available.  ---  **Bowling Statistics**  ### Matches  - **Match 1:** 55(4) Econ: 13.8 Wkts: 1 - **Match 2:** 35(4) Econ: 8.8 Wkts: 0 - **Match 3:** 43(4) Econ: 10.8 Wkts: 3 - **Match 4:** 22(4) Econ: 5.5 Wkts: 1 - **Match 5:** 29(4) Econ: 7.2 Wkts: 1 - **Match 6:** 28(4) Econ: 7.0 Wkts: 1 - **Match 7:** 35(4) Econ: 8.8 Wkts: 2 - **Match 8:** 32(4) Econ: 8.0 Wkts: 1 - **Match 9:** 22(4) Econ: 5.5 Wkts: 3 - **Match 10:** 50(4) Econ: 12.5 Wkts: 1 - **Match 11:** 35(4) Econ: 8.8 Wkts: 2 - **Match 12:** 55(4) Econ: 13.8 Wkts: 1 - **Match 13:** 29(4) Econ: 7.2 Wkts: 1  ### Total Bowling Statistics  - **Total Runs Conceded:** 470 - **Total Wickets:** 18 - **Total Balls Bowled:** 312 - **Runs per Wicket:** 26.11 - **Balls per Wicket:** 17.33  ### Bowling Phase Stats  - **Powerplay:** 141(93) Econ: 9.10 Wkts: 3 - **Middle Overs:** 180(141) Econ: 7.66 Wkts: 7 - **Death Overs:** 169(89) Econ: 11.39 Wkts: 3  ### Wicket Analysis  No data available.  ### Boundary Analysis  - **Boundary Percentage:** 21.67% - **Details:**   - **(full, outside-off, normal):** 4   - **(full, wide, normal):** 3   - **(short, outside-off, normal):** 6   - **(short, wide, normal):** 5  ### Bowling Variations  - **Normal:** 237 - **Slower:** 55 - **Yorker:** 13 - **Quick:** 8 - **Cutter:** 5 - **Bouncer:** 2 - **Seam-up:** 2 - **Swing:** 1
# --------------------------------------------------
# Player ID: 10276
# Name: Ishan Kishan
# Summary: **Ishan Kishan's Performance Breakdown**  **BATTING STATISTICS**  ### Matches  1. 8(11) SR: 72.73 2. 14(20) SR: 70.0 3. 18(14) SR: 128.57 4. 77(23) SR: 334.78 5. 20(13) SR: 153.85 6. 24(15) SR: 160.0 7. 20(14) SR: 142.86 8. 0(3) SR: 0.0 9. 8(8) SR: 100.0 10. 23(15) SR: 153.33 11. 38(31) SR: 122.58 12. 34(13) SR: 261.54  ### Total Batting Statistics  * Total Runs: 284 * Total Balls: 180 * Average Runs: 23.666666666666668 * Overall Strike Rate: 157.77777777777777  ### Batting Phase Stats  * Powerplay: 768(550) SR: 139.64 * Middle: 328(244) SR: 134.43 * Death: 39(16) SR: 243.75  ### Wicket Analysis  * ('cut', 'short', 'outside-off', 'point'): 2 * ('pull', 'short', 'leg-stump', 'fine-leg'): 2 * ('pushed slightly', 'short', 'outside-off', 'cover'): 2  ### Batting Control  * In-control: 661 * No-control: 129 * Beaten: 20  ### Scoring Zones  * Mid-wicket: 128 * Cover: 108 * Square: 94 * Point: 76 * Keeper: 70 * Long-on: 54 * Long-off: 54 * Blocked: 49 * Fine-leg: 26 * Third-man: 22  ### Boundary Analysis  * ('cut', 'short', 'outside-off'): 5 * ('cut', 'short', 'wide'): 3 * ('drive', 'full', 'outside-off'): 8 * ('drive', 'full', 'wide'): 3 * ('pull', 'short', 'leg-stump'): 4 * ('sweep', 'short', 'leg-stump'): 3 * Boundary Percentage: 21.23456790123457  **BOWLING STATISTICS**  ### Matches  1. 2(1.0) Econ: 2.0 Wkts: 0  ### Total Bowling Statistics  * Total Runs Conceded: 2 * Total Wickets: 0 * Total Balls Bowled: 6 * Runs per Wicket: inf * Balls per Wicket: inf  ### Bowling Phase Stats  * Powerplay: No data available * Middle: No data available * Death: No data available  ### Wicket Analysis  No data available  ### Boundary Analysis  No data available  ### Variation Frequency  No data available  ### Opponent team players head to head Analysis  No data available
# --------------------------------------------------
# Player ID: 8356
# Name: Sandeep Sharma
# Summary: **Sandeep Sharma's Performance Breakdown**  **Batting Performance**  ### Matches  - Match 1: 5(2) SR: 250 - Match 2: 2(2) SR: 100  ### Total Batting Statistics  - Total Runs: 7 - Total Balls: 4 - Average Runs: 3.5 - Overall Strike Rate: 175.0  ### Batting Phase Stats  - **Powerplay**: 0(0) SR: 0 - **Middle**: 0(1) SR: 0.0 - **Death**: 2(6) SR: 33.33  ### Batting Control  - In-Control: 6 - No-Control: 1  ### Scoring Zones  - Mid-Wicket: 1 - Third-Man: 1 - Blocked: 1  ### Boundary Analysis  - No boundaries scored in the recent matches. - Boundary Percentage: 0.0%  ### Wicket Analysis  - No wicket analysis data available.  ### Shot Selection  - No shot selection data available.  ---  **Bowling Performance**  ### Matches  - Match 1: 39(4) Econ: 9.8 Wkts: 0 - Match 2: 35(4) Econ: 8.8 Wkts: 0 - Match 3: 28(4) Econ: 7.0 Wkts: 1 - Match 4: 22(4) Econ: 5.5 Wkts: 4 - Match 5: 26(4) Econ: 6.5 Wkts: 2 - Match 6: 36(4) Econ: 9.0 Wkts: 2 - Match 7: 31(4) Econ: 7.8 Wkts: 2 - Match 8: 18(4) Econ: 4.5 Wkts: 5 - Match 9: 36(4) Econ: 9.0 Wkts: 0 - Match 10: 22(3) Econ: 7.3 Wkts: 1  ### Total Bowling Statistics  - Total Runs Conceded: 293 - Total Wickets: 17 - Total Balls Bowled: 234 - Runs per Wicket: 17.24 - Balls per Wicket: 13.76  ### Bowling Phase Stats  - **Powerplay**: 274(254) Econ: 6.47 Wkts: 4 - **Middle**: 184(135) Econ: 8.18 Wkts: 4 - **Death**: 197(121) Econ: 9.77 Wkts: 13  ### Wicket Analysis  - ('full', 'outside-off', 'normal'): 3  ### Boundary Analysis  - ('full', 'outside-off', 'normal'): 8 - ('full-toss', 'leg-stump', 'normal'): 3 - ('good length', 'outside-off', 'normal'): 3 - ('short', 'middle-stump', 'normal'): 3 - ('short', 'outside-off', 'normal'): 6 - ('yorker', 'wide', 'yorker'): 3 - Boundary Percentage: 18.04%  ### Bowling Variations  - Normal: 366 - Slower: 53 - Yorker: 43 - In-Swing: 13 - Quick: 9 - Out-Swing: 8 - Swing: 6 - Cutter: 5 - Seam-Away: 2 - Knuckle Ball: 2 - Seam-Up: 2 - Seam-In: 1
# --------------------------------------------------
# Player ID: 11307
# Name: Tushar Deshpande
# Summary: **Tushar Deshpande's Performance Breakdown**  **Batting Statistics**  * **Matches:** No matches played * **Total Runs:** 0 * **Total Balls:** 0 * **Average Runs:** 0 * **Overall Strike Rate:** 0 * **Phase Stats:**  + **Powerplay:** 0 runs (0 balls) SR: 0  + **Middle:** 0 runs (0 balls) SR: 0  + **Death:** 1 run (1 ball) SR: 100.0 * **Wicket Analysis:** No wickets taken * **Batting Control:** In-control: 1 * **Scoring Zones:** Blocked: 1 * **Boundary Analysis:**  + **Details:** No boundaries taken  + **Percentage:** 0.0%  **Bowling Statistics**  * **Matches:**  + Match 1: 34 runs (3.0 overs) Econ: 11.3 Wkts: 0  + Match 2: 42 runs (4.0 overs) Econ: 10.5 Wkts: 0  + Match 3: 29 runs (4.0 overs) Econ: 7.2 Wkts: 1  + Match 4: 33 runs (4.0 overs) Econ: 8.2 Wkts: 3  + Match 5: 20 runs (2.0 overs) Econ: 10.0 Wkts: 0  + Match 6: 24 runs (4.0 overs) Econ: 6.0 Wkts: 0  + Match 7: 21 runs (4.0 overs) Econ: 5.2 Wkts: 2  + Match 8: 47 runs (4.0 overs) Econ: 11.8 Wkts: 0  + Match 9: 56 runs (4.0 overs) Econ: 14.0 Wkts: 0  + Match 10: 43 runs (4.0 overs) Econ: 10.8 Wkts: 1  + Match 11: 20 runs (2.0 overs) Econ: 10.0 Wkts: 0 * **Total Runs Conceded:** 369 * **Total Wickets:** 7 * **Total Balls Bowled:** 234 * **Runs per Wicket:** 52.714285714285715 * **Balls per Wicket:** 33.42857142857143 * **Phase Stats:**  + **Powerplay:** 419 runs (311 balls) Wkts: 7 Econ: 8.083601286173634  + **Middle:** 167 runs (110 balls) Wkts: 7 Econ: 9.10909090909091  + **Death:** 292 runs (173 balls) Wkts: 10 Econ: 10.127167630057803 * **Wicket Analysis:**  + **Details:**    - (full, leg-stump, normal): 2   - (full, outside-off, normal): 2   - (short, outside-off, normal): 2 * **Boundary Analysis:**  + **Details:**    - (full, leg-stump, normal): 4   - (full, outside-off, normal): 11   - (full-toss, outside-off, normal): 7   - (length ball, outside-off, normal): 6   - (short, leg-stump, normal): 4   - (short, outside-off, normal): 8   - (short, outside-off, slower): 4  + **Percentage:** 22.895622895622896 * **Variation Frequency:**  + **Normal:** 434  + **Slower:** 88  + **Yorker:** 34  + **Quick:** 15  + **Out-swing:** 8  + **Seam-away:** 4  + **Cutter:** 4  + **Seam-up:** 2  + **Bouncer:** 2  + **Swing:** 2  + **In-swing:** 1
# --------------------------------------------------
# Player ID: 10926
# Name: Wanindu Hasaranga
# Summary: **Wanindu Hasaranga's Performance Breakdown**  **Batting Performance**  ### Matches  1. 5(4) SR: 125.0 2. 6(7) SR: 85.71 3. 12(8) SR: 150.0 4. 8(7) SR: 114.29 5. 2(2) SR: 100.0 6. 0(1) SR: 0.0  ### Total Batting Statistics  - Total Runs: 33 - Total Balls: 29 - Average Runs: 5.5 - Overall Strike Rate: 113.79310344827587  ### Batting Phase Stats  - **Powerplay**: 0(0) SR: 0 - **Middle**: 30(40) SR: 75.0 - **Death**: 50(38) SR: 131.57894736842107  ### Wicket Analysis  No data available  ### Batting Control  - In-control: 54 - No-control: 23 - Beaten: 1  ### Scoring Zones  - Cover: 14 - Blocked: 13 - Point: 12 - Keeper: 8 - Long-off: 7 - Long-on: 5 - Mid-wicket: 4 - Fine-leg: 4 - Square: 3 - Third-man: 1  ### Boundary Analysis  - Percentage: 12.82051282051282 - Details: No data available  ### Opponent Team Bowlers Head-to-Head Analysis  - Rahul Chahar:   - Balls: 2   - Runs: 1   - Strike Rate: 50.0   - Wickets: 1   - Wicket Patterns: ('caught', 'sweep', 'unknown', 'full'): 1  **Bowling Performance**  ### Matches  1. 24(4) Econ: 6.0 Wkts: 2 2. 32(4) Econ: 8.0 Wkts: 0 3. 53(4) Econ: 13.2 Wkts: 2 4. 32(4) Econ: 8.0 Wkts: 0 5. 39(4) Econ: 9.8 Wkts: 2 6. 20(4) Econ: 5.0 Wkts: 1 7. 21(2) Econ: 10.5 Wkts: 1 8. 37(3) Econ: 12.3 Wkts: 1 9. 26(4) Econ: 6.5 Wkts: 1 10. 42(4) Econ: 10.5 Wkts: 1  ### Total Bowling Statistics  - Total Runs Conceded: 326 - Total Wickets: 11 - Total Balls Bowled: 222 - Runs per Wicket: 29.636363636363637 - Balls per Wicket: 20.181818181818183  ### Bowling Phase Stats  - **Powerplay**: 80(48) Econ: 10.0 Wkts: 3   - Runs per Wicket: 26.666666666666668   - Balls per Wicket: 16.0 - **Middle**: 573(431) Econ: 7.976798143851508 Wkts: 19   - Runs per Wicket: 30.157894736842106   - Balls per Wicket: 22.68421052631579 - **Death**: 48(42) Econ: 6.857142857142857 Wkts: 6   - Runs per Wicket: 8.0   - Balls per Wicket: 7.0  ### Wicket Analysis  No data available  ### Boundary Analysis  - Percentage: 16.698656429942417 - Details:   - ('short', 'leg-stump', 'normal'): 3   - ('short', 'outside-off', 'normal'): 3   - ('short', 'wide', 'normal'): 3   - ('tossed up', 'leg-stump', 'normal'): 4  ### Variation Frequency  - Normal: 370 - Googly: 110 - Quick: 23 - Leg-break: 7 - Slower: 3 - Leg-spin: 3 - Skidding: 2 - Slider: 2 - Swing: 1  ### Opponent Team Players Head-to-Head Analysis  No data available
# --------------------------------------------------
# Player ID: 8497
# Name: Travis Head
# Summary: **Travis Head's Performance Breakdown**  **Matches Performance**  1. 89(32) SR: 278.12 2. 102(41) SR: 248.78 3. 21(15) SR: 140.0 4. 19(14) SR: 135.71 5. 62(24) SR: 258.33 6. 62(24) SR: 258.33  **Total Batting Statistics**  - **Total Runs:** 355 - **Total Balls:** 150 - **Average Runs:** 59.166666666666664 - **Overall Strike Rate:** 236.66666666666666  **Batting Phase Stats**  - **Powerplay:** 261(113) SR: 230.97 - **Middle:** 66(46) SR: 143.48 - **Death:** 0(0) SR: 0  **Wicket Analysis**  No data available  **Batting Control**  - **In-Control:** 126 - **No-Control:** 27 - **Beaten:** 6  **Scoring Zones**  - **Mid-wicket:** 24 - **Long-off:** 23 - **Cover:** 20 - **Blocked:** 15 - **Keeper:** 14 - **Square:** 14 - **Point:** 12 - **Long-on:** 11 - **Third-man:** 5 - **Fine-leg:** 3  **Boundary Analysis**  - **Boundary Details:** ('cut', 'short', 'outside-off'): 3 - **Boundary Percentage:** 35.84905660377358%  **Opponent Team Bowlers Head-to-Head Analysis**  - **Maheesh Theekshana:**   - **Balls:** 6   - **Runs:** 5   - **Strike Rate:** 83.33333333333334   - **Wickets:** 1   - **Wicket Patterns:** ('caught', 'sweep', 'leg-stump', 'length ball'): 1
# --------------------------------------------------
# Player ID: 23346
# Name: Kwena Maphaka
# Summary: **Kwena Maphaka's Bowling Performance Analysis**  **Matches:**  1. 23(2.0) Econ: 11.5 Wkts: 1 2. 66(4.0) Econ: 16.5 Wkts: 0 3. 66(4.0) Econ: 16.5 Wkts: 0  **Total Bowling Statistics:**  - Total Runs Conceded: 155 - Total Wickets: 1 - Total Balls Bowled: 60 - Runs per Wicket: 155.0 - Balls per Wicket: 60.0  **Phase Stats:**  **Powerplay:** - Runs: 51 - Balls: 25 - Wickets: 0 - Runs per Wicket: Infinity - Balls per Wicket: Infinity - Economy: 12.24  **Middle:** - Runs: 20 - Balls: 6 - Wickets: 0 - Runs per Wicket: Infinity - Balls per Wicket: Infinity - Economy: 20.0  **Death:** - Runs: 16 - Balls: 8 - Wickets: 0 - Runs per Wicket: Infinity - Balls per Wicket: Infinity - Economy: 12.0  **Wicket Analysis:**  No wickets taken in the specified matches.  **Boundary Analysis:**  - Short deliveries outside off stump: 2 - Boundary percentage: 43.58974358974359%  **Bowling Variations:**  - Normal deliveries: 30 - Yorker deliveries: 6 - Slower deliveries: 3  **Overall Bowling Statistics:**  - Total runs conceded: 155 - Total balls bowled: 60 - Total wickets: 1 - Runs per wicket: 155.0 - Balls per wicket: 60.0
# --------------------------------------------------
# Player ID: 12086
# Name: Abhishek Sharma
# Summary: **Abhishek Sharma's Batting Performance**  ### Matches  | Match ID | Runs (Balls) | SR: Strike Rate | Fantasy Points | | --- | --- | --- | --- | | 98924 | 106 (29) SR: 365.52 | 158 | | 98879 | 0 (2) SR: 0.0 | 0 | | 98762 | 21 (17) SR: 123.53 | 25 | | 98508 | 61 (36) SR: 169.44 | 84 | | 98321 | 33 (14) SR: 235.71 | 51 | | 98249 | 18 (8) SR: 225.0 | 24 | | 91524 | 31 (13) SR: 238.46 | 48 | | 91474 | 46 (12) SR: 383.33 | 70 | | 91434 | 34 (22) SR: 154.55 | 48 | | 91389 | 16 (11) SR: 145.45 | 22 | | 66183 | 0 (3) SR: 0.0 | 0 | | 66285 | 1 (2) SR: 50.0 | 1 | | 66344 | 9 (10) SR: 90.0 | 10 | | 66414 | 7 (5) SR: 140.0 | 8 | | 66449 | 5 (5) SR: 100.0 | 5 |  ### Total Batting Statistics  * Total Runs: 388 * Total Balls: 189 * Average Runs: 25.866666666666667 * Overall Strike Rate: 205.2910052910053  ### Batting Phase Stats  | Phase | Runs (Balls) | SR: Strike Rate | | --- | --- | --- | | Powerplay | 588 (390) SR: 150.76923076923077 | | Middle | 350 (228) SR: 153.50877192982458 | | Death | 21 (14) SR: 150.0 |  ### Batting Control  * In-control: 529 * No-control: 91 * Beaten: 12  ### Scoring Zones  | Zone | Runs | | --- | --- | | Cover | 114 | | Mid-wicket | 104 | | Point | 79 | | Square | 65 | | Blocked | 53 | | Keeper | 46 | | Long-off | 40 | | Long-on | 39 | | Fine-leg | 27 | | Third-man | 15 |  ### Boundary Analysis  * Details: 	+ ('cut', 'short', 'wide'): 3 	+ ('drive', 'full', 'outside-off'): 6 	+ ('loft', 'full', 'outside-off'): 6 	+ ('pull', 'short', 'leg-stump'): 4 	+ ('pull', 'short', 'outside-off'): 4 * Percentage: 22.943037974683545  ### Wicket Analysis  * No data available  ### Opponent Team Bowlers Head-to-Head Analysis  * Maheesh Theekshana: 	+ Balls: 19 	+ Runs: 33 	+ Strike Rate: 173.6842105263158 	+ Wickets: 0  **Abhishek Sharma's Bowling Performance**  ### Matches  | Match ID | Runs (Overs) | Econ: Economy Rate | Wkts: Wickets | Fantasy Points | | --- | --- | --- | --- | --- | | 98924 | 24 (4.0) Econ: 6.0 Wkts: 2 | 52 | | 98879 | 15 (3.0) Econ: 5.0 Wkts: 0 | 4 | | 98762 | 10 (1.0) Econ: 10.0 Wkts: 0 | 0 | | 98508 | 29 (3.0) Econ: 9.7 Wkts: 2 | 50 | | 98321 | 13 (3.0) Econ: 4.3 Wkts: 0 | 18 | | 98249 | 37 (4.0) Econ: 9.2 Wkts: 3 | 79 | | 91524 | 10 (1.0) Econ: 10.0 Wkts: 0 | 0 | | 91434 | 10 (1.0) Econ: 10.0 Wkts: 0 | 0 | | 66414 | 42 (3.0) Econ: 14.0 Wkts: 1 | 19 |  ### Total Bowling Statistics  * Total Runs Conceded: 190 * Total Wickets: 8 * Total Balls Bowled: 138 * Runs per Wicket: 23.75 * Balls per Wicket: 17.25  ### Bowling Phase Stats  | Phase | Runs (Balls) | Wkts: Wickets | Runs per Wicket | Balls per Wicket | Econ: Economy Rate | | --- | --- | --- | --- | --- | --- | | Powerplay | 38 (25) Wkts: 0 | Infinity | Infinity | Infinity | 9.12 | | Middle | 152 (92) Wkts: 2 | 76.0 | 46.0 | 9.91304347826087 | | Death | 0 (0) Wkts: 0 | Infinity | Infinity | Infinity | 0 |  ### Wicket Analysis  * No data available  ### Boundary Analysis  * Details: 	+ ('short', 'wide', 'normal'): 2 * Percentage: 21.367521367521366  ### Variation Frequency  * Normal: 104 * Quick: 6 * Arm ball: 2 * Slower: 2 * In-swing: 1 * Swing: 1 * Yorker: 1  ### Opponent Team Players Head-to-Head Analysis  * No data available
# --------------------------------------------------
# Player ID: 12087
# Name: Rahul Chahar
# Summary: **Rahul Chahar's Performance Breakdown**  **BATTING STATISTICS**  ### Matches  - Match 1: 5(3) SR: 166.67 - Match 2: 4(4) SR: 100.0 - Match 3: 0(8) SR: 0.0  ### Total Batting Statistics  - Total Runs: 9 - Total Balls: 15 - Average Runs: 3.0 - Overall Strike Rate: 60.0  ### Batting Phase Stats  - **Powerplay**: 0(0) SR: 0 - **Middle**: 6(21) SR: 28.57 - **Death**: 71(59) SR: 120.34  ### Wicket Analysis  - No wickets taken  ### Batting Control  - In-control: 57 - No-control: 20 - Beaten: 3  ### Scoring Zones  - Blocked: 16 - Keeper: 10 - Point: 9 - Mid-wicket: 8 - Cover: 7 - Long-off: 6 - Square: 5 - Fine-leg: 3 - Third-man: 3 - Long-on: 1  ### Boundary Analysis  - Percentage: 13.75%  ### Opponent Team Bowlers Head-to-Head Analysis  - No data available  **BOWLING STATISTICS**  ### Matches  - Match 1: 29(4.0) Econ: 7.2 Wkts: 0 - Match 2: 33(4.0) Econ: 8.2 Wkts: 1 - Match 3: 24(2.0) Econ: 12.0 Wkts: 0 - Match 4: 12(4.0) Econ: 3.0 Wkts: 2 - Match 5: 25(4.0) Econ: 6.2 Wkts: 0 - Match 6: 32(4.0) Econ: 8.0 Wkts: 1 - Match 7: 14(4.0) Econ: 3.5 Wkts: 2 - Match 8: 33(4.0) Econ: 8.2 Wkts: 1 - Match 9: 42(3.0) Econ: 14.0 Wkts: 1 - Match 10: 16(1.0) Econ: 16.0 Wkts: 0 - Match 11: 28(3.0) Econ: 9.3 Wkts: 1  ### Total Bowling Statistics  - Total Runs Conceded: 288 - Total Wickets: 9 - Total Balls Bowled: 222 - Runs per Wicket: 32.0 - Balls per Wicket: 24.67  ### Bowling Phase Stats  - **Powerplay**: 9(6) Econ: 9.0 Wkts: 0 - **Middle**: 798(616) Econ: 7.77 Wkts: 15 - **Death**: 67(41) Econ: 9.80 Wkts: 3  ### Wicket Analysis  - Full, leg-stump, normal: 2 - Full, outside-off, normal: 2  ### Boundary Analysis  - Percentage: 15.38%  ### Variation Frequency  - Normal: 522 - Quick: 63 - Googly: 43 - Leg-break: 19 - Slower: 8 - Slider: 2 - Flipper: 1 - Swing: 1 - Yorker: 1 - Seam-up: 1 - Leg-spin: 1 - Skidding: 1  ### Opponent Team Players Head-to-Head Analysis  - No data available
# --------------------------------------------------
# Player ID: 6327
# Name: Jaydev Unadkat
# Summary: **Jaydev Unadkat's Performance Breakdown**  **Batting Performance**  ### Matches  * Match 1: 1(1) SR: 100 * Match 2: 0(1) SR: 0 * Match 3: 16(16) SR: 100 * Match 4: 8(10) SR: 80 * Match 5: 8(10) SR: 80  ### Total Batting Statistics  * Total Runs: 33 * Total Balls: 38 * Average Runs: 6.6 * Overall Strike Rate: 86.84  ### Batting Phase Stats  * **Powerplay**: 0(0) SR: 0 * **Middle**: 4(7) SR: 57.14 * **Death**: 29(49) SR: 175.51  ### Wicket Analysis  No wickets taken.  ### Batting Control  * In-control: 38 * No-control: 16 * Beaten: 2  ### Scoring Zones  * Keeper: 9 * Cover: 8 * Square: 5 * Long-off: 5 * Long-on: 4 * Fine-leg: 4 * Third-man: 4 * Mid-wicket: 3 * Point: 3 * Blocked: 2  ### Boundary Analysis  * Boundaries: 2 (21.43% of total shots)  ### Shot Selection  * Drive: 12 * Cut: 8 * Sweep: 2 * Other shots: 16  **Bowling Performance**  ### Matches  * Match 1: 31(4) Econ: 7.8 Wkts: 1 * Match 2: 20(4) Econ: 5.0 Wkts: 2 * Match 3: 45(4) Econ: 11.2 Wkts: 1 * Match 4: 32(4) Econ: 8.0 Wkts: 1 * Match 5: 23(4) Econ: 5.8 Wkts: 1 * Match 6: 17(4) Econ: 4.2 Wkts: 2 * Match 7: 32(3) Econ: 10.7 Wkts: 0 * Match 8: 14(3) Econ: 4.7 Wkts: 0 * Match 9: 30(4) Econ: 7.5 Wkts: 3 * Match 10: 37(2) Econ: 18.5 Wkts: 0 * Match 11: 47(4) Econ: 11.8 Wkts: 2 * Match 12: 29(4) Econ: 7.2 Wkts: 1 * Match 13: 30(4) Econ: 7.5 Wkts: 3  ### Total Bowling Statistics  * Total Runs Conceded: 387 * Total Wickets: 17 * Total Balls Bowled: 288 * Runs per Wicket: 22.76 * Balls per Wicket: 16.94  ### Bowling Phase Stats  * **Powerplay**: 107(74) Econ: 8.68 Wkts: 0 * **Middle**: 200(137) Econ: 8.76 Wkts: 6 * **Death**: 201(100) Econ: 12.06 Wkts: 5  ### Wicket Analysis  * ('full', 'outside-off', 'slower'): 2  ### Boundary Analysis  * Boundaries: 11 (22.19% of total balls bowled)  ### Variation Frequency  * Normal: 202 * Slower: 83 * Quick: 10 * Cutter: 9 * Yorker: 6 * Bouncer: 1  Note: The statistics are presented in a clear and readable format, with each section focusing on a specific aspect of Jaydev Unadkat's performance. The data is not summarized, but rather presented in its raw form to allow for easy interpretation.
# --------------------------------------------------
# Player ID: 9789
# Name: Shimron Hetmyer
# Summary: **Shimron Hetmyer's Performance Breakdown**  **Matches:**  1. 0(1) SR: 0.0 2. 27(10) SR: 270.0 3. 13(5) SR: 260.0 4. 11(6) SR: 183.33 5. 14(7) SR: 200.0 6. 5(7) SR: 71.43 7. 8(10) SR: 80.0 8. 22(16) SR: 137.5  **Total Batting Statistics:**  - Total Runs: 100 - Total Balls: 62 - Average Runs: 12.5 - Overall Strike Rate: 161.29  **Batting Phase Stats:**  - **Powerplay:** 7(5) SR: 140.0 - **Middle Overs:** 242(220) SR: 110.0 - **Death Overs:** 458(239) SR: 191.63  **Wicket Analysis:**  No data available for wicket analysis.  **Batting Control:**  - In-Control: 382 - No-Control: 80 - Beaten: 2  **Scoring Zones:**  - Mid-wicket: 70 - Cover: 68 - Blocked: 57 - Long-on: 42 - Long-off: 42 - Square: 42 - Keeper: 35 - Point: 30 - Fine-leg: 13 - Third-man: 8  **Boundary Analysis:**  - **Boundary Details:** ('pull', 'short', 'leg-stump'): 3 - **Boundary Percentage:** 19.83%  **Opponent Team Bowlers Head-to-Head Analysis:**  - **Mohammed Shami:**   - Balls: 7   - Runs: 15   - Strike Rate: 214.29   - Wickets: 2   - Wicket Patterns:     - ('caught', 'pushed slightly', 'unknown', 'full'): 1     - ('caught', 'pushed slightly', 'unknown', 'unknown'): 1 - **Harshal Patel:**   - Balls: 18   - Runs: 22   - Strike Rate: 122.22   - Wickets: 0
# --------------------------------------------------
# Player ID: 8642
# Name: Adam Zampa
# Summary: **Adam Zampa's Performance Breakdown**  **Batting Statistics**  ### Matches  - Match 1: 2(6) SR: 33.33 - Match 2: 7(9) SR: 77.78 - Match 3: 1(1) SR: 100.0  ### Total Batting Statistics  - Total Runs: 10 - Total Balls: 16 - Average Runs: 3.33 - Overall Strike Rate: 62.5  ### Batting Phase Stats  - **Powerplay**: 0(0) SR: 0 - **Middle**: 5(12) SR: 41.67 - **Death**: 5(5) SR: 100.0  ### Batting Control  - In-Control: 13 - No-Control: 4  ### Scoring Zones  - Cover: 3 - Long-Off: 3 - Point: 3 - Keeper: 2 - Fine-Leg: 1 - Mid-Wicket: 1 - Blocked: 1  ### Boundary Analysis  - No boundaries scored in the recent matches. - Boundary Percentage: 0.0%  ### Wicket Analysis  - No wicket analysis data available.  ### Opponent Team Bowlers Head-to-Head Analysis  - No data available.  ---  **Bowling Statistics**  ### Matches  - Match 1: 22(3.0) Econ: 7.3 Wkts: 3 - Match 2: 26(4.0) Econ: 6.5 Wkts: 1 - Match 3: 25(4.0) Econ: 6.2 Wkts: 2 - Match 4: 40(3.0) Econ: 13.3 Wkts: 0 - Match 5: 32(4.0) Econ: 8.0 Wkts: 1 - Match 6: 43(4.0) Econ: 10.8 Wkts: 1  ### Total Bowling Statistics  - Total Runs Conceded: 188 - Total Wickets: 8 - Total Balls Bowled: 132 - Runs per Wicket: 23.5 - Balls per Wicket: 16.5  ### Bowling Phase Stats  - **Powerplay**: 39(36) Econ: 6.5 Wkts: 1 Runs per Wicket: 39.0 Balls per Wicket: 36.0 - **Middle**: 114(79) Econ: 8.66 Wkts: 4 Runs per Wicket: 28.5 Balls per Wicket: 19.75 - **Death**: 34(18) Econ: 11.33 Wkts: 0 Runs per Wicket: Infinity Balls per Wicket: Infinity  ### Wicket Analysis  - No wicket analysis data available.  ### Boundary Analysis  - Boundaries Conceded: 4 - Details:   - Full, Leg-Stump, Normal: 2   - Full, Outside-Off, Normal: 2 - Boundary Percentage: 17.29%  ### Variation Frequency  - Normal: 95 - Quick: 26 - Googly: 8 - Yorker: 1 - Flipper: 1 - Leg-Spin: 1 - Slower: 1  ### Opponent Team Players Head-to-Head Analysis  - No data available.
# --------------------------------------------------
# Player ID: 18504
# Name: Maheesh Theekshana
# Summary: **Maheesh Theekshana's Performance Breakdown**  **Batting Statistics**  * **Matches:** No matches played * **Total Runs:** 0 * **Total Balls:** 0 * **Average Runs:** 0 * **Overall Strike Rate:** 0 * **Phase Stats:** 	+ **Powerplay:** 0(0) SR: 0 	+ **Middle:** 0(3) SR: 0.0 	+ **Death:** 11(4) SR: 275.0 * **Wicket Analysis:** No data available * **Batting Control:** 	+ **In-Control:** 6 	+ **No-Control:** 1 * **Scoring Zones:** 	+ **Blocked:** 2 	+ **Fine-Leg:** 1 	+ **Cover:** 1 * **Boundary Analysis:** 	+ **Details:** No data available 	+ **Percentage:** 28.57% * **Opponent Team Bowlers Head-to-Head Analysis:** No data available  **Bowling Statistics**  * **Matches:** 	+ Match 1: 28(4) Econ: 7.0 Wkts: 1 	+ Match 2: 27(4) Econ: 6.8 Wkts: 1 	+ Match 3: 36(4) Econ: 9.0 Wkts: 0 	+ Match 4: 36(4) Econ: 9.0 Wkts: 0 	+ Match 5: 28(4) Econ: 7.0 Wkts: 2 	+ Match 6: 24(4) Econ: 6.0 Wkts: 1 	+ Match 7: 23(4) Econ: 5.8 Wkts: 2 	+ Match 8: 22(3) Econ: 7.3 Wkts: 0 	+ Match 9: 32(4) Econ: 8.0 Wkts: 2 	+ Match 10: 16(2) Econ: 8.0 Wkts: 0 	+ Match 11: 27(4) Econ: 6.8 Wkts: 1 * **Total Runs Conceded:** 299 * **Total Wickets:** 10 * **Total Balls Bowled:** 246 * **Runs per Wicket:** 29.9 * **Balls per Wicket:** 24.6 * **Phase Stats:** 	+ **Powerplay:** 269(188) Wkts: 5 Runs per Wicket: 53.8 Balls per Wicket: 37.6 Econ: 8.59 	+ **Middle:** 392(310) Wkts: 8 Runs per Wicket: 49.0 Balls per Wicket: 38.75 Econ: 7.59 	+ **Death:** 61(60) Wkts: 6 Runs per Wicket: 10.17 Balls per Wicket: 10.0 Econ: 6.1 * **Wicket Analysis:** 	+ **('short', 'outside-off', 'normal')**: 2 * **Boundary Analysis:** 	+ **Details:**  		- ('full', 'leg-stump', 'normal'): 3 		- ('full', 'outside-off', 'normal'): 6 		- ('full', 'wide', 'normal'): 4 		- ('short', 'leg-stump', 'normal'): 4 		- ('short', 'outside-off', 'normal'): 7 	+ **Percentage:** 14.16% * **Variation Frequency:** 	+ **Normal:** 454 	+ **Carrom Ball:** 40 	+ **Quick:** 35 	+ **Yorker:** 12 	+ **Seam-Up:** 5 	+ **Slower:** 4 	+ **Off-Break:** 3 	+ **Googly:** 2 	+ **Seam-Away:** 1 	+ **Skidding:** 1 	+ **Leg-Spin:** 1 * **Opponent Team Players Head-to-Head Analysis:** No data available
# --------------------------------------------------
# Player ID: 14282
# Name: Fazalhaq Farooqi
# Summary: **Fazalhaq Farooqi's Performance Breakdown**  **Batting Statistics**  ### Matches  - Match 1: 1(5) SR: 20 - Match 2: 2(8) SR: 25  ### Total Batting Statistics  - Total Runs: 3 - Total Balls: 13 - Average Runs: 1.5 - Overall Strike Rate: 23.08  ### Batting Phase Stats  - **Powerplay**: 0(0) SR: 0 - **Middle**: 0(0) SR: 0 - **Death**: 3(13) SR: 23.08  ### Wicket Analysis  No data available  ### Batting Control  - In-Control: 10 - No-Control: 3  ### Scoring Zones  - Point: 2 - Blocked: 2 - Keeper: 1 - Square: 1 - Long-Off: 1  ### Boundary Analysis  - No boundaries scored - Boundary Percentage: 0.0%  ### Opponent Team Bowlers Head-to-Head Analysis  No data available  **Bowling Statistics**  ### Matches  - Match 1: 31(3.0) Econ: 10.3 Wkts: 1 - Match 2: 32(3.2) Econ: 9.6 Wkts: 0 - Match 3: 41(4.0) Econ: 10.2 Wkts: 2 - Match 4: 32(4.0) Econ: 8.0 Wkts: 2 - Match 5: 31(4.0) Econ: 7.8 Wkts: 0 - Match 6: 47(4.0) Econ: 11.8 Wkts: 0 - Match 7: 41(4.0) Econ: 10.2 Wkts: 2 - Match 8: 32(3.2) Econ: 9.6 Wkts: 0  ### Total Bowling Statistics  - Total Runs Conceded: 287 - Total Wickets: 7 - Total Balls Bowled: 178 - Runs per Wicket: 41.0 - Balls per Wicket: 25.43  ### Bowling Phase Stats  - **Powerplay**: 90(76) Wkts: 2 Runs per Wicket: 45.0 Balls per Wicket: 38.0 Econ: 7.11 - **Middle**: 60(52) Wkts: 2 Runs per Wicket: 30.0 Balls per Wicket: 26.0 Econ: 6.92 - **Death**: 69(34) Wkts: 1 Runs per Wicket: 69.0 Balls per Wicket: 34.0 Econ: 12.18  ### Wicket Analysis  - ('back of a length', 'off-stump', 'normal'): 2  ### Boundary Analysis  - ('full', 'outside-off', 'normal'): 3 - ('short', 'wide', 'normal'): 3 - Boundary Percentage: 19.75%  ### Variation Frequency  - Normal: 103 - Slower: 37 - Yorker: 10 - Quick: 8 - Swing: 3 - Cutter: 1  ### Opponent Team Players Head-to-Head Analysis  No data available
# --------------------------------------------------
# Player ID: 51791
# Name: Vaibhav Suryavanshi
# Summary: **Vaibhav Suryavanshi's Performance Breakdown**  **Matches:**  1. 13(6) SR: 216.67    - Fantasy Points: 17    - Match ID: 98258    - Batting Position: 2  **Total Batting Statistics:**  - Total Runs: 13 - Total Balls: 6 - Average Runs: 13.0 - Overall Strike Rate: 216.67  **Batting Phase Stats:**  No data available for Powerplay, Middle Overs, and Death Overs.  **Wicket Analysis:**  No data available for shot_played, ball_length, ball_line, and shot_direction.  **Boundary Analysis:**  No data available for shot_played, ball_length, and ball_line.  **Opponent Team Bowlers Head-to-Head Analysis:**  No data available.  **Batting Control:**  No data available.  **Scoring Zones:**  No data available.  **Shot Selection:**  No data available.  **Bowling Statistics:**  No bowling data available for Vaibhav Suryavanshi.  **Overall Bowling Statistics:**  No bowling data available for Vaibhav Suryavanshi.  However, if we consider the provided batting statistics, we can infer that Vaibhav Suryavanshi has shown impressive batting skills with a high strike rate of 216.67 and an average of 13.0 runs per match. He has scored 13 runs in just 6 balls, indicating his ability to accelerate the scoring rate. However, more data is required to make a comprehensive analysis of his batting and bowling performance.
# --------------------------------------------------
# Player ID: 8271
# Name: Sanju Samson
# Summary: **Sanju Samson's Performance Breakdown**  **Matches:**  1. 7(12) SR: 58.33 2. 31(15) SR: 206.67 3. 4(4) SR: 100.0 4. 19(15) SR: 126.67 5. 75(45) SR: 166.67 6. 71(33) SR: 215.15 7. 38(28) SR: 135.71 8. 12(8) SR: 150.0 9. 18(14) SR: 128.57 10. 68(38) SR: 178.95 11. 55(32) SR: 171.88 12. 75(45) SR: 166.67 13. 19(15) SR: 126.67 14. 4(4) SR: 100.0 15. 31(15) SR: 206.67  **Total Batting Statistics:**  - Total Runs: 527 - Total Balls: 323 - Average Runs: 35.13 - Overall Strike Rate: 163.16  **Batting Phase Stats:**  - **Powerplay:** 283(204) SR: 138.73 - **Middle:** 790(525) SR: 150.48 - **Death:** 164(82) SR: 200.0  **Batting Control:**  - In-Control: 683 - No-Control: 112 - Beaten: 16  **Scoring Zones:**  - Mid-wicket: 119 - Cover: 112 - Long-off: 78 - Long-on: 76 - Blocked: 70 - Point: 70 - Square: 64 - Keeper: 61 - Third-man: 32 - Fine-leg: 30  **Boundary Analysis:**  - Details:   - (cut, short, outside-off): 9   - (cut, short, wide): 4   - (drive, full, outside-off): 5   - (loft, full, outside-off): 6   - (pull, short, outside-off): 3 - Percentage: 21.82%  **Opponent Team Bowlers Head-to-Head Analysis:**  - **Harshal Patel:**   - Balls: 12   - Runs: 16   - Strike Rate: 133.33   - Wickets: 1   - Wicket Patterns:     - (edge&caught, pushed slightly, outside-off, short): 1 - **Rahul Chahar:**   - Balls: 10   - Runs: 14   - Strike Rate: 140.0   - Wickets: 1   - Wicket Patterns:     - (caught, pushed slightly, leg-stump, unknown): 1
# --------------------------------------------------
# Player ID: 14163
# Name: Simarjeet Singh
# Summary: **Simarjeet Singh's Performance Breakdown**  **BATTING PERFORMANCE**  ### Matches  - Match 1: 3(3) SR: 100 - Match 2: 2(3) SR: 66.67 - Match 3: 2(2) SR: 100  ### Total Batting Statistics  - Total Runs: 7 - Total Balls: 8 - Average Runs: 2.33 - Overall Strike Rate: 87.5  ### Batting Phase Stats  - **Powerplay**: 0(0) SR: 0 - **Middle**: 2(3) SR: 66.67 - **Death**: 5(5) SR: 100  ### Batting Control  - In-Control: 6 - No-Control: 2  ### Scoring Zones  - Keeper: 2 - Mid-Wicket: 2 - Blocked: 1 - Long-On: 1  ### Boundary Analysis  - No boundaries scored in the recent matches. - Boundary Percentage: 0.0%  ### Shot Selection  - Drive: 0 - Cut: 0 - Pull: 0 - Sweep: 0 - Flick: 0 - Other: 0  **BOWLING PERFORMANCE**  ### Matches  - Match 1: 35(3.0) Econ: 11.7 Wkts: 1 - Match 2: 29(3.2) Econ: 8.7 Wkts: 1 - Match 3: 16(3.2) Econ: 4.8 Wkts: 3 - Match 4: 17(4.0) Econ: 4.2 Wkts: 2 - Match 5: 37(4.0) Econ: 9.2 Wkts: 2 - Match 6: 18(3.0) Econ: 6.0 Wkts: 1 - Match 7: 26(3.0) Econ: 8.7 Wkts: 0 - Match 8: 22(4.0) Econ: 5.5 Wkts: 1 - Match 9: 27(4.0) Econ: 6.8 Wkts: 2 - Match 10: 21(2.0) Econ: 10.5 Wkts: 0  ### Total Bowling Statistics  - Total Runs Conceded: 248 - Total Wickets: 13 - Total Balls Bowled: 202 - Runs per Wicket: 19.08 - Balls per Wicket: 15.54  ### Bowling Phase Stats  - **Powerplay**: 122(94) Econ: 7.79 Wkts: 3   - Runs per Wicket: 40.67   - Balls per Wicket: 31.33 - **Middle**: 15(19) Econ: 4.74 Wkts: 1   - Runs per Wicket: 15.00   - Balls per Wicket: 19.00 - **Death**: 0(0) Econ: 0 Wkts: 0   - Runs per Wicket: Infinity   - Balls per Wicket: Infinity  ### Bowling Variation Frequency  - Normal: 91 - Quick: 7 - Slower: 6 - Out-Swing: 5 - Yorker: 3 - In-Swing: 1  ### Boundary Analysis  - Details:   - ('short', 'outside-off', 'normal'): 3   - ('short', 'wide', 'normal'): 4 - Boundary Percentage: 20.35%
# --------------------------------------------------
# Player ID: 13914
# Name: Atharva Taide
# ...
# --------------------------------------------------
# Player ID: 14701
# Name: Nitish Reddy
# Summary: **Nitish Reddy's Performance Breakdown**  **BATTING STATISTICS**  ### Matches  | Match ID | Runs (Balls) | Strike Rate | Fantasy Points | | --- | --- | --- | --- | | 91524 | 13 (13) SR: 100.0 | 15 | | 91474 | 37 (27) SR: 137.04 | 49 | | 91389 | 64 (37) SR: 172.97 | 92 | | 89752 | 14 (8) SR: 175.0 | 17 | | 89752 | 14 (8) SR: 175.0 | 17 | | 91524 | 13 (13) SR: 100.0 | 15 |  ### Total Batting Statistics  * Total Runs: 155 * Total Balls: 106 * Average Runs: 25.83 * Overall Strike Rate: 146.23  ### Batting Phase Stats  * **Powerplay**: 11 (13) SR: 84.62 * **Middle**: 94 (62) SR: 151.61 * **Death**: 27 (13) SR: 207.69  ### Batting Control  * In-Control: 77 * No-Control: 9 * Beaten: 2  ### Scoring Zones  * Mid-Wicket: 18 * Point: 10 * Long-On: 10 * Square: 9 * Blocked: 8 * Cover: 8 * Long-Off: 6 * Keeper: 6 * Third-Man: 3  ### Boundary Analysis  * Total Boundaries: 30 * Boundary Percentage: 19.32%  ### Wicket Analysis  * No dismissals recorded  ### Shot Selection  * Drive: 12 * Cut: 8 * Other shots: 86  **BOWLING STATISTICS**  ### Matches  | Match ID | Runs (Overs) | Economy | Wickets | Fantasy Points | | --- | --- | --- | --- | --- | | 91474 | 17 (2.1) Econ: 7.8 Wkts: 2 | 50 | | 91389 | 33 (3.0) Econ: 11.0 Wkts: 1 | 21 | | 66495 | 35 (3.0) Econ: 11.7 Wkts: 0 | -4 | | 66467 | 19 (2.0) Econ: 9.5 Wkts: 0 | 0 | | 66467 | 19 (2.0) Econ: 9.5 Wkts: 0 | 0 |  ### Total Bowling Statistics  * Total Runs Conceded: 123 * Total Wickets: 3 * Total Balls Bowled: 73 * Runs per Wicket: 41.0 * Balls per Wicket: 24.33  ### Bowling Phase Stats  * **Powerplay**: 25 (12) Econ: 12.5 Wkts: 0 * **Middle**: 82 (51) Econ: 9.65 Wkts: 2 * **Death**: 0 (1) Econ: 0.0 Wkts: 1  ### Bowling Variation Frequency  * Normal: 48 * Slower: 9 * Quick: 4 * Out-Swing: 1 * In-Swing: 1 * Yorker: 1  ### Boundary Analysis  * Total Boundaries: 5 * Boundary Percentage: 21.88%  ### Wicket Analysis  * No dismissals recorded
# --------------------------------------------------
# Player ID: 14190
# Name: Kumar Kartikeya
# Summary: **Kumar Kartikeya's Performance Breakdown**  **Batting Performance**  ### Matches  - Match 1: 1(2) SR: 50 - Match 2: 0(1) SR: 0 - Match 3: 2(4) SR: 50 - Match 4: 4(3) SR: 133.33  ### Total Batting Statistics  - Total Runs: 7 - Total Balls: 10 - Average Runs: 1.75 - Overall Strike Rate: 70.0  ### Batting Phase Stats  - **Powerplay**: 0(0) SR: 0 - **Middle**: 1(3) SR: 33.33 - **Death**: 9(10) SR: 90.0  ### Batting Control  - In-Control: 10 - No-Control: 3  ### Scoring Zones  - Blocked: 3 - Fine-Leg: 2 - Square: 2 - Cover: 2 - Long-On: 1 - Mid-Wicket: 1  ### Boundary Analysis  - **Boundary Details**:    - ('shot_played', 'ball_length', 'ball_line'): {} - **Boundary Percentage**: 7.69%  ### Wicket Analysis  - **Wicket Details**:    - ('shot_played', 'ball_length', 'ball_line','shot_direction'): {}  **Bowling Performance**  ### Matches  - Match 1: 39(4.0) Econ: 9.8 Wkts: 1 - Match 2: 23(3.0) Econ: 7.7 Wkts: 1 - Match 3: 29(3.0) Econ: 9.7 Wkts: 0 - Match 4: 14(4.0) Econ: 3.5 Wkts: 2 - Match 5: 25(4.0) Econ: 6.2 Wkts: 3 - Match 6: 36(4.0) Econ: 9.0 Wkts: 3 - Match 7: 37(4.0) Econ: 9.2 Wkts: 1 - Match 8: 32(4.0) Econ: 8.0 Wkts: 3 - Match 9: 29(4.0) Econ: 7.2 Wkts: 1 - Match 10: 26(4.0) Econ: 6.5 Wkts: 2  ### Total Bowling Statistics  - Total Runs Conceded: 290 - Total Wickets: 17 - Total Balls Bowled: 228 - Runs per Wicket: 17.06 - Balls per Wicket: 13.41  ### Bowling Phase Stats  - **Powerplay**: 16(6) Econ: 16.0 Wkts: 1 - **Middle**: 278(215) Econ: 7.76 Wkts: 8 - **Death**: 38(20) Econ: 11.4 Wkts: 0  ### Bowling Variations  - Normal: 207 - Quick: 19 - Slower: 8 - Slider: 2 - Googly: 2 - Leg-Break: 1 - Seam-Up: 1 - Arm Ball: 1  ### Boundary Analysis  - **Boundary Details**:    - ('ball_length', 'ball_line','bowling_variation'):      - ('short', 'leg-stump', 'normal'): 2     - ('short', 'outside-off', 'normal'): 2 - **Boundary Percentage**: 15.77%  **Overall Performance**  Kumar Kartikeya has shown a decent batting performance, with an average of 1.75 and a strike rate of 70.0. He has been more effective in the death overs, with a strike rate of 90.0. In the bowling department, he has taken 17 wickets at an economy rate of 7.76, with a runs per wicket ratio of 17.06. His bowling variations have been effective, with a boundary percentage of 15.77%.
# --------------------------------------------------
# Player ID: 15727
# Name: Akash Madhwal
# Summary: **Akash Madhwal's Performance Breakdown**  **BATTING PERFORMANCE**  ### Matches  * 4(5) SR: 80 * 4(5) SR: 80  ### Total Batting Statistics  * Total Runs: 4 * Total Balls: 5 * Average Runs: 4.0 * Overall Strike Rate: 80.0  ### Batting Phase Stats  * **Powerplay**: 0(0) SR: 0 * **Middle**: 0(0) SR: 0 * **Death**: 5(5) SR: 100  ### Wicket Analysis  * No dismissals recorded  ### Batting Control  * In-control: 4 * No-control: 1  ### Scoring Zones  * Long-off: 1 * Cover: 1 * Keeper: 1 * Blocked: 1  ### Boundary Analysis  * No boundaries recorded * Boundary percentage: 0.0%  ### Opponent Team Bowlers Head-to-Head Analysis  * No data available  **BOWLING PERFORMANCE**  ### Matches  * 34(4) Econ: 8.5 Wkts: 2 * 32(4) Econ: 8.0 Wkts: 3 * 3(2) Econ: 1.5 Wkts: 0 * 30(3) Econ: 10.0 Wkts: 0 * 48(3.5) Econ: 12.5 Wkts: 3 * 37(3) Econ: 12.3 Wkts: 0 * 57(4) Econ: 14.2 Wkts: 1 * 20(4) Econ: 5.0 Wkts: 3 * 52(4) Econ: 13.0 Wkts: 1 * 5(3.3) Econ: 1.4 Wkts: 5  ### Total Bowling Statistics  * Total Runs Conceded: 318 * Total Wickets: 18 * Total Balls Bowled: 212 * Runs per Wicket: 17.666666666666668 * Balls per Wicket: 11.777777777777779  ### Bowling Phase Stats  * **Powerplay**: 91(73) Econ: 7.48 Wkts: 4 	+ Runs per Wicket: 22.75 	+ Balls per Wicket: 18.25 * **Middle**: 210(122) Econ: 10.33 Wkts: 7 	+ Runs per Wicket: 30.0 	+ Balls per Wicket: 17.428571428571427 * **Death**: 136(84) Econ: 9.71 Wkts: 5 	+ Runs per Wicket: 27.2 	+ Balls per Wicket: 16.8  ### Wicket Analysis  * Full, outside-off, normal: 2 * Short, off-stump, normal: 2  ### Boundary Analysis  * Full, leg-stump, normal: 3 * Full, outside-off, normal: 3 * Full-toss, outside-off, normal: 4 * Short, outside-off, normal: 5 * Boundary percentage: 22.22222222222222%  ### Variation Frequency  * Normal: 224 * Yorker: 36 * Slower: 7 * Quick: 6 * Swing: 2 * Out-swing: 2 * Seam-up: 1 * Skidding: 1  ### Opponent Team Players Head-to-Head Analysis  * No data available
# --------------------------------------------------
# Player ID: 8175
# Name: Harshal Patel
# Summary: **Harshal Patel's Performance Breakdown**  **BATTING STATISTICS**  ### Matches  | Match | Runs (Balls) | SR: Strike Rate | Fantasy Points | | --- | --- | --- | --- | | 98726 | 18 (18) SR: 100.0 | 22 | | 98665 | 2 (6) SR: 33.33 | 2 | | 98539 | 0 (2) SR: 0.0 | 0 | | 91488 | 0 (1) SR: 0.0 | 0 | | 91461 | 1 (4) SR: 25.0 | 1 |  ### Total Batting Statistics  * Total Runs: 21 * Total Balls: 31 * Average Runs: 4.2 * Overall Strike Rate: 67.74  ### Batting Phase Stats  | Phase | Runs (Balls) | SR: Strike Rate | | --- | --- | --- | | Powerplay | 0 (0) SR: 0 |  | | Middle | 20 (18) SR: 111.11 |  | | Death | 35 (35) SR: 100.0 |  |  ### Batting Control  * In-control: 37 * No-control: 15 * Beaten: 1  ### Scoring Zones  | Zone | Runs | | --- | --- | | Keeper | 12 | | Cover | 9 | | Long-on | 8 | | Blocked | 5 | | Point | 4 | | Mid-wicket | 4 | | Fine-leg | 3 | | Square | 1 | | Third-man | 1 | | Long-off | 1 |  ### Boundary Analysis  * Boundary Percentage: 15.09% * Details: 	+ (shot_played, ball_length, ball_line): (details)  ### Wicket Analysis  * No wickets taken  ### Batting Control  * In-control: 37 * No-control: 15 * Beaten: 1  ### Opponent Team Bowlers Head-to-Head Analysis  * No data available  **BOWLING STATISTICS**  ### Matches  | Match | Runs (Overs) | Econ: Economy Rate | Wkts: Wickets | Fantasy Points | | --- | --- | --- | --- | --- | | 99025 | 26 (3.0) Econ: 8.7 Wkts: 0 | 0 | | 98836 | 44 (4.0) Econ: 11.0 Wkts: 1 | 21 | | 98726 | 16 (3.0) Econ: 5.3 Wkts: 2 | 54 | | 98665 | 27 (2.5) Econ: 9.5 Wkts: 1 | 23 | | 98539 | 29 (3.0) Econ: 9.7 Wkts: 1 | 25 | | 98420 | 12 (4.0) Econ: 3.0 Wkts: 5 | 159 | | 98222 | 25 (3.0) Econ: 8.3 Wkts: 1 | 25 | | 91528 | 48 (3.0) Econ: 16.0 Wkts: 1 | 19 | | 91488 | 15 (3.0) Econ: 5.0 Wkts: 3 | 83 | | 91461 | 31 (4.0) Econ: 7.8 Wkts: 3 | 79 | | 66467 | 37 (4.0) Econ: 9.2 Wkts: 1 | 25 |  ### Total Bowling Statistics  * Total Runs Conceded: 310 * Total Wickets: 19 * Total Balls Bowled: 221 * Runs per Wicket: 16.32 * Balls per Wicket: 11.63  ### Bowling Phase Stats  | Phase | Runs (Balls) | Wkts: Wickets | Runs per Wicket | Balls per Wicket | Econ: Economy Rate | | --- | --- | --- | --- | --- | --- | | Powerplay | 42 (30) | 0 | Infinity | Infinity | 8.4 | | Middle | 618 (488) | 18 | 34.33 | 27.11 | 7.60 | | Death | 535 (329) | 23 | 23.26 | 14.30 | 9.76 |  ### Wicket Analysis  | Variation | Wkts | | --- | --- | | ('full', 'outside-off', 'normal') | 2 | | ('good length', 'outside-off', 'normal') | 2 | | ('short', 'outside-off', 'normal') | 2 | | ('short', 'outside-off', 'slower') | 4 |  ### Boundary Analysis  * Boundary Percentage: 18.18% * Details: 	+ (ball_length, ball_line, bowling_variation): (details)  ### Variation Frequency  | Variation | Frequency | | --- | --- | | Normal | 499 | | Slower | 235 | | Yorker | 51 | | Quick | 22 | | Cutter | 21 | | Seam-up | 12 | | Bouncer | 5 | | Off-break | 1 | | Swing | 1 |  ### Opponent Team Players Head-to-Head Analysis  * No data available
# --------------------------------------------------
# Player ID: 13940
# Name: Yashasvi Jaiswal
# Summary: **Yashasvi Jaiswal's Performance Breakdown**  **Batting Performance**  ### Matches  1. 24(18) SR: 133.33 2. 104(60) SR: 173.33 3. 19(9) SR: 211.11 4. 24(19) SR: 126.32 5. 0(2) SR: 0.0 6. 10(6) SR: 166.67 7. 5(7) SR: 71.43 8. 24(12) SR: 200.0 9. 77(43) SR: 179.07 10. 50(36) SR: 138.89 11. 54(37) SR: 145.95  ### Total Batting Statistics  - Total Runs: 391 - Total Balls: 249 - Average Runs: 35.54545454545455 - Overall Strike Rate: 157.0281124497992  ### Batting Phase Stats  - **Powerplay**: 717(452) SR: 158.63 - **Middle**: 400(290) SR: 137.93 - **Death**: 48(21) SR: 228.57  ### Wicket Analysis  No wicket analysis data available.  ### Batting Control  - In-control: 605 - No-control: 137 - Beaten: 21  ### Scoring Zones  - Cover: 110 - Mid-wicket: 98 - Keeper: 85 - Square: 80 - Point: 80 - Long-off: 69 - Blocked: 52 - Long-on: 40 - Fine-leg: 33 - Third-man: 29  ### Boundary Analysis  - Details:   - ('cut', 'back of a length', 'outside-off'): 4   - ('cut', 'short', 'outside-off'): 8   - ('drive', 'full', 'outside-off'): 10   - ('pull', 'short', 'outside-off'): 3   - ('sweep', 'full', 'leg-stump'): 3 - Percentage: 25.032765399737876  ### Opponent Team Bowlers Head-to-Head Analysis  - **Mohammed Shami**: 24 balls, 33 runs, 137.5 strike rate, 0 wickets - **Harshal Patel**: 7 balls, 5 runs, 71.43 strike rate, 1 wicket   - ('caught', 'pushed slightly', 'unknown', 'full-toss'): 1 - **Rahul Chahar**: 18 balls, 29 runs, 161.11 strike rate, 0 wickets  **Bowling Performance**  ### Matches  No bowling match data available.  ### Total Bowling Statistics  - Total Runs Conceded: 0 - Total Wickets: 0 - Total Balls Bowled: 0 - Runs per Wicket: 0 - Balls per Wicket: 0  ### Bowling Phase Stats  - **Powerplay**: 0 runs, 0 balls, 0 wickets, Infinity runs per wicket, Infinity balls per wicket, 0 economy - **Middle**: 0 runs, 0 balls, 0 wickets, Infinity runs per wicket, Infinity balls per wicket, 0 economy - **Death**: 6 runs, 1 ball, 0 wickets, Infinity runs per wicket, Infinity balls per wicket, 36.0 economy  ### Wicket Analysis  No wicket analysis data available.  ### Boundary Analysis  - Details: {} - Percentage: 100.0  ### Variation Frequency  - Normal: 1  ### Opponent Team Players Head-to-Head Analysis  No data available.
# --------------------------------------------------
# Player ID: 9204
# Name: Nitish Rana
# Summary: **Nitish Rana's Batting Performance**  ### Matches  1. 2(3) SR: 66.67 2. 4(7) SR: 57.14 3. 16(22) SR: 72.73 4. 0(1) SR: 0.0 5. 3(4) SR: 75.0 6. 2(4) SR: 50.0 7. 20(7) SR: 285.71 8. 3(7) SR: 42.86 9. 61(42) SR: 145.24 10. 9(11) SR: 81.82 11. 42(31) SR: 135.48  ### Total Batting Statistics  - Total Runs: 162 - Total Balls: 139 - Average Runs: 14.727272727272727 - Overall Strike Rate: 116.54676258992806  ### Batting Phase Stats  - **Powerplay**: 187(143) SR: 130.76923076923077 - **Middle**: 537(386) SR: 139.11917098445596 - **Death**: 77(46) SR: 167.3913043478261  ### Wicket Analysis  No wickets taken.  ### Batting Control  - In-control: 449 - No-control: 108 - Beaten: 18  ### Scoring Zones  - Mid-wicket: 80 - Square: 78 - Cover: 67 - Keeper: 66 - Point: 56 - Blocked: 49 - Fine-leg: 35 - Long-off: 23 - Long-on: 21 - Third-man: 20  ### Boundary Analysis  - Details:   - ('cut', 'short', 'outside-off'): 3   - ('drive', 'full', 'outside-off'): 3   - ('sweep', 'full', 'leg-stump'): 5 - Percentage: 19.47826086956522  ### Opponent Team Bowlers Head-to-Head Analysis  - Rahul Chahar:   - Balls: 14   - Runs: 13   - Strike Rate: 92.85714285714286   - Wickets: 1   - Wicket Patterns:     - ('caught', 'pushed slightly', 'outside-off', 'unknown'): 1  **Nitish Rana's Bowling Performance**  ### Matches  1. 23(3.0) Econ: 7.7 Wkts: 1 2. 19(4.0) Econ: 4.8 Wkts: 2 3. 10(2.0) Econ: 5.0 Wkts: 0 4. 22(4.0) Econ: 5.5 Wkts: 0 5. 20(2.0) Econ: 10.0 Wkts: 1  ### Total Bowling Statistics  - Total Runs Conceded: 94 - Total Wickets: 4 - Total Balls Bowled: 90 - Runs per Wicket: 23.5 - Balls per Wicket: 22.5  ### Bowling Phase Stats  - **Powerplay**: 26(6) Econ: 26.0 Wkts: 0 - **Middle**: 50(42) Econ: 7.142857142857143 Wkts: 2 - **Death**: 21(18) Econ: 7.0 Wkts: 1  ### Wicket Analysis  No wickets taken.  ### Boundary Analysis  - Details:   - ('full', 'leg-stump', 'normal'): 2   - ('tossed up', 'outside-off', 'normal'): 2 - Percentage: 21.21212121212121  ### Variation Frequency  - Normal: 59 - Quick: 4 - Slower: 2 - Skidding: 1  ### Opponent Team Players Head-to-Head Analysis  No analysis available.
# --------------------------------------------------
