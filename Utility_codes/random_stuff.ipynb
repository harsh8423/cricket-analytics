# %%
import requests
from bs4 import BeautifulSoup

def get_player_info(player_id):
    """
    Scrapes player information from Cricbuzz profile page
    
    Args:
        player_id (str): Player ID from Cricbuzz URL
        
    Returns:
        dict: Dictionary containing role, batting style and bowling style
    """
    
    # Construct the URL
    url = f"https://www.cricbuzz.com/profiles/{player_id}"
    
    try:
        # Send GET request
        response = requests.get(url)
        response.raise_for_status()  # Raise exception for bad status codes
        
        # Parse HTML content
        soup = BeautifulSoup(response.content, 'html.parser')
        
        # Find the div containing personal information
        info_div = soup.find('div', class_='cb-hm-rght')
        
        # Initialize dictionary to store player info
        player_info = {}
        
        # Extract role, batting style and bowling style
        div_elements = info_div.find_all('div', class_='cb-col')
        
        for i in range(len(div_elements)-1):
            current_div = div_elements[i]
            next_div = div_elements[i+1]
            
            if 'Role' in current_div.text:
                player_info['role'] = next_div.text.strip()
            elif 'Batting Style' in current_div.text:
                player_info['batting_style'] = next_div.text.strip()
            elif 'Bowling Style' in current_div.text:
                player_info['bowling_style'] = next_div.text.strip()
                
        return player_info
        
    except requests.RequestException as e:
        print(f"Error fetching data: {e}")
        return None
    except Exception as e:
        print(f"Error processing data: {e}")
        return None

# Example usage
if __name__ == "__main__":
    player_id = "11813"
    player_info = get_player_info(player_id)
    
    if player_info:
        print("Player Information:")
        print(f"Role: {player_info.get('role', 'Not found')}")
        print(f"Batting Style: {player_info.get('batting_style', 'Not found')}")
        print(f"Bowling Style: {player_info.get('bowling_style', 'Not found')}")
# Out:
# Player Information:
# Role: Batsman
# Batting Style: Right Handed Bat
# Bowling Style: Right-arm offbreak

# %%
import requests
from bs4 import BeautifulSoup
from pymongo import MongoClient
import time

# MongoDB Atlas connection
client = MongoClient("mongodb+srv://harsh8423:8423047004@cluster0.1xbklyu.mongodb.net/cricket")
db = client["cricket"]
players_collection = db["players"]

def get_player_info(player_id):
    """
    Scrapes player information from Cricbuzz profile page
    """
    url = f"https://www.cricbuzz.com/profiles/{player_id}"
    
    try:
        response = requests.get(url)
        response.raise_for_status()
        
        soup = BeautifulSoup(response.content, 'html.parser')
        info_div = soup.find('div', class_='cb-hm-rght')
        
        if not info_div:
            print(f"No information found for player {player_id}")
            return None
            
        player_info = {}
        div_elements = info_div.find_all('div', class_='cb-col')
        
        for i in range(len(div_elements)-1):
            current_div = div_elements[i]
            next_div = div_elements[i+1]
            
            if 'Role' in current_div.text:
                player_info['role'] = next_div.text.strip()
            elif 'Batting Style' in current_div.text:
                player_info['batting_style'] = next_div.text.strip()
            elif 'Bowling Style' in current_div.text:
                player_info['bowling_style'] = next_div.text.strip()
                
        return player_info
        
    except requests.RequestException as e:
        print(f"Error fetching data for player {player_id}: {e}")
        return None
    except Exception as e:
        print(f"Error processing data for player {player_id}: {e}")
        return None

def update_all_players_info():
    """
    Updates player information in MongoDB for all existing players in the database
    """
    print("Starting update for all players in database")
    
    # Get all player IDs from database
    all_players = list(players_collection.find({}, {"_id": 1, "name": 1}))
    total_players = len(all_players)
    
    print(f"Found {total_players} players in database")
    
    # Counter for successful updates
    updates_count = 0
    failed_count = 0
    
    for index, player in enumerate(all_players, 1):
        player_id = player['_id']
        player_name = player.get('name', 'Unknown')
        
        print(f"\nProcessing {index}/{total_players}: {player_name} (ID: {player_id})")
        
        # Get player info from Cricbuzz
        player_info = get_player_info(str(player_id))
        
        if player_info:
            try:
                # Update player document
                result = players_collection.update_one(
                    {"_id": player_id},
                    {"$set": {
                        "role": player_info.get('role', ''),
                        "batting_style": player_info.get('batting_style', ''),
                        "bowling_style": player_info.get('bowling_style', '')
                    }}
                )
                
                if result.modified_count > 0:
                    print(f"✓ Updated {player_name}")
                    updates_count += 1
                else:
                    print(f"- No changes needed for {player_name}")
                    
            except Exception as e:
                print(f"× Error updating MongoDB for {player_name}: {e}")
                failed_count += 1
        else:
            print(f"× No Cricbuzz data found for {player_name}")
            failed_count += 1
            
        # Add a small delay to avoid overwhelming the server
        time.sleep(1)
    
    print("\nUpdate complete!")
    print(f"Total players processed: {total_players}")
    print(f"Successfully updated: {updates_count}")
    print(f"Failed updates: {failed_count}")

# Example usage
if __name__ == "__main__":
    update_all_players_info()
# Out:
# Starting update for all players in database
# Found 810 players in database
#
# Processing 1/810: Ruturaj Gaikwad (ID: 11813)
# - No changes needed for Ruturaj Gaikwad
#
# Processing 2/810: Andre Siddarth C (ID: 1427488)
# - No changes needed for Andre Siddarth C
#
# Processing 3/810: Shaik Rasheed (ID: 22571)
# - No changes needed for Shaik Rasheed
#
# Processing 4/810: Rahul Tripathi (ID: 9012)
# - No changes needed for Rahul Tripathi
#
# Processing 5/810: Shivam Dube (ID: 11195)
# - No changes needed for Shivam Dube
#
# Processing 6/810: Rachin Ravindra (ID: 11177)
# - No changes needed for Rachin Ravindra
#
# Processing 7/810: Deepak Hooda (ID: 9427)
# - No changes needed for Deepak Hooda
#
# Processing 8/810: Vijay Shankar (ID: 8204)
# - No changes needed for Vijay Shankar
#
# Processing 9/810: Ramakrishna Ghosh (ID: 32835)
# - No changes needed for Ramakrishna Ghosh
#
# Processing 10/810: Ravindra Jadeja (ID: 587)
# - No changes needed for Ravindra Jadeja
#
# Processing 11/810: Anshul Kamboj (ID: 14598)
# - No changes needed for Anshul Kamboj
#
# Processing 12/810: Jamie Overton (ID: 8512)
# ✓ Updated Jamie Overton
#
# Processing 13/810: Sam Curran (ID: 10420)
# - No changes needed for Sam Curran
#
# Processing 14/810: Ravichandran Ashwin (ID: 1593)
# - No changes needed for Ravichandran Ashwin
#
# Processing 15/810: Devon Conway (ID: 9838)
# ✓ Updated Devon Conway
#
# Processing 16/810: MS Dhoni (ID: 265)
# ✓ Updated MS Dhoni
#
# Processing 17/810: Vansh Bedi (ID: 1429626)
# ✓ Updated Vansh Bedi
#
# Processing 18/810: Kamlesh Nagarkoti (ID: 12092)
# - No changes needed for Kamlesh Nagarkoti
#
# Processing 19/810: Shreyas Gopal (ID: 9746)
# - No changes needed for Shreyas Gopal
#
# Processing 20/810: Matheesha Pathirana (ID: 16458)
# - No changes needed for Matheesha Pathirana
#
# Processing 21/810: Mukesh Choudhary (ID: 13184)
# - No changes needed for Mukesh Choudhary
#
# Processing 22/810: Nathan Ellis (ID: 15480)
# - No changes needed for Nathan Ellis
#
# Processing 23/810: Gurjapneet Singh (ID: 19807)
# - No changes needed for Gurjapneet Singh
#
# Processing 24/810: Noor Ahmad (ID: 15452)
# - No changes needed for Noor Ahmad
#
# Processing 25/810: Khaleel Ahmed (ID: 10952)
# - No changes needed for Khaleel Ahmed
#
# Processing 26/810: Vaibhav Suryavanshi (ID: 51791)
# - No changes needed for Vaibhav Suryavanshi
#
# Processing 27/810: Shimron Hetmyer (ID: 9789)
# ✓ Updated Shimron Hetmyer
#
# Processing 28/810: Yashasvi Jaiswal (ID: 13940)
# - No changes needed for Yashasvi Jaiswal
#
# Processing 29/810: Shubham Dubey (ID: 19328)
# ✓ Updated Shubham Dubey
#
# Processing 30/810: Nitish Rana (ID: 9204)
# - No changes needed for Nitish Rana
#
# Processing 31/810: Riyan Parag (ID: 12305)
# - No changes needed for Riyan Parag
#
# Processing 32/810: Yudhvir Singh Charak (ID: 15749)
# - No changes needed for Yudhvir Singh Charak
#
# Processing 33/810: Wanindu Hasaranga (ID: 10926)
# - No changes needed for Wanindu Hasaranga
#
# Processing 34/810: Sanju Samson (ID: 8271)
# ✓ Updated Sanju Samson
#
# Processing 35/810: Dhruv Jurel (ID: 14691)
# - No changes needed for Dhruv Jurel
#
# Processing 36/810: Kunal Singh Rathore (ID: 32854)
# - No changes needed for Kunal Singh Rathore
#
# Processing 37/810: Sandeep Sharma (ID: 8356)
# - No changes needed for Sandeep Sharma
#
# Processing 38/810: Tushar Deshpande (ID: 11307)
# - No changes needed for Tushar Deshpande
#
# Processing 39/810: Kumar Kartikeya (ID: 14190)
# - No changes needed for Kumar Kartikeya
#
# Processing 40/810: Akash Madhwal (ID: 15727)
# ✓ Updated Akash Madhwal
#
# Processing 41/810: Kwena Maphaka (ID: 23346)
# - No changes needed for Kwena Maphaka
#
# Processing 42/810: Maheesh Theekshana (ID: 18504)
# - No changes needed for Maheesh Theekshana
#
# Processing 43/810: Fazalhaq Farooqi (ID: 14282)
# - No changes needed for Fazalhaq Farooqi
#
# Processing 44/810: Ashok Sharma (ID: 24261)
# ✓ Updated Ashok Sharma
#
# Processing 45/810: Jofra Archer (ID: 11540)
# - No changes needed for Jofra Archer
#
# Processing 46/810: Manish Pandey (ID: 1836)
# - No changes needed for Manish Pandey
#
# Processing 47/810: Ajinkya Rahane (ID: 1447)
# - No changes needed for Ajinkya Rahane
#
# Processing 48/810: Rinku Singh (ID: 10896)
# - No changes needed for Rinku Singh
#
# Processing 49/810: Angkrish Raghuvanshi (ID: 22566)
# - No changes needed for Angkrish Raghuvanshi
#
# Processing 50/810: Rovman Powell (ID: 11445)
# - No changes needed for Rovman Powell
#
# Processing 51/810: Anukul Roy (ID: 12344)
# - No changes needed for Anukul Roy
#
# Processing 52/810: Ramandeep Singh (ID: 12337)
# - No changes needed for Ramandeep Singh
#
# Processing 53/810: Venkatesh Iyer (ID: 10917)
# - No changes needed for Venkatesh Iyer
#
# Processing 54/810: Moeen Ali (ID: 6692)
# - No changes needed for Moeen Ali
#
# Processing 55/810: Sunil Narine (ID: 2276)
# - No changes needed for Sunil Narine
#
# Processing 56/810: Andre Russell (ID: 7736)
# - No changes needed for Andre Russell
#
# Processing 57/810: Quinton de Kock (ID: 8520)
# - No changes needed for Quinton de Kock
#
# Processing 58/810: Rahmanullah Gurbaz (ID: 13213)
# - No changes needed for Rahmanullah Gurbaz
#
# Processing 59/810: Luvnith Sisodia (ID: 13972)
# - No changes needed for Luvnith Sisodia
#
# Processing 60/810: Varun Chakaravarthy (ID: 12926)
# - No changes needed for Varun Chakaravarthy
#
# Processing 61/810: Mayank Markande (ID: 12627)
# - No changes needed for Mayank Markande
#
# Processing 62/810: Vaibhav Arora (ID: 15861)
# - No changes needed for Vaibhav Arora
#
# Processing 63/810: Harshit Rana (ID: 24729)
# ✓ Updated Harshit Rana
#
# Processing 64/810: Anrich Nortje (ID: 11427)
# ✓ Updated Anrich Nortje
#
# Processing 65/810: Umran Malik (ID: 19027)
# ✓ Updated Umran Malik
#
# Processing 66/810: Spencer Johnson (ID: 13143)
# ✓ Updated Spencer Johnson
#
# Processing 67/810: Atharva Taide (ID: 13914)
# ✓ Updated Atharva Taide
#
# Processing 68/810: Travis Head (ID: 8497)
# ✓ Updated Travis Head
#
# Processing 69/810: Abhinav Manohar (ID: 10499)
# ✓ Updated Abhinav Manohar
#
# Processing 70/810: Sachin Baby (ID: 8709)
# ✓ Updated Sachin Baby
#
# Processing 71/810: Aniket Verma (ID: 1447065)
# ✓ Updated Aniket Verma
#
# Processing 72/810: Nitish Kumar Reddy (ID: 14701)
# ✓ Updated Nitish Kumar Reddy
#
# Processing 73/810: Abhishek Sharma (ID: 12086)
# ✓ Updated Abhishek Sharma
#
# Processing 74/810: Kamindu Mendis (ID: 10940)
# ✓ Updated Kamindu Mendis
#
# Processing 75/810: Brydon Carse (ID: 11436)
# ✓ Updated Brydon Carse
#
# Processing 76/810: Heinrich Klaasen (ID: 10209)
# ✓ Updated Heinrich Klaasen
#
# Processing 77/810: Ishan Kishan (ID: 10276)
# ✓ Updated Ishan Kishan
#
# Processing 78/810: Zeeshan Ansari (ID: 10946)
# ✓ Updated Zeeshan Ansari
#
# Processing 79/810: Pat Cummins (ID: 8095)
# ✓ Updated Pat Cummins
#
# Processing 80/810: Mohammed Shami (ID: 7909)
# ✓ Updated Mohammed Shami
#
# Processing 81/810: Harshal Patel (ID: 8175)
# ✓ Updated Harshal Patel
#
# Processing 82/810: Rahul Chahar (ID: 12087)
# ✓ Updated Rahul Chahar
#
# Processing 83/810: Simarjeet Singh (ID: 14163)
# ✓ Updated Simarjeet Singh
#
# Processing 84/810: Eshan Malinga (ID: 46926)
# ✓ Updated Eshan Malinga
#
# Processing 85/810: Adam Zampa (ID: 8642)
# ✓ Updated Adam Zampa
#
# Processing 86/810: Jaydev Unadkat (ID: 6327)
# ✓ Updated Jaydev Unadkat
#
# Processing 87/810: Virat Kohli (ID: 1413)
# ✓ Updated Virat Kohli
#
# Processing 88/810: Rajat Patidar (ID: 10636)
# ✓ Updated Rajat Patidar
#
# Processing 89/810: Devdutt Padikkal (ID: 13088)
# ✓ Updated Devdutt Padikkal
#
# Processing 90/810: Swastik Chikara (ID: 52418)
# ✓ Updated Swastik Chikara
#
# Processing 91/810: Tim David (ID: 13169)
# ✓ Updated Tim David
#
# Processing 92/810: Krunal Pandya (ID: 11311)
# ✓ Updated Krunal Pandya
#
# Processing 93/810: Liam Livingstone (ID: 10045)
# ✓ Updated Liam Livingstone
#
# Processing 94/810: Manoj Bhandage (ID: 13962)
# ✓ Updated Manoj Bhandage
#
# Processing 95/810: Jacob Bethell (ID: 19636)
# ✓ Updated Jacob Bethell
#
# Processing 96/810: Romario Shepherd (ID: 13646)
# ✓ Updated Romario Shepherd
#
# Processing 97/810: Swapnil Singh (ID: 10238)
# ✓ Updated Swapnil Singh
#
# Processing 98/810: Mohit Rathee (ID: 36524)
# ✓ Updated Mohit Rathee
#
# Processing 99/810: Philip Salt (ID: 10479)
# ✓ Updated Philip Salt
#
# Processing 100/810: Jitesh Sharma (ID: 10214)
# ✓ Updated Jitesh Sharma
#
# Processing 101/810: Josh Hazlewood (ID: 6258)
# ✓ Updated Josh Hazlewood
#
# Processing 102/810: Bhuvneshwar Kumar (ID: 1726)
# ✓ Updated Bhuvneshwar Kumar
#
# Processing 103/810: Lungi Ngidi (ID: 9603)
# ✓ Updated Lungi Ngidi
#
# Processing 104/810: Rasikh Dar Salam (ID: 14274)
# ✓ Updated Rasikh Dar Salam
#
# Processing 105/810: Suyash Sharma (ID: 36487)
# ✓ Updated Suyash Sharma
#
# Processing 106/810: Yash Dayal (ID: 14172)
# ✓ Updated Yash Dayal
#
# Processing 107/810: Nuwan Thushara (ID: 18509)
# ✓ Updated Nuwan Thushara
#
# Processing 108/810: Abhinandan Singh (ID: 1447073)
# ✓ Updated Abhinandan Singh
#
# Processing 109/810: Faf du Plessis (ID: 7825)
# ✓ Updated Faf du Plessis
#
# Processing 110/810: Karun Nair (ID: 8257)
# ✓ Updated Karun Nair
#
# Processing 111/810: Harry Brook (ID: 12201)
# ✓ Updated Harry Brook
#
# Processing 112/810: Jake Fraser-McGurk (ID: 14501)
# ✓ Updated Jake Fraser-McGurk
#
# Processing 113/810: Sameer Rizvi (ID: 14700)
# ✓ Updated Sameer Rizvi
#
# Processing 114/810: Ashutosh Sharma (ID: 13497)
# ✓ Updated Ashutosh Sharma
#
# Processing 115/810: Tripurana Vijay (ID: 22386)
# ✓ Updated Tripurana Vijay
#
# Processing 116/810: Vipraj Nigam (ID: 1431811)
# ✓ Updated Vipraj Nigam
#
# Processing 117/810: Axar Patel (ID: 8808)
# ✓ Updated Axar Patel
#
# Processing 118/810: Darshan Nalkande (ID: 12779)
# ✓ Updated Darshan Nalkande
#
# Processing 119/810: Ajay Jadav Mandal (ID: 11777)
# ✓ Updated Ajay Jadav Mandal
#
# Processing 120/810: Manvanth Kumar L (ID: 47742)
# ✓ Updated Manvanth Kumar L
#
# Processing 121/810: Madhav Tiwari (ID: 1447321)
# ✓ Updated Madhav Tiwari
#
# Processing 122/810: Tristan Stubbs (ID: 19243)
# ✓ Updated Tristan Stubbs
#
# Processing 123/810: Abishek Porel (ID: 24326)
# ✓ Updated Abishek Porel
#
# Processing 124/810: Donovan Ferreira (ID: 14798)
# ✓ Updated Donovan Ferreira
#
# Processing 125/810: KL Rahul (ID: 8733)
# ✓ Updated KL Rahul
#
# Processing 126/810: Kuldeep Yadav (ID: 8292)
# ✓ Updated Kuldeep Yadav
#
# Processing 127/810: Dushmantha Chameera (ID: 8393)
# ✓ Updated Dushmantha Chameera
#
# Processing 128/810: Mitchell Starc (ID: 7710)
# ✓ Updated Mitchell Starc
#
# Processing 129/810: Mohit Sharma (ID: 8181)
# ✓ Updated Mohit Sharma
#
# Processing 130/810: T Natarajan (ID: 10225)
# ✓ Updated T Natarajan
#
# Processing 131/810: Mukesh Kumar (ID: 10754)
# ✓ Updated Mukesh Kumar
#
# Processing 132/810: Nehal Wadhera (ID: 13915)
# ✓ Updated Nehal Wadhera
#
# Processing 133/810: Harnoor Singh (ID: 22561)
# ✓ Updated Harnoor Singh
#
# Processing 134/810: Shreyas Iyer (ID: 9428)
# ✓ Updated Shreyas Iyer
#
# Processing 135/810: Pyla Avinash (ID: 32525)
# ✓ Updated Pyla Avinash
#
# Processing 136/810: Priyansh Arya (ID: 14689)
# ✓ Updated Priyansh Arya
#
# Processing 137/810: Musheer Khan (ID: 27424)
# ✓ Updated Musheer Khan
#
# Processing 138/810: Marcus Stoinis (ID: 8989)
# ✓ Updated Marcus Stoinis
#
# Processing 139/810: Glenn Maxwell (ID: 7662)
# ✓ Updated Glenn Maxwell
#
# Processing 140/810: Aaron Hardie (ID: 13170)
# ✓ Updated Aaron Hardie
#
# Processing 141/810: Suryansh Shedge (ID: 14922)
# ✓ Updated Suryansh Shedge
#
# Processing 142/810: Shashank Singh (ID: 10919)
# ✓ Updated Shashank Singh
#
# Processing 143/810: Praveen Dubey (ID: 10484)
# ✓ Updated Praveen Dubey
#
# Processing 144/810: Azmatullah Omarzai (ID: 13214)
# ✓ Updated Azmatullah Omarzai
#
# Processing 145/810: Marco Jansen (ID: 14565)
# ✓ Updated Marco Jansen
#
# Processing 146/810: Prabhsimran Singh (ID: 14254)
# ✓ Updated Prabhsimran Singh
#
# Processing 147/810: Josh Inglis (ID: 10637)
# ✓ Updated Josh Inglis
#
# Processing 148/810: Vishnu Vinod (ID: 11893)
# ✓ Updated Vishnu Vinod
#
# Processing 149/810: Harpreet Brar (ID: 14452)
# ✓ Updated Harpreet Brar
#
# Processing 150/810: Lockie Ferguson (ID: 10692)
# ✓ Updated Lockie Ferguson
#
# Processing 151/810: Arshdeep Singh (ID: 13217)
# ✓ Updated Arshdeep Singh
#
# Processing 152/810: Yuzvendra Chahal (ID: 7910)
# ✓ Updated Yuzvendra Chahal
#
# Processing 153/810: Vijaykumar Vyshak (ID: 10486)
# ✓ Updated Vijaykumar Vyshak
#
# Processing 154/810: Kuldeep Sen (ID: 14336)
# ✓ Updated Kuldeep Sen
#
# Processing 155/810: Yash Thakur (ID: 12096)
# ✓ Updated Yash Thakur
#
# Processing 156/810: Xavier Bartlett (ID: 11689)
# ✓ Updated Xavier Bartlett
#
# Processing 157/810: Rohit Sharma (ID: 576)
# ✓ Updated Rohit Sharma
#
# Processing 158/810: Suryakumar Yadav (ID: 7915)
# ✓ Updated Suryakumar Yadav
#
# Processing 159/810: Tilak Varma (ID: 14504)
# ✓ Updated Tilak Varma
#
# Processing 160/810: Naman Dhir (ID: 36139)
# ✓ Updated Naman Dhir
#
# Processing 161/810: Bevon Jacobs (ID: 52428)
# ✓ Updated Bevon Jacobs
#
# Processing 162/810: Hardik Pandya (Captain) (ID: 9647)
# ✓ Updated Hardik Pandya (Captain)
#
# Processing 163/810: Raj Bawa (ID: 22601)
# ✓ Updated Raj Bawa
#
# Processing 164/810: Will Jacks (ID: 12258)
# ✓ Updated Will Jacks
#
# Processing 165/810: Vignesh Puthur (ID: 1447337)
# ✓ Updated Vignesh Puthur
#
# Processing 166/810: Satyanarayana Raju (ID: 1431171)
# ✓ Updated Satyanarayana Raju
#
# Processing 167/810: Mitchell Santner (ID: 10100)
# ✓ Updated Mitchell Santner
#
# Processing 168/810: Arjun Tendulkar (ID: 13747)
# ✓ Updated Arjun Tendulkar
#
# Processing 169/810: Ryan Rickelton (ID: 13070)
# ✓ Updated Ryan Rickelton
#
# Processing 170/810: Krishnan Shrijith (ID: 13082)
# ✓ Updated Krishnan Shrijith
#
# Processing 171/810: Robin Minz (ID: 36454)
# ✓ Updated Robin Minz
#
# Processing 172/810: Jasprit Bumrah (ID: 9311)
# ✓ Updated Jasprit Bumrah
#
# Processing 173/810: Ashwani Kumar (ID: 11684)
# ✓ Updated Ashwani Kumar
#
# Processing 174/810: AM Ghazanfar (ID: 36501)
# ✓ Updated AM Ghazanfar
#
# Processing 175/810: Reece Topley (ID: 8349)
# ✓ Updated Reece Topley
#
# Processing 176/810: Lizaad Williams (ID: 8531)
# ✓ Updated Lizaad Williams
#
# Processing 177/810: Karn Sharma (ID: 1844)
# ✓ Updated Karn Sharma
#
# Processing 178/810: Trent Boult (ID: 8117)
# ✓ Updated Trent Boult
#
# Processing 179/810: Deepak Chahar (ID: 7836)
# ✓ Updated Deepak Chahar
#
# Processing 180/810: Sai Sudharsan (ID: 13866)
# ✓ Updated Sai Sudharsan
#
# Processing 181/810: Shubman Gill (ID: 11808)
# ✓ Updated Shubman Gill
#
# Processing 182/810: Glenn Phillips (ID: 10693)
# ✓ Updated Glenn Phillips
#
# Processing 183/810: Shahrukh Khan (ID: 10226)
# ✓ Updated Shahrukh Khan
#
# Processing 184/810: Rahul Tewatia (ID: 9693)
# ✓ Updated Rahul Tewatia
#
# Processing 185/810: Nishant Sindhu (ID: 22576)
# ✓ Updated Nishant Sindhu
#
# Processing 186/810: Sherfane Rutherford (ID: 13748)
# ✓ Updated Sherfane Rutherford
#
# Processing 187/810: Mahipal Lomror (ID: 10954)
# ✓ Updated Mahipal Lomror
#
# Processing 188/810: Rashid Khan (ID: 10738)
# ✓ Updated Rashid Khan
#
# Processing 189/810: Ravisrinivasan Sai Kishore (ID: 11595)
# ✓ Updated Ravisrinivasan Sai Kishore
#
# Processing 190/810: Arshad Khan (ID: 18637)
# ✓ Updated Arshad Khan
#
# Processing 191/810: Jayant Yadav (ID: 8182)
# ✓ Updated Jayant Yadav
#
# Processing 192/810: Karim Janat (ID: 11077)
# ✓ Updated Karim Janat
#
# Processing 193/810: Washington Sundar (ID: 10945)
# ✓ Updated Washington Sundar
#
# Processing 194/810: Kumar Kushagra (ID: 15779)
# ✓ Updated Kumar Kushagra
#
# Processing 195/810: Anuj Rawat (ID: 13135)
# ✓ Updated Anuj Rawat
#
# Processing 196/810: Jos Buttler (ID: 2258)
# ✓ Updated Jos Buttler
#
# Processing 197/810: Gerald Coetzee (ID: 13320)
# ✓ Updated Gerald Coetzee
#
# Processing 198/810: Manav Suthar (ID: 14596)
# ✓ Updated Manav Suthar
#
# Processing 199/810: Gurnoor Brar (ID: 22141)
# ✓ Updated Gurnoor Brar
#
# Processing 200/810: Ishant Sharma (ID: 702)
# ✓ Updated Ishant Sharma
#
# Processing 201/810: Kagiso Rabada (ID: 9585)
# ✓ Updated Kagiso Rabada
#
# Processing 202/810: Kulwant Khejroliya (ID: 12643)
# ✓ Updated Kulwant Khejroliya
#
# Processing 203/810: Prasidh Krishna (ID: 10551)
# ✓ Updated Prasidh Krishna
#
# Processing 204/810: Mohammed Siraj (ID: 10808)
# ✓ Updated Mohammed Siraj
#
# Processing 205/810: Himmat Singh (ID: 10223)
# ✓ Updated Himmat Singh
#
# Processing 206/810: David Miller (ID: 6349)
# ✓ Updated David Miller
#
# Processing 207/810: Aiden Markram (ID: 9582)
# ✓ Updated Aiden Markram
#
# Processing 208/810: Ayush Badoni (ID: 13907)
# ✓ Updated Ayush Badoni
#
# Processing 209/810: Mitchell Marsh (ID: 6250)
# ✓ Updated Mitchell Marsh
#
# Processing 210/810: Abdul Samad (ID: 14628)
# ✓ Updated Abdul Samad
#
# Processing 211/810: Arshin Kulkarni (ID: 51378)
# ✓ Updated Arshin Kulkarni
#
# Processing 212/810: Yuvraj Chaudhary (ID: 14693)
# ✓ Updated Yuvraj Chaudhary
#
# Processing 213/810: Shahbaz Ahmed (ID: 14606)
# ✓ Updated Shahbaz Ahmed
#
# Processing 214/810: RS Hangargekar (ID: 14599)
# ✓ Updated RS Hangargekar
#
# Processing 215/810: Digvesh Singh (ID: 36515)
# ✓ Updated Digvesh Singh
#
# Processing 216/810: Matthew Breetzke (ID: 13089)
# ✓ Updated Matthew Breetzke
#
# Processing 217/810: Nicholas Pooran (ID: 9406)
# ✓ Updated Nicholas Pooran
#
# Processing 218/810: Aryan Juyal (ID: 13388)
# ✓ Updated Aryan Juyal
#
# Processing 219/810: Rishabh Pant (ID: 10744)
# ✓ Updated Rishabh Pant
#
# Processing 220/810: Akash Singh (ID: 14327)
# ✓ Updated Akash Singh
#
# Processing 221/810: Ravi Bishnoi (ID: 14659)
# ✓ Updated Ravi Bishnoi
#
# Processing 222/810: Mayank Yadav (ID: 22401)
# ✓ Updated Mayank Yadav
#
# Processing 223/810: Akash Deep (ID: 14726)
# ✓ Updated Akash Deep
#
# Processing 224/810: Manimaran Siddharth (ID: 12930)
# ✓ Updated Manimaran Siddharth
#
# Processing 225/810: Shamar Joseph (ID: 50458)
# ✓ Updated Shamar Joseph
#
# Processing 226/810: Avesh Khan (ID: 9781)
# ✓ Updated Avesh Khan
#
# Processing 227/810: Prince Yadav (ID: 54735)
# ✓ Updated Prince Yadav
#
# Processing 228/810: Mohsin Khan (ID: 13534)
# ✓ Updated Mohsin Khan
#
# Processing 229/810: Kane Williamson (ID: 6326)
# ✓ Updated Kane Williamson
#
# Processing 230/810: Wriddhiman Saha (ID: 1465)
# ✓ Updated Wriddhiman Saha
#
# Processing 231/810: Alzarri Joseph (ID: 11220)
# ✓ Updated Alzarri Joseph
#
# Processing 232/810: Ambati Rayudu (ID: 6311)
# ✓ Updated Ambati Rayudu
#
# Processing 233/810: Ben Stokes (ID: 6557)
# ✓ Updated Ben Stokes
#
# Processing 234/810: Joshua Little (ID: 11128)
# ✓ Updated Joshua Little
#
# Processing 235/810: Bhanuka Rajapaksa (ID: 7869)
# ✓ Updated Bhanuka Rajapaksa
#
# Processing 236/810: Sikandar Raza (ID: 9354)
# ✓ Updated Sikandar Raza
#
# Processing 237/810: Shikhar Dhawan (ID: 1446)
# ✓ Updated Shikhar Dhawan
#
# Processing 238/810: Shardul Thakur (ID: 8683)
# ✓ Updated Shardul Thakur
#
# Processing 239/810: Tim Southee (ID: 1057)
# ✓ Updated Tim Southee
#
# Processing 240/810: Mandeep Singh (ID: 6319)
# ✓ Updated Mandeep Singh
#
# Processing 241/810: Umesh Yadav (ID: 1858)
# ✓ Updated Umesh Yadav
#
# Processing 242/810: Kyle Mayers (ID: 8440)
# ✓ Updated Kyle Mayers
#
# Processing 243/810: David Warner (ID: 1739)
# ✓ Updated David Warner
#
# Processing 244/810: Mark Wood (ID: 8383)
# ✓ Updated Mark Wood
#
# Processing 245/810: Rilee Rossouw (ID: 2244)
# ✓ Updated Rilee Rossouw
#
# Processing 246/810: Sarfaraz Khan (ID: 9429)
# ✓ Updated Sarfaraz Khan
#
# Processing 247/810: Chetan Sakariya (ID: 13494)
# ✓ Updated Chetan Sakariya
#
# Processing 248/810: Prithvi Shaw (ID: 12094)
# ✓ Updated Prithvi Shaw
#
# Processing 249/810: Mayank Agarwal (ID: 2195)
# ✓ Updated Mayank Agarwal
#
# Processing 250/810: Adil Rashid (ID: 1742)
# ✓ Updated Adil Rashid
#
# Processing 251/810: KM Asif (ID: 13483)
# ✓ Updated KM Asif
#
# Processing 252/810: Jason Holder (ID: 8313)
# ✓ Updated Jason Holder
#
# Processing 253/810: Michael Bracewell (ID: 9551)
# ✓ Updated Michael Bracewell
#
# Processing 254/810: Cameron Green (ID: 12225)
# ✓ Updated Cameron Green
#
# Processing 255/810: Dinesh Karthik (ID: 145)
# ✓ Updated Dinesh Karthik
#
# Processing 256/810: Hrithik Shokeen (ID: 14595)
# ✓ Updated Hrithik Shokeen
#
# Processing 257/810: Piyush Chawla (ID: 466)
# ✓ Updated Piyush Chawla
#
# Processing 258/810: Krishnappa Gowtham (ID: 8925)
# ✓ Updated Krishnappa Gowtham
#
# Processing 259/810: Aman Hakim Khan (ID: 19473)
# ✓ Updated Aman Hakim Khan
#
# Processing 260/810: David Willey (ID: 6592)
# ✓ Updated David Willey
#
# Processing 261/810: Amit Mishra (ID: 1454)
# ✓ Updated Amit Mishra
#
# Processing 262/810: Anmolpreet Singh (ID: 10947)
# ✓ Updated Anmolpreet Singh
#
# Processing 263/810: Lalit Yadav (ID: 13252)
# ✓ Updated Lalit Yadav
#
# Processing 264/810: Dwaine Pretorius (ID: 8651)
# ✓ Updated Dwaine Pretorius
#
# Processing 265/810: Sisanda Magala (ID: 10172)
# ✓ Updated Sisanda Magala
#
# Processing 266/810: Jason Behrendorff (ID: 7773)
# ✓ Updated Jason Behrendorff
#
# Processing 267/810: N Jagadeesan (ID: 11675)
# ✓ Updated N Jagadeesan
#
# Processing 268/810: Matthew Short (ID: 9456)
# ✓ Updated Matthew Short
#
# Processing 269/810: Wayne Parnell (ID: 1692)
# ✓ Updated Wayne Parnell
#
# Processing 270/810: Mustafizur Rahman (ID: 9863)
# ✓ Updated Mustafizur Rahman
#
# Processing 271/810: Riley Meredith (ID: 12226)
# ✓ Updated Riley Meredith
#
# Processing 272/810: Yash Dhull (ID: 22556)
# ✓ Updated Yash Dhull
#
# Processing 273/810: Akash Singh (ID: 14696)
# ✓ Updated Akash Singh
#
# Processing 274/810: Rishi Dhawan (ID: 8616)
# ✓ Updated Rishi Dhawan
#
# Processing 275/810: Harpreet Singh Bhatia (ID: 6322)
# ✓ Updated Harpreet Singh Bhatia
#
# Processing 276/810: Duan Jansen (ID: 18523)
# ✓ Updated Duan Jansen
#
# Processing 277/810: Naveen-ul-Haq (ID: 11289)
# ✓ Updated Naveen-ul-Haq
#
# Processing 278/810: Suyash Prabhudessai (ID: 12669)
# ✓ Updated Suyash Prabhudessai
#
# Processing 279/810: Jason Roy (ID: 6534)
# ✓ Updated Jason Roy
#
# Processing 280/810: Litton Das (ID: 8540)
# ✓ Updated Litton Das
#
# Processing 281/810: Abdul Basith (ID: 22466)
# ✓ Updated Abdul Basith
#
# Processing 282/810: David Wiese (ID: 8589)
# ✓ Updated David Wiese
#
# Processing 283/810: Ripal Patel (ID: 15516)
# ✓ Updated Ripal Patel
#
# Processing 284/810: Priyam Garg (ID: 12089)
# ✓ Updated Priyam Garg
#
# Processing 285/810: Akeal Hosein (ID: 8435)
# ✓ Updated Akeal Hosein
#
# Processing 286/810: Kartik Tyagi (ID: 13136)
# ✓ Updated Kartik Tyagi
#
# Processing 287/810: Kedar Jadhav (ID: 1851)
# ✓ Updated Kedar Jadhav
#
# Processing 288/810: Joe Root (ID: 8019)
# ✓ Updated Joe Root
#
# Processing 289/810: Vivrant Sharma (ID: 19302)
# ✓ Updated Vivrant Sharma
#
# Processing 290/810: Kuldip Yadav (ID: 13537)
# ✓ Updated Kuldip Yadav
#
# Processing 291/810: Murugan Ashwin (ID: 8796)
# ✓ Updated Murugan Ashwin
#
# Processing 292/810: Chris Jordan (ID: 6532)
# ✓ Updated Chris Jordan
#
# Processing 293/810: Prerak Mankad (ID: 11054)
# ✓ Updated Prerak Mankad
#
# Processing 294/810: Dasun Shanaka (ID: 8422)
# ✓ Updated Dasun Shanaka
#
# Processing 295/810: Sanvir Singh (ID: 13509)
# ✓ Updated Sanvir Singh
#
# Processing 296/810: Mayank Dagar (ID: 10953)
# ✓ Updated Mayank Dagar
#
# Processing 297/810: Navdeep Saini (ID: 9715)
# ✓ Updated Navdeep Saini
#
# Processing 298/810: Karan Sharma (ID: 18738)
# ✓ Updated Karan Sharma
#
# Processing 299/810: Daryl Mitchell (ID: 10713)
# ✓ Updated Daryl Mitchell
#
# Processing 300/810: Jonny Bairstow (ID: 6507)
# ✓ Updated Jonny Bairstow
#
# Processing 301/810: Shai Hope (ID: 10384)
# ✓ Updated Shai Hope
#
# Processing 302/810: Ricky Bhui (ID: 9425)
# ✓ Updated Ricky Bhui
#
# Processing 303/810: Sumit Kumar (ID: 14650)
# ✓ Updated Sumit Kumar
#
# Processing 304/810: Luke Wood (ID: 9821)
# ✓ Updated Luke Wood
#
# Processing 305/810: Shams Mulani (ID: 13496)
# ✓ Updated Shams Mulani
#
# Processing 306/810: Nandre Burger (ID: 13630)
# ✓ Updated Nandre Burger
#
# Processing 307/810: Saurav Chauhan (ID: 21686)
# ✓ Updated Saurav Chauhan
#
# Processing 308/810: Mohammad Nabi (ID: 3007)
# ✓ Updated Mohammad Nabi
#
# Processing 309/810: Jhye Richardson (ID: 10280)
# ✓ Updated Jhye Richardson
#
# Processing 310/810: Sharath BR (ID: 10520)
# ✓ Updated Sharath BR
#
# Processing 311/810: Matthew Wade (ID: 1649)
# ✓ Updated Matthew Wade
#
# Processing 312/810: Tanush Kotian (ID: 13216)
# ✓ Updated Tanush Kotian
#
# Processing 313/810: Keshav Maharaj (ID: 9720)
# ✓ Updated Keshav Maharaj
#
# Processing 314/810: Sandeep Warrier (ID: 8944)
# ✓ Updated Sandeep Warrier
#
# Processing 315/810: Matt Henry (ID: 9067)
# ✓ Updated Matt Henry
#
# Processing 316/810: Robin Uthappa (ID: 527)
# ✓ Updated Robin Uthappa
#
# Processing 317/810: Dwayne Bravo (ID: 242)
# ✓ Updated Dwayne Bravo
#
# Processing 318/810: Adam Milne (ID: 7625)
# ✓ Updated Adam Milne
#
# Processing 319/810: Sam Billings (ID: 7990)
# ✓ Updated Sam Billings
#
# Processing 320/810: Sheldon Jackson (ID: 8846)
# ✓ Updated Sheldon Jackson
#
# Processing 321/810: Shivam Mavi (ID: 12345)
# ✓ Updated Shivam Mavi
#
# Processing 322/810: Tim Seifert (ID: 9443)
# ✓ Updated Tim Seifert
#
# Processing 323/810: Kieron Pollard (ID: 657)
# ✓ Updated Kieron Pollard
#
# Processing 324/810: Daniel Sams (ID: 13162)
# ✓ Updated Daniel Sams
#
# Processing 325/810: Basil Thampi (ID: 10267)
# ✓ Updated Basil Thampi
#
# Processing 326/810: Tymal Mills (ID: 7860)
# ✓ Updated Tymal Mills
#
# Processing 327/810: Odean Smith (ID: 11215)
# ✓ Updated Odean Smith
#
# Processing 328/810: Varun Aaron (ID: 6293)
# ✓ Updated Varun Aaron
#
# Processing 329/810: Evin Lewis (ID: 8579)
# ✓ Updated Evin Lewis
#
# Processing 330/810: Nathan Coulter-Nile (ID: 7774)
# ✓ Updated Nathan Coulter-Nile
#
# Processing 331/810: Andrew Tye (ID: 9617)
# ✓ Updated Andrew Tye
#
# Processing 332/810: Dewald Brevis (ID: 20538)
# ✓ Updated Dewald Brevis
#
# Processing 333/810: Rassie van der Dussen (ID: 9554)
# ✓ Updated Rassie van der Dussen
#
# Processing 334/810: James Neesham (ID: 8983)
# ✓ Updated James Neesham
#
# Processing 335/810: Aaron Finch (ID: 1643)
# ✓ Updated Aaron Finch
#
# Processing 336/810: Jagadeesha Suchith (ID: 10357)
# ✓ Updated Jagadeesha Suchith
#
# Processing 337/810: Fabian Allen (ID: 9785)
# ✓ Updated Fabian Allen
#
# Processing 338/810: Obed McCoy (ID: 11221)
# ✓ Updated Obed McCoy
#
# Processing 339/810: Baba Indrajith (ID: 9624)
# ✓ Updated Baba Indrajith
#
# Processing 340/810: Pradeep Sangwan (ID: 1472)
# ✓ Updated Pradeep Sangwan
#
# Processing 341/810: Sean Abbott (ID: 8136)
# ✓ Updated Sean Abbott
#
# Processing 342/810: Srikar Bharat (ID: 9025)
# ✓ Updated Srikar Bharat
#
# Processing 343/810: Prashant Solanki (ID: 12805)
# ✓ Updated Prashant Solanki
#
# Processing 344/810: Sanjay Yadav (ID: 11631)
# ✓ Updated Sanjay Yadav
#
# Processing 345/810: Manan Vohra (ID: 8358)
# ✓ Updated Manan Vohra
#
# Processing 346/810: Abhijeet Tomar (ID: 12813)
# ✓ Updated Abhijeet Tomar
#
# Processing 347/810: Siddarth Kaul (ID: 1828)
# ✓ Updated Siddarth Kaul
#
# Processing 348/810: Tanmay Agarwal (ID: 10258)
# ✓ Updated Tanmay Agarwal
#
# Processing 349/810: Prateek Reddy (ID: 17154)
# ✓ Updated Prateek Reddy
#
# Processing 350/810: Telukupalli Ravi Teja (ID: 12309)
# ✓ Updated Telukupalli Ravi Teja
#
# Processing 351/810: Chama V Milind (ID: 9281)
# ✓ Updated Chama V Milind
#
# Processing 352/810: Tanay Thyagarajan (ID: 12335)
# ✓ Updated Tanay Thyagarajan
#
# Processing 353/810: Mickil Jaiswal (ID: 15482)
# ✓ Updated Mickil Jaiswal
#
# Processing 354/810: Larry Sangma (ID: 14653)
# ✓ Updated Larry Sangma
#
# Processing 355/810: Saranu Nishanth (ID: 52327)
# ✓ Updated Saranu Nishanth
#
# Processing 356/810: Hemant Phukan (ID: 21738)
# ✓ Updated Hemant Phukan
#
# Processing 357/810: Anish Charak (ID: 18827)
# ✓ Updated Anish Charak
#
# Processing 358/810: Arpit Bhatewara (ID: 10237)
# ✓ Updated Arpit Bhatewara
#
# Processing 359/810: Dippu Sangma (ID: 14132)
# ✓ Updated Dippu Sangma
#
# Processing 360/810: Ram Gurung (ID: 21683)
# ✓ Updated Ram Gurung
#
# Processing 361/810: Akash Choudhary (ID: 15485)
# ✓ Updated Akash Choudhary
#
# Processing 362/810: Jaskirat Singh (ID: 52369)
# ✓ Updated Jaskirat Singh
#
# Processing 363/810: Roshan Warbah (ID: 1433345)
# ✓ Updated Roshan Warbah
#
# Processing 364/810: Swarajeet Das (ID: 14410)
# ✓ Updated Swarajeet Das
#
# Processing 365/810: Wanlambok Nongkhlaw (ID: 14129)
# ✓ Updated Wanlambok Nongkhlaw
#
# Processing 366/810: Gahlaut Rahul Singh (ID: 11857)
# ✓ Updated Gahlaut Rahul Singh
#
# Processing 367/810: Rahul Buddhi (ID: 16584)
# ✓ Updated Rahul Buddhi
#
# Processing 368/810: Aniketh Reddy (ID: 17145)
# ✓ Updated Aniketh Reddy
#
# Processing 369/810: Tarang Gohel (ID: 14889)
# ✓ Updated Tarang Gohel
#
# Processing 370/810: Chirag Jani (ID: 8270)
# ✓ Updated Chirag Jani
#
# Processing 371/810: Sammar Gajjar (ID: 36531)
# ✓ Updated Sammar Gajjar
#
# Processing 372/810: Jay Gohil (ID: 21658)
# ✓ Updated Jay Gohil
#
# Processing 373/810: Dharmendrasinh Jadeja (ID: 9033)
# ✓ Updated Dharmendrasinh Jadeja
#
# Processing 374/810: Harvik Desai (ID: 12088)
# ✓ Updated Harvik Desai
#
# Processing 375/810: Devang Karamta (ID: 14900)
# ✓ Updated Devang Karamta
#
# Processing 376/810: Saurav Prasad (ID: 52355)
# ✓ Updated Saurav Prasad
#
# Processing 377/810: Ashish Thapa (ID: 14101)
# ✓ Updated Ashish Thapa
#
# Processing 378/810: Palzor Tamang (ID: 14100)
# ✓ Updated Palzor Tamang
#
# Processing 379/810: Nilesh Lamichaney (ID: 14093)
# ✓ Updated Nilesh Lamichaney
#
# Processing 380/810: Lee Yong Lepcha (ID: 14094)
# ✓ Updated Lee Yong Lepcha
#
# Processing 381/810: Ankur Malik (ID: 24336)
# ✓ Updated Ankur Malik
#
# Processing 382/810: Parth Palawat (ID: 1432283)
# ✓ Updated Parth Palawat
#
# Processing 383/810: Robin Limboo (ID: 1447497)
# ✓ Updated Robin Limboo
#
# Processing 384/810: Roshan Kumar (ID: 1447493)
# ✓ Updated Roshan Kumar
#
# Processing 385/810: Bhim Luitel (ID: 51742)
# ✓ Updated Bhim Luitel
#
# Processing 386/810: Yuvraj Chudasama (ID: 11308)
# ✓ Updated Yuvraj Chudasama
#
# Processing 387/810: Vishvaraj Jadeja (ID: 13493)
# ✓ Updated Vishvaraj Jadeja
#
# Processing 388/810: Md Saptulla (ID: 18758)
# ✓ Updated Md Saptulla
#
# Processing 389/810: Techi Sonam (ID: 19317)
# ✓ Updated Techi Sonam
#
# Processing 390/810: Agnivesh Ayachi (ID: 12644)
# ✓ Updated Agnivesh Ayachi
#
# Processing 391/810: Nabam Abo (ID: 24451)
# ✓ Updated Nabam Abo
#
# Processing 392/810: Techi Doria (ID: 14073)
# ✓ Updated Techi Doria
#
# Processing 393/810: Nabam Tempol (ID: 15746)
# ✓ Updated Nabam Tempol
#
# Processing 394/810: Licha John (ID: 51245)
# ✓ Updated Licha John
#
# Processing 395/810: Hardik Varma (ID: 1431705)
# ✓ Updated Hardik Varma
#
# Processing 396/810: Aditya Verma (ID: 1431755)
# ✓ Updated Aditya Verma
#
# Processing 397/810: Aryan Malik (ID: 1447505)
# ✓ Updated Aryan Malik
#
# Processing 398/810: Prashant Chopra (ID: 8425)
# ✓ Updated Prashant Chopra
#
# Processing 399/810: Akash Vasisht (ID: 10266)
# ✓ Updated Akash Vasisht
#
# Processing 400/810: Ekant Sen (ID: 11401)
# ✓ Updated Ekant Sen
#
# Processing 401/810: Sumeet Verma (ID: 8825)
# ✓ Updated Sumeet Verma
#
# Processing 402/810: Mukul Negi (ID: 51399)
# ✓ Updated Mukul Negi
#
# Processing 403/810: Divesh Sharma (ID: 53485)
# ✓ Updated Divesh Sharma
#
# Processing 404/810: Ayush Jamwal (ID: 12090)
# ✓ Updated Ayush Jamwal
#
# Processing 405/810: Kara Hakap (ID: 1447513)
# ✓ Updated Kara Hakap
#
# Processing 406/810: Ankush Bains (ID: 9298)
# ✓ Updated Ankush Bains
#
# Processing 407/810: Bobby Zothansanga (ID: 14440)
# ✓ Updated Bobby Zothansanga
#
# Processing 408/810: Subhranshu Senapati (ID: 11804)
# ✓ Updated Subhranshu Senapati
#
# Processing 409/810: Shivam Shukla (ID: 1447165)
# ✓ Updated Shivam Shukla
#
# Processing 410/810: Tripuresh Singh (ID: 1447173)
# ✓ Updated Tripuresh Singh
#
# Processing 411/810: Abhishek Pathak (ID: 1447553)
# ✓ Updated Abhishek Pathak
#
# Processing 412/810: Arpit Gaud (ID: 18618)
# ✓ Updated Arpit Gaud
#
# Processing 413/810: F Vanlalmuanzuala (ID: 1447365)
# ✓ Updated F Vanlalmuanzuala
#
# Processing 414/810: Vikash Kumar (ID: 19432)
# ✓ Updated Vikash Kumar
#
# Processing 415/810: Mohit Jangra (ID: 13908)
# ✓ Updated Mohit Jangra
#
# Processing 416/810: Lalhriatrenga (ID: 32959)
# ✓ Updated Lalhriatrenga
#
# Processing 417/810: Khiangte Vanrotlinga (ID: 1447557)
# ✓ Updated Khiangte Vanrotlinga
#
# Processing 418/810: Joseph Lalthankhuma (ID: 21708)
# ✓ Updated Joseph Lalthankhuma
#
# Processing 419/810: Naveen Gurung (ID: 36174)
# ✓ Updated Naveen Gurung
#
# Processing 420/810: KC Cariappa (ID: 10353)
# ✓ Updated KC Cariappa
#
# Processing 421/810: Jehu Anderson (ID: 36116)
# ✓ Updated Jehu Anderson
#
# Processing 422/810: Agni Chopra (ID: 14990)
# ✓ Updated Agni Chopra
#
# Processing 423/810: Ishaan Gadekar (ID: 19223)
# ✓ Updated Ishaan Gadekar
#
# Processing 424/810: Rohan Kadam (ID: 10478)
# ✓ Updated Rohan Kadam
#
# Processing 425/810: Mohit Redkar (ID: 22146)
# ✓ Updated Mohit Redkar
#
# Processing 426/810: Vikash Kanwar Singh (ID: 51340)
# ✓ Updated Vikash Kanwar Singh
#
# Processing 427/810: Krishnamurthy Siddharth (ID: 10562)
# ✓ Updated Krishnamurthy Siddharth
#
# Processing 428/810: Darshan Misal (ID: 8898)
# ✓ Updated Darshan Misal
#
# Processing 429/810: Deepraj Gaonkar (ID: 10294)
# ✓ Updated Deepraj Gaonkar
#
# Processing 430/810: Shubham Tari (ID: 51074)
# ✓ Updated Shubham Tari
#
# Processing 431/810: Heramb Parab (ID: 12164)
# ✓ Updated Heramb Parab
#
# Processing 432/810: Mohit Avasthi (ID: 14940)
# ✓ Updated Mohit Avasthi
#
# Processing 433/810: Hardik Tamore (ID: 14964)
# ✓ Updated Hardik Tamore
#
# Processing 434/810: Royston Dias (ID: 9241)
# ✓ Updated Royston Dias
#
# Processing 435/810: Satyajeet Bachhav (ID: 8923)
# ✓ Updated Satyajeet Bachhav
#
# Processing 436/810: Chetan Bist (ID: 9666)
# ✓ Updated Chetan Bist
#
# Processing 437/810: Azim Kazi (ID: 14666)
# ✓ Updated Azim Kazi
#
# Processing 438/810: Dega Nischal (ID: 9508)
# ✓ Updated Dega Nischal
#
# Processing 439/810: Nikhil Naik (ID: 9295)
# ✓ Updated Nikhil Naik
#
# Processing 440/810: Rongsen Jonathan (ID: 9700)
# ✓ Updated Rongsen Jonathan
#
# Processing 441/810: Hokaito Zhimomi (ID: 8763)
# ✓ Updated Hokaito Zhimomi
#
# Processing 442/810: Divyang Hinganekar (ID: 13485)
# ✓ Updated Divyang Hinganekar
#
# Processing 443/810: Ankit Bawne (ID: 8617)
# ✓ Updated Ankit Bawne
#
# Processing 444/810: Dhanraj Shinde (ID: 51392)
# ✓ Updated Dhanraj Shinde
#
# Processing 445/810: Shamphri Terang (ID: 1447429)
# ✓ Updated Shamphri Terang
#
# Processing 446/810: Chopise Hopongkyu (ID: 16566)
# ✓ Updated Chopise Hopongkyu
#
# Processing 447/810: Khrievitso Kense (ID: 18867)
# ✓ Updated Khrievitso Kense
#
# Processing 448/810: Dip Borah (ID: 1431771)
# ✓ Updated Dip Borah
#
# Processing 449/810: Hem Chetri (ID: 18873)
# ✓ Updated Hem Chetri
#
# Processing 450/810: Joshua Ozukum (ID: 18672)
# ✓ Updated Joshua Ozukum
#
# Processing 451/810: Arjun Azad (ID: 14688)
# ✓ Updated Arjun Azad
#
# Processing 452/810: Shivam Bhambri (ID: 12359)
# ✓ Updated Shivam Bhambri
#
# Processing 453/810: Chiragvir Dhindsa (ID: 1447545)
# ✓ Updated Chiragvir Dhindsa
#
# Processing 454/810: Bhagmender Lather (ID: 19003)
# ✓ Updated Bhagmender Lather
#
# Processing 455/810: Jagjit Singh (ID: 16514)
# ✓ Updated Jagjit Singh
#
# Processing 456/810: Karthikeyan Jayasundaram (ID: 21576)
# ✓ Updated Karthikeyan Jayasundaram
#
# Processing 457/810: Akash Kargave (ID: 32443)
# ✓ Updated Akash Kargave
#
# Processing 458/810: Nishunk Birla (ID: 1432249)
# ✓ Updated Nishunk Birla
#
# Processing 459/810: Krishna Pandey (ID: 15419)
# ✓ Updated Krishna Pandey
#
# Processing 460/810: Parameeswaran Sivaraman (ID: 32455)
# ✓ Updated Parameeswaran Sivaraman
#
# Processing 461/810: Arun Karthik (ID: 1672)
# ✓ Updated Arun Karthik
#
# Processing 462/810: Sidak Gurvinder Singh (ID: 24416)
# ✓ Updated Sidak Gurvinder Singh
#
# Processing 463/810: Ajay Rohera (ID: 13577)
# ✓ Updated Ajay Rohera
#
# Processing 464/810: Mohamed Safeequddin (ID: 1447477)
# ✓ Updated Mohamed Safeequddin
#
# Processing 465/810: Fabid Ahmed (ID: 10642)
# ✓ Updated Fabid Ahmed
#
# Processing 466/810: Pradeep Yadav (ID: 1447537)
# ✓ Updated Pradeep Yadav
#
# Processing 467/810: Gaurav Puri (ID: 12503)
# ✓ Updated Gaurav Puri
#
# Processing 468/810: Gaurav Yadav (ID: 8730)
# ✓ Updated Gaurav Yadav
#
# Processing 469/810: Ankit Sharma (ID: 7810)
# ✓ Updated Ankit Sharma
#
# Processing 470/810: Susheel Kumar (ID: 32784)
# ✓ Updated Susheel Kumar
#
# Processing 471/810: Sumit Ghadigaonkar (ID: 14975)
# ✓ Updated Sumit Ghadigaonkar
#
# Processing 472/810: Saahil Jain (ID: 11026)
# ✓ Updated Saahil Jain
#
# Processing 473/810: Ruhinandan Pegu (ID: 1431923)
# ✓ Updated Ruhinandan Pegu
#
# Processing 474/810: Avinov Choudhury (ID: 33115)
# ✓ Updated Avinov Choudhury
#
# Processing 475/810: Akash Sengupta (ID: 21596)
# ✓ Updated Akash Sengupta
#
# Processing 476/810: Swarupam Purkayastha (ID: 10250)
# ✓ Updated Swarupam Purkayastha
#
# Processing 477/810: Pratham Singh (ID: 12640)
# ✓ Updated Pratham Singh
#
# Processing 478/810: Vivek Singh (ID: 9217)
# ✓ Updated Vivek Singh
#
# Processing 479/810: Mukhtar Hussain (ID: 13607)
# ✓ Updated Mukhtar Hussain
#
# Processing 480/810: Nipan Deka (ID: 13507)
# ✓ Updated Nipan Deka
#
# Processing 481/810: Jitumoni Kalita (ID: 12306)
# ✓ Updated Jitumoni Kalita
#
# Processing 482/810: Upendra Yadav (ID: 11965)
# ✓ Updated Upendra Yadav
#
# Processing 483/810: Samarth Vyas (ID: 10839)
# ✓ Updated Samarth Vyas
#
# Processing 484/810: Navneet Virk (ID: 15890)
# ✓ Updated Navneet Virk
#
# Processing 485/810: Akash Pandey (ID: 19183)
# ✓ Updated Akash Pandey
#
# Processing 486/810: Denish Das (ID: 18793)
# ✓ Updated Denish Das
#
# Processing 487/810: Mrinmoy Dutta (ID: 11025)
# ✓ Updated Mrinmoy Dutta
#
# Processing 488/810: Raj Choudhary (ID: 51088)
# ✓ Updated Raj Choudhary
#
# Processing 489/810: Kunal Yadav (ID: 36095)
# ✓ Updated Kunal Yadav
#
# Processing 490/810: Himanshu Rana (ID: 10297)
# ✓ Updated Himanshu Rana
#
# Processing 491/810: Ankit Kumar (ID: 14438)
# ✓ Updated Ankit Kumar
#
# Processing 492/810: Rohit Parmod Sharma (ID: 10755)
# ✓ Updated Rohit Parmod Sharma
#
# Processing 493/810: L Kishan Singha (ID: 18832)
# ✓ Updated L Kishan Singha
#
# Processing 494/810: Ulenyai Khwairakpam (ID: 19352)
# ✓ Updated Ulenyai Khwairakpam
#
# Processing 495/810: Chingakham Bidash (ID: 32660)
# ✓ Updated Chingakham Bidash
#
# Processing 496/810: Ajay Lamabam Singh (ID: 14662)
# ✓ Updated Ajay Lamabam Singh
#
# Processing 497/810: Al Bashid Muhammed (ID: 15496)
# ✓ Updated Al Bashid Muhammed
#
# Processing 498/810: Ahmed Shah (ID: 14508)
# ✓ Updated Ahmed Shah
#
# Processing 499/810: Pheiroijam Jotin (ID: 34450)
# ✓ Updated Pheiroijam Jotin
#
# Processing 500/810: Dheeru Singh (ID: 1432507)
# ✓ Updated Dheeru Singh
#
# Processing 501/810: Bishworjit Konthoujam (ID: 14136)
# ✓ Updated Bishworjit Konthoujam
#
# Processing 502/810: Kangabam Priyojit Singh (ID: 14140)
# ✓ Updated Kangabam Priyojit Singh
#
# Processing 503/810: Rex Rajkumar (ID: 14143)
# ✓ Updated Rex Rajkumar
#
# Processing 504/810: Johnson Singh (ID: 15497)
# ✓ Updated Johnson Singh
#
# Processing 505/810: Subham Ghosh (ID: 14349)
# ✓ Updated Subham Ghosh
#
# Processing 506/810: Abhijit K Sarkar (ID: 10252)
# ✓ Updated Abhijit K Sarkar
#
# Processing 507/810: Sridam Paul (ID: 22461)
# ✓ Updated Sridam Paul
#
# Processing 508/810: Parvez Sultan (ID: 18898)
# ✓ Updated Parvez Sultan
#
# Processing 509/810: Rajat Dey (ID: 11016)
# ✓ Updated Rajat Dey
#
# Processing 510/810: Sonu Yadav (ID: 11641)
# ✓ Updated Sonu Yadav
#
# Processing 511/810: Bikramkumar Das (ID: 11014)
# ✓ Updated Bikramkumar Das
#
# Processing 512/810: Ajay Sarkar (ID: 11015)
# ✓ Updated Ajay Sarkar
#
# Processing 513/810: Tejasvi Jaiswal (ID: 1431833)
# ✓ Updated Tejasvi Jaiswal
#
# Processing 514/810: Manisankar Murasingh (ID: 8659)
# ✓ Updated Manisankar Murasingh
#
# Processing 515/810: Srinivas Sharath (ID: 10519)
# ✓ Updated Srinivas Sharath
#
# Processing 516/810: Rithik Easwaran (ID: 27373)
# ✓ Updated Rithik Easwaran
#
# Processing 517/810: Vivekanand Tiwari (ID: 12340)
# ✓ Updated Vivekanand Tiwari
#
# Processing 518/810: Bal Krishna (ID: 18973)
# ✓ Updated Bal Krishna
#
# Processing 519/810: Auqib Nabi Dar (ID: 14179)
# ✓ Updated Auqib Nabi Dar
#
# Processing 520/810: Utkarsh Singh (ID: 12630)
# ✓ Updated Utkarsh Singh
#
# Processing 521/810: Ravi Kumar Yadav (ID: 1447093)
# ✓ Updated Ravi Kumar Yadav
#
# Processing 522/810: Shivansh Sharma (ID: 32429)
# ✓ Updated Shivansh Sharma
#
# Processing 523/810: Pankaj Kishor Kumar (ID: 15968)
# ✓ Updated Pankaj Kishor Kumar
#
# Processing 524/810: Sharandeep Singh Bhatia (ID: 1432873)
# ✓ Updated Sharandeep Singh Bhatia
#
# Processing 525/810: Shubham Khajuria (ID: 8937)
# ✓ Updated Shubham Khajuria
#
# Processing 526/810: Virat Singh (ID: 10213)
# ✓ Updated Virat Singh
#
# Processing 527/810: Vikash Singh (ID: 10984)
# ✓ Updated Vikash Singh
#
# Processing 528/810: Paras Dogra (ID: 1860)
# ✓ Updated Paras Dogra
#
# Processing 529/810: Qamran Iqbal (ID: 14467)
# ✓ Updated Qamran Iqbal
#
# Processing 530/810: Abid Mushtaq (ID: 15528)
# ✓ Updated Abid Mushtaq
#
# Processing 531/810: LR Chethan (ID: 15327)
# ✓ Updated LR Chethan
#
# Processing 532/810: Rajan Kumar (ID: 32786)
# ✓ Updated Rajan Kumar
#
# Processing 533/810: Vijay Sharma (ID: 14642)
# ✓ Updated Vijay Sharma
#
# Processing 534/810: Agrim Tiwari (ID: 16722)
# ✓ Updated Agrim Tiwari
#
# Processing 535/810: Vasuki Koushik (ID: 10489)
# ✓ Updated Vasuki Koushik
#
# Processing 536/810: Shubhang Hegde (ID: 14523)
# ✓ Updated Shubhang Hegde
#
# Processing 537/810: Avneesh Sudha (ID: 14548)
# ✓ Updated Avneesh Sudha
#
# Processing 538/810: Himanshu Bisht (ID: 14638)
# ✓ Updated Himanshu Bisht
#
# Processing 539/810: Aditya Tare (ID: 6315)
# ✓ Updated Aditya Tare
#
# Processing 540/810: Kunal Chandela (ID: 13111)
# ✓ Updated Kunal Chandela
#
# Processing 541/810: Ravikumar Samarth (ID: 9688)
# ✓ Updated Ravikumar Samarth
#
# Processing 542/810: Bipin Saurabh (ID: 21671)
# ✓ Updated Bipin Saurabh
#
# Processing 543/810: Himanshu Singh (ID: 35241)
# ✓ Updated Himanshu Singh
#
# Processing 544/810: Mrityunjay Singh (ID: 1447565)
# ✓ Updated Mrityunjay Singh
#
# Processing 545/810: Kumar Rajnish (ID: 14323)
# ✓ Updated Kumar Rajnish
#
# Processing 546/810: Paramjit Singh (ID: 51336)
# ✓ Updated Paramjit Singh
#
# Processing 547/810: Amod Yadav (ID: 16749)
# ✓ Updated Amod Yadav
#
# Processing 548/810: Raghuvendra Pratap Singh (ID: 32898)
# ✓ Updated Raghuvendra Pratap Singh
#
# Processing 549/810: Sakib Hussain (ID: 33129)
# ✓ Updated Sakib Hussain
#
# Processing 550/810: Aniket Choudhary (ID: 8190)
# ✓ Updated Aniket Choudhary
#
# Processing 551/810: Kartik Sharma (ID: 49557)
# ✓ Updated Kartik Sharma
#
# Processing 552/810: Ayush Loharuka (ID: 1431939)
# ✓ Updated Ayush Loharuka
#
# Processing 553/810: Zubair Ali khan (ID: 49403)
# ✓ Updated Zubair Ali khan
#
# Processing 554/810: Bharat Sharma (ID: 19002)
# ✓ Updated Bharat Sharma
#
# Processing 555/810: Sakibul Gani (ID: 15594)
# ✓ Updated Sakibul Gani
#
# Processing 556/810: Ninad Ashvinkumar Rathva (ID: 13250)
# ✓ Updated Ninad Ashvinkumar Rathva
#
# Processing 557/810: Hemang Patel (ID: 14186)
# ✓ Updated Hemang Patel
#
# Processing 558/810: Mitesh Patel (ID: 13130)
# ✓ Updated Mitesh Patel
#
# Processing 559/810: Arzan Nagwaswalla (ID: 13600)
# ✓ Updated Arzan Nagwaswalla
#
# Processing 560/810: Chintan Gaja (ID: 11867)
# ✓ Updated Chintan Gaja
#
# Processing 561/810: Shivalik Sharma (ID: 14408)
# ✓ Updated Shivalik Sharma
#
# Processing 562/810: Lukman Meriwala (ID: 9244)
# ✓ Updated Lukman Meriwala
#
# Processing 563/810: Tejas Patel (ID: 14625)
# ✓ Updated Tejas Patel
#
# Processing 564/810: Mahesh Pithiya (ID: 32422)
# ✓ Updated Mahesh Pithiya
#
# Processing 565/810: Raj Limbani (ID: 52488)
# ✓ Updated Raj Limbani
#
# Processing 566/810: Aarya Desai (ID: 38132)
# ✓ Updated Aarya Desai
#
# Processing 567/810: Umang Kumar (ID: 21593)
# ✓ Updated Umang Kumar
#
# Processing 568/810: Urvil Patel (ID: 13476)
# ✓ Updated Urvil Patel
#
# Processing 569/810: Atit Sheth (ID: 9509)
# ✓ Updated Atit Sheth
#
# Processing 570/810: Vishnu Solanki (ID: 9245)
# ✓ Updated Vishnu Solanki
#
# Processing 571/810: Bhanu Pania (ID: 18697)
# ✓ Updated Bhanu Pania
#
# Processing 572/810: Madhav Kaushik (ID: 14338)
# ✓ Updated Madhav Kaushik
#
# Processing 573/810: Vineet Panwar (ID: 12628)
# ✓ Updated Vineet Panwar
#
# Processing 574/810: Mayank Rawat (ID: 12341)
# ✓ Updated Mayank Rawat
#
# Processing 575/810: Shivam Sharma (ID: 14702)
# ✓ Updated Shivam Sharma
#
# Processing 576/810: Mayank Gusain (ID: 1429676)
# ✓ Updated Mayank Gusain
#
# Processing 577/810: Sudip Chatterjee (ID: 8992)
# ✓ Updated Sudip Chatterjee
#
# Processing 578/810: Sudip Kumar Gharami (ID: 18133)
# ✓ Updated Sudip Kumar Gharami
#
# Processing 579/810: Writtick Chatterjee (ID: 9717)
# ✓ Updated Writtick Chatterjee
#
# Processing 580/810: Karan Lal (ID: 14708)
# ✓ Updated Karan Lal
#
# Processing 581/810: Kanishk Seth (ID: 10955)
# ✓ Updated Kanishk Seth
#
# Processing 582/810: Ritwik Chowdhury (ID: 13478)
# ✓ Updated Ritwik Chowdhury
#
# Processing 583/810: Pradipta Pramanik (ID: 10880)
# ✓ Updated Pradipta Pramanik
#
# Processing 584/810: Ishan Porel (ID: 11404)
# ✓ Updated Ishan Porel
#
# Processing 585/810: Harshit Rathod (ID: 19342)
# ✓ Updated Harshit Rathod
#
# Processing 586/810: Parth Rekhade (ID: 15663)
# ✓ Updated Parth Rekhade
#
# Processing 587/810: Aasirwad Swain (ID: 32800)
# ✓ Updated Aasirwad Swain
#
# Processing 588/810: Swastik Samal (ID: 14669)
# ✓ Updated Swastik Samal
#
# Processing 589/810: Pradeep Pradhan (ID: 1447573)
# ✓ Updated Pradeep Pradhan
#
# Processing 590/810: Harsh Dubey (ID: 14695)
# ✓ Updated Harsh Dubey
#
# Processing 591/810: Mandar Mahale (ID: 51161)
# ✓ Updated Mandar Mahale
#
# Processing 592/810: Apoorv Wankhade (ID: 8273)
# ✓ Updated Apoorv Wankhade
#
# Processing 593/810: Debabrata Pradhan (ID: 12663)
# ✓ Updated Debabrata Pradhan
#
# Processing 594/810: Sandeep Pattnaik (ID: 11802)
# ✓ Updated Sandeep Pattnaik
#
# Processing 595/810: Gourav Choudhury (ID: 18887)
# ✓ Updated Gourav Choudhury
#
# Processing 596/810: Govinda Poddar (ID: 8691)
# ✓ Updated Govinda Poddar
#
# Processing 597/810: Prabin Luha (ID: 15743)
# ✓ Updated Prabin Luha
#
# Processing 598/810: Abhishek Yadav (ID: 11012)
# ✓ Updated Abhishek Yadav
#
# Processing 599/810: Tarani Sa (ID: 19153)
# ✓ Updated Tarani Sa
#
# Processing 600/810: Rohan Kunnummal (ID: 12253)
# ✓ Updated Rohan Kunnummal
#
# Processing 601/810: Mohit Ahlawat (ID: 10649)
# ✓ Updated Mohit Ahlawat
#
# Processing 602/810: MD Nidheesh (ID: 10315)
# ✓ Updated MD Nidheesh
#
# Processing 603/810: Shubham Rohilla (ID: 10322)
# ✓ Updated Shubham Rohilla
#
# Processing 604/810: Arun Kumar (ID: 1431835)
# ✓ Updated Arun Kumar
#
# Processing 605/810: Mohammed Azharuddeen (ID: 10809)
# ✓ Updated Mohammed Azharuddeen
#
# Processing 606/810: Vineet Dhankhar (ID: 51319)
# ✓ Updated Vineet Dhankhar
#
# Processing 607/810: Akhil Scaria (ID: 34466)
# ✓ Updated Akhil Scaria
#
# Processing 608/810: Vishal Gaur (ID: 1447581)
# ✓ Updated Vishal Gaur
#
# Processing 609/810: Gaurav Sharma (ID: 33162)
# ✓ Updated Gaurav Sharma
#
# Processing 610/810: Amit Shukla (ID: 9464)
# ✓ Updated Amit Shukla
#
# Processing 611/810: Poonam Poonia (ID: 10667)
# ✓ Updated Poonam Poonia
#
# Processing 612/810: Pulkit Narang (ID: 10645)
# ✓ Updated Pulkit Narang
#
# Processing 613/810: Kunwar Pathak (ID: 1447577)
# ✓ Updated Kunwar Pathak
#
# Processing 614/810: Salman Nizar (ID: 10332)
# ✓ Updated Salman Nizar
#
# Processing 615/810: Sijomon Joseph (ID: 12625)
# ✓ Updated Sijomon Joseph
#
# Processing 616/810: Vinod Kumar (ID: 11797)
# ✓ Updated Vinod Kumar
#
# Processing 617/810: Soubam Rohit Kiran Singh (ID: 1447717)
# ✓ Updated Soubam Rohit Kiran Singh
#
# Processing 618/810: Vidyadhar Patil (ID: 13976)
# ✓ Updated Vidyadhar Patil
#
# Processing 619/810: Smaran Ravichandran (ID: 29130)
# ✓ Updated Smaran Ravichandran
#
# Processing 620/810: Saurabh Das (ID: 10323)
# ✓ Updated Saurabh Das
#
# Processing 621/810: Samrat Sutradhar (ID: 1447353)
# ✓ Updated Samrat Sutradhar
#
# Processing 622/810: Rajesh Bishnoi Jr (ID: 11912)
# ✓ Updated Rajesh Bishnoi Jr
#
# Processing 623/810: Lalhruai Ralte (ID: 14065)
# ✓ Updated Lalhruai Ralte
#
# Processing 624/810: Rajat Paliwal (ID: 8787)
# ✓ Updated Rajat Paliwal
#
# Processing 625/810: Rakesh Pattnaik (ID: 19368)
# ✓ Updated Rakesh Pattnaik
#
# Processing 626/810: Suraj Ahuja (ID: 14590)
# ✓ Updated Suraj Ahuja
#
# Processing 627/810: Sambit S Baral (ID: 1447725)
# ✓ Updated Sambit S Baral
#
# Processing 628/810: Dipesh Parwani (ID: 51532)
# ✓ Updated Dipesh Parwani
#
# Processing 629/810: Baltej Singh (ID: 8962)
# ✓ Updated Baltej Singh
#
# Processing 630/810: Nawaz Khan (ID: 39209)
# ✓ Updated Nawaz Khan
#
# Processing 631/810: Sachin Kumar (ID: 15490)
# ✓ Updated Sachin Kumar
#
# Processing 632/810: Sharman Nigrodh (ID: 51469)
# ✓ Updated Sharman Nigrodh
#
# Processing 633/810: Mayank Choudhary (ID: 1431945)
# ✓ Updated Mayank Choudhary
#
# Processing 634/810: Irfan ul Haq (ID: 21758)
# ✓ Updated Irfan ul Haq
#
# Processing 635/810: Harsh Tyagi (ID: 12624)
# ✓ Updated Harsh Tyagi
#
# Processing 636/810: Vivek Ranjan (ID: 1447753)
# ✓ Updated Vivek Ranjan
#
# Processing 637/810: Ramesh Rahul (ID: 1447745)
# ✓ Updated Ramesh Rahul
#
# Processing 638/810: Abhishek Pujari (ID: 1447737)
# ✓ Updated Abhishek Pujari
#
# Processing 639/810: Yorjum Sera (ID: 51238)
# ✓ Updated Yorjum Sera
#
# Processing 640/810: Boopathi Kumar (ID: 46212)
# ✓ Updated Boopathi Kumar
#
# Processing 641/810: M Mohammed (ID: 8797)
# ✓ Updated M Mohammed
#
# Processing 642/810: Tarun Sharma (ID: 24491)
# ✓ Updated Tarun Sharma
#
# Processing 643/810: Anwesh Sharma (ID: 19312)
# ✓ Updated Anwesh Sharma
#
# Processing 644/810: Arien Sangma (ID: 51343)
# ✓ Updated Arien Sangma
#
# Processing 645/810: Rahul Batham (ID: 10948)
# ✓ Updated Rahul Batham
#
# Processing 646/810: Sanjeet Desai (ID: 13606)
# ✓ Updated Sanjeet Desai
#
# Processing 647/810: Sourabh Majumdar (ID: 18892)
# ✓ Updated Sourabh Majumdar
#
# Processing 648/810: Amandeep Khare (ID: 10949)
# ✓ Updated Amandeep Khare
#
# Processing 649/810: Gagandeep Singh (ID: 51112)
# ✓ Updated Gagandeep Singh
#
# Processing 650/810: Vikneshwaran Marimuthu (ID: 14043)
# ✓ Updated Vikneshwaran Marimuthu
#
# Processing 651/810: Shashank Chandrakar (ID: 13490)
# ✓ Updated Shashank Chandrakar
#
# Processing 652/810: Adil Ayub Tunda (ID: 1447761)
# ✓ Updated Adil Ayub Tunda
#
# Processing 653/810: Aayush Pandey (ID: 36111)
# ✓ Updated Aayush Pandey
#
# Processing 654/810: Ravi Kiran (ID: 8936)
# ✓ Updated Ravi Kiran
#
# Processing 655/810: Shubham Agarwal (ID: 12322)
# ✓ Updated Shubham Agarwal
#
# Processing 656/810: Prateek Yadav (ID: 32728)
# ✓ Updated Prateek Yadav
#
# Processing 657/810: SDNV Prasad (ID: 1447757)
# ✓ Updated SDNV Prasad
#
# Processing 658/810: KV Sasikanth (ID: 10638)
# ✓ Updated KV Sasikanth
#
# Processing 659/810: Bodhala Kumar (ID: 51739)
# ✓ Updated Bodhala Kumar
#
# Processing 660/810: Vamsi Krishna (ID: 8753)
# ✓ Updated Vamsi Krishna
#
# Processing 661/810: Cheepurapalli Stephen (ID: 9620)
# ✓ Updated Cheepurapalli Stephen
#
# Processing 662/810: Ashwin Hebbar (ID: 10254)
# ✓ Updated Ashwin Hebbar
#
# Processing 663/810: Sankar Paul (ID: 18727)
# ✓ Updated Sankar Paul
#
# Processing 664/810: Vishal Jayswal (ID: 32931)
# ✓ Updated Vishal Jayswal
#
# Processing 665/810: Riaz Uddin (ID: 1447805)
# ✓ Updated Riaz Uddin
#
# Processing 666/810: Lal Rin Fela (ID: 1447813)
# ✓ Updated Lal Rin Fela
#
# Processing 667/810: Sayan Ghosh (ID: 10786)
# ✓ Updated Sayan Ghosh
#
# Processing 668/810: Shakir Gandhi (ID: 21621)
# ✓ Updated Shakir Gandhi
#
# Processing 669/810: Parvez Ahmed (ID: 14621)
# ✓ Updated Parvez Ahmed
#
# Processing 670/810: Sougrakpam Singh (ID: 1447801)
# ✓ Updated Sougrakpam Singh
#
# Processing 671/810: Somorjit Salam (ID: 14146)
# ✓ Updated Somorjit Salam
#
# Processing 672/810: Bailapudi Yeswanth (ID: 1447057)
# ✓ Updated Bailapudi Yeswanth
#
# Processing 673/810: Shivendra Bhujbal (ID: 1447817)
# ✓ Updated Shivendra Bhujbal
#
# Processing 674/810: Kashyap Bakhale (ID: 11018)
# ✓ Updated Kashyap Bakhale
#
# Processing 675/810: Nadeem Khan (ID: 3726)
# ✓ Updated Nadeem Khan
#
# Processing 676/810: Sabhay Chadha (ID: 1447089)
# ✓ Updated Sabhay Chadha
#
# Processing 677/810: Jalaj Saxena (ID: 8107)
# ✓ Updated Jalaj Saxena
#
# Processing 678/810: Maruthungal Ajinas (ID: 51546)
# ✓ Updated Maruthungal Ajinas
#
# Processing 679/810: Nedumankuzhy Basil (ID: 16702)
# ✓ Updated Nedumankuzhy Basil
#
# Processing 680/810: Imliwati Lemtur (ID: 14114)
# ✓ Updated Imliwati Lemtur
#
# Processing 681/810: Afzal Hussain (ID: 1431763)
# ✓ Updated Afzal Hussain
#
# Processing 682/810: Mayank Yadav (ID: 34480)
# ✓ Updated Mayank Yadav
#
# Processing 683/810: Rahul Sharma (ID: 24406)
# ✓ Updated Rahul Sharma
#
# Processing 684/810: Shivam Chaudhary (ID: 10335)
# ✓ Updated Shivam Chaudhary
#
# Processing 685/810: Shubham Arora (ID: 13526)
# ✓ Updated Shubham Arora
#
# Processing 686/810: Kanwar Abhinay Singh (ID: 8961)
# ✓ Updated Kanwar Abhinay Singh
#
# Processing 687/810: Arpit Guleria (ID: 14383)
# ✓ Updated Arpit Guleria
#
# Processing 688/810: Ankur Panwar (ID: 48477)
# ✓ Updated Ankur Panwar
#
# Processing 689/810: Pranesh Chettri (ID: 51315)
# ✓ Updated Pranesh Chettri
#
# Processing 690/810: Akhil Rawat (ID: 36090)
# ✓ Updated Akhil Rawat
#
# Processing 691/810: Anshul Singh (ID: 1448061)
# ✓ Updated Anshul Singh
#
# Processing 692/810: Sparsh Joshi (ID: 1447985)
# ✓ Updated Sparsh Joshi
#
# Processing 693/810: Suhas Pampana (ID: 55158)
# ✓ Updated Suhas Pampana
#
# Processing 694/810: Nabam Hachang (ID: 33239)
# ✓ Updated Nabam Hachang
#
# Processing 695/810: Toko Techir (ID: 1447989)
# ✓ Updated Toko Techir
#
# Processing 696/810: Tadakamalla Mohith (ID: 1431731)
# ✓ Updated Tadakamalla Mohith
#
# Processing 697/810: Sahil Lotra (ID: 34135)
# ✓ Updated Sahil Lotra
#
# Processing 698/810: Amrit Lubana (ID: 18883)
# ✓ Updated Amrit Lubana
#
# Processing 699/810: Danish Choudhary (ID: 1448257)
# ✓ Updated Danish Choudhary
#
# Processing 700/810: Ajay Dev Goud (ID: 13939)
# ✓ Updated Ajay Dev Goud
#
# Processing 701/810: Chinntla Rakshan Readdi (ID: 21581)
# ✓ Updated Chinntla Rakshan Readdi
#
# Processing 702/810: Rohit Rayudu (ID: 12650)
# ✓ Updated Rohit Rayudu
#
# Processing 703/810: Nitin Sai Yadav (ID: 52362)
# ✓ Updated Nitin Sai Yadav
#
# Processing 704/810: Sanskar Rawat (ID: 1447205)
# ✓ Updated Sanskar Rawat
#
# Processing 705/810: Ruchit Ahir (ID: 48554)
# ✓ Updated Ruchit Ahir
#
# Processing 706/810: Ankit Kalsi (ID: 10264)
# ✓ Updated Ankit Kalsi
#
# Processing 707/810: Vicky Ostwal (ID: 22616)
# ✓ Updated Vicky Ostwal
#
# Processing 708/810: Siddharth Mhatre (ID: 51385)
# ✓ Updated Siddharth Mhatre
#
# Processing 709/810: Sudhesan Midhun (ID: 13520)
# ✓ Updated Sudhesan Midhun
#
# Processing 710/810: Arslan Khan (ID: 15851)
# ✓ Updated Arslan Khan
#
# Processing 711/810: Sibsankar Roy (ID: 8768)
# ✓ Updated Sibsankar Roy
#
# Processing 712/810: Ronit More (ID: 8734)
# ✓ Updated Ronit More
#
# Processing 713/810: Deepak (ID: 1448309)
# ✓ Updated Deepak
#
# Processing 714/810: Tana Teti (ID: 51228)
# ✓ Updated Tana Teti
#
# Processing 715/810: Akshay Jain (ID: 52386)
# ✓ Updated Akshay Jain
#
# Processing 716/810: Shubham Garhwal (ID: 22471)
# ✓ Updated Shubham Garhwal
#
# Processing 717/810: Jamala Mohapatra (ID: 55694)
# ✓ Updated Jamala Mohapatra
#
# Processing 718/810: Tejas Baroka (ID: 12639)
# ✓ Updated Tejas Baroka
#
# Processing 719/810: Subham Satrujit (ID: 1448317)
# ✓ Updated Subham Satrujit
#
# Processing 720/810: Nitin Tanwar (ID: 13117)
# ✓ Updated Nitin Tanwar
#
# Processing 721/810: Nagaho Chishi (ID: 15493)
# ✓ Updated Nagaho Chishi
#
# Processing 722/810: Sedezhalie Rupero (ID: 14118)
# ✓ Updated Sedezhalie Rupero
#
# Processing 723/810: Amit Rana (ID: 12692)
# ✓ Updated Amit Rana
#
# Processing 724/810: Dinesh Bana (ID: 22591)
# ✓ Updated Dinesh Bana
#
# Processing 725/810: Vikas Kumar (ID: 1432467)
# ✓ Updated Vikas Kumar
#
# Processing 726/810: Mohamed Ali (ID: 46247)
# ✓ Updated Mohamed Ali
#
# Processing 727/810: Abhishek Desai (ID: 1448329)
# ✓ Updated Abhishek Desai
#
# Processing 728/810: Priyajitsing Jadeja (ID: 54626)
# ✓ Updated Priyajitsing Jadeja
#
# Processing 729/810: Roshan Alam (ID: 15483)
# ✓ Updated Roshan Alam
#
# Processing 730/810: Ranjot Khaira (ID: 1447117)
# ✓ Updated Ranjot Khaira
#
# Processing 731/810: Ibitlang Thabah (ID: 1447425)
# ✓ Updated Ibitlang Thabah
#
# Processing 732/810: Aryan Bora (ID: 17163)
# ✓ Updated Aryan Bora
#
# Processing 733/810: Prayas Barman (ID: 14168)
# ✓ Updated Prayas Barman
#
# Processing 734/810: Roberth Sangma (ID: 1447417)
# ✓ Updated Roberth Sangma
#
# Processing 735/810: Lalit Kumar (ID: 1448349)
# ✓ Updated Lalit Kumar
#
# Processing 736/810: Alish (ID: 1448341)
# ✓ Updated Alish
#
# Processing 737/810: Nazeeb Saiyed (ID: 18808)
# ✓ Updated Nazeeb Saiyed
#
# Processing 738/810: Aaqib Khan (ID: 15798)
# ✓ Updated Aaqib Khan
#
# Processing 739/810: Madhur (ID: 1448337)
# ✓ Updated Madhur
#
# Processing 740/810: Mridul Surroch (ID: 1448361)
# ✓ Updated Mridul Surroch
#
# Processing 741/810: Abhimanyu Singh Rajput (ID: 51060)
# ✓ Updated Abhimanyu Singh Rajput
#
# Processing 742/810: Shashwat Rawat (ID: 14690)
# ✓ Updated Shashwat Rawat
#
# Processing 743/810: Jassinder Singh (ID: 36132)
# ✓ Updated Jassinder Singh
#
# Processing 744/810: Prashant Bhati (ID: 51595)
# ✓ Updated Prashant Bhati
#
# Processing 745/810: Chiranjit Paul (ID: 10317)
# ✓ Updated Chiranjit Paul
#
# Processing 746/810: Lone Nasir Muzaffar (ID: 19308)
# ✓ Updated Lone Nasir Muzaffar
#
# Processing 747/810: Sanatombaroy Laiphangbam (ID: 35178)
# ✓ Updated Sanatombaroy Laiphangbam
#
# Processing 748/810: Ankit Singh (ID: 1448369)
# ✓ Updated Ankit Singh
#
# Processing 749/810: Gajendra Singh (ID: 8188)
# ✓ Updated Gajendra Singh
#
# Processing 750/810: Felix Alemao (ID: 11020)
# ✓ Updated Felix Alemao
#
# Processing 751/810: Sharafuddeen (ID: 21666)
# ✓ Updated Sharafuddeen
#
# Processing 752/810: Azaan Thota (ID: 1448377)
# ✓ Updated Azaan Thota
#
# Processing 753/810: Jagmohan Nagarkoti (ID: 52897)
# ✓ Updated Jagmohan Nagarkoti
#
# Processing 754/810: Mukesh Gupta (ID: 1448409)
# ✓ Updated Mukesh Gupta
#
# Processing 755/810: Agniv Pan (ID: 11511)
# ✓ Updated Agniv Pan
#
# Processing 756/810: Baljeet Singh Binny (ID: 32912)
# ✓ Updated Baljeet Singh Binny
#
# Processing 757/810: Prashant Singh (ID: 14644)
# ✓ Updated Prashant Singh
#
# Processing 758/810: Vikas Hathwala (ID: 10374)
# ✓ Updated Vikas Hathwala
#
# Processing 759/810: Gaurav Kochar (ID: 10371)
# ✓ Updated Gaurav Kochar
#
# Processing 760/810: Vikas Umesh Yadav (ID: 11823)
# ✓ Updated Vikas Umesh Yadav
#
# Processing 761/810: Anuj Tiwary (ID: 14477)
# ✓ Updated Anuj Tiwary
#
# Processing 762/810: Vishvas Malik (ID: 22371)
# ✓ Updated Vishvas Malik
#
# Processing 763/810: Ashutosh Singh (ID: 11032)
# ✓ Updated Ashutosh Singh
#
# Processing 764/810: Kodavandla Sudharsan (ID: 35698)
# ✓ Updated Kodavandla Sudharsan
#
# Processing 765/810: Rajesh Mohanty (ID: 14167)
# ✓ Updated Rajesh Mohanty
#
# Processing 766/810: Parvej Musaraf (ID: 55305)
# ✓ Updated Parvej Musaraf
#
# Processing 767/810: Yuvraj Yogender Singh (ID: 24346)
# ✓ Updated Yuvraj Yogender Singh
#
# Processing 768/810: Ankush Bedi (ID: 10290)
# ✓ Updated Ankush Bedi
#
# Processing 769/810: Mani Sharma (ID: 19037)
# ✓ Updated Mani Sharma
#
# Processing 770/810: Tushar Raheja (ID: 13860)
# ✓ Updated Tushar Raheja
#
# Processing 771/810: Pradosh Ranjan Paul (ID: 12929)
# ✓ Updated Pradosh Ranjan Paul
#
# Processing 772/810: Kamal Tripathi (ID: 32842)
# ✓ Updated Kamal Tripathi
#
# Processing 773/810: Harsh Gawli (ID: 27422)
# ✓ Updated Harsh Gawli
#
# Processing 774/810: Vaibhav Kandpal (ID: 14593)
# ✓ Updated Vaibhav Kandpal
#
# Processing 775/810: Sushant Rana (ID: 1448425)
# ✓ Updated Sushant Rana
#
# Processing 776/810: Sagar Kisan Sakpal (ID: 1448421)
# ✓ Updated Sagar Kisan Sakpal
#
# Processing 777/810: Jiwanjot Singh (ID: 8702)
# ✓ Updated Jiwanjot Singh
#
# Processing 778/810: Jonathan Lalrinchhana (ID: 19397)
# ✓ Updated Jonathan Lalrinchhana
#
# Processing 779/810: Salil Arora (ID: 15418)
# ✓ Updated Salil Arora
#
# Processing 780/810: Sohraab Dhaliwal (ID: 11031)
# ✓ Updated Sohraab Dhaliwal
#
# Processing 781/810: Riboklang Hynniewta (ID: 21641)
# ✓ Updated Riboklang Hynniewta
#
# Processing 782/810: Yogesh Tiwari (ID: 18822)
# ✓ Updated Yogesh Tiwari
#
# Processing 783/810: Chintal Gandhi (ID: 18698)
# ✓ Updated Chintal Gandhi
#
# Processing 784/810: Aayush Singh (ID: 1448297)
# ✓ Updated Aayush Singh
#
# Processing 785/810: Shrey Sharma (ID: 1448481)
# ✓ Updated Shrey Sharma
#
# Processing 786/810: Harshil Doshi (ID: 1448489)
# ✓ Updated Harshil Doshi
#
# Processing 787/810: Digvesh Rathi (ID: 1448289)
# ✓ Updated Digvesh Rathi
#
# Processing 788/810: Yash V Thakur (ID: 1448473)
# ✓ Updated Yash V Thakur
#
# Processing 789/810: Samarth Seth (ID: 14079)
# ✓ Updated Samarth Seth
#
# Processing 790/810: Siddharth Balodi (ID: 37154)
# ✓ Updated Siddharth Balodi
#
# Processing 791/810: Himanshu Chauhan (ID: 54630)
# ✓ Updated Himanshu Chauhan
#
# Processing 792/810: Gagan Vats (ID: 54514)
# ✓ Updated Gagan Vats
#
# Processing 793/810: Sunny Pandit (ID: 1447149)
# ✓ Updated Sunny Pandit
#
# Processing 794/810: Atharva Kale (ID: 13580)
# ✓ Updated Atharva Kale
#
# Processing 795/810: Moakumzuk Tzudir (ID: 15585)
# ✓ Updated Moakumzuk Tzudir
#
# Processing 796/810: Nikhil Sharma (ID: 1447549)
# ✓ Updated Nikhil Sharma
#
# Processing 797/810: Ravi Singh (ID: 1448413)
# ✓ Updated Ravi Singh
#
# Processing 798/810: Akshat Pandey (ID: 10805)
# ✓ Updated Akshat Pandey
#
# Processing 799/810: Mohammad Saif (ID: 9431)
# ✓ Updated Mohammad Saif
#
# Processing 800/810: Jashwanth Shreeram (ID: 1448497)
# ✓ Updated Jashwanth Shreeram
#
# Processing 801/810: Macneil Hadley Noronha (ID: 29181)
# ✓ Updated Macneil Hadley Noronha
#
# Processing 802/810: Mohammed Kaif (ID: 19132)
# ✓ Updated Mohammed Kaif
#
# Processing 803/810: Rahul Radesh (ID: 39195)
# ✓ Updated Rahul Radesh
#
# Processing 804/810: Aman Rao (ID: 51081)
# ✓ Updated Aman Rao
#
# Processing 805/810: K Nitesh Reddy (ID: 39356)
# ✓ Updated K Nitesh Reddy
#
# Processing 806/810: Ashish Chouhan (ID: 51515)
# ✓ Updated Ashish Chouhan
#
# Processing 807/810: Piyush Singh (ID: 51578)
# ✓ Updated Piyush Singh
#
# Processing 808/810: Hridyanand Singh (ID: 1448517)
# ✓ Updated Hridyanand Singh
#
# Processing 809/810: Sakshaim Chaudhary (ID: 51560)
# ✓ Updated Sakshaim Chaudhary
#
# Processing 810/810: Atharva Ankolekar (ID: 14703)
# ✓ Updated Atharva Ankolekar
#
# Update complete!
# Total players processed: 810
# Successfully updated: 757
# Failed updates: 0

# %%
import requests
from bs4 import BeautifulSoup
from pymongo import MongoClient
import time

# MongoDB Atlas connection
client = MongoClient("mongodb+srv://harsh8423:8423047004@cluster0.1xbklyu.mongodb.net/cricket")
db = client["cricket"]
players_collection = db["players"]

def get_player_info(player_id):
    """
    Scrapes player information from Cricbuzz profile page with added delay for HTML loading
    """
    url = f"https://www.cricbuzz.com/profiles/{player_id}"
    
    try:
        response = requests.get(url)
        response.raise_for_status()
        
        # Wait for 3 seconds to ensure HTML is loaded
        time.sleep(3)
        
        soup = BeautifulSoup(response.content, 'html.parser')
        info_div = soup.find('div', class_='cb-hm-rght')
        
        if not info_div:
            print(f"No information found for player {player_id}")
            return None
            
        player_info = {}
        div_elements = info_div.find_all('div', class_='cb-col')
        
        for i in range(len(div_elements)-1):
            current_div = div_elements[i]
            next_div = div_elements[i+1]
            
            if 'Role' in current_div.text:
                player_info['role'] = next_div.text.strip()
            elif 'Batting Style' in current_div.text:
                player_info['batting_style'] = next_div.text.strip()
            elif 'Bowling Style' in current_div.text:
                player_info['bowling_style'] = next_div.text.strip()
                
        return player_info
        
    except requests.RequestException as e:
        print(f"Error fetching data for player {player_id}: {e}")
        return None
    except Exception as e:
        print(f"Error processing data for player {player_id}: {e}")
        return None

def update_missing_info_players():
    """
    Updates information only for players with missing or empty role/batting_style
    """
    print("Starting update for players with missing information")
    
    # Find players with missing information
    query = {
        "$or": [
            {"role": {"$in": ["--", "", None]}},
            {"batting_style": {"$in": ["--", "", None]}},
            {"role": {"$exists": False}},
            {"batting_style": {"$exists": False}}
        ]
    }
    
    players_to_update = list(players_collection.find(query, {"_id": 1, "name": 1, "role": 1, "batting_style": 1}))
    total_players = len(players_to_update)
    
    print(f"Found {total_players} players with missing information")
    
    # # Counter for successful updates
    # updates_count = 0
    # failed_count = 0
    
    # for index, player in enumerate(players_to_update, 1):
    #     player_id = player['_id']
    #     player_name = player.get('name', 'Unknown')
    #     current_role = player.get('role', 'Not set')
    #     current_batting_style = player.get('batting_style', 'Not set')
        
    #     print(f"\nProcessing {index}/{total_players}: {player_name} (ID: {player_id})")
    #     print(f"Current Role: {current_role}")
    #     print(f"Current Batting Style: {current_batting_style}")
        
    #     # Get player info from Cricbuzz
    #     player_info = get_player_info(str(player_id))
        
    #     if player_info:
    #         try:
    #             # Only update fields that have new information
    #             update_fields = {}
                
    #             if player_info.get('role'):
    #                 update_fields['role'] = player_info['role']
    #             if player_info.get('batting_style'):
    #                 update_fields['batting_style'] = player_info['batting_style']
    #             if player_info.get('bowling_style'):
    #                 update_fields['bowling_style'] = player_info['bowling_style']
                
    #             if update_fields:
    #                 result = players_collection.update_one(
    #                     {"_id": player_id},
    #                     {"$set": update_fields}
    #                 )
                    
    #                 if result.modified_count > 0:
    #                     print(f"✓ Updated {player_name} with new information:")
    #                     for field, value in update_fields.items():
    #                         print(f"  - {field}: {value}")
    #                     updates_count += 1
    #                 else:
    #                     print(f"- No changes made for {player_name}")
    #             else:
    #                 print(f"- No new information found for {player_name}")
                    
    #         except Exception as e:
    #             print(f"× Error updating MongoDB for {player_name}: {e}")
    #             failed_count += 1
    #     else:
    #         print(f"× No Cricbuzz data found for {player_name}")
    #         failed_count += 1
    
    # print("\nUpdate complete!")
    # print(f"Total players with missing info: {total_players}")
    # print(f"Successfully updated: {updates_count}")
    # print(f"Failed updates: {failed_count}")

# Example usage
if __name__ == "__main__":
    update_missing_info_players()
# Out:
# Starting update for players with missing information
# Found 93 players with missing information

# %%
from pymongo import MongoClient

# MongoDB Atlas connection
client = MongoClient("mongodb+srv://harsh8423:8423047004@cluster0.1xbklyu.mongodb.net/cricket")
db = client["cricket"]
players_collection = db["players"]

def classify_bowling_type():
    """
    Analyzes bowling_style field and adds bowling_type classification
    """
    print("Starting bowling type classification")
    
    # Find all players with non-empty bowling_style
    query = {
        "bowling_style": {"$exists": True, "$ne": "", "$ne": None}
    }
    
    players = list(players_collection.find(query, {"_id": 1, "name": 1, "bowling_style": 1}))
    total_players = len(players)
    
    print(f"Found {total_players} players with bowling style information")
    
    # Define bowling type categories
    spin_keywords = ['legbreak', 'offbreak', 'wrist-spin', 'orthodox']
    pace_keywords = ['fast-medium', 'medium', 'fast']
    
    # Counters for updates
    updates_count = 0
    no_match_count = 0
    
    for index, player in enumerate(players, 1):
        player_id = player['_id']
        player_name = player.get('name', 'Unknown')
        bowling_style = player.get('bowling_style', '').lower()
        
        print(f"\nProcessing {index}/{total_players}: {player_name}")
        print(f"Current bowling style: {bowling_style}")
        
        # Get the last word of bowling style
        last_word = bowling_style.split()[-1] if bowling_style else ''
        
        try:
            bowling_type = None
            
            # Check for spin bowling
            if any(keyword in bowling_style for keyword in spin_keywords):
                bowling_type = 'spin'
                print(f"Classified as spin bowler (matched: {last_word})")
                
            # Check for pace bowling
            elif any(keyword in bowling_style for keyword in pace_keywords):
                bowling_type = 'pace'
                print(f"Classified as pace bowler (matched: {last_word})")
            
            # Update the document if bowling type was determined
            if bowling_type:
                result = players_collection.update_one(
                    {"_id": player_id},
                    {"$set": {"bowling_type": bowling_type}}
                )
                
                if result.modified_count > 0:
                    print(f"✓ Updated {player_name} - Set bowling_type: {bowling_type}")
                    updates_count += 1
                else:
                    print(f"- No changes needed for {player_name}")
            else:
                print(f"× Could not classify bowling type for {player_name}")
                no_match_count += 1
                
        except Exception as e:
            print(f"× Error updating {player_name}: {e}")
            no_match_count += 1
    
    print("\nClassification complete!")
    print(f"Total players processed: {total_players}")
    print(f"Successfully classified and updated: {updates_count}")
    print(f"Unclassified bowlers: {no_match_count}")
    
    # Print some examples of unclassified bowling styles for review
    print("\nSample of unclassified bowling styles:")
    unclassified = players_collection.find({
        "bowling_style": {"$exists": True, "$ne": ""},
        "bowling_type": {"$exists": False}
    }).limit(5)
    
    for player in unclassified:
        print(f"- {player.get('name')}: {player.get('bowling_style')}")

# Example usage
if __name__ == "__main__":
    classify_bowling_type()
# Out:
# Starting bowling type classification
# Found 810 players with bowling style information
#
# Processing 1/810: Rahul Tripathi
# Current bowling style: right-arm medium
# Classified as pace bowler (matched: medium)
# ✓ Updated Rahul Tripathi - Set bowling_type: pace
#
# Processing 2/810: Deepak Hooda
# Current bowling style: right-arm offbreak
# Classified as spin bowler (matched: offbreak)
# ✓ Updated Deepak Hooda - Set bowling_type: spin
#
# Processing 3/810: Anshul Kamboj
# Current bowling style: right-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Anshul Kamboj - Set bowling_type: pace
#
# Processing 4/810: Vansh Bedi
# Current bowling style:
# × Could not classify bowling type for Vansh Bedi
#
# Processing 5/810: Dhruv Jurel
# Current bowling style:
# × Could not classify bowling type for Dhruv Jurel
#
# Processing 6/810: Akash Madhwal
# Current bowling style: right-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Akash Madhwal - Set bowling_type: pace
#
# Processing 7/810: Maheesh Theekshana
# Current bowling style: right-arm offbreak
# Classified as spin bowler (matched: offbreak)
# ✓ Updated Maheesh Theekshana - Set bowling_type: spin
#
# Processing 8/810: Fazalhaq Farooqi
# Current bowling style: left-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Fazalhaq Farooqi - Set bowling_type: pace
#
# Processing 9/810: Jofra Archer
# Current bowling style: right-arm fast
# Classified as pace bowler (matched: fast)
# ✓ Updated Jofra Archer - Set bowling_type: pace
#
# Processing 10/810: Manish Pandey
# Current bowling style: right-arm medium
# Classified as pace bowler (matched: medium)
# ✓ Updated Manish Pandey - Set bowling_type: pace
#
# Processing 11/810: Rinku Singh
# Current bowling style: right-arm offbreak
# Classified as spin bowler (matched: offbreak)
# ✓ Updated Rinku Singh - Set bowling_type: spin
#
# Processing 12/810: Sunil Narine
# Current bowling style: right-arm offbreak
# Classified as spin bowler (matched: offbreak)
# ✓ Updated Sunil Narine - Set bowling_type: spin
#
# Processing 13/810: Andre Russell
# Current bowling style: right-arm fast
# Classified as pace bowler (matched: fast)
# ✓ Updated Andre Russell - Set bowling_type: pace
#
# Processing 14/810: Quinton de Kock
# Current bowling style:
# × Could not classify bowling type for Quinton de Kock
#
# Processing 15/810: Luvnith Sisodia
# Current bowling style:
# × Could not classify bowling type for Luvnith Sisodia
#
# Processing 16/810: Mayank Markande
# Current bowling style: right-arm legbreak
# Classified as spin bowler (matched: legbreak)
# ✓ Updated Mayank Markande - Set bowling_type: spin
#
# Processing 17/810: Anrich Nortje
# Current bowling style: right-arm fast
# Classified as pace bowler (matched: fast)
# ✓ Updated Anrich Nortje - Set bowling_type: pace
#
# Processing 18/810: Travis Head
# Current bowling style: right-arm offbreak
# Classified as spin bowler (matched: offbreak)
# ✓ Updated Travis Head - Set bowling_type: spin
#
# Processing 19/810: Zeeshan Ansari
# Current bowling style: right-arm legbreak
# Classified as spin bowler (matched: legbreak)
# ✓ Updated Zeeshan Ansari - Set bowling_type: spin
#
# Processing 20/810: Rahul Chahar
# Current bowling style: right-arm legbreak
# Classified as spin bowler (matched: legbreak)
# ✓ Updated Rahul Chahar - Set bowling_type: spin
#
# Processing 21/810: Swapnil Singh
# Current bowling style: left-arm orthodox
# Classified as spin bowler (matched: orthodox)
# ✓ Updated Swapnil Singh - Set bowling_type: spin
#
# Processing 22/810: Rasikh Dar Salam
# Current bowling style: right-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Rasikh Dar Salam - Set bowling_type: pace
#
# Processing 23/810: Jake Fraser-McGurk
# Current bowling style: right-arm legbreak
# Classified as spin bowler (matched: legbreak)
# ✓ Updated Jake Fraser-McGurk - Set bowling_type: spin
#
# Processing 24/810: Tripurana Vijay
# Current bowling style: right-arm offbreak
# Classified as spin bowler (matched: offbreak)
# ✓ Updated Tripurana Vijay - Set bowling_type: spin
#
# Processing 25/810: Madhav Tiwari
# Current bowling style: right-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Madhav Tiwari - Set bowling_type: pace
#
# Processing 26/810: Mitchell Starc
# Current bowling style: left-arm fast
# Classified as pace bowler (matched: fast)
# ✓ Updated Mitchell Starc - Set bowling_type: pace
#
# Processing 27/810: Mohit Sharma
# Current bowling style: right-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Mohit Sharma - Set bowling_type: pace
#
# Processing 28/810: Pyla Avinash
# Current bowling style: right-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Pyla Avinash - Set bowling_type: pace
#
# Processing 29/810: Aaron Hardie
# Current bowling style: right-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Aaron Hardie - Set bowling_type: pace
#
# Processing 30/810: Suryansh Shedge
# Current bowling style: right-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Suryansh Shedge - Set bowling_type: pace
#
# Processing 31/810: Shashank Singh
# Current bowling style: right-arm medium
# Classified as pace bowler (matched: medium)
# ✓ Updated Shashank Singh - Set bowling_type: pace
#
# Processing 32/810: Praveen Dubey
# Current bowling style: right-arm legbreak
# Classified as spin bowler (matched: legbreak)
# ✓ Updated Praveen Dubey - Set bowling_type: spin
#
# Processing 33/810: Prabhsimran Singh
# Current bowling style:
# × Could not classify bowling type for Prabhsimran Singh
#
# Processing 34/810: Josh Inglis
# Current bowling style:
# × Could not classify bowling type for Josh Inglis
#
# Processing 35/810: Vishnu Vinod
# Current bowling style:
# × Could not classify bowling type for Vishnu Vinod
#
# Processing 36/810: Harpreet Brar
# Current bowling style: left-arm orthodox
# Classified as spin bowler (matched: orthodox)
# ✓ Updated Harpreet Brar - Set bowling_type: spin
#
# Processing 37/810: Lockie Ferguson
# Current bowling style: right-arm fast
# Classified as pace bowler (matched: fast)
# ✓ Updated Lockie Ferguson - Set bowling_type: pace
#
# Processing 38/810: Vignesh Puthur
# Current bowling style: left-arm wrist-spin
# Classified as spin bowler (matched: wrist-spin)
# ✓ Updated Vignesh Puthur - Set bowling_type: spin
#
# Processing 39/810: Karn Sharma
# Current bowling style: right-arm legbreak
# Classified as spin bowler (matched: legbreak)
# ✓ Updated Karn Sharma - Set bowling_type: spin
#
# Processing 40/810: Mahipal Lomror
# Current bowling style: left-arm orthodox
# Classified as spin bowler (matched: orthodox)
# ✓ Updated Mahipal Lomror - Set bowling_type: spin
#
# Processing 41/810: Arshad Khan
# Current bowling style: left-arm medium
# Classified as pace bowler (matched: medium)
# ✓ Updated Arshad Khan - Set bowling_type: pace
#
# Processing 42/810: Jayant Yadav
# Current bowling style: right-arm offbreak
# Classified as spin bowler (matched: offbreak)
# ✓ Updated Jayant Yadav - Set bowling_type: spin
#
# Processing 43/810: Karim Janat
# Current bowling style: right-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Karim Janat - Set bowling_type: pace
#
# Processing 44/810: Manav Suthar
# Current bowling style: left-arm orthodox
# Classified as spin bowler (matched: orthodox)
# ✓ Updated Manav Suthar - Set bowling_type: spin
#
# Processing 45/810: Kagiso Rabada
# Current bowling style: right-arm fast
# Classified as pace bowler (matched: fast)
# ✓ Updated Kagiso Rabada - Set bowling_type: pace
#
# Processing 46/810: Aiden Markram
# Current bowling style: right-arm offbreak
# Classified as spin bowler (matched: offbreak)
# ✓ Updated Aiden Markram - Set bowling_type: spin
#
# Processing 47/810: Ayush Badoni
# Current bowling style: right-arm offbreak
# Classified as spin bowler (matched: offbreak)
# ✓ Updated Ayush Badoni - Set bowling_type: spin
#
# Processing 48/810: Rishabh Pant
# Current bowling style:
# × Could not classify bowling type for Rishabh Pant
#
# Processing 49/810: Ravi Bishnoi
# Current bowling style: right-arm legbreak
# Classified as spin bowler (matched: legbreak)
# ✓ Updated Ravi Bishnoi - Set bowling_type: spin
#
# Processing 50/810: Ruturaj Gaikwad
# Current bowling style: right-arm offbreak
# Classified as spin bowler (matched: offbreak)
# ✓ Updated Ruturaj Gaikwad - Set bowling_type: spin
#
# Processing 51/810: Andre Siddarth C
# Current bowling style:
# × Could not classify bowling type for Andre Siddarth C
#
# Processing 52/810: Shaik Rasheed
# Current bowling style: right-arm legbreak
# Classified as spin bowler (matched: legbreak)
# ✓ Updated Shaik Rasheed - Set bowling_type: spin
#
# Processing 53/810: Rachin Ravindra
# Current bowling style: left-arm orthodox
# Classified as spin bowler (matched: orthodox)
# ✓ Updated Rachin Ravindra - Set bowling_type: spin
#
# Processing 54/810: Vijay Shankar
# Current bowling style: right-arm medium
# Classified as pace bowler (matched: medium)
# ✓ Updated Vijay Shankar - Set bowling_type: pace
#
# Processing 55/810: Sam Curran
# Current bowling style: left-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Sam Curran - Set bowling_type: pace
#
# Processing 56/810: MS Dhoni
# Current bowling style: right-arm medium
# Classified as pace bowler (matched: medium)
# ✓ Updated MS Dhoni - Set bowling_type: pace
#
# Processing 57/810: Khaleel Ahmed
# Current bowling style: left-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Khaleel Ahmed - Set bowling_type: pace
#
# Processing 58/810: Vaibhav Suryavanshi
# Current bowling style: left-arm orthodox
# Classified as spin bowler (matched: orthodox)
# ✓ Updated Vaibhav Suryavanshi - Set bowling_type: spin
#
# Processing 59/810: Shimron Hetmyer
# Current bowling style:
# × Could not classify bowling type for Shimron Hetmyer
#
# Processing 60/810: Yashasvi Jaiswal
# Current bowling style: right-arm legbreak
# Classified as spin bowler (matched: legbreak)
# ✓ Updated Yashasvi Jaiswal - Set bowling_type: spin
#
# Processing 61/810: Nitish Rana
# Current bowling style: right-arm offbreak
# Classified as spin bowler (matched: offbreak)
# ✓ Updated Nitish Rana - Set bowling_type: spin
#
# Processing 62/810: Riyan Parag
# Current bowling style: right-arm legbreak
# Classified as spin bowler (matched: legbreak)
# ✓ Updated Riyan Parag - Set bowling_type: spin
#
# Processing 63/810: Yudhvir Singh Charak
# Current bowling style: right-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Yudhvir Singh Charak - Set bowling_type: pace
#
# Processing 64/810: Kunal Singh Rathore
# Current bowling style: right-arm offbreak
# Classified as spin bowler (matched: offbreak)
# ✓ Updated Kunal Singh Rathore - Set bowling_type: spin
#
# Processing 65/810: Sandeep Sharma
# Current bowling style: right-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Sandeep Sharma - Set bowling_type: pace
#
# Processing 66/810: Kumar Kartikeya
# Current bowling style: left-arm wrist-spin
# Classified as spin bowler (matched: wrist-spin)
# ✓ Updated Kumar Kartikeya - Set bowling_type: spin
#
# Processing 67/810: Kwena Maphaka
# Current bowling style: left-arm medium
# Classified as pace bowler (matched: medium)
# ✓ Updated Kwena Maphaka - Set bowling_type: pace
#
# Processing 68/810: Ashok Sharma
# Current bowling style: right-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Ashok Sharma - Set bowling_type: pace
#
# Processing 69/810: Moeen Ali
# Current bowling style: right-arm offbreak
# Classified as spin bowler (matched: offbreak)
# ✓ Updated Moeen Ali - Set bowling_type: spin
#
# Processing 70/810: Vaibhav Arora
# Current bowling style: right-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Vaibhav Arora - Set bowling_type: pace
#
# Processing 71/810: Aniket Verma
# Current bowling style: right-arm medium
# Classified as pace bowler (matched: medium)
# ✓ Updated Aniket Verma - Set bowling_type: pace
#
# Processing 72/810: Brydon Carse
# Current bowling style: right-arm fast
# Classified as pace bowler (matched: fast)
# ✓ Updated Brydon Carse - Set bowling_type: pace
#
# Processing 73/810: Heinrich Klaasen
# Current bowling style: right-arm offbreak
# Classified as spin bowler (matched: offbreak)
# ✓ Updated Heinrich Klaasen - Set bowling_type: spin
#
# Processing 74/810: Pat Cummins
# Current bowling style: right-arm fast
# Classified as pace bowler (matched: fast)
# ✓ Updated Pat Cummins - Set bowling_type: pace
#
# Processing 75/810: Harshal Patel
# Current bowling style: right-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Harshal Patel - Set bowling_type: pace
#
# Processing 76/810: Jaydev Unadkat
# Current bowling style: left-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Jaydev Unadkat - Set bowling_type: pace
#
# Processing 77/810: Tim David
# Current bowling style: right-arm offbreak
# Classified as spin bowler (matched: offbreak)
# ✓ Updated Tim David - Set bowling_type: spin
#
# Processing 78/810: Manoj Bhandage
# Current bowling style: right-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Manoj Bhandage - Set bowling_type: pace
#
# Processing 79/810: Mohit Rathee
# Current bowling style: right-arm legbreak
# Classified as spin bowler (matched: legbreak)
# ✓ Updated Mohit Rathee - Set bowling_type: spin
#
# Processing 80/810: Josh Hazlewood
# Current bowling style: right-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Josh Hazlewood - Set bowling_type: pace
#
# Processing 81/810: Bhuvneshwar Kumar
# Current bowling style: right-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Bhuvneshwar Kumar - Set bowling_type: pace
#
# Processing 82/810: Suyash Sharma
# Current bowling style: right-arm legbreak
# Classified as spin bowler (matched: legbreak)
# ✓ Updated Suyash Sharma - Set bowling_type: spin
#
# Processing 83/810: Karun Nair
# Current bowling style: right-arm offbreak
# Classified as spin bowler (matched: offbreak)
# ✓ Updated Karun Nair - Set bowling_type: spin
#
# Processing 84/810: Axar Patel
# Current bowling style: left-arm orthodox
# Classified as spin bowler (matched: orthodox)
# ✓ Updated Axar Patel - Set bowling_type: spin
#
# Processing 85/810: Darshan Nalkande
# Current bowling style: right-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Darshan Nalkande - Set bowling_type: pace
#
# Processing 86/810: Manvanth Kumar L
# Current bowling style: right-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Manvanth Kumar L - Set bowling_type: pace
#
# Processing 87/810: Abishek Porel
# Current bowling style:
# × Could not classify bowling type for Abishek Porel
#
# Processing 88/810: Nehal Wadhera
# Current bowling style: right-arm legbreak
# Classified as spin bowler (matched: legbreak)
# ✓ Updated Nehal Wadhera - Set bowling_type: spin
#
# Processing 89/810: Harnoor Singh
# Current bowling style: right-arm legbreak
# Classified as spin bowler (matched: legbreak)
# ✓ Updated Harnoor Singh - Set bowling_type: spin
#
# Processing 90/810: Priyansh Arya
# Current bowling style: right-arm offbreak
# Classified as spin bowler (matched: offbreak)
# ✓ Updated Priyansh Arya - Set bowling_type: spin
#
# Processing 91/810: Musheer Khan
# Current bowling style: left-arm orthodox
# Classified as spin bowler (matched: orthodox)
# ✓ Updated Musheer Khan - Set bowling_type: spin
#
# Processing 92/810: Marcus Stoinis
# Current bowling style: right-arm medium
# Classified as pace bowler (matched: medium)
# ✓ Updated Marcus Stoinis - Set bowling_type: pace
#
# Processing 93/810: Vijaykumar Vyshak
# Current bowling style: right-arm medium
# Classified as pace bowler (matched: medium)
# ✓ Updated Vijaykumar Vyshak - Set bowling_type: pace
#
# Processing 94/810: Kuldeep Sen
# Current bowling style: right-arm fast
# Classified as pace bowler (matched: fast)
# ✓ Updated Kuldeep Sen - Set bowling_type: pace
#
# Processing 95/810: Yash Thakur
# Current bowling style: right-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Yash Thakur - Set bowling_type: pace
#
# Processing 96/810: Xavier Bartlett
# Current bowling style: right-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Xavier Bartlett - Set bowling_type: pace
#
# Processing 97/810: Suryakumar Yadav
# Current bowling style: right-arm offbreak
# Classified as spin bowler (matched: offbreak)
# ✓ Updated Suryakumar Yadav - Set bowling_type: spin
#
# Processing 98/810: Hardik Pandya (Captain)
# Current bowling style: right-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Hardik Pandya (Captain) - Set bowling_type: pace
#
# Processing 99/810: Raj Bawa
# Current bowling style: right-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Raj Bawa - Set bowling_type: pace
#
# Processing 100/810: Will Jacks
# Current bowling style: right-arm offbreak
# Classified as spin bowler (matched: offbreak)
# ✓ Updated Will Jacks - Set bowling_type: spin
#
# Processing 101/810: Arjun Tendulkar
# Current bowling style: left-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Arjun Tendulkar - Set bowling_type: pace
#
# Processing 102/810: Jasprit Bumrah
# Current bowling style: right-arm fast
# Classified as pace bowler (matched: fast)
# ✓ Updated Jasprit Bumrah - Set bowling_type: pace
#
# Processing 103/810: Ashwani Kumar
# Current bowling style: left-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Ashwani Kumar - Set bowling_type: pace
#
# Processing 104/810: Reece Topley
# Current bowling style: left-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Reece Topley - Set bowling_type: pace
#
# Processing 105/810: Lizaad Williams
# Current bowling style: right-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Lizaad Williams - Set bowling_type: pace
#
# Processing 106/810: Shubman Gill
# Current bowling style: right-arm offbreak
# Classified as spin bowler (matched: offbreak)
# ✓ Updated Shubman Gill - Set bowling_type: spin
#
# Processing 107/810: Glenn Phillips
# Current bowling style: right-arm offbreak
# Classified as spin bowler (matched: offbreak)
# ✓ Updated Glenn Phillips - Set bowling_type: spin
#
# Processing 108/810: Rahul Tewatia
# Current bowling style: right-arm legbreak
# Classified as spin bowler (matched: legbreak)
# ✓ Updated Rahul Tewatia - Set bowling_type: spin
#
# Processing 109/810: Nishant Sindhu
# Current bowling style: left-arm orthodox
# Classified as spin bowler (matched: orthodox)
# ✓ Updated Nishant Sindhu - Set bowling_type: spin
#
# Processing 110/810: Rashid Khan
# Current bowling style: right-arm legbreak
# Classified as spin bowler (matched: legbreak)
# ✓ Updated Rashid Khan - Set bowling_type: spin
#
# Processing 111/810: Kumar Kushagra
# Current bowling style:
# × Could not classify bowling type for Kumar Kushagra
#
# Processing 112/810: Prasidh Krishna
# Current bowling style: right-arm fast
# Classified as pace bowler (matched: fast)
# ✓ Updated Prasidh Krishna - Set bowling_type: pace
#
# Processing 113/810: Mohammed Siraj
# Current bowling style: right-arm fast
# Classified as pace bowler (matched: fast)
# ✓ Updated Mohammed Siraj - Set bowling_type: pace
#
# Processing 114/810: Akash Singh
# Current bowling style: right-arm legbreak
# Classified as spin bowler (matched: legbreak)
# ✓ Updated Akash Singh - Set bowling_type: spin
#
# Processing 115/810: Mayank Yadav
# Current bowling style: right-arm fast
# Classified as pace bowler (matched: fast)
# ✓ Updated Mayank Yadav - Set bowling_type: pace
#
# Processing 116/810: Manimaran Siddharth
# Current bowling style: left-arm orthodox
# Classified as spin bowler (matched: orthodox)
# ✓ Updated Manimaran Siddharth - Set bowling_type: spin
#
# Processing 117/810: Avesh Khan
# Current bowling style: right-arm fast
# Classified as pace bowler (matched: fast)
# ✓ Updated Avesh Khan - Set bowling_type: pace
#
# Processing 118/810: Shivam Dube
# Current bowling style: right-arm medium
# Classified as pace bowler (matched: medium)
# ✓ Updated Shivam Dube - Set bowling_type: pace
#
# Processing 119/810: Ramakrishna Ghosh
# Current bowling style: right-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Ramakrishna Ghosh - Set bowling_type: pace
#
# Processing 120/810: Ravindra Jadeja
# Current bowling style: left-arm orthodox
# Classified as spin bowler (matched: orthodox)
# ✓ Updated Ravindra Jadeja - Set bowling_type: spin
#
# Processing 121/810: Kamlesh Nagarkoti
# Current bowling style: right-arm fast
# Classified as pace bowler (matched: fast)
# ✓ Updated Kamlesh Nagarkoti - Set bowling_type: pace
#
# Processing 122/810: Mukesh Choudhary
# Current bowling style: left-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Mukesh Choudhary - Set bowling_type: pace
#
# Processing 123/810: Noor Ahmad
# Current bowling style: left-arm wrist-spin
# Classified as spin bowler (matched: wrist-spin)
# ✓ Updated Noor Ahmad - Set bowling_type: spin
#
# Processing 124/810: Shubham Dubey
# Current bowling style: right-arm offbreak
# Classified as spin bowler (matched: offbreak)
# ✓ Updated Shubham Dubey - Set bowling_type: spin
#
# Processing 125/810: Tushar Deshpande
# Current bowling style: right-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Tushar Deshpande - Set bowling_type: pace
#
# Processing 126/810: Ajinkya Rahane
# Current bowling style: right-arm medium
# Classified as pace bowler (matched: medium)
# ✓ Updated Ajinkya Rahane - Set bowling_type: pace
#
# Processing 127/810: Rovman Powell
# Current bowling style: right-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Rovman Powell - Set bowling_type: pace
#
# Processing 128/810: Ramandeep Singh
# Current bowling style: right-arm medium
# Classified as pace bowler (matched: medium)
# ✓ Updated Ramandeep Singh - Set bowling_type: pace
#
# Processing 129/810: Venkatesh Iyer
# Current bowling style: right-arm medium
# Classified as pace bowler (matched: medium)
# ✓ Updated Venkatesh Iyer - Set bowling_type: pace
#
# Processing 130/810: Rahmanullah Gurbaz
# Current bowling style:
# × Could not classify bowling type for Rahmanullah Gurbaz
#
# Processing 131/810: Harshit Rana
# Current bowling style: right-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Harshit Rana - Set bowling_type: pace
#
# Processing 132/810: Umran Malik
# Current bowling style: right-arm fast
# Classified as pace bowler (matched: fast)
# ✓ Updated Umran Malik - Set bowling_type: pace
#
# Processing 133/810: Kamindu Mendis
# Current bowling style: right-arm offbreak
# Classified as spin bowler (matched: offbreak)
# ✓ Updated Kamindu Mendis - Set bowling_type: spin
#
# Processing 134/810: Ishan Kishan
# Current bowling style:
# × Could not classify bowling type for Ishan Kishan
#
# Processing 135/810: Eshan Malinga
# Current bowling style: right-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Eshan Malinga - Set bowling_type: pace
#
# Processing 136/810: Devdutt Padikkal
# Current bowling style: right-arm offbreak
# Classified as spin bowler (matched: offbreak)
# ✓ Updated Devdutt Padikkal - Set bowling_type: spin
#
# Processing 137/810: Swastik Chikara
# Current bowling style: right-arm offbreak
# Classified as spin bowler (matched: offbreak)
# ✓ Updated Swastik Chikara - Set bowling_type: spin
#
# Processing 138/810: Krunal Pandya
# Current bowling style: left-arm orthodox
# Classified as spin bowler (matched: orthodox)
# ✓ Updated Krunal Pandya - Set bowling_type: spin
#
# Processing 139/810: Liam Livingstone
# Current bowling style: right-arm legbreak
# Classified as spin bowler (matched: legbreak)
# ✓ Updated Liam Livingstone - Set bowling_type: spin
#
# Processing 140/810: Romario Shepherd
# Current bowling style: right-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Romario Shepherd - Set bowling_type: pace
#
# Processing 141/810: Lungi Ngidi
# Current bowling style: right-arm fast
# Classified as pace bowler (matched: fast)
# ✓ Updated Lungi Ngidi - Set bowling_type: pace
#
# Processing 142/810: Nuwan Thushara
# Current bowling style: right-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Nuwan Thushara - Set bowling_type: pace
#
# Processing 143/810: Abhinandan Singh
# Current bowling style: right-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Abhinandan Singh - Set bowling_type: pace
#
# Processing 144/810: Ashutosh Sharma
# Current bowling style: right-arm medium
# Classified as pace bowler (matched: medium)
# ✓ Updated Ashutosh Sharma - Set bowling_type: pace
#
# Processing 145/810: Tristan Stubbs
# Current bowling style: right-arm offbreak
# Classified as spin bowler (matched: offbreak)
# ✓ Updated Tristan Stubbs - Set bowling_type: spin
#
# Processing 146/810: Donovan Ferreira
# Current bowling style: right-arm offbreak
# Classified as spin bowler (matched: offbreak)
# ✓ Updated Donovan Ferreira - Set bowling_type: spin
#
# Processing 147/810: KL Rahul
# Current bowling style:
# × Could not classify bowling type for KL Rahul
#
# Processing 148/810: Kuldeep Yadav
# Current bowling style: left-arm wrist-spin
# Classified as spin bowler (matched: wrist-spin)
# ✓ Updated Kuldeep Yadav - Set bowling_type: spin
#
# Processing 149/810: Shreyas Iyer
# Current bowling style: right-arm legbreak
# Classified as spin bowler (matched: legbreak)
# ✓ Updated Shreyas Iyer - Set bowling_type: spin
#
# Processing 150/810: Glenn Maxwell
# Current bowling style: right-arm offbreak
# Classified as spin bowler (matched: offbreak)
# ✓ Updated Glenn Maxwell - Set bowling_type: spin
#
# Processing 151/810: Rohit Sharma
# Current bowling style: right-arm offbreak
# Classified as spin bowler (matched: offbreak)
# ✓ Updated Rohit Sharma - Set bowling_type: spin
#
# Processing 152/810: Tilak Varma
# Current bowling style: right-arm offbreak
# Classified as spin bowler (matched: offbreak)
# ✓ Updated Tilak Varma - Set bowling_type: spin
#
# Processing 153/810: Naman Dhir
# Current bowling style: right-arm offbreak
# Classified as spin bowler (matched: offbreak)
# ✓ Updated Naman Dhir - Set bowling_type: spin
#
# Processing 154/810: Krishnan Shrijith
# Current bowling style:
# × Could not classify bowling type for Krishnan Shrijith
#
# Processing 155/810: AM Ghazanfar
# Current bowling style: right-arm offbreak
# Classified as spin bowler (matched: offbreak)
# ✓ Updated AM Ghazanfar - Set bowling_type: spin
#
# Processing 156/810: Trent Boult
# Current bowling style: left-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Trent Boult - Set bowling_type: pace
#
# Processing 157/810: Sherfane Rutherford
# Current bowling style: right-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Sherfane Rutherford - Set bowling_type: pace
#
# Processing 158/810: Ravisrinivasan Sai Kishore
# Current bowling style: left-arm orthodox
# Classified as spin bowler (matched: orthodox)
# ✓ Updated Ravisrinivasan Sai Kishore - Set bowling_type: spin
#
# Processing 159/810: Washington Sundar
# Current bowling style: right-arm offbreak
# Classified as spin bowler (matched: offbreak)
# ✓ Updated Washington Sundar - Set bowling_type: spin
#
# Processing 160/810: David Miller
# Current bowling style:
# × Could not classify bowling type for David Miller
#
# Processing 161/810: Abdul Samad
# Current bowling style: right-arm legbreak
# Classified as spin bowler (matched: legbreak)
# ✓ Updated Abdul Samad - Set bowling_type: spin
#
# Processing 162/810: Arshin Kulkarni
# Current bowling style: right-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Arshin Kulkarni - Set bowling_type: pace
#
# Processing 163/810: RS Hangargekar
# Current bowling style: right-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated RS Hangargekar - Set bowling_type: pace
#
# Processing 164/810: Digvesh Singh
# Current bowling style: right-arm legbreak
# Classified as spin bowler (matched: legbreak)
# ✓ Updated Digvesh Singh - Set bowling_type: spin
#
# Processing 165/810: Akash Deep
# Current bowling style: right-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Akash Deep - Set bowling_type: pace
#
# Processing 166/810: Shamar Joseph
# Current bowling style: right-arm fast
# Classified as pace bowler (matched: fast)
# ✓ Updated Shamar Joseph - Set bowling_type: pace
#
# Processing 167/810: Mohsin Khan
# Current bowling style: left-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Mohsin Khan - Set bowling_type: pace
#
# Processing 168/810: Jamie Overton
# Current bowling style: right-arm fast
# Classified as pace bowler (matched: fast)
# ✓ Updated Jamie Overton - Set bowling_type: pace
#
# Processing 169/810: Ravichandran Ashwin
# Current bowling style: right-arm offbreak
# Classified as spin bowler (matched: offbreak)
# ✓ Updated Ravichandran Ashwin - Set bowling_type: spin
#
# Processing 170/810: Devon Conway
# Current bowling style: right-arm medium
# Classified as pace bowler (matched: medium)
# ✓ Updated Devon Conway - Set bowling_type: pace
#
# Processing 171/810: Shreyas Gopal
# Current bowling style: right-arm legbreak
# Classified as spin bowler (matched: legbreak)
# ✓ Updated Shreyas Gopal - Set bowling_type: spin
#
# Processing 172/810: Matheesha Pathirana
# Current bowling style: right-arm fast
# Classified as pace bowler (matched: fast)
# ✓ Updated Matheesha Pathirana - Set bowling_type: pace
#
# Processing 173/810: Nathan Ellis
# Current bowling style: right-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Nathan Ellis - Set bowling_type: pace
#
# Processing 174/810: Gurjapneet Singh
# Current bowling style: left-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Gurjapneet Singh - Set bowling_type: pace
#
# Processing 175/810: Wanindu Hasaranga
# Current bowling style: right-arm legbreak
# Classified as spin bowler (matched: legbreak)
# ✓ Updated Wanindu Hasaranga - Set bowling_type: spin
#
# Processing 176/810: Sanju Samson
# Current bowling style:
# × Could not classify bowling type for Sanju Samson
#
# Processing 177/810: Angkrish Raghuvanshi
# Current bowling style: right-arm offbreak
# Classified as spin bowler (matched: offbreak)
# ✓ Updated Angkrish Raghuvanshi - Set bowling_type: spin
#
# Processing 178/810: Anukul Roy
# Current bowling style: left-arm orthodox
# Classified as spin bowler (matched: orthodox)
# ✓ Updated Anukul Roy - Set bowling_type: spin
#
# Processing 179/810: Varun Chakaravarthy
# Current bowling style: right-arm legbreak
# Classified as spin bowler (matched: legbreak)
# ✓ Updated Varun Chakaravarthy - Set bowling_type: spin
#
# Processing 180/810: Spencer Johnson
# Current bowling style: left-arm fast
# Classified as pace bowler (matched: fast)
# ✓ Updated Spencer Johnson - Set bowling_type: pace
#
# Processing 181/810: Atharva Taide
# Current bowling style: left-arm orthodox
# Classified as spin bowler (matched: orthodox)
# ✓ Updated Atharva Taide - Set bowling_type: spin
#
# Processing 182/810: Abhinav Manohar
# Current bowling style: right-arm legbreak
# Classified as spin bowler (matched: legbreak)
# ✓ Updated Abhinav Manohar - Set bowling_type: spin
#
# Processing 183/810: Sachin Baby
# Current bowling style: right-arm offbreak
# Classified as spin bowler (matched: offbreak)
# ✓ Updated Sachin Baby - Set bowling_type: spin
#
# Processing 184/810: Nitish Kumar Reddy
# Current bowling style: right-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Nitish Kumar Reddy - Set bowling_type: pace
#
# Processing 185/810: Abhishek Sharma
# Current bowling style: left-arm orthodox
# Classified as spin bowler (matched: orthodox)
# ✓ Updated Abhishek Sharma - Set bowling_type: spin
#
# Processing 186/810: Mohammed Shami
# Current bowling style: right-arm fast
# Classified as pace bowler (matched: fast)
# ✓ Updated Mohammed Shami - Set bowling_type: pace
#
# Processing 187/810: Simarjeet Singh
# Current bowling style: right-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Simarjeet Singh - Set bowling_type: pace
#
# Processing 188/810: Adam Zampa
# Current bowling style: right-arm legbreak
# Classified as spin bowler (matched: legbreak)
# ✓ Updated Adam Zampa - Set bowling_type: spin
#
# Processing 189/810: Virat Kohli
# Current bowling style: right-arm medium
# Classified as pace bowler (matched: medium)
# ✓ Updated Virat Kohli - Set bowling_type: pace
#
# Processing 190/810: Rajat Patidar
# Current bowling style: right-arm offbreak
# Classified as spin bowler (matched: offbreak)
# ✓ Updated Rajat Patidar - Set bowling_type: spin
#
# Processing 191/810: Jacob Bethell
# Current bowling style: left-arm orthodox
# Classified as spin bowler (matched: orthodox)
# ✓ Updated Jacob Bethell - Set bowling_type: spin
#
# Processing 192/810: Philip Salt
# Current bowling style: right-arm offbreak
# Classified as spin bowler (matched: offbreak)
# ✓ Updated Philip Salt - Set bowling_type: spin
#
# Processing 193/810: Jitesh Sharma
# Current bowling style:
# × Could not classify bowling type for Jitesh Sharma
#
# Processing 194/810: Yash Dayal
# Current bowling style: left-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Yash Dayal - Set bowling_type: pace
#
# Processing 195/810: Faf du Plessis
# Current bowling style: right-arm legbreak
# Classified as spin bowler (matched: legbreak)
# ✓ Updated Faf du Plessis - Set bowling_type: spin
#
# Processing 196/810: Harry Brook
# Current bowling style: right-arm medium
# Classified as pace bowler (matched: medium)
# ✓ Updated Harry Brook - Set bowling_type: pace
#
# Processing 197/810: Sameer Rizvi
# Current bowling style: right-arm offbreak
# Classified as spin bowler (matched: offbreak)
# ✓ Updated Sameer Rizvi - Set bowling_type: spin
#
# Processing 198/810: Vipraj Nigam
# Current bowling style: right-arm legbreak
# Classified as spin bowler (matched: legbreak)
# ✓ Updated Vipraj Nigam - Set bowling_type: spin
#
# Processing 199/810: Ajay Jadav Mandal
# Current bowling style: left-arm orthodox
# Classified as spin bowler (matched: orthodox)
# ✓ Updated Ajay Jadav Mandal - Set bowling_type: spin
#
# Processing 200/810: Dushmantha Chameera
# Current bowling style: right-arm fast
# Classified as pace bowler (matched: fast)
# ✓ Updated Dushmantha Chameera - Set bowling_type: pace
#
# Processing 201/810: T Natarajan
# Current bowling style: left-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated T Natarajan - Set bowling_type: pace
#
# Processing 202/810: Mukesh Kumar
# Current bowling style: right-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Mukesh Kumar - Set bowling_type: pace
#
# Processing 203/810: Azmatullah Omarzai
# Current bowling style: right-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Azmatullah Omarzai - Set bowling_type: pace
#
# Processing 204/810: Marco Jansen
# Current bowling style: left-arm fast
# Classified as pace bowler (matched: fast)
# ✓ Updated Marco Jansen - Set bowling_type: pace
#
# Processing 205/810: Arshdeep Singh
# Current bowling style: left-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Arshdeep Singh - Set bowling_type: pace
#
# Processing 206/810: Yuzvendra Chahal
# Current bowling style: right-arm legbreak
# Classified as spin bowler (matched: legbreak)
# ✓ Updated Yuzvendra Chahal - Set bowling_type: spin
#
# Processing 207/810: Bevon Jacobs
# Current bowling style: right-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Bevon Jacobs - Set bowling_type: pace
#
# Processing 208/810: Satyanarayana Raju
# Current bowling style: right-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Satyanarayana Raju - Set bowling_type: pace
#
# Processing 209/810: Mitchell Santner
# Current bowling style: left-arm orthodox
# Classified as spin bowler (matched: orthodox)
# ✓ Updated Mitchell Santner - Set bowling_type: spin
#
# Processing 210/810: Ryan Rickelton
# Current bowling style:
# × Could not classify bowling type for Ryan Rickelton
#
# Processing 211/810: Robin Minz
# Current bowling style: right-arm offbreak
# Classified as spin bowler (matched: offbreak)
# ✓ Updated Robin Minz - Set bowling_type: spin
#
# Processing 212/810: Deepak Chahar
# Current bowling style: right-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Deepak Chahar - Set bowling_type: pace
#
# Processing 213/810: Sai Sudharsan
# Current bowling style: right-arm legbreak
# Classified as spin bowler (matched: legbreak)
# ✓ Updated Sai Sudharsan - Set bowling_type: spin
#
# Processing 214/810: Shahrukh Khan
# Current bowling style: right-arm offbreak
# Classified as spin bowler (matched: offbreak)
# ✓ Updated Shahrukh Khan - Set bowling_type: spin
#
# Processing 215/810: Anuj Rawat
# Current bowling style:
# × Could not classify bowling type for Anuj Rawat
#
# Processing 216/810: Jos Buttler
# Current bowling style:
# × Could not classify bowling type for Jos Buttler
#
# Processing 217/810: Gerald Coetzee
# Current bowling style: right-arm fast
# Classified as pace bowler (matched: fast)
# ✓ Updated Gerald Coetzee - Set bowling_type: pace
#
# Processing 218/810: Gurnoor Brar
# Current bowling style: right-arm fast
# Classified as pace bowler (matched: fast)
# ✓ Updated Gurnoor Brar - Set bowling_type: pace
#
# Processing 219/810: Ishant Sharma
# Current bowling style: right-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Ishant Sharma - Set bowling_type: pace
#
# Processing 220/810: Kulwant Khejroliya
# Current bowling style: left-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Kulwant Khejroliya - Set bowling_type: pace
#
# Processing 221/810: Himmat Singh
# Current bowling style: right-arm offbreak
# Classified as spin bowler (matched: offbreak)
# ✓ Updated Himmat Singh - Set bowling_type: spin
#
# Processing 222/810: Mitchell Marsh
# Current bowling style: right-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Mitchell Marsh - Set bowling_type: pace
#
# Processing 223/810: Yuvraj Chaudhary
# Current bowling style: left-arm orthodox
# Classified as spin bowler (matched: orthodox)
# ✓ Updated Yuvraj Chaudhary - Set bowling_type: spin
#
# Processing 224/810: Shahbaz Ahmed
# Current bowling style: left-arm orthodox
# Classified as spin bowler (matched: orthodox)
# ✓ Updated Shahbaz Ahmed - Set bowling_type: spin
#
# Processing 225/810: Matthew Breetzke
# Current bowling style:
# × Could not classify bowling type for Matthew Breetzke
#
# Processing 226/810: Nicholas Pooran
# Current bowling style: right-arm offbreak
# Classified as spin bowler (matched: offbreak)
# ✓ Updated Nicholas Pooran - Set bowling_type: spin
#
# Processing 227/810: Aryan Juyal
# Current bowling style: right-arm offbreak
# Classified as spin bowler (matched: offbreak)
# ✓ Updated Aryan Juyal - Set bowling_type: spin
#
# Processing 228/810: Prince Yadav
# Current bowling style: right-arm fast
# Classified as pace bowler (matched: fast)
# ✓ Updated Prince Yadav - Set bowling_type: pace
#
# Processing 229/810: Kane Williamson
# Current bowling style: right-arm offbreak
# Classified as spin bowler (matched: offbreak)
# ✓ Updated Kane Williamson - Set bowling_type: spin
#
# Processing 230/810: Wriddhiman Saha
# Current bowling style:
# × Could not classify bowling type for Wriddhiman Saha
#
# Processing 231/810: Alzarri Joseph
# Current bowling style: right-arm fast
# Classified as pace bowler (matched: fast)
# ✓ Updated Alzarri Joseph - Set bowling_type: pace
#
# Processing 232/810: Ambati Rayudu
# Current bowling style: right-arm offbreak
# Classified as spin bowler (matched: offbreak)
# ✓ Updated Ambati Rayudu - Set bowling_type: spin
#
# Processing 233/810: Ben Stokes
# Current bowling style: right-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Ben Stokes - Set bowling_type: pace
#
# Processing 234/810: Joshua Little
# Current bowling style: left-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Joshua Little - Set bowling_type: pace
#
# Processing 235/810: Bhanuka Rajapaksa
# Current bowling style: right-arm medium
# Classified as pace bowler (matched: medium)
# ✓ Updated Bhanuka Rajapaksa - Set bowling_type: pace
#
# Processing 236/810: Sikandar Raza
# Current bowling style: right-arm offbreak
# Classified as spin bowler (matched: offbreak)
# ✓ Updated Sikandar Raza - Set bowling_type: spin
#
# Processing 237/810: Shikhar Dhawan
# Current bowling style: right-arm offbreak
# Classified as spin bowler (matched: offbreak)
# ✓ Updated Shikhar Dhawan - Set bowling_type: spin
#
# Processing 238/810: Shardul Thakur
# Current bowling style: right-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Shardul Thakur - Set bowling_type: pace
#
# Processing 239/810: Tim Southee
# Current bowling style: right-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Tim Southee - Set bowling_type: pace
#
# Processing 240/810: Mandeep Singh
# Current bowling style: right-arm medium
# Classified as pace bowler (matched: medium)
# ✓ Updated Mandeep Singh - Set bowling_type: pace
#
# Processing 241/810: Umesh Yadav
# Current bowling style: right-arm fast
# Classified as pace bowler (matched: fast)
# ✓ Updated Umesh Yadav - Set bowling_type: pace
#
# Processing 242/810: Kyle Mayers
# Current bowling style: right-arm medium
# Classified as pace bowler (matched: medium)
# ✓ Updated Kyle Mayers - Set bowling_type: pace
#
# Processing 243/810: David Warner
# Current bowling style:
# × Could not classify bowling type for David Warner
#
# Processing 244/810: Mark Wood
# Current bowling style: right-arm fast
# Classified as pace bowler (matched: fast)
# ✓ Updated Mark Wood - Set bowling_type: pace
#
# Processing 245/810: Rilee Rossouw
# Current bowling style: right-arm offbreak
# Classified as spin bowler (matched: offbreak)
# ✓ Updated Rilee Rossouw - Set bowling_type: spin
#
# Processing 246/810: Sarfaraz Khan
# Current bowling style: right-arm legbreak
# Classified as spin bowler (matched: legbreak)
# ✓ Updated Sarfaraz Khan - Set bowling_type: spin
#
# Processing 247/810: Chetan Sakariya
# Current bowling style: left-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Chetan Sakariya - Set bowling_type: pace
#
# Processing 248/810: Prithvi Shaw
# Current bowling style: right-arm offbreak
# Classified as spin bowler (matched: offbreak)
# ✓ Updated Prithvi Shaw - Set bowling_type: spin
#
# Processing 249/810: Mayank Agarwal
# Current bowling style: right-arm offbreak
# Classified as spin bowler (matched: offbreak)
# ✓ Updated Mayank Agarwal - Set bowling_type: spin
#
# Processing 250/810: Adil Rashid
# Current bowling style: right-arm legbreak
# Classified as spin bowler (matched: legbreak)
# ✓ Updated Adil Rashid - Set bowling_type: spin
#
# Processing 251/810: KM Asif
# Current bowling style: right-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated KM Asif - Set bowling_type: pace
#
# Processing 252/810: Jason Holder
# Current bowling style: right-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Jason Holder - Set bowling_type: pace
#
# Processing 253/810: Michael Bracewell
# Current bowling style: right-arm offbreak
# Classified as spin bowler (matched: offbreak)
# ✓ Updated Michael Bracewell - Set bowling_type: spin
#
# Processing 254/810: Cameron Green
# Current bowling style: right-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Cameron Green - Set bowling_type: pace
#
# Processing 255/810: Dinesh Karthik
# Current bowling style:
# × Could not classify bowling type for Dinesh Karthik
#
# Processing 256/810: Hrithik Shokeen
# Current bowling style: right-arm offbreak
# Classified as spin bowler (matched: offbreak)
# ✓ Updated Hrithik Shokeen - Set bowling_type: spin
#
# Processing 257/810: Piyush Chawla
# Current bowling style: right-arm legbreak
# Classified as spin bowler (matched: legbreak)
# ✓ Updated Piyush Chawla - Set bowling_type: spin
#
# Processing 258/810: Krishnappa Gowtham
# Current bowling style: right-arm offbreak
# Classified as spin bowler (matched: offbreak)
# ✓ Updated Krishnappa Gowtham - Set bowling_type: spin
#
# Processing 259/810: Aman Hakim Khan
# Current bowling style: right-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Aman Hakim Khan - Set bowling_type: pace
#
# Processing 260/810: David Willey
# Current bowling style: left-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated David Willey - Set bowling_type: pace
#
# Processing 261/810: Amit Mishra
# Current bowling style: right-arm legbreak
# Classified as spin bowler (matched: legbreak)
# ✓ Updated Amit Mishra - Set bowling_type: spin
#
# Processing 262/810: Anmolpreet Singh
# Current bowling style: right-arm offbreak
# Classified as spin bowler (matched: offbreak)
# ✓ Updated Anmolpreet Singh - Set bowling_type: spin
#
# Processing 263/810: Lalit Yadav
# Current bowling style:
# × Could not classify bowling type for Lalit Yadav
#
# Processing 264/810: Dwaine Pretorius
# Current bowling style: right-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Dwaine Pretorius - Set bowling_type: pace
#
# Processing 265/810: Sisanda Magala
# Current bowling style: right-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Sisanda Magala - Set bowling_type: pace
#
# Processing 266/810: Jason Behrendorff
# Current bowling style: left-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Jason Behrendorff - Set bowling_type: pace
#
# Processing 267/810: N Jagadeesan
# Current bowling style:
# × Could not classify bowling type for N Jagadeesan
#
# Processing 268/810: Matthew Short
# Current bowling style: right-arm offbreak
# Classified as spin bowler (matched: offbreak)
# ✓ Updated Matthew Short - Set bowling_type: spin
#
# Processing 269/810: Wayne Parnell
# Current bowling style: left-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Wayne Parnell - Set bowling_type: pace
#
# Processing 270/810: Mustafizur Rahman
# Current bowling style: left-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Mustafizur Rahman - Set bowling_type: pace
#
# Processing 271/810: Riley Meredith
# Current bowling style: right-arm fast
# Classified as pace bowler (matched: fast)
# ✓ Updated Riley Meredith - Set bowling_type: pace
#
# Processing 272/810: Yash Dhull
# Current bowling style: right-arm offbreak
# Classified as spin bowler (matched: offbreak)
# ✓ Updated Yash Dhull - Set bowling_type: spin
#
# Processing 273/810: Akash Singh
# Current bowling style: left-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Akash Singh - Set bowling_type: pace
#
# Processing 274/810: Rishi Dhawan
# Current bowling style: right-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Rishi Dhawan - Set bowling_type: pace
#
# Processing 275/810: Harpreet Singh Bhatia
# Current bowling style: right-arm medium
# Classified as pace bowler (matched: medium)
# ✓ Updated Harpreet Singh Bhatia - Set bowling_type: pace
#
# Processing 276/810: Duan Jansen
# Current bowling style: left-arm fast
# Classified as pace bowler (matched: fast)
# ✓ Updated Duan Jansen - Set bowling_type: pace
#
# Processing 277/810: Naveen-ul-Haq
# Current bowling style: right-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Naveen-ul-Haq - Set bowling_type: pace
#
# Processing 278/810: Suyash Prabhudessai
# Current bowling style: right-arm medium
# Classified as pace bowler (matched: medium)
# ✓ Updated Suyash Prabhudessai - Set bowling_type: pace
#
# Processing 279/810: Jason Roy
# Current bowling style:
# × Could not classify bowling type for Jason Roy
#
# Processing 280/810: Litton Das
# Current bowling style:
# × Could not classify bowling type for Litton Das
#
# Processing 281/810: Abdul Basith
# Current bowling style: right-arm offbreak
# Classified as spin bowler (matched: offbreak)
# ✓ Updated Abdul Basith - Set bowling_type: spin
#
# Processing 282/810: David Wiese
# Current bowling style: right-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated David Wiese - Set bowling_type: pace
#
# Processing 283/810: Ripal Patel
# Current bowling style: right-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Ripal Patel - Set bowling_type: pace
#
# Processing 284/810: Priyam Garg
# Current bowling style: right-arm medium
# Classified as pace bowler (matched: medium)
# ✓ Updated Priyam Garg - Set bowling_type: pace
#
# Processing 285/810: Akeal Hosein
# Current bowling style: left-arm orthodox
# Classified as spin bowler (matched: orthodox)
# ✓ Updated Akeal Hosein - Set bowling_type: spin
#
# Processing 286/810: Kartik Tyagi
# Current bowling style: right-arm fast
# Classified as pace bowler (matched: fast)
# ✓ Updated Kartik Tyagi - Set bowling_type: pace
#
# Processing 287/810: Kedar Jadhav
# Current bowling style: right-arm offbreak
# Classified as spin bowler (matched: offbreak)
# ✓ Updated Kedar Jadhav - Set bowling_type: spin
#
# Processing 288/810: Joe Root
# Current bowling style: right-arm offbreak
# Classified as spin bowler (matched: offbreak)
# ...
# Current bowling style:
# × Could not classify bowling type for Ruchit Ahir
#
# Processing 706/810: Ankit Kalsi
# Current bowling style: left-arm orthodox
# Classified as spin bowler (matched: orthodox)
# ✓ Updated Ankit Kalsi - Set bowling_type: spin
#
# Processing 707/810: Vicky Ostwal
# Current bowling style: left-arm orthodox
# Classified as spin bowler (matched: orthodox)
# ✓ Updated Vicky Ostwal - Set bowling_type: spin
#
# Processing 708/810: Siddharth Mhatre
# Current bowling style: right-arm offbreak
# Classified as spin bowler (matched: offbreak)
# ✓ Updated Siddharth Mhatre - Set bowling_type: spin
#
# Processing 709/810: Sudhesan Midhun
# Current bowling style: right-arm legbreak
# Classified as spin bowler (matched: legbreak)
# ✓ Updated Sudhesan Midhun - Set bowling_type: spin
#
# Processing 710/810: Arslan Khan
# Current bowling style:
# × Could not classify bowling type for Arslan Khan
#
# Processing 711/810: Sibsankar Roy
# Current bowling style: right-arm offbreak
# Classified as spin bowler (matched: offbreak)
# ✓ Updated Sibsankar Roy - Set bowling_type: spin
#
# Processing 712/810: Ronit More
# Current bowling style: right-arm medium
# Classified as pace bowler (matched: medium)
# ✓ Updated Ronit More - Set bowling_type: pace
#
# Processing 713/810: Deepak
# Current bowling style: right-arm medium
# Classified as pace bowler (matched: medium)
# ✓ Updated Deepak - Set bowling_type: pace
#
# Processing 714/810: Tana Teti
# Current bowling style: right-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Tana Teti - Set bowling_type: pace
#
# Processing 715/810: Akshay Jain
# Current bowling style: right-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Akshay Jain - Set bowling_type: pace
#
# Processing 716/810: Shubham Garhwal
# Current bowling style: left-arm orthodox
# Classified as spin bowler (matched: orthodox)
# ✓ Updated Shubham Garhwal - Set bowling_type: spin
#
# Processing 717/810: Tejas Baroka
# Current bowling style:
# × Could not classify bowling type for Tejas Baroka
#
# Processing 718/810: Jamala Mohapatra
# Current bowling style: left-arm orthodox
# Classified as spin bowler (matched: orthodox)
# ✓ Updated Jamala Mohapatra - Set bowling_type: spin
#
# Processing 719/810: Subham Satrujit
# Current bowling style:
# × Could not classify bowling type for Subham Satrujit
#
# Processing 720/810: Nitin Tanwar
# Current bowling style: right-arm offbreak
# Classified as spin bowler (matched: offbreak)
# ✓ Updated Nitin Tanwar - Set bowling_type: spin
#
# Processing 721/810: Nagaho Chishi
# Current bowling style: right-arm medium
# Classified as pace bowler (matched: medium)
# ✓ Updated Nagaho Chishi - Set bowling_type: pace
#
# Processing 722/810: Sedezhalie Rupero
# Current bowling style: right-arm offbreak
# Classified as spin bowler (matched: offbreak)
# ✓ Updated Sedezhalie Rupero - Set bowling_type: spin
#
# Processing 723/810: Amit Rana
# Current bowling style: right-arm offbreak
# Classified as spin bowler (matched: offbreak)
# ✓ Updated Amit Rana - Set bowling_type: spin
#
# Processing 724/810: Dinesh Bana
# Current bowling style:
# × Could not classify bowling type for Dinesh Bana
#
# Processing 725/810: Vikas Kumar
# Current bowling style: right-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Vikas Kumar - Set bowling_type: pace
#
# Processing 726/810: Mohamed Ali
# Current bowling style: right-arm offbreak
# Classified as spin bowler (matched: offbreak)
# ✓ Updated Mohamed Ali - Set bowling_type: spin
#
# Processing 727/810: Abhishek Desai
# Current bowling style:
# × Could not classify bowling type for Abhishek Desai
#
# Processing 728/810: Priyajitsing Jadeja
# Current bowling style: right-arm medium
# Classified as pace bowler (matched: medium)
# ✓ Updated Priyajitsing Jadeja - Set bowling_type: pace
#
# Processing 729/810: Roshan Alam
# Current bowling style: left-arm orthodox
# Classified as spin bowler (matched: orthodox)
# ✓ Updated Roshan Alam - Set bowling_type: spin
#
# Processing 730/810: Ranjot Khaira
# Current bowling style: right-arm legbreak
# Classified as spin bowler (matched: legbreak)
# ✓ Updated Ranjot Khaira - Set bowling_type: spin
#
# Processing 731/810: Ibitlang Thabah
# Current bowling style: right-arm medium
# Classified as pace bowler (matched: medium)
# ✓ Updated Ibitlang Thabah - Set bowling_type: pace
#
# Processing 732/810: Aryan Bora
# Current bowling style: left-arm orthodox
# Classified as spin bowler (matched: orthodox)
# ✓ Updated Aryan Bora - Set bowling_type: spin
#
# Processing 733/810: Prayas Barman
# Current bowling style: right-arm offbreak
# Classified as spin bowler (matched: offbreak)
# ✓ Updated Prayas Barman - Set bowling_type: spin
#
# Processing 734/810: Roberth Sangma
# Current bowling style: right-arm medium
# Classified as pace bowler (matched: medium)
# ✓ Updated Roberth Sangma - Set bowling_type: pace
#
# Processing 735/810: Lalit Kumar
# Current bowling style:
# × Could not classify bowling type for Lalit Kumar
#
# Processing 736/810: Alish
# Current bowling style:
# × Could not classify bowling type for Alish
#
# Processing 737/810: Nazeeb Saiyed
# Current bowling style:
# × Could not classify bowling type for Nazeeb Saiyed
#
# Processing 738/810: Aaqib Khan
# Current bowling style: right-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Aaqib Khan - Set bowling_type: pace
#
# Processing 739/810: Madhur
# Current bowling style:
# × Could not classify bowling type for Madhur
#
# Processing 740/810: Mridul Surroch
# Current bowling style: right-arm offbreak
# Classified as spin bowler (matched: offbreak)
# ✓ Updated Mridul Surroch - Set bowling_type: spin
#
# Processing 741/810: Abhimanyu Singh Rajput
# Current bowling style:
# × Could not classify bowling type for Abhimanyu Singh Rajput
#
# Processing 742/810: Shashwat Rawat
# Current bowling style: right-arm medium
# Classified as pace bowler (matched: medium)
# ✓ Updated Shashwat Rawat - Set bowling_type: pace
#
# Processing 743/810: Jassinder Singh
# Current bowling style: right-arm offbreak
# Classified as spin bowler (matched: offbreak)
# ✓ Updated Jassinder Singh - Set bowling_type: spin
#
# Processing 744/810: Prashant Bhati
# Current bowling style: left-arm fast
# Classified as pace bowler (matched: fast)
# ✓ Updated Prashant Bhati - Set bowling_type: pace
#
# Processing 745/810: Chiranjit Paul
# Current bowling style: left-arm orthodox
# Classified as spin bowler (matched: orthodox)
# ✓ Updated Chiranjit Paul - Set bowling_type: spin
#
# Processing 746/810: Lone Nasir Muzaffar
# Current bowling style: right-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Lone Nasir Muzaffar - Set bowling_type: pace
#
# Processing 747/810: Sanatombaroy Laiphangbam
# Current bowling style:
# × Could not classify bowling type for Sanatombaroy Laiphangbam
#
# Processing 748/810: Ankit Singh
# Current bowling style:
# × Could not classify bowling type for Ankit Singh
#
# Processing 749/810: Gajendra Singh
# Current bowling style: left-arm orthodox
# Classified as spin bowler (matched: orthodox)
# ✓ Updated Gajendra Singh - Set bowling_type: spin
#
# Processing 750/810: Felix Alemao
# Current bowling style: right-arm medium
# Classified as pace bowler (matched: medium)
# ✓ Updated Felix Alemao - Set bowling_type: pace
#
# Processing 751/810: Sharafuddeen
# Current bowling style:
# × Could not classify bowling type for Sharafuddeen
#
# Processing 752/810: Azaan Thota
# Current bowling style: right-arm medium
# Classified as pace bowler (matched: medium)
# ✓ Updated Azaan Thota - Set bowling_type: pace
#
# Processing 753/810: Jagmohan Nagarkoti
# Current bowling style:
# × Could not classify bowling type for Jagmohan Nagarkoti
#
# Processing 754/810: Mukesh Gupta
# Current bowling style: right-arm legbreak
# Classified as spin bowler (matched: legbreak)
# ✓ Updated Mukesh Gupta - Set bowling_type: spin
#
# Processing 755/810: Agniv Pan
# Current bowling style:
# × Could not classify bowling type for Agniv Pan
#
# Processing 756/810: Baljeet Singh Binny
# Current bowling style:
# × Could not classify bowling type for Baljeet Singh Binny
#
# Processing 757/810: Prashant Singh
# Current bowling style: right-arm medium
# Classified as pace bowler (matched: medium)
# ✓ Updated Prashant Singh - Set bowling_type: pace
#
# Processing 758/810: Vikas Hathwala
# Current bowling style: left-arm medium
# Classified as pace bowler (matched: medium)
# ✓ Updated Vikas Hathwala - Set bowling_type: pace
#
# Processing 759/810: Gaurav Kochar
# Current bowling style:
# × Could not classify bowling type for Gaurav Kochar
#
# Processing 760/810: Vikas Umesh Yadav
# Current bowling style: left-arm orthodox
# Classified as spin bowler (matched: orthodox)
# ✓ Updated Vikas Umesh Yadav - Set bowling_type: spin
#
# Processing 761/810: Anuj Tiwary
# Current bowling style: right-arm offbreak
# Classified as spin bowler (matched: offbreak)
# ✓ Updated Anuj Tiwary - Set bowling_type: spin
#
# Processing 762/810: Ashutosh Singh
# Current bowling style: right-arm offbreak
# Classified as spin bowler (matched: offbreak)
# ✓ Updated Ashutosh Singh - Set bowling_type: spin
#
# Processing 763/810: Vishvas Malik
# Current bowling style: right-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Vishvas Malik - Set bowling_type: pace
#
# Processing 764/810: Kodavandla Sudharsan
# Current bowling style: left-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Kodavandla Sudharsan - Set bowling_type: pace
#
# Processing 765/810: Rajesh Mohanty
# Current bowling style: right-arm medium
# Classified as pace bowler (matched: medium)
# ✓ Updated Rajesh Mohanty - Set bowling_type: pace
#
# Processing 766/810: Parvej Musaraf
# Current bowling style:
# × Could not classify bowling type for Parvej Musaraf
#
# Processing 767/810: Yuvraj Yogender Singh
# Current bowling style: right-arm offbreak
# Classified as spin bowler (matched: offbreak)
# ✓ Updated Yuvraj Yogender Singh - Set bowling_type: spin
#
# Processing 768/810: Ankush Bedi
# Current bowling style:
# × Could not classify bowling type for Ankush Bedi
#
# Processing 769/810: Mani Sharma
# Current bowling style:
# × Could not classify bowling type for Mani Sharma
#
# Processing 770/810: Tushar Raheja
# Current bowling style:
# × Could not classify bowling type for Tushar Raheja
#
# Processing 771/810: Pradosh Ranjan Paul
# Current bowling style: right-arm offbreak
# Classified as spin bowler (matched: offbreak)
# ✓ Updated Pradosh Ranjan Paul - Set bowling_type: spin
#
# Processing 772/810: Kamal Tripathi
# Current bowling style: right-arm offbreak
# Classified as spin bowler (matched: offbreak)
# ✓ Updated Kamal Tripathi - Set bowling_type: spin
#
# Processing 773/810: Harsh Gawli
# Current bowling style:
# × Could not classify bowling type for Harsh Gawli
#
# Processing 774/810: Vaibhav Kandpal
# Current bowling style: right-arm offbreak
# Classified as spin bowler (matched: offbreak)
# ✓ Updated Vaibhav Kandpal - Set bowling_type: spin
#
# Processing 775/810: Sushant Rana
# Current bowling style:
# × Could not classify bowling type for Sushant Rana
#
# Processing 776/810: Sagar Kisan Sakpal
# Current bowling style:
# × Could not classify bowling type for Sagar Kisan Sakpal
#
# Processing 777/810: Jiwanjot Singh
# Current bowling style: right-arm offbreak
# Classified as spin bowler (matched: offbreak)
# ✓ Updated Jiwanjot Singh - Set bowling_type: spin
#
# Processing 778/810: Jonathan Lalrinchhana
# Current bowling style:
# × Could not classify bowling type for Jonathan Lalrinchhana
#
# Processing 779/810: Salil Arora
# Current bowling style:
# × Could not classify bowling type for Salil Arora
#
# Processing 780/810: Sohraab Dhaliwal
# Current bowling style:
# × Could not classify bowling type for Sohraab Dhaliwal
#
# Processing 781/810: Riboklang Hynniewta
# Current bowling style: right-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Riboklang Hynniewta - Set bowling_type: pace
#
# Processing 782/810: Yogesh Tiwari
# Current bowling style: right-arm offbreak
# Classified as spin bowler (matched: offbreak)
# ✓ Updated Yogesh Tiwari - Set bowling_type: spin
#
# Processing 783/810: Chintal Gandhi
# Current bowling style:
# × Could not classify bowling type for Chintal Gandhi
#
# Processing 784/810: Aayush Singh
# Current bowling style: right-arm medium
# Classified as pace bowler (matched: medium)
# ✓ Updated Aayush Singh - Set bowling_type: pace
#
# Processing 785/810: Shrey Sharma
# Current bowling style:
# × Could not classify bowling type for Shrey Sharma
#
# Processing 786/810: Harshil Doshi
# Current bowling style:
# × Could not classify bowling type for Harshil Doshi
#
# Processing 787/810: Digvesh Rathi
# Current bowling style: right-arm legbreak
# Classified as spin bowler (matched: legbreak)
# ✓ Updated Digvesh Rathi - Set bowling_type: spin
#
# Processing 788/810: Yash V Thakur
# Current bowling style: right-arm offbreak
# Classified as spin bowler (matched: offbreak)
# ✓ Updated Yash V Thakur - Set bowling_type: spin
#
# Processing 789/810: Samarth Seth
# Current bowling style:
# × Could not classify bowling type for Samarth Seth
#
# Processing 790/810: Siddharth Balodi
# Current bowling style: right-arm medium
# Classified as pace bowler (matched: medium)
# ✓ Updated Siddharth Balodi - Set bowling_type: pace
#
# Processing 791/810: Himanshu Chauhan
# Current bowling style: right-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Himanshu Chauhan - Set bowling_type: pace
#
# Processing 792/810: Gagan Vats
# Current bowling style: right-arm legbreak
# Classified as spin bowler (matched: legbreak)
# ✓ Updated Gagan Vats - Set bowling_type: spin
#
# Processing 793/810: Sunny Pandit
# Current bowling style:
# × Could not classify bowling type for Sunny Pandit
#
# Processing 794/810: Atharva Kale
# Current bowling style:
# × Could not classify bowling type for Atharva Kale
#
# Processing 795/810: Moakumzuk Tzudir
# Current bowling style:
# × Could not classify bowling type for Moakumzuk Tzudir
#
# Processing 796/810: Nikhil Sharma
# Current bowling style: right-arm medium
# Classified as pace bowler (matched: medium)
# ✓ Updated Nikhil Sharma - Set bowling_type: pace
#
# Processing 797/810: Ravi Singh
# Current bowling style: right-arm legbreak
# Classified as spin bowler (matched: legbreak)
# ✓ Updated Ravi Singh - Set bowling_type: spin
#
# Processing 798/810: Akshat Pandey
# Current bowling style: right-arm medium
# Classified as pace bowler (matched: medium)
# ✓ Updated Akshat Pandey - Set bowling_type: pace
#
# Processing 799/810: Mohammad Saif
# Current bowling style:
# × Could not classify bowling type for Mohammad Saif
#
# Processing 800/810: Jashwanth Shreeram
# Current bowling style:
# × Could not classify bowling type for Jashwanth Shreeram
#
# Processing 801/810: Macneil Hadley Noronha
# Current bowling style:
# × Could not classify bowling type for Macneil Hadley Noronha
#
# Processing 802/810: Mohammed Kaif
# Current bowling style: right-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Mohammed Kaif - Set bowling_type: pace
#
# Processing 803/810: Rahul Radesh
# Current bowling style:
# × Could not classify bowling type for Rahul Radesh
#
# Processing 804/810: Aman Rao
# Current bowling style:
# × Could not classify bowling type for Aman Rao
#
# Processing 805/810: K Nitesh Reddy
# Current bowling style: right-arm offbreak
# Classified as spin bowler (matched: offbreak)
# ✓ Updated K Nitesh Reddy - Set bowling_type: spin
#
# Processing 806/810: Ashish Chouhan
# Current bowling style: right-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Ashish Chouhan - Set bowling_type: pace
#
# Processing 807/810: Piyush Singh
# Current bowling style: right-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Piyush Singh - Set bowling_type: pace
#
# Processing 808/810: Hridyanand Singh
# Current bowling style:
# × Could not classify bowling type for Hridyanand Singh
#
# Processing 809/810: Sakshaim Chaudhary
# Current bowling style: right-arm fast-medium
# Classified as pace bowler (matched: fast-medium)
# ✓ Updated Sakshaim Chaudhary - Set bowling_type: pace
#
# Processing 810/810: Atharva Ankolekar
# Current bowling style: left-arm orthodox
# Classified as spin bowler (matched: orthodox)
# ✓ Updated Atharva Ankolekar - Set bowling_type: spin
#
# Classification complete!
# Total players processed: 810
# Successfully classified and updated: 627
# Unclassified bowlers: 183
#
# Sample of unclassified bowling styles:
